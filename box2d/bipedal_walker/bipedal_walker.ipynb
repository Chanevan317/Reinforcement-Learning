# %% [markdown]
# Import libraries

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# %% [markdown]
# Initialize the environment

# %%
env_id = "BipedalWalker-v3"

# Create vectorized environments
vec_env = make_vec_env(env_id, n_envs=32, seed=42)

# %% [markdown]
# Initialize the agent

# %%
ppo_kwargs = dict(
    n_steps=2048,         
    batch_size=64,
    n_epochs=10,          
    gamma=0.999,          
    gae_lambda=0.95,      
    ent_coef=0.0,         
    learning_rate=3e-4,   
)

# PPO agent with an MLP policy
model = PPO(
    "MlpPolicy",
    vec_env,
    verbose=1,
    **ppo_kwargs
)
# Out:
# Using cuda device

# %% [markdown]
# Train the agent

# %%
model.learn(total_timesteps=5_000_000)
model.save("ppo_bipedal_walker")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 503      |
# |    ep_rew_mean     | -113     |
# | time/              |          |
# |    fps             | 4151     |
# |    iterations      | 1        |
# |    time_elapsed    | 15       |
# |    total_timesteps | 65536    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 534          |
# |    ep_rew_mean          | -111         |
# | time/                   |              |
# |    fps                  | 1191         |
# |    iterations           | 2            |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0046990905 |
# |    clip_fraction        | 0.0384       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.66        |
# |    explained_variance   | 0.00232      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.58         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000967    |
# |    std                  | 0.997        |
# |    value_loss           | 57.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 580         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 935         |
# |    iterations           | 3           |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.005532003 |
# |    clip_fraction        | 0.0492      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.63       |
# |    explained_variance   | 0.764       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.07        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00108    |
# |    std                  | 0.988       |
# |    value_loss           | 17.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 702          |
# |    ep_rew_mean          | -107         |
# | time/                   |              |
# |    fps                  | 810          |
# |    iterations           | 4            |
# |    time_elapsed         | 323          |
# |    total_timesteps      | 262144       |
# | train/                  |              |
# |    approx_kl            | 0.0067103207 |
# |    clip_fraction        | 0.0732       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.6         |
# |    explained_variance   | 0.872        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.09         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00103     |
# |    std                  | 0.983        |
# |    value_loss           | 16.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 762         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 751         |
# |    iterations           | 5           |
# |    time_elapsed         | 435         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.008374542 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.57       |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.7         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.000184   |
# |    std                  | 0.972       |
# |    value_loss           | 14.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 745         |
# |    ep_rew_mean          | -100        |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 6           |
# |    time_elapsed         | 545         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.013013348 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.52       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.93        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00085    |
# |    std                  | 0.963       |
# |    value_loss           | 21.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 865         |
# |    ep_rew_mean          | -96.9       |
# | time/                   |             |
# |    fps                  | 701         |
# |    iterations           | 7           |
# |    time_elapsed         | 654         |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.012529809 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.48       |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.45        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 8.16e-05    |
# |    std                  | 0.95        |
# |    value_loss           | 18.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 836         |
# |    ep_rew_mean          | -92.3       |
# | time/                   |             |
# |    fps                  | 679         |
# |    iterations           | 8           |
# |    time_elapsed         | 771         |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.009935429 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.4        |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.84        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.000113   |
# |    std                  | 0.931       |
# |    value_loss           | 12.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 821         |
# |    ep_rew_mean          | -90.5       |
# | time/                   |             |
# |    fps                  | 665         |
# |    iterations           | 9           |
# |    time_elapsed         | 886         |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.008578723 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.34       |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.83        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.00013     |
# |    std                  | 0.922       |
# |    value_loss           | 16          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 868         |
# |    ep_rew_mean          | -86.8       |
# | time/                   |             |
# |    fps                  | 653         |
# |    iterations           | 10          |
# |    time_elapsed         | 1003        |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.010410829 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.28       |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.11        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 9.87e-05    |
# |    std                  | 0.902       |
# |    value_loss           | 14.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 961         |
# |    ep_rew_mean          | -80.8       |
# | time/                   |             |
# |    fps                  | 642         |
# |    iterations           | 11          |
# |    time_elapsed         | 1121        |
# |    total_timesteps      | 720896      |
# | train/                  |             |
# |    approx_kl            | 0.009794323 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.2        |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.8        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.000191   |
# |    std                  | 0.881       |
# |    value_loss           | 20.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 958        |
# |    ep_rew_mean          | -76.9      |
# | time/                   |            |
# |    fps                  | 636        |
# |    iterations           | 12         |
# |    time_elapsed         | 1236       |
# |    total_timesteps      | 786432     |
# | train/                  |            |
# |    approx_kl            | 0.01085536 |
# |    clip_fraction        | 0.14       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.1       |
# |    explained_variance   | 0.921      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.52       |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.00135   |
# |    std                  | 0.861      |
# |    value_loss           | 11.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 929         |
# |    ep_rew_mean          | -71.8       |
# | time/                   |             |
# |    fps                  | 630         |
# |    iterations           | 13          |
# |    time_elapsed         | 1351        |
# |    total_timesteps      | 851968      |
# | train/                  |             |
# |    approx_kl            | 0.010198507 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.02       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.155       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00137    |
# |    std                  | 0.85        |
# |    value_loss           | 11.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 908         |
# |    ep_rew_mean          | -65.2       |
# | time/                   |             |
# |    fps                  | 624         |
# |    iterations           | 14          |
# |    time_elapsed         | 1468        |
# |    total_timesteps      | 917504      |
# | train/                  |             |
# |    approx_kl            | 0.011085497 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.97       |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.3        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00105    |
# |    std                  | 0.842       |
# |    value_loss           | 14.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 840         |
# |    ep_rew_mean          | -62.3       |
# | time/                   |             |
# |    fps                  | 619         |
# |    iterations           | 15          |
# |    time_elapsed         | 1586        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.011171182 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.91       |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.294       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00156    |
# |    std                  | 0.823       |
# |    value_loss           | 14.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 959         |
# |    ep_rew_mean          | -49.8       |
# | time/                   |             |
# |    fps                  | 615         |
# |    iterations           | 16          |
# |    time_elapsed         | 1703        |
# |    total_timesteps      | 1048576     |
# | train/                  |             |
# |    approx_kl            | 0.012163451 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.84       |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.5         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00119    |
# |    std                  | 0.811       |
# |    value_loss           | 19.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.08e+03     |
# |    ep_rew_mean          | -32.8        |
# | time/                   |              |
# |    fps                  | 611          |
# |    iterations           | 17           |
# |    time_elapsed         | 1821         |
# |    total_timesteps      | 1114112      |
# | train/                  |              |
# |    approx_kl            | 0.0117207095 |
# |    clip_fraction        | 0.146        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.76        |
# |    explained_variance   | 0.906        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.79         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00203     |
# |    std                  | 0.795        |
# |    value_loss           | 13.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 991         |
# |    ep_rew_mean          | -31.8       |
# | time/                   |             |
# |    fps                  | 608         |
# |    iterations           | 18          |
# |    time_elapsed         | 1939        |
# |    total_timesteps      | 1179648     |
# | train/                  |             |
# |    approx_kl            | 0.011154675 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.69       |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.2        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.000911   |
# |    std                  | 0.782       |
# |    value_loss           | 16.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.06e+03    |
# |    ep_rew_mean          | -15         |
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 19          |
# |    time_elapsed         | 2056        |
# |    total_timesteps      | 1245184     |
# | train/                  |             |
# |    approx_kl            | 0.010785077 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.62       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.6        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00148    |
# |    std                  | 0.767       |
# |    value_loss           | 19.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.18e+03    |
# |    ep_rew_mean          | 5.39        |
# | time/                   |             |
# |    fps                  | 601         |
# |    iterations           | 20          |
# |    time_elapsed         | 2178        |
# |    total_timesteps      | 1310720     |
# | train/                  |             |
# |    approx_kl            | 0.010008205 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.56       |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.52        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00116    |
# |    std                  | 0.756       |
# |    value_loss           | 22.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.15e+03    |
# |    ep_rew_mean          | 24.5        |
# | time/                   |             |
# |    fps                  | 598         |
# |    iterations           | 21          |
# |    time_elapsed         | 2298        |
# |    total_timesteps      | 1376256     |
# | train/                  |             |
# |    approx_kl            | 0.010155134 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.49       |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.54        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00181    |
# |    std                  | 0.745       |
# |    value_loss           | 13.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.02e+03   |
# |    ep_rew_mean          | 16.2       |
# | time/                   |            |
# |    fps                  | 596        |
# |    iterations           | 22         |
# |    time_elapsed         | 2418       |
# |    total_timesteps      | 1441792    |
# | train/                  |            |
# |    approx_kl            | 0.01176037 |
# |    clip_fraction        | 0.145      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.43      |
# |    explained_variance   | 0.873      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 33.3       |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00154   |
# |    std                  | 0.734      |
# |    value_loss           | 24.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | 53.5        |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 23          |
# |    time_elapsed         | 2540        |
# |    total_timesteps      | 1507328     |
# | train/                  |             |
# |    approx_kl            | 0.010585297 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.4        |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.05        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.000292   |
# |    std                  | 0.726       |
# |    value_loss           | 25.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.39e+03     |
# |    ep_rew_mean          | 96.9         |
# | time/                   |              |
# |    fps                  | 591          |
# |    iterations           | 24           |
# |    time_elapsed         | 2658         |
# |    total_timesteps      | 1572864      |
# | train/                  |              |
# |    approx_kl            | 0.0107624065 |
# |    clip_fraction        | 0.131        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.33        |
# |    explained_variance   | 0.846        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.54         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00197     |
# |    std                  | 0.718        |
# |    value_loss           | 14           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.45e+03    |
# |    ep_rew_mean          | 111         |
# | time/                   |             |
# |    fps                  | 590         |
# |    iterations           | 25          |
# |    time_elapsed         | 2774        |
# |    total_timesteps      | 1638400     |
# | train/                  |             |
# |    approx_kl            | 0.010176398 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.81        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00389    |
# |    std                  | 0.703       |
# |    value_loss           | 6.3         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.38e+03    |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 589         |
# |    iterations           | 26          |
# |    time_elapsed         | 2892        |
# |    total_timesteps      | 1703936     |
# | train/                  |             |
# |    approx_kl            | 0.011456965 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.829       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.292       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00162    |
# |    std                  | 0.692       |
# |    value_loss           | 15.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.32e+03    |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 27          |
# |    time_elapsed         | 3011        |
# |    total_timesteps      | 1769472     |
# | train/                  |             |
# |    approx_kl            | 0.010212041 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | 0.866       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47          |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00069    |
# |    std                  | 0.682       |
# |    value_loss           | 15.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.39e+03    |
# |    ep_rew_mean          | 132         |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 28          |
# |    time_elapsed         | 3128        |
# |    total_timesteps      | 1835008     |
# | train/                  |             |
# |    approx_kl            | 0.011527331 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.39        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00188    |
# |    std                  | 0.669       |
# |    value_loss           | 13          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.44e+03   |
# |    ep_rew_mean          | 148        |
# | time/                   |            |
# |    fps                  | 585        |
# |    iterations           | 29         |
# |    time_elapsed         | 3246       |
# |    total_timesteps      | 1900544    |
# | train/                  |            |
# |    approx_kl            | 0.00980675 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.99      |
# |    explained_variance   | 0.858      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.78       |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.000748  |
# |    std                  | 0.658      |
# |    value_loss           | 14.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.44e+03    |
# |    ep_rew_mean          | 156         |
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 30          |
# |    time_elapsed         | 3365        |
# |    total_timesteps      | 1966080     |
# | train/                  |             |
# |    approx_kl            | 0.010069976 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.395       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.000616   |
# |    std                  | 0.651       |
# |    value_loss           | 14.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.43e+03    |
# |    ep_rew_mean          | 164         |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 31          |
# |    time_elapsed         | 3484        |
# |    total_timesteps      | 2031616     |
# | train/                  |             |
# |    approx_kl            | 0.010985437 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.9        |
# |    explained_variance   | 0.864       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.6         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00074    |
# |    std                  | 0.644       |
# |    value_loss           | 16.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.46e+03    |
# |    ep_rew_mean          | 178         |
# | time/                   |             |
# |    fps                  | 582         |
# |    iterations           | 32          |
# |    time_elapsed         | 3602        |
# |    total_timesteps      | 2097152     |
# | train/                  |             |
# |    approx_kl            | 0.010879505 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.84       |
# |    explained_variance   | 0.867       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.544       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00154    |
# |    std                  | 0.637       |
# |    value_loss           | 10.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.45e+03    |
# |    ep_rew_mean          | 186         |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 33          |
# |    time_elapsed         | 3721        |
# |    total_timesteps      | 2162688     |
# | train/                  |             |
# |    approx_kl            | 0.011887932 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.8        |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.646       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00245    |
# |    std                  | 0.626       |
# |    value_loss           | 8.71        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.44e+03    |
# |    ep_rew_mean          | 196         |
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 34          |
# |    time_elapsed         | 3839        |
# |    total_timesteps      | 2228224     |
# | train/                  |             |
# |    approx_kl            | 0.011845861 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.73       |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.6        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00196    |
# |    std                  | 0.614       |
# |    value_loss           | 10.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.48e+03    |
# |    ep_rew_mean          | 221         |
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 35          |
# |    time_elapsed         | 3956        |
# |    total_timesteps      | 2293760     |
# | train/                  |             |
# |    approx_kl            | 0.012440421 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.6        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00183    |
# |    std                  | 0.6         |
# |    value_loss           | 12          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.45e+03    |
# |    ep_rew_mean          | 231         |
# | time/                   |             |
# |    fps                  | 578         |
# |    iterations           | 36          |
# |    time_elapsed         | 4074        |
# |    total_timesteps      | 2359296     |
# | train/                  |             |
# |    approx_kl            | 0.011769447 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.57       |
# |    explained_variance   | 0.716       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.01        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.000325   |
# |    std                  | 0.591       |
# |    value_loss           | 11.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.45e+03    |
# |    ep_rew_mean          | 241         |
# | time/                   |             |
# |    fps                  | 578         |
# |    iterations           | 37          |
# |    time_elapsed         | 4193        |
# |    total_timesteps      | 2424832     |
# | train/                  |             |
# |    approx_kl            | 0.012145256 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.51       |
# |    explained_variance   | 0.751       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.626       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.000321   |
# |    std                  | 0.583       |
# |    value_loss           | 14.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.43e+03   |
# |    ep_rew_mean          | 245        |
# | time/                   |            |
# |    fps                  | 577        |
# |    iterations           | 38         |
# |    time_elapsed         | 4311       |
# |    total_timesteps      | 2490368    |
# | train/                  |            |
# |    approx_kl            | 0.01347293 |
# |    clip_fraction        | 0.164      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.46      |
# |    explained_variance   | 0.742      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.02       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | 0.000159   |
# |    std                  | 0.577      |
# |    value_loss           | 14.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.44e+03    |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 577         |
# |    iterations           | 39          |
# |    time_elapsed         | 4429        |
# |    total_timesteps      | 2555904     |
# | train/                  |             |
# |    approx_kl            | 0.012266376 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.42       |
# |    explained_variance   | 0.513       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.32        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.000382    |
# |    std                  | 0.569       |
# |    value_loss           | 13.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.37e+03     |
# |    ep_rew_mean          | 243          |
# | time/                   |              |
# |    fps                  | 576          |
# |    iterations           | 40           |
# |    time_elapsed         | 4547         |
# |    total_timesteps      | 2621440      |
# | train/                  |              |
# |    approx_kl            | 0.0125347935 |
# |    clip_fraction        | 0.157        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.39        |
# |    explained_variance   | 0.624        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.6         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | 0.000859     |
# |    std                  | 0.565        |
# |    value_loss           | 13.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.33e+03    |
# |    ep_rew_mean          | 241         |
# | time/                   |             |
# |    fps                  | 575         |
# |    iterations           | 41          |
# |    time_elapsed         | 4664        |
# |    total_timesteps      | 2686976     |
# | train/                  |             |
# |    approx_kl            | 0.013763025 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.35       |
# |    explained_variance   | 0.797       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.4        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.000351    |
# |    std                  | 0.56        |
# |    value_loss           | 19.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.34e+03    |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 575         |
# |    iterations           | 42          |
# |    time_elapsed         | 4782        |
# |    total_timesteps      | 2752512     |
# | train/                  |             |
# |    approx_kl            | 0.013972022 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 0.702       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.79        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.000556    |
# |    std                  | 0.553       |
# |    value_loss           | 22.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.32e+03    |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 575         |
# |    iterations           | 43          |
# |    time_elapsed         | 4899        |
# |    total_timesteps      | 2818048     |
# | train/                  |             |
# |    approx_kl            | 0.012929798 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.25       |
# |    explained_variance   | 0.623       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26          |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.000708    |
# |    std                  | 0.548       |
# |    value_loss           | 25.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.32e+03    |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 574         |
# |    iterations           | 44          |
# |    time_elapsed         | 5018        |
# |    total_timesteps      | 2883584     |
# | train/                  |             |
# |    approx_kl            | 0.014341906 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.21       |
# |    explained_variance   | 0.665       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.16        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.000374    |
# |    std                  | 0.541       |
# |    value_loss           | 24.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.31e+03    |
# |    ep_rew_mean          | 249         |
# | time/                   |             |
# |    fps                  | 574         |
# |    iterations           | 45          |
# |    time_elapsed         | 5136        |
# |    total_timesteps      | 2949120     |
# | train/                  |             |
# |    approx_kl            | 0.012504319 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.593       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.84        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.000831    |
# |    std                  | 0.537       |
# |    value_loss           | 25.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.29e+03    |
# |    ep_rew_mean          | 249         |
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 46          |
# |    time_elapsed         | 5254        |
# |    total_timesteps      | 3014656     |
# | train/                  |             |
# |    approx_kl            | 0.013295172 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.15       |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.7        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.000996    |
# |    std                  | 0.534       |
# |    value_loss           | 29.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.28e+03    |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 47          |
# |    time_elapsed         | 5373        |
# |    total_timesteps      | 3080192     |
# | train/                  |             |
# |    approx_kl            | 0.014060783 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.13       |
# |    explained_variance   | 0.641       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.7        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00105     |
# |    std                  | 0.532       |
# |    value_loss           | 31.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.27e+03    |
# |    ep_rew_mean          | 265         |
# | time/                   |             |
# |    fps                  | 572         |
# |    iterations           | 48          |
# |    time_elapsed         | 5491        |
# |    total_timesteps      | 3145728     |
# | train/                  |             |
# |    approx_kl            | 0.014422798 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.1        |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.00155     |
# |    std                  | 0.524       |
# |    value_loss           | 33.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.24e+03     |
# |    ep_rew_mean          | 262          |
# | time/                   |              |
# |    fps                  | 572          |
# |    iterations           | 49           |
# |    time_elapsed         | 5610         |
# |    total_timesteps      | 3211264      |
# | train/                  |              |
# |    approx_kl            | 0.0144032445 |
# |    clip_fraction        | 0.187        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.05        |
# |    explained_variance   | 0.351        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.2         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 0.00103      |
# |    std                  | 0.521        |
# |    value_loss           | 33.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.23e+03    |
# |    ep_rew_mean          | 261         |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 50          |
# |    time_elapsed         | 5729        |
# |    total_timesteps      | 3276800     |
# | train/                  |             |
# |    approx_kl            | 0.016350858 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.627       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.4        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.00164     |
# |    std                  | 0.518       |
# |    value_loss           | 41.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.22e+03    |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 51          |
# |    time_elapsed         | 5847        |
# |    total_timesteps      | 3342336     |
# | train/                  |             |
# |    approx_kl            | 0.014198891 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.641       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.2        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.00211     |
# |    std                  | 0.516       |
# |    value_loss           | 42.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.21e+03    |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 52          |
# |    time_elapsed         | 5964        |
# |    total_timesteps      | 3407872     |
# | train/                  |             |
# |    approx_kl            | 0.015088247 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.98       |
# |    explained_variance   | 0.678       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.29        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.00226     |
# |    std                  | 0.511       |
# |    value_loss           | 54.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.21e+03    |
# |    ep_rew_mean          | 261         |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 53          |
# |    time_elapsed         | 6082        |
# |    total_timesteps      | 3473408     |
# | train/                  |             |
# |    approx_kl            | 0.014469144 |
# ...
# |    explained_variance   | 0.355      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 34.5       |
# |    n_updates            | 590        |
# |    policy_gradient_loss | 0.0023     |
# |    std                  | 0.488      |
# |    value_loss           | 72         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | 274         |
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 61          |
# |    time_elapsed         | 7022        |
# |    total_timesteps      | 3997696     |
# | train/                  |             |
# |    approx_kl            | 0.015699176 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.555       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.2        |
# |    n_updates            | 600         |
# |    policy_gradient_loss | 0.00279     |
# |    std                  | 0.485       |
# |    value_loss           | 76.8        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.18e+03  |
# |    ep_rew_mean          | 271       |
# | time/                   |           |
# |    fps                  | 570       |
# |    iterations           | 62        |
# |    time_elapsed         | 7121      |
# |    total_timesteps      | 4063232   |
# | train/                  |           |
# |    approx_kl            | 0.0152247 |
# |    clip_fraction        | 0.195     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.77     |
# |    explained_variance   | 0.434     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 113       |
# |    n_updates            | 610       |
# |    policy_gradient_loss | 0.00252   |
# |    std                  | 0.486     |
# |    value_loss           | 69.3      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 63          |
# |    time_elapsed         | 7220        |
# |    total_timesteps      | 4128768     |
# | train/                  |             |
# |    approx_kl            | 0.016877722 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.463       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.43        |
# |    n_updates            | 620         |
# |    policy_gradient_loss | 0.00212     |
# |    std                  | 0.484       |
# |    value_loss           | 83.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | 264         |
# | time/                   |             |
# |    fps                  | 572         |
# |    iterations           | 64          |
# |    time_elapsed         | 7320        |
# |    total_timesteps      | 4194304     |
# | train/                  |             |
# |    approx_kl            | 0.017036187 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.37        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28          |
# |    n_updates            | 630         |
# |    policy_gradient_loss | 0.00217     |
# |    std                  | 0.483       |
# |    value_loss           | 82.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.18e+03    |
# |    ep_rew_mean          | 269         |
# | time/                   |             |
# |    fps                  | 574         |
# |    iterations           | 65          |
# |    time_elapsed         | 7419        |
# |    total_timesteps      | 4259840     |
# | train/                  |             |
# |    approx_kl            | 0.016851384 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08        |
# |    n_updates            | 640         |
# |    policy_gradient_loss | 0.00249     |
# |    std                  | 0.486       |
# |    value_loss           | 87.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | 280         |
# | time/                   |             |
# |    fps                  | 575         |
# |    iterations           | 66          |
# |    time_elapsed         | 7517        |
# |    total_timesteps      | 4325376     |
# | train/                  |             |
# |    approx_kl            | 0.016369125 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.326       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40          |
# |    n_updates            | 650         |
# |    policy_gradient_loss | 0.00248     |
# |    std                  | 0.486       |
# |    value_loss           | 82.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | 278         |
# | time/                   |             |
# |    fps                  | 576         |
# |    iterations           | 67          |
# |    time_elapsed         | 7615        |
# |    total_timesteps      | 4390912     |
# | train/                  |             |
# |    approx_kl            | 0.016010262 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.254       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.3        |
# |    n_updates            | 660         |
# |    policy_gradient_loss | 0.0019      |
# |    std                  | 0.485       |
# |    value_loss           | 81.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 577         |
# |    iterations           | 68          |
# |    time_elapsed         | 7714        |
# |    total_timesteps      | 4456448     |
# | train/                  |             |
# |    approx_kl            | 0.014923835 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.328       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 124         |
# |    n_updates            | 670         |
# |    policy_gradient_loss | 0.00241     |
# |    std                  | 0.485       |
# |    value_loss           | 96.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.19e+03   |
# |    ep_rew_mean          | 275        |
# | time/                   |            |
# |    fps                  | 578        |
# |    iterations           | 69         |
# |    time_elapsed         | 7813       |
# |    total_timesteps      | 4521984    |
# | train/                  |            |
# |    approx_kl            | 0.01427466 |
# |    clip_fraction        | 0.187      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.76      |
# |    explained_variance   | 0.041      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.39       |
# |    n_updates            | 680        |
# |    policy_gradient_loss | 0.002      |
# |    std                  | 0.484      |
# |    value_loss           | 77.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.18e+03    |
# |    ep_rew_mean          | 273         |
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 70          |
# |    time_elapsed         | 7912        |
# |    total_timesteps      | 4587520     |
# | train/                  |             |
# |    approx_kl            | 0.015868146 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.451       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 64.4        |
# |    n_updates            | 690         |
# |    policy_gradient_loss | 0.00195     |
# |    std                  | 0.483       |
# |    value_loss           | 86.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.18e+03    |
# |    ep_rew_mean          | 275         |
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 71          |
# |    time_elapsed         | 8011        |
# |    total_timesteps      | 4653056     |
# | train/                  |             |
# |    approx_kl            | 0.016200326 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71.2        |
# |    n_updates            | 700         |
# |    policy_gradient_loss | 0.00141     |
# |    std                  | 0.485       |
# |    value_loss           | 95.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | 280         |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 72          |
# |    time_elapsed         | 8109        |
# |    total_timesteps      | 4718592     |
# | train/                  |             |
# |    approx_kl            | 0.015008386 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.502       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 60          |
# |    n_updates            | 710         |
# |    policy_gradient_loss | 0.00217     |
# |    std                  | 0.487       |
# |    value_loss           | 105         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | 283         |
# | time/                   |             |
# |    fps                  | 582         |
# |    iterations           | 73          |
# |    time_elapsed         | 8209        |
# |    total_timesteps      | 4784128     |
# | train/                  |             |
# |    approx_kl            | 0.014593521 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.217       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 141         |
# |    n_updates            | 720         |
# |    policy_gradient_loss | 0.0018      |
# |    std                  | 0.485       |
# |    value_loss           | 98.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.18e+03    |
# |    ep_rew_mean          | 279         |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 74          |
# |    time_elapsed         | 8309        |
# |    total_timesteps      | 4849664     |
# | train/                  |             |
# |    approx_kl            | 0.015180979 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.0191      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.94        |
# |    n_updates            | 730         |
# |    policy_gradient_loss | 0.00147     |
# |    std                  | 0.482       |
# |    value_loss           | 92.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.17e+03    |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 75          |
# |    time_elapsed         | 8408        |
# |    total_timesteps      | 4915200     |
# | train/                  |             |
# |    approx_kl            | 0.014807165 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.446       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 147         |
# |    n_updates            | 740         |
# |    policy_gradient_loss | 0.00166     |
# |    std                  | 0.482       |
# |    value_loss           | 105         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.18e+03    |
# |    ep_rew_mean          | 272         |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 76          |
# |    time_elapsed         | 8507        |
# |    total_timesteps      | 4980736     |
# | train/                  |             |
# |    approx_kl            | 0.014659868 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.439       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 86.6        |
# |    n_updates            | 750         |
# |    policy_gradient_loss | 0.0018      |
# |    std                  | 0.48        |
# |    value_loss           | 112         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | 265         |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 77          |
# |    time_elapsed         | 8605        |
# |    total_timesteps      | 5046272     |
# | train/                  |             |
# |    approx_kl            | 0.016020283 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | 0.571       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 155         |
# |    n_updates            | 760         |
# |    policy_gradient_loss | 0.00209     |
# |    std                  | 0.479       |
# |    value_loss           | 116         |
# -----------------------------------------

# %% [markdown]
# Visualize the agent

# %%
import numpy as np
import imageio
import tempfile
from IPython.display import Video, display

# Load the trained PPO agent
model = PPO.load("ppo_bipedal_walker")

# Create evaluation env in rgb_array mode to capture frames
eval_env = gym.make("BipedalWalker-v3", render_mode="rgb_array")

frames = []

# Run one rollout
obs, info = eval_env.reset()
done = False
while not done:
    # For vector models, wrap obs into batch of size 1
    action, _ = model.predict(np.array(obs)[None, :], deterministic=True)
    obs, reward, terminated, truncated, info = eval_env.step(action[0])
    done = terminated or truncated

    # Get the rendered frame (RGB)
    frame = eval_env.render()
    if frame is not None:
        frames.append(frame)

eval_env.close()
print(f"Captured {len(frames)} frames.")

# Save captured frames to a temporary mp4 video
tmp_path = tempfile.NamedTemporaryFile(suffix=".mp4", delete=False).name
writer = imageio.get_writer(tmp_path, fps=30, codec="libx264")
for frame in frames:
    writer.append_data(frame)
writer.close()

# Display video inline
display(Video(tmp_path, embed=True))
# Out:
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Captured 1108 frames.
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
