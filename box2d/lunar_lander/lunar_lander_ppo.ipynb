# %% [markdown]
# Import libraries

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# %% [markdown]
# Initialize the environment

# %%
env_id = "LunarLander-v3"

# Create vectorized environments
vec_env = make_vec_env(env_id, n_envs=12, seed=42)

# %% [markdown]
# Initialize the agent

# %%
ppo_kwargs = dict(
    n_steps=1024,
    batch_size=64,
    n_epochs=6,
    gamma=0.999,
    gae_lambda=0.98,
    ent_coef=0.005,
    vf_coef=0.5,
)

# PPO agent with an MLP policy
model = PPO(
    "MlpPolicy",
    vec_env,
    verbose=1,
    **ppo_kwargs
)
# Out:
# Using cuda device

# %% [markdown]
# Train the agent

# %%
model.learn(total_timesteps=5_000_000)
model.save("ppo_lunarlander")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91       |
# |    ep_rew_mean     | -192     |
# | time/              |          |
# |    fps             | 2623     |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 12288    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92          |
# |    ep_rew_mean          | -136        |
# | time/                   |             |
# |    fps                  | 1259        |
# |    iterations           | 2           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009620388 |
# |    clip_fraction        | 0.0829      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -5.66e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.76e+03    |
# |    n_updates            | 6           |
# |    policy_gradient_loss | -0.00877    |
# |    value_loss           | 4.98e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.5        |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 1102        |
# |    iterations           | 3           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009366052 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.00234    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 596         |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.00757    |
# |    value_loss           | 1.88e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 101         |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 1044        |
# |    iterations           | 4           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009003381 |
# |    clip_fraction        | 0.0893      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.00157    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 170         |
# |    n_updates            | 18          |
# |    policy_gradient_loss | -0.00585    |
# |    value_loss           | 586         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.1        |
# |    ep_rew_mean          | -88.9       |
# | time/                   |             |
# |    fps                  | 991         |
# |    iterations           | 5           |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.008430901 |
# |    clip_fraction        | 0.0697      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.00115    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 271         |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.00518    |
# |    value_loss           | 574         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 106          |
# |    ep_rew_mean          | -74.1        |
# | time/                   |              |
# |    fps                  | 954          |
# |    iterations           | 6            |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0076794066 |
# |    clip_fraction        | 0.0733       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | -2.69e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 117          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00592     |
# |    value_loss           | 379          |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 113       |
# |    ep_rew_mean          | -54.4     |
# | time/                   |           |
# |    fps                  | 927       |
# |    iterations           | 7         |
# |    time_elapsed         | 92        |
# |    total_timesteps      | 86016     |
# | train/                  |           |
# |    approx_kl            | 0.0102296 |
# |    clip_fraction        | 0.105     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.28     |
# |    explained_variance   | -1.07e-06 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 111       |
# |    n_updates            | 36        |
# |    policy_gradient_loss | -0.00741  |
# |    value_loss           | 383       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 111         |
# |    ep_rew_mean          | -40.8       |
# | time/                   |             |
# |    fps                  | 907         |
# |    iterations           | 8           |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.008815794 |
# |    clip_fraction        | 0.0944      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | -1.16e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 132         |
# |    n_updates            | 42          |
# |    policy_gradient_loss | -0.00579    |
# |    value_loss           | 340         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 134         |
# |    ep_rew_mean          | -25.7       |
# | time/                   |             |
# |    fps                  | 892         |
# |    iterations           | 9           |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.010096037 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 3.22e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 147         |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.00289    |
# |    value_loss           | 330         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -22.7       |
# | time/                   |             |
# |    fps                  | 869         |
# |    iterations           | 10          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.006774737 |
# |    clip_fraction        | 0.037       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 5.33e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 186         |
# |    n_updates            | 54          |
# |    policy_gradient_loss | -0.00239    |
# |    value_loss           | 458         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 205        |
# |    ep_rew_mean          | -19        |
# | time/                   |            |
# |    fps                  | 856        |
# |    iterations           | 11         |
# |    time_elapsed         | 157        |
# |    total_timesteps      | 135168     |
# | train/                  |            |
# |    approx_kl            | 0.00744106 |
# |    clip_fraction        | 0.0328     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.16      |
# |    explained_variance   | 0.00112    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 261        |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00353   |
# |    value_loss           | 491        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 266          |
# |    ep_rew_mean          | -18.6        |
# | time/                   |              |
# |    fps                  | 830          |
# |    iterations           | 12           |
# |    time_elapsed         | 177          |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0069441698 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.112        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 440          |
# |    n_updates            | 66           |
# |    policy_gradient_loss | -0.00356     |
# |    value_loss           | 486          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 319          |
# |    ep_rew_mean          | -10.5        |
# | time/                   |              |
# |    fps                  | 807          |
# |    iterations           | 13           |
# |    time_elapsed         | 197          |
# |    total_timesteps      | 159744       |
# | train/                  |              |
# |    approx_kl            | 0.0045780074 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.308        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 285          |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.00237     |
# |    value_loss           | 381          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 366         |
# |    ep_rew_mean          | -6.84       |
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 14          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.011399202 |
# |    clip_fraction        | 0.0678      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.545       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 82.9        |
# |    n_updates            | 78          |
# |    policy_gradient_loss | -0.00226    |
# |    value_loss           | 193         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 430          |
# |    ep_rew_mean          | -1.25        |
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 15           |
# |    time_elapsed         | 238          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0043998146 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.637        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 126          |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.00187     |
# |    value_loss           | 236          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 474          |
# |    ep_rew_mean          | -1.18        |
# | time/                   |              |
# |    fps                  | 755          |
# |    iterations           | 16           |
# |    time_elapsed         | 260          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0070603327 |
# |    clip_fraction        | 0.0529       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.722        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 87.4         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00277     |
# |    value_loss           | 160          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 516          |
# |    ep_rew_mean          | 1.58         |
# | time/                   |              |
# |    fps                  | 739          |
# |    iterations           | 17           |
# |    time_elapsed         | 282          |
# |    total_timesteps      | 208896       |
# | train/                  |              |
# |    approx_kl            | 0.0038484596 |
# |    clip_fraction        | 0.0169       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.571        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 159          |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.00286     |
# |    value_loss           | 325          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 573          |
# |    ep_rew_mean          | 10.9         |
# | time/                   |              |
# |    fps                  | 728          |
# |    iterations           | 18           |
# |    time_elapsed         | 303          |
# |    total_timesteps      | 221184       |
# | train/                  |              |
# |    approx_kl            | 0.0069479453 |
# |    clip_fraction        | 0.0579       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.811        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22           |
# |    n_updates            | 102          |
# |    policy_gradient_loss | -0.00266     |
# |    value_loss           | 70.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 646         |
# |    ep_rew_mean          | 23.6        |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 19          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 233472      |
# | train/                  |             |
# |    approx_kl            | 0.005629953 |
# |    clip_fraction        | 0.0401      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 93.1        |
# |    n_updates            | 108         |
# |    policy_gradient_loss | -0.00155    |
# |    value_loss           | 92.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 687        |
# |    ep_rew_mean          | 35.1       |
# | time/                   |            |
# |    fps                  | 711        |
# |    iterations           | 20         |
# |    time_elapsed         | 345        |
# |    total_timesteps      | 245760     |
# | train/                  |            |
# |    approx_kl            | 0.00565646 |
# |    clip_fraction        | 0.0341     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.18      |
# |    explained_variance   | 0.902      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 34         |
# |    n_updates            | 114        |
# |    policy_gradient_loss | -0.00185   |
# |    value_loss           | 70.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 732         |
# |    ep_rew_mean          | 45.3        |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 21          |
# |    time_elapsed         | 365         |
# |    total_timesteps      | 258048      |
# | train/                  |             |
# |    approx_kl            | 0.007006178 |
# |    clip_fraction        | 0.0643      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 67          |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00237    |
# |    value_loss           | 82.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 793         |
# |    ep_rew_mean          | 54.4        |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 22          |
# |    time_elapsed         | 383         |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.007826512 |
# |    clip_fraction        | 0.0603      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.5        |
# |    n_updates            | 126         |
# |    policy_gradient_loss | -0.002      |
# |    value_loss           | 35.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 810         |
# |    ep_rew_mean          | 60.7        |
# | time/                   |             |
# |    fps                  | 698         |
# |    iterations           | 23          |
# |    time_elapsed         | 404         |
# |    total_timesteps      | 282624      |
# | train/                  |             |
# |    approx_kl            | 0.009548393 |
# |    clip_fraction        | 0.0509      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.765       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.59        |
# |    n_updates            | 132         |
# |    policy_gradient_loss | -0.00167    |
# |    value_loss           | 222         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 826          |
# |    ep_rew_mean          | 66.9         |
# | time/                   |              |
# |    fps                  | 693          |
# |    iterations           | 24           |
# |    time_elapsed         | 425          |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0087519325 |
# |    clip_fraction        | 0.0558       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.742        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 54.8         |
# |    n_updates            | 138          |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 295          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 860          |
# |    ep_rew_mean          | 72.2         |
# | time/                   |              |
# |    fps                  | 688          |
# |    iterations           | 25           |
# |    time_elapsed         | 446          |
# |    total_timesteps      | 307200       |
# | train/                  |              |
# |    approx_kl            | 0.0077870265 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.57         |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 22.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 870         |
# |    ep_rew_mean          | 76.6        |
# | time/                   |             |
# |    fps                  | 684         |
# |    iterations           | 26          |
# |    time_elapsed         | 466         |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.006601343 |
# |    clip_fraction        | 0.0465      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.98        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.002      |
# |    value_loss           | 32.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 869         |
# |    ep_rew_mean          | 79.8        |
# | time/                   |             |
# |    fps                  | 683         |
# |    iterations           | 27          |
# |    time_elapsed         | 485         |
# |    total_timesteps      | 331776      |
# | train/                  |             |
# |    approx_kl            | 0.004722968 |
# |    clip_fraction        | 0.0275      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.6        |
# |    n_updates            | 156         |
# |    policy_gradient_loss | -0.00084    |
# |    value_loss           | 77.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 855          |
# |    ep_rew_mean          | 78.9         |
# | time/                   |              |
# |    fps                  | 680          |
# |    iterations           | 28           |
# |    time_elapsed         | 505          |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0057768566 |
# |    clip_fraction        | 0.0243       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.953        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.2         |
# |    n_updates            | 162          |
# |    policy_gradient_loss | -0.00171     |
# |    value_loss           | 40.5         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 849        |
# |    ep_rew_mean          | 86.3       |
# | time/                   |            |
# |    fps                  | 675        |
# |    iterations           | 29         |
# |    time_elapsed         | 527        |
# |    total_timesteps      | 356352     |
# | train/                  |            |
# |    approx_kl            | 0.00543415 |
# |    clip_fraction        | 0.0411     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.99      |
# |    explained_variance   | 0.819      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 50.2       |
# |    n_updates            | 168        |
# |    policy_gradient_loss | -0.000954  |
# |    value_loss           | 227        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 855        |
# |    ep_rew_mean          | 91.2       |
# | time/                   |            |
# |    fps                  | 671        |
# |    iterations           | 30         |
# |    time_elapsed         | 548        |
# |    total_timesteps      | 368640     |
# | train/                  |            |
# |    approx_kl            | 0.00465674 |
# |    clip_fraction        | 0.0453     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.965     |
# |    explained_variance   | 0.893      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 30.2       |
# |    n_updates            | 174        |
# |    policy_gradient_loss | -0.00185   |
# |    value_loss           | 105        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 830          |
# |    ep_rew_mean          | 89.6         |
# | time/                   |              |
# |    fps                  | 668          |
# |    iterations           | 31           |
# |    time_elapsed         | 569          |
# |    total_timesteps      | 380928       |
# | train/                  |              |
# |    approx_kl            | 0.0052321516 |
# |    clip_fraction        | 0.0332       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.939       |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.9         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 71.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 830          |
# |    ep_rew_mean          | 92           |
# | time/                   |              |
# |    fps                  | 665          |
# |    iterations           | 32           |
# |    time_elapsed         | 590          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0068729133 |
# |    clip_fraction        | 0.0997       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.902       |
# |    explained_variance   | 0.927        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16           |
# |    n_updates            | 186          |
# |    policy_gradient_loss | -0.00235     |
# |    value_loss           | 71.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 833         |
# |    ep_rew_mean          | 95.5        |
# | time/                   |             |
# |    fps                  | 664         |
# |    iterations           | 33          |
# |    time_elapsed         | 609         |
# |    total_timesteps      | 405504      |
# | train/                  |             |
# |    approx_kl            | 0.006032554 |
# |    clip_fraction        | 0.0368      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.903      |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.7        |
# |    n_updates            | 192         |
# |    policy_gradient_loss | -0.000689   |
# |    value_loss           | 34.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 845         |
# |    ep_rew_mean          | 101         |
# | time/                   |             |
# |    fps                  | 660         |
# |    iterations           | 34          |
# |    time_elapsed         | 632         |
# |    total_timesteps      | 417792      |
# | train/                  |             |
# |    approx_kl            | 0.002893212 |
# |    clip_fraction        | 0.0292      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.849      |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.19        |
# |    n_updates            | 198         |
# |    policy_gradient_loss | -0.000383   |
# |    value_loss           | 75.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 864          |
# |    ep_rew_mean          | 107          |
# | time/                   |              |
# |    fps                  | 657          |
# |    iterations           | 35           |
# |    time_elapsed         | 654          |
# |    total_timesteps      | 430080       |
# | train/                  |              |
# |    approx_kl            | 0.0035550955 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.853       |
# |    explained_variance   | 0.932        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.36         |
# |    n_updates            | 204          |
# |    policy_gradient_loss | 0.000414     |
# |    value_loss           | 52.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 885         |
# |    ep_rew_mean          | 110         |
# | time/                   |             |
# |    fps                  | 653         |
# |    iterations           | 36          |
# |    time_elapsed         | 676         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.004231117 |
# |    clip_fraction        | 0.0284      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.839      |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.78        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.000641   |
# |    value_loss           | 83.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 871          |
# |    ep_rew_mean          | 117          |
# | time/                   |              |
# |    fps                  | 651          |
# |    iterations           | 37           |
# |    time_elapsed         | 697          |
# |    total_timesteps      | 454656       |
# | train/                  |              |
# |    approx_kl            | 0.0035516408 |
# |    clip_fraction        | 0.0393       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.862       |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.91         |
# |    n_updates            | 216          |
# |    policy_gradient_loss | -0.00113     |
# |    value_loss           | 12.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 866         |
# |    ep_rew_mean          | 123         |
# | time/                   |             |
# |    fps                  | 651         |
# |    iterations           | 38          |
# |    time_elapsed         | 717         |
# |    total_timesteps      | 466944      |
# | train/                  |             |
# |    approx_kl            | 0.012906037 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.804      |
# |    explained_variance   | 0.794       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 133         |
# |    n_updates            | 222         |
# |    policy_gradient_loss | -0.00332    |
# |    value_loss           | 223         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 861          |
# |    ep_rew_mean          | 136          |
# | time/                   |              |
# |    fps                  | 649          |
# |    iterations           | 39           |
# |    time_elapsed         | 737          |
# |    total_timesteps      | 479232       |
# | train/                  |              |
# |    approx_kl            | 0.0060027093 |
# |    clip_fraction        | 0.0631       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.766       |
# |    explained_variance   | 0.838        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 166          |
# |    n_updates            | 228          |
# |    policy_gradient_loss | -0.00287     |
# |    value_loss           | 169          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 796          |
# |    ep_rew_mean          | 158          |
# | time/                   |              |
# |    fps                  | 648          |
# |    iterations           | 40           |
# |    time_elapsed         | 757          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0049665235 |
# |    clip_fraction        | 0.0522       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.681       |
# |    explained_variance   | 0.786        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 95.7         |
# |    n_updates            | 234          |
# |    policy_gradient_loss | -0.0031      |
# |    value_loss           | 215          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 751         |
# |    ep_rew_mean          | 174         |
# | time/                   |             |
# |    fps                  | 648         |
# |    iterations           | 41          |
# |    time_elapsed         | 777         |
# |    total_timesteps      | 503808      |
# | train/                  |             |
# |    approx_kl            | 0.005985953 |
# |    clip_fraction        | 0.0666      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.719      |
# |    explained_variance   | 0.644       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.8        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0036     |
# |    value_loss           | 422         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 624         |
# |    ep_rew_mean          | 203         |
# | time/                   |             |
# |    fps                  | 647         |
# |    iterations           | 42          |
# |    time_elapsed         | 796         |
# |    total_timesteps      | 516096      |
# | train/                  |             |
# |    approx_kl            | 0.004479211 |
# |    clip_fraction        | 0.048       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.693      |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 181         |
# |    n_updates            | 246         |
# |    policy_gradient_loss | -0.00144    |
# |    value_loss           | 190         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 488        |
# |    ep_rew_mean          | 212        |
# | time/                   |            |
# |    fps                  | 648        |
# |    iterations           | 43         |
# |    time_elapsed         | 814        |
# |    total_timesteps      | 528384     |
# | train/                  |            |
# |    approx_kl            | 0.01156187 |
# |    clip_fraction        | 0.0646     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.725     |
# |    explained_variance   | 0.541      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 114        |
# |    n_updates            | 252        |
# |    policy_gradient_loss | -0.0038    |
# |    value_loss           | 302        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 432         |
# |    ep_rew_mean          | 202         |
# | time/                   |             |
# |    fps                  | 649         |
# |    iterations           | 44          |
# |    time_elapsed         | 831         |
# |    total_timesteps      | 540672      |
# | train/                  |             |
# |    approx_kl            | 0.003206484 |
# |    clip_fraction        | 0.0277      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.786      |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 190         |
# |    n_updates            | 258         |
# |    policy_gradient_loss | -0.000808   |
# |    value_loss           | 387         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 396         |
# |    ep_rew_mean          | 199         |
# | time/                   |             |
# |    fps                  | 650         |
# |    iterations           | 45          |
# |    time_elapsed         | 850         |
# |    total_timesteps      | 552960      |
# | train/                  |             |
# |    approx_kl            | 0.005415216 |
# |    clip_fraction        | 0.0581      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.773      |
# |    explained_variance   | 0.81        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.8        |
# |    n_updates            | 264         |
# |    policy_gradient_loss | -0.00169    |
# |    value_loss           | 312         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 399         |
# |    ep_rew_mean          | 202         |
# | time/                   |             |
# |    fps                  | 650         |
# |    iterations           | 46          |
# |    time_elapsed         | 869         |
# |    total_timesteps      | 565248      |
# | train/                  |             |
# |    approx_kl            | 0.004411482 |
# |    clip_fraction        | 0.0283      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.769      |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 105         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00121    |
# |    value_loss           | 369         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 379          |
# |    ep_rew_mean          | 221          |
# | time/                   |              |
# |    fps                  | 650          |
# |    iterations           | 47           |
# |    time_elapsed         | 887          |
# |    total_timesteps      | 577536       |
# | train/                  |              |
# |    approx_kl            | 0.0042824834 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.773       |
# |    explained_variance   | 0.762        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.8         |
# |    n_updates            | 276          |
# |    policy_gradient_loss | -0.00205     |
# |    value_loss           | 225          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 363          |
# |    ep_rew_mean          | 236          |
# | time/                   |              |
# |    fps                  | 651          |
# |    iterations           | 48           |
# |    time_elapsed         | 905          |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0038896278 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.798       |
# |    explained_variance   | 0.661        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 117          |
# |    n_updates            | 282          |
# |    policy_gradient_loss | -0.00127     |
# |    value_loss           | 231          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 354          |
# |    ep_rew_mean          | 251          |
# | time/                   |              |
# |    fps                  | 651          |
# |    iterations           | 49           |
# |    time_elapsed         | 923          |
# |    total_timesteps      | 602112       |
# | train/                  |              |
# |    approx_kl            | 0.0040275366 |
# |    clip_fraction        | 0.0369       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.773       |
# |    explained_variance   | 0.873        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.6         |
# |    n_updates            | 288          |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 67.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 354          |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 652          |
# |    iterations           | 50           |
# |    time_elapsed         | 941          |
# |    total_timesteps      | 614400       |
# | train/                  |              |
# |    approx_kl            | 0.0029805389 |
# |    clip_fraction        | 0.0191       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.776       |
# |    explained_variance   | 0.813        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 348          |
# |    n_updates            | 294          |
# |    policy_gradient_loss | -0.000442    |
# |    value_loss           | 128          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 345          |
# |    ep_rew_mean          | 256          |
# | time/                   |              |
# |    fps                  | 654          |
# |    iterations           | 51           |
# |    time_elapsed         | 957          |
# |    total_timesteps      | 626688       |
# | train/                  |              |
# |    approx_kl            | 0.0050787465 |
# |    clip_fraction        | 0.0412       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.782       |
# |    explained_variance   | 0.877        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.2         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000437    |
# |    value_loss           | 52.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 343          |
# |    ep_rew_mean          | 260          |
# | time/                   |              |
# |    fps                  | 654          |
# |    iterations           | 52           |
# |    time_elapsed         | 975          |
# |    total_timesteps      | 638976       |
# | train/                  |              |
# |    approx_kl            | 0.0071779895 |
# |    clip_fraction        | 0.0728       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.773       |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.12         |
# |    n_updates            | 306          |
# |    policy_gradient_loss | -0.00219     |
# |    value_loss           | 25.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 326         |
# |    ep_rew_mean          | 262         |
# | time/                   |             |
# |    fps                  | 655         |
# |    iterations           | 53          |
# |    time_elapsed         | 993         |
# |    total_timesteps      | 651264      |
# | train/                  |             |
# |    approx_kl            | 0.005806081 |
# |    clip_fraction        | 0.0592      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.744      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.5        |
# |    n_updates            | 312         |
# |    policy_gradient_loss | -0.00223    |
# |    value_loss           | 18.4        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 403       |
# |    ep_rew_mean          | 250       |
# | time/                   |           |
# |    fps                  | 654       |
# |    iterations           | 54        |
# |    time_elapsed         | 1014      |
# |    total_timesteps      | 663552    |
# | train/                  |           |
# |    approx_kl            | 0.0251906 |
# |    clip_fraction        | 0.146     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.839    |
# |    explained_variance   | 0.984     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.63      |
# |    n_updates            | 318       |
# |    policy_gradient_loss | -0.0123   |
# |    value_loss           | 8.57      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 469          |
# |    ep_rew_mean          | 242          |
# | time/                   |              |
# |    fps                  | 653          |
# |    iterations           | 55           |
# |    time_elapsed         | 1034         |
# |    total_timesteps      | 675840       |
# | train/                  |              |
# |    approx_kl            | 0.0026967207 |
# |    clip_fraction        | 0.0338       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.705       |
# ...
# | rollout/                |              |
# |    ep_len_mean          | 207          |
# |    ep_rew_mean          | 281          |
# | time/                   |              |
# |    fps                  | 733          |
# |    iterations           | 390          |
# |    time_elapsed         | 6533         |
# |    total_timesteps      | 4792320      |
# | train/                  |              |
# |    approx_kl            | 0.0033681297 |
# |    clip_fraction        | 0.0452       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.4         |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16           |
# |    n_updates            | 2334         |
# |    policy_gradient_loss | -0.000562    |
# |    value_loss           | 83           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | 286          |
# | time/                   |              |
# |    fps                  | 733          |
# |    iterations           | 391          |
# |    time_elapsed         | 6549         |
# |    total_timesteps      | 4804608      |
# | train/                  |              |
# |    approx_kl            | 0.0030647647 |
# |    clip_fraction        | 0.0514       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.38        |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.69         |
# |    n_updates            | 2340         |
# |    policy_gradient_loss | 0.000448     |
# |    value_loss           | 134          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | 287         |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 392         |
# |    time_elapsed         | 6565        |
# |    total_timesteps      | 4816896     |
# | train/                  |             |
# |    approx_kl            | 0.004503669 |
# |    clip_fraction        | 0.0593      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.357      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.771       |
# |    n_updates            | 2346        |
# |    policy_gradient_loss | 0.00106     |
# |    value_loss           | 2.88        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 205          |
# |    ep_rew_mean          | 283          |
# | time/                   |              |
# |    fps                  | 733          |
# |    iterations           | 393          |
# |    time_elapsed         | 6582         |
# |    total_timesteps      | 4829184      |
# | train/                  |              |
# |    approx_kl            | 0.0061457977 |
# |    clip_fraction        | 0.0548       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.383       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.649        |
# |    n_updates            | 2352         |
# |    policy_gradient_loss | 0.000341     |
# |    value_loss           | 2.81         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 214         |
# |    ep_rew_mean          | 286         |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 394         |
# |    time_elapsed         | 6598        |
# |    total_timesteps      | 4841472     |
# | train/                  |             |
# |    approx_kl            | 0.002993468 |
# |    clip_fraction        | 0.0364      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.386      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 131         |
# |    n_updates            | 2358        |
# |    policy_gradient_loss | 0.00109     |
# |    value_loss           | 101         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 214        |
# |    ep_rew_mean          | 280        |
# | time/                   |            |
# |    fps                  | 733        |
# |    iterations           | 395        |
# |    time_elapsed         | 6613       |
# |    total_timesteps      | 4853760    |
# | train/                  |            |
# |    approx_kl            | 0.00382247 |
# |    clip_fraction        | 0.0523     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.392     |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.608      |
# |    n_updates            | 2364       |
# |    policy_gradient_loss | 0.00112    |
# |    value_loss           | 1.76       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 206          |
# |    ep_rew_mean          | 278          |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 396          |
# |    time_elapsed         | 6629         |
# |    total_timesteps      | 4866048      |
# | train/                  |              |
# |    approx_kl            | 0.0025500616 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.396       |
# |    explained_variance   | 0.958        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 137          |
# |    n_updates            | 2370         |
# |    policy_gradient_loss | 0.000334     |
# |    value_loss           | 169          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 198          |
# |    ep_rew_mean          | 282          |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 397          |
# |    time_elapsed         | 6645         |
# |    total_timesteps      | 4878336      |
# | train/                  |              |
# |    approx_kl            | 0.0037169335 |
# |    clip_fraction        | 0.057        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.374       |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.8          |
# |    n_updates            | 2376         |
# |    policy_gradient_loss | 0.000161     |
# |    value_loss           | 65.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 201          |
# |    ep_rew_mean          | 281          |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 398          |
# |    time_elapsed         | 6662         |
# |    total_timesteps      | 4890624      |
# | train/                  |              |
# |    approx_kl            | 0.0029316284 |
# |    clip_fraction        | 0.0435       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.369       |
# |    explained_variance   | 0.956        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.8         |
# |    n_updates            | 2382         |
# |    policy_gradient_loss | -0.000431    |
# |    value_loss           | 113          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 206         |
# |    ep_rew_mean          | 286         |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 399         |
# |    time_elapsed         | 6678        |
# |    total_timesteps      | 4902912     |
# | train/                  |             |
# |    approx_kl            | 0.005387721 |
# |    clip_fraction        | 0.0578      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.375      |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.2        |
# |    n_updates            | 2388        |
# |    policy_gradient_loss | -0.0011     |
# |    value_loss           | 96.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 196         |
# |    ep_rew_mean          | 286         |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 400         |
# |    time_elapsed         | 6695        |
# |    total_timesteps      | 4915200     |
# | train/                  |             |
# |    approx_kl            | 0.003518914 |
# |    clip_fraction        | 0.0514      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.38       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.9        |
# |    n_updates            | 2394        |
# |    policy_gradient_loss | 0.001       |
# |    value_loss           | 82.9        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 199       |
# |    ep_rew_mean          | 289       |
# | time/                   |           |
# |    fps                  | 734       |
# |    iterations           | 401       |
# |    time_elapsed         | 6711      |
# |    total_timesteps      | 4927488   |
# | train/                  |           |
# |    approx_kl            | 0.0049963 |
# |    clip_fraction        | 0.0553    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.376    |
# |    explained_variance   | 0.971     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 119       |
# |    n_updates            | 2400      |
# |    policy_gradient_loss | 0.00066   |
# |    value_loss           | 99.5      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 197          |
# |    ep_rew_mean          | 287          |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 402          |
# |    time_elapsed         | 6726         |
# |    total_timesteps      | 4939776      |
# | train/                  |              |
# |    approx_kl            | 0.0045580147 |
# |    clip_fraction        | 0.0563       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.383       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.7          |
# |    n_updates            | 2406         |
# |    policy_gradient_loss | 0.0018       |
# |    value_loss           | 5.42         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 201          |
# |    ep_rew_mean          | 288          |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 403          |
# |    time_elapsed         | 6740         |
# |    total_timesteps      | 4952064      |
# | train/                  |              |
# |    approx_kl            | 0.0028731122 |
# |    clip_fraction        | 0.0395       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.367       |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.725        |
# |    n_updates            | 2412         |
# |    policy_gradient_loss | 0.000298     |
# |    value_loss           | 5.17         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 203         |
# |    ep_rew_mean          | 279         |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 404         |
# |    time_elapsed         | 6757        |
# |    total_timesteps      | 4964352     |
# | train/                  |             |
# |    approx_kl            | 0.004162051 |
# |    clip_fraction        | 0.0574      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.376      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.522       |
# |    n_updates            | 2418        |
# |    policy_gradient_loss | 0.000797    |
# |    value_loss           | 1.37        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 205          |
# |    ep_rew_mean          | 284          |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 405          |
# |    time_elapsed         | 6773         |
# |    total_timesteps      | 4976640      |
# | train/                  |              |
# |    approx_kl            | 0.0040759244 |
# |    clip_fraction        | 0.0223       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.391       |
# |    explained_variance   | 0.932        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.7         |
# |    n_updates            | 2424         |
# |    policy_gradient_loss | -0.00011     |
# |    value_loss           | 149          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 195          |
# |    ep_rew_mean          | 287          |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 406          |
# |    time_elapsed         | 6789         |
# |    total_timesteps      | 4988928      |
# | train/                  |              |
# |    approx_kl            | 0.0036529955 |
# |    clip_fraction        | 0.0447       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.366       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.83         |
# |    n_updates            | 2430         |
# |    policy_gradient_loss | -0.000692    |
# |    value_loss           | 9.01         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 193         |
# |    ep_rew_mean          | 287         |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 407         |
# |    time_elapsed         | 6805        |
# |    total_timesteps      | 5001216     |
# | train/                  |             |
# |    approx_kl            | 0.004652917 |
# |    clip_fraction        | 0.0553      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.367      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.767       |
# |    n_updates            | 2436        |
# |    policy_gradient_loss | 0.0015      |
# |    value_loss           | 2.38        |
# -----------------------------------------

# %% [markdown]
# Visualize the agent

# %%
import numpy as np
import imageio
import tempfile
from IPython.display import Video, display
import os
os.environ['IMAGEIO_FFMPEG_EXE'] = "ffmpeg"

# Load the trained PPO agent
model = PPO.load("ppo_lunarlander")

# Create evaluation env in rgb_array mode to capture frames
eval_env = gym.make("LunarLander-v3", render_mode="rgb_array")

frames = []

# Run one rollout
obs, info = eval_env.reset()
done = False
while not done:
    # For vector models, wrap obs into batch of size 1
    action, _ = model.predict(np.array(obs)[None, :], deterministic=True)
    obs, reward, terminated, truncated, info = eval_env.step(action[0])
    done = terminated or truncated

    # Get the rendered frame (RGB)
    frame = eval_env.render()
    if frame is not None:
        frames.append(frame)

eval_env.close()
print(f"Captured {len(frames)} frames.")

# Save captured frames to a temporary mp4 video
tmp_path = tempfile.NamedTemporaryFile(suffix=".mp4", delete=False).name
writer = imageio.get_writer(tmp_path, fps=30, codec="libx264")
for frame in frames:
    writer.append_data(frame)
writer.close()

# Display video inline
display(Video(tmp_path, embed=True))
# Out:
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Captured 198 frames.
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
