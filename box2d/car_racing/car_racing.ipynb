# %% [markdown]
# Import libraries

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecNormalize, VecTransposeImage

# %% [markdown]
# Initialize the environment

# %%
env_id = "CarRacing-v3"

# Create vectorized environments
vec_env = make_vec_env(env_id, n_envs=12, seed=42)

vec_env = VecTransposeImage(vec_env)

# %% [markdown]
# Initialize the agent

# %%
# PPO agent with an CNN policy
model = PPO(
    "CnnPolicy",
    vec_env,
    verbose=1,

    # Exploration (very important for CarRacing)
    use_sde=True,
    sde_sample_freq=4,
    ent_coef=0.05,

    # PPO stability
    learning_rate=1e-4,
    n_steps=2048,
    batch_size=256,
    n_epochs=10,
    gamma=0.995,
    gae_lambda=0.95,
    clip_range=0.1,

    # IMPORTANT: images already scaled
    policy_kwargs=dict(normalize_images=False),
)
# Out:
# Using cuda device

# %% [markdown]
# Train the agent

# %%
model.learn(total_timesteps=5_000_000)
model.save("ppo_car_racing")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -60.4    |
# | time/              |          |
# |    fps             | 103      |
# |    iterations      | 1        |
# |    time_elapsed    | 236      |
# |    total_timesteps | 24576    |
# ---------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1e+03    |
# |    ep_rew_mean          | -60.4    |
# | time/                   |          |
# |    fps                  | 100      |
# |    iterations           | 2        |
# |    time_elapsed         | 489      |
# |    total_timesteps      | 49152    |
# | train/                  |          |
# |    approx_kl            | 80.42634 |
# |    clip_fraction        | 0.989    |
# |    clip_range           | 0.1      |
# |    entropy_loss         | -24.7    |
# |    explained_variance   | 0.441    |
# |    learning_rate        | 0.0001   |
# |    loss                 | 5.88     |
# |    n_updates            | 10       |
# |    policy_gradient_loss | 0.44     |
# |    std                  | 1        |
# |    value_loss           | 895      |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -60.2     |
# | time/                   |           |
# |    fps                  | 99        |
# |    iterations           | 3         |
# |    time_elapsed         | 742       |
# |    total_timesteps      | 73728     |
# | train/                  |           |
# |    approx_kl            | 0.6041537 |
# |    clip_fraction        | 0.858     |
# |    clip_range           | 0.1       |
# |    entropy_loss         | -22.8     |
# |    explained_variance   | 0.875     |
# |    learning_rate        | 0.0001    |
# |    loss                 | 3.75      |
# |    n_updates            | 20        |
# |    policy_gradient_loss | 0.127     |
# |    std                  | 1         |
# |    value_loss           | 10.4      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -60.2      |
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 4          |
# |    time_elapsed         | 998        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.20059447 |
# |    clip_fraction        | 0.827      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -21.9      |
# |    explained_variance   | 0.901      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.8        |
# |    n_updates            | 30         |
# |    policy_gradient_loss | 0.0909     |
# |    std                  | 1          |
# |    value_loss           | 6.15       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -60.2       |
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 5           |
# |    time_elapsed         | 1252        |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.066940404 |
# |    clip_fraction        | 0.711       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -21.3       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0873     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.0446      |
# |    std                  | 1.01        |
# |    value_loss           | 3.93        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -58.8      |
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 6          |
# |    time_elapsed         | 1509       |
# |    total_timesteps      | 147456     |
# | train/                  |            |
# |    approx_kl            | 0.04777947 |
# |    clip_fraction        | 0.71       |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -20.9      |
# |    explained_variance   | 0.941      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.17      |
# |    n_updates            | 50         |
# |    policy_gradient_loss | 0.0434     |
# |    std                  | 1.01       |
# |    value_loss           | 2.49       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -57.8      |
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 7          |
# |    time_elapsed         | 1766       |
# |    total_timesteps      | 172032     |
# | train/                  |            |
# |    approx_kl            | 0.04024856 |
# |    clip_fraction        | 0.676      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -20.7      |
# |    explained_variance   | 0.918      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.39      |
# |    n_updates            | 60         |
# |    policy_gradient_loss | 0.031      |
# |    std                  | 1.02       |
# |    value_loss           | 2.49       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -58.4       |
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 8           |
# |    time_elapsed         | 2040        |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.010438957 |
# |    clip_fraction        | 0.531       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -20.5       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.293      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.0152      |
# |    std                  | 1.02        |
# |    value_loss           | 1.61        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -57.7        |
# | time/                   |              |
# |    fps                  | 95           |
# |    iterations           | 9            |
# |    time_elapsed         | 2306         |
# |    total_timesteps      | 221184       |
# | train/                  |              |
# |    approx_kl            | 0.0102143055 |
# |    clip_fraction        | 0.574        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -20.3        |
# |    explained_variance   | 0.922        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.713       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | 0.0219       |
# |    std                  | 1.03         |
# |    value_loss           | 1.18         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -59.2        |
# | time/                   |              |
# |    fps                  | 95           |
# |    iterations           | 10           |
# |    time_elapsed         | 2567         |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0052367025 |
# |    clip_fraction        | 0.407        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -20.3        |
# |    explained_variance   | 0.857        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.734       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 0.00969      |
# |    std                  | 1.04         |
# |    value_loss           | 0.901        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -60.5        |
# | time/                   |              |
# |    fps                  | 95           |
# |    iterations           | 11           |
# |    time_elapsed         | 2826         |
# |    total_timesteps      | 270336       |
# | train/                  |              |
# |    approx_kl            | 0.0067772255 |
# |    clip_fraction        | 0.505        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -20.1        |
# |    explained_variance   | 0.87         |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.858       |
# |    n_updates            | 100          |
# |    policy_gradient_loss | 0.0186       |
# |    std                  | 1.05         |
# |    value_loss           | 0.716        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -59.4        |
# | time/                   |              |
# |    fps                  | 95           |
# |    iterations           | 12           |
# |    time_elapsed         | 3088         |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0031835574 |
# |    clip_fraction        | 0.283        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -20.1        |
# |    explained_variance   | 0.833        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.839       |
# |    n_updates            | 110          |
# |    policy_gradient_loss | 0.00441      |
# |    std                  | 1.05         |
# |    value_loss           | 0.615        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -58.7        |
# | time/                   |              |
# |    fps                  | 95           |
# |    iterations           | 13           |
# |    time_elapsed         | 3349         |
# |    total_timesteps      | 319488       |
# | train/                  |              |
# |    approx_kl            | 0.0048496868 |
# |    clip_fraction        | 0.36         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -20.1        |
# |    explained_variance   | 0.857        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.855       |
# |    n_updates            | 120          |
# |    policy_gradient_loss | 0.00814      |
# |    std                  | 1.06         |
# |    value_loss           | 0.476        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -57.4       |
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 14          |
# |    time_elapsed         | 3612        |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.006491363 |
# |    clip_fraction        | 0.355       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -20.1       |
# |    explained_variance   | 0.843       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.884      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.00846     |
# |    std                  | 1.07        |
# |    value_loss           | 0.462       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -54.7        |
# | time/                   |              |
# |    fps                  | 95           |
# |    iterations           | 15           |
# |    time_elapsed         | 3877         |
# |    total_timesteps      | 368640       |
# | train/                  |              |
# |    approx_kl            | 0.0107506765 |
# |    clip_fraction        | 0.39         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -20.1        |
# |    explained_variance   | 0.865        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.909       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | 0.0104       |
# |    std                  | 1.07         |
# |    value_loss           | 0.43         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -51.6       |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 16          |
# |    time_elapsed         | 4142        |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.009091035 |
# |    clip_fraction        | 0.331       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -20.1       |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.934      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00672     |
# |    std                  | 1.07        |
# |    value_loss           | 0.398       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.7       |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 17          |
# |    time_elapsed         | 4407        |
# |    total_timesteps      | 417792      |
# | train/                  |             |
# |    approx_kl            | 0.006285208 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -20.1       |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.928      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.0034      |
# |    std                  | 1.07        |
# |    value_loss           | 0.401       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -45.6      |
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 18         |
# |    time_elapsed         | 4674       |
# |    total_timesteps      | 442368     |
# | train/                  |            |
# |    approx_kl            | 0.00901378 |
# |    clip_fraction        | 0.31       |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -20.1      |
# |    explained_variance   | 0.889      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.937     |
# |    n_updates            | 170        |
# |    policy_gradient_loss | 0.00796    |
# |    std                  | 1.07       |
# |    value_loss           | 0.398      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -43         |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 19          |
# |    time_elapsed         | 4940        |
# |    total_timesteps      | 466944      |
# | train/                  |             |
# |    approx_kl            | 0.007890512 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -20.1       |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.9        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.0064      |
# |    std                  | 1.07        |
# |    value_loss           | 0.466       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -38.1        |
# | time/                   |              |
# |    fps                  | 94           |
# |    iterations           | 20           |
# |    time_elapsed         | 5210         |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0075547635 |
# |    clip_fraction        | 0.27         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -20.2        |
# |    explained_variance   | 0.906        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.952       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | 0.00269      |
# |    std                  | 1.06         |
# |    value_loss           | 0.406        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -31.5       |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 21          |
# |    time_elapsed         | 5477        |
# |    total_timesteps      | 516096      |
# | train/                  |             |
# |    approx_kl            | 0.008524523 |
# |    clip_fraction        | 0.386       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -20.4       |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.937      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.0065      |
# |    std                  | 1.06        |
# |    value_loss           | 0.546       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -27.5       |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 22          |
# |    time_elapsed         | 5743        |
# |    total_timesteps      | 540672      |
# | train/                  |             |
# |    approx_kl            | 0.010231955 |
# |    clip_fraction        | 0.37        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -20.2       |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.945      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.00407     |
# |    std                  | 1.05        |
# |    value_loss           | 0.452       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -19         |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 23          |
# |    time_elapsed         | 6012        |
# |    total_timesteps      | 565248      |
# | train/                  |             |
# |    approx_kl            | 0.008715256 |
# |    clip_fraction        | 0.409       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -20.4       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.936      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00759     |
# |    std                  | 1.04        |
# |    value_loss           | 0.612       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -15.2       |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 24          |
# |    time_elapsed         | 6280        |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.008147224 |
# |    clip_fraction        | 0.398       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -20.5       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.909      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.0042      |
# |    std                  | 1.04        |
# |    value_loss           | 0.715       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -5.01       |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 25          |
# |    time_elapsed         | 6549        |
# |    total_timesteps      | 614400      |
# | train/                  |             |
# |    approx_kl            | 0.011740486 |
# |    clip_fraction        | 0.487       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -20.5       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.883      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.00811     |
# |    std                  | 1.03        |
# |    value_loss           | 0.805       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 2.54        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 26          |
# |    time_elapsed         | 6817        |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.008666761 |
# |    clip_fraction        | 0.408       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -20.6       |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.911      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.00787     |
# |    std                  | 1.03        |
# |    value_loss           | 1.06        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 19.7        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 27          |
# |    time_elapsed         | 7090        |
# |    total_timesteps      | 663552      |
# | train/                  |             |
# |    approx_kl            | 0.011172139 |
# |    clip_fraction        | 0.423       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -20.7       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.892      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.00119     |
# |    std                  | 1.03        |
# |    value_loss           | 1.11        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 37.4        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 28          |
# |    time_elapsed         | 7361        |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.009158797 |
# |    clip_fraction        | 0.463       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -20.8       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.847      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.0119      |
# |    std                  | 1.02        |
# |    value_loss           | 1.52        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 55.8       |
# | time/                   |            |
# |    fps                  | 93         |
# |    iterations           | 29         |
# |    time_elapsed         | 7631       |
# |    total_timesteps      | 712704     |
# | train/                  |            |
# |    approx_kl            | 0.00880414 |
# |    clip_fraction        | 0.413      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -20.9      |
# |    explained_variance   | 0.915      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.748     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.00882    |
# |    std                  | 1.02       |
# |    value_loss           | 1.7        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 75.5        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 30          |
# |    time_elapsed         | 7904        |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.010690379 |
# |    clip_fraction        | 0.435       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -20.9       |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.781      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.0083      |
# |    std                  | 1.01        |
# |    value_loss           | 2.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 82.9        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 31          |
# |    time_elapsed         | 8176        |
# |    total_timesteps      | 761856      |
# | train/                  |             |
# |    approx_kl            | 0.008833627 |
# |    clip_fraction        | 0.417       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -20.9       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.755      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.00472     |
# |    std                  | 1.01        |
# |    value_loss           | 2.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 88          |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 32          |
# |    time_elapsed         | 8447        |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.011707389 |
# |    clip_fraction        | 0.478       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -21.1       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.683      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.0168      |
# |    std                  | 1           |
# |    value_loss           | 2.7         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 88.5        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 33          |
# |    time_elapsed         | 8718        |
# |    total_timesteps      | 811008      |
# | train/                  |             |
# |    approx_kl            | 0.009344111 |
# |    clip_fraction        | 0.453       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -21.2       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.737      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.0149      |
# |    std                  | 1           |
# |    value_loss           | 2.63        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 90.6         |
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 34           |
# |    time_elapsed         | 8991         |
# |    total_timesteps      | 835584       |
# | train/                  |              |
# |    approx_kl            | 0.0077247075 |
# |    clip_fraction        | 0.332        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -21.3        |
# |    explained_variance   | 0.948        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.776       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | 0.00331      |
# |    std                  | 0.998        |
# |    value_loss           | 2.62         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 110          |
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 35           |
# |    time_elapsed         | 9264         |
# |    total_timesteps      | 860160       |
# | train/                  |              |
# |    approx_kl            | 0.0072233914 |
# |    clip_fraction        | 0.362        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -21.4        |
# |    explained_variance   | 0.933        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.717       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | 0.00494      |
# |    std                  | 0.996        |
# |    value_loss           | 3.28         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 124          |
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 36           |
# |    time_elapsed         | 9537         |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0071037486 |
# |    clip_fraction        | 0.365        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -21.4        |
# |    explained_variance   | 0.928        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.601       |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.00816      |
# |    std                  | 0.993        |
# |    value_loss           | 3.58         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 143         |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 37          |
# |    time_elapsed         | 9809        |
# |    total_timesteps      | 909312      |
# | train/                  |             |
# |    approx_kl            | 0.009237257 |
# |    clip_fraction        | 0.43        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -21.5       |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.56       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00851     |
# |    std                  | 0.991       |
# |    value_loss           | 3.51        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 164         |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 38          |
# |    time_elapsed         | 10084       |
# |    total_timesteps      | 933888      |
# | train/                  |             |
# |    approx_kl            | 0.008146742 |
# |    clip_fraction        | 0.371       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -21.5       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.512      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00879     |
# |    std                  | 0.989       |
# |    value_loss           | 4.22        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 177          |
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 39           |
# |    time_elapsed         | 10359        |
# |    total_timesteps      | 958464       |
# | train/                  |              |
# |    approx_kl            | 0.0077131353 |
# |    clip_fraction        | 0.361        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -21.6        |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.489       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 0.00567      |
# |    std                  | 0.987        |
# |    value_loss           | 4.1          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 182        |
# | time/                   |            |
# |    fps                  | 92         |
# |    iterations           | 40         |
# |    time_elapsed         | 10636      |
# |    total_timesteps      | 983040     |
# | train/                  |            |
# |    approx_kl            | 0.00842448 |
# |    clip_fraction        | 0.411      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -21.7      |
# |    explained_variance   | 0.947      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.568     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.00859    |
# |    std                  | 0.985      |
# |    value_loss           | 3.94       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 188         |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 41          |
# |    time_elapsed         | 10920       |
# |    total_timesteps      | 1007616     |
# | train/                  |             |
# |    approx_kl            | 0.015571441 |
# |    clip_fraction        | 0.499       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -21.9       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.205      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.0223      |
# |    std                  | 0.982       |
# |    value_loss           | 5.31        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 198         |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 42          |
# |    time_elapsed         | 11202       |
# |    total_timesteps      | 1032192     |
# | train/                  |             |
# |    approx_kl            | 0.006797002 |
# |    clip_fraction        | 0.311       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -21.9       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.345      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.00347     |
# |    std                  | 0.981       |
# |    value_loss           | 4.23        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 207         |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 43          |
# |    time_elapsed         | 11466       |
# |    total_timesteps      | 1056768     |
# | train/                  |             |
# |    approx_kl            | 0.009117955 |
# |    clip_fraction        | 0.435       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -22         |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0254      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.0124      |
# |    std                  | 0.98        |
# |    value_loss           | 5.58        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 212         |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 44          |
# |    time_elapsed         | 11701       |
# |    total_timesteps      | 1081344     |
# | train/                  |             |
# |    approx_kl            | 0.010985167 |
# |    clip_fraction        | 0.427       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -22.1       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0908      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.0106      |
# |    std                  | 0.979       |
# |    value_loss           | 7.36        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 212         |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 45          |
# |    time_elapsed         | 11939       |
# |    total_timesteps      | 1105920     |
# | train/                  |             |
# |    approx_kl            | 0.010383216 |
# |    clip_fraction        | 0.418       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.196       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.012       |
# |    std                  | 0.978       |
# |    value_loss           | 7.02        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 214         |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 46          |
# |    time_elapsed         | 12160       |
# |    total_timesteps      | 1130496     |
# | train/                  |             |
# |    approx_kl            | 0.007049624 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.266       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00411     |
# |    std                  | 0.977       |
# |    value_loss           | 6.44        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 218        |
# | time/                   |            |
# |    fps                  | 93         |
# |    iterations           | 47         |
# |    time_elapsed         | 12379      |
# |    total_timesteps      | 1155072    |
# | train/                  |            |
# |    approx_kl            | 0.00825979 |
# |    clip_fraction        | 0.349      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -22.2      |
# |    explained_variance   | 0.957      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.279     |
# |    n_updates            | 460        |
# |    policy_gradient_loss | 0.00591    |
# |    std                  | 0.977      |
# |    value_loss           | 6.23       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 237         |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 48          |
# |    time_elapsed         | 12600       |
# |    total_timesteps      | 1179648     |
# | train/                  |             |
# |    approx_kl            | 0.008729145 |
# |    clip_fraction        | 0.353       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0642     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.0125      |
# |    std                  | 0.976       |
# |    value_loss           | 7.24        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 49          |
# |    time_elapsed         | 12802       |
# |    total_timesteps      | 1204224     |
# | train/                  |             |
# |    approx_kl            | 0.008803513 |
# |    clip_fraction        | 0.386       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -22.3       |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.264       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00914     |
# |    std                  | 0.975       |
# |    value_loss           | 7.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 261         |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 50          |
# |    time_elapsed         | 13005       |
# |    total_timesteps      | 1228800     |
# | train/                  |             |
# |    approx_kl            | 0.009432432 |
# |    clip_fraction        | 0.38        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.758       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.0125      |
# |    std                  | 0.974       |
# |    value_loss           | 8.33        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 259         |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 51          |
# |    time_elapsed         | 13208       |
# |    total_timesteps      | 1253376     |
# | train/                  |             |
# |    approx_kl            | 0.010667242 |
# |    clip_fraction        | 0.476       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.48        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.0149      |
# |    std                  | 0.973       |
# |    value_loss           | 7           |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 52          |
# |    time_elapsed         | 13410       |
# |    total_timesteps      | 1277952     |
# | train/                  |             |
# |    approx_kl            | 0.008081102 |
# |    clip_fraction        | 0.322       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.137      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.00446     |
# |    std                  | 0.973       |
# |    value_loss           | 7.97        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 53          |
# |    time_elapsed         | 13614       |
# |    total_timesteps      | 1302528     |
# | train/                  |             |
# |    approx_kl            | 0.008025098 |
# |    clip_fraction        | 0.368       |
# |    clip_range           | 0.1         |
# ...
# |    loss                 | 6.5         |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | 0.0169      |
# |    std                  | 0.96        |
# |    value_loss           | 32          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 983         |
# |    ep_rew_mean          | 798         |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 188         |
# |    time_elapsed         | 40485       |
# |    total_timesteps      | 4620288     |
# | train/                  |             |
# |    approx_kl            | 0.017338177 |
# |    clip_fraction        | 0.414       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -24.1       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 11.7        |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | 0.0176      |
# |    std                  | 0.96        |
# |    value_loss           | 40.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 989          |
# |    ep_rew_mean          | 811          |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 189          |
# |    time_elapsed         | 40683        |
# |    total_timesteps      | 4644864      |
# | train/                  |              |
# |    approx_kl            | 0.0109027475 |
# |    clip_fraction        | 0.325        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -24.2        |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 10.3         |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | 0.0128       |
# |    std                  | 0.96         |
# |    value_loss           | 39.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 992         |
# |    ep_rew_mean          | 794         |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 190         |
# |    time_elapsed         | 40882       |
# |    total_timesteps      | 4669440     |
# | train/                  |             |
# |    approx_kl            | 0.009615623 |
# |    clip_fraction        | 0.352       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -24.3       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 7.83        |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | 0.0155      |
# |    std                  | 0.96        |
# |    value_loss           | 27.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 991        |
# |    ep_rew_mean          | 790        |
# | time/                   |            |
# |    fps                  | 114        |
# |    iterations           | 191        |
# |    time_elapsed         | 41080      |
# |    total_timesteps      | 4694016    |
# | train/                  |            |
# |    approx_kl            | 0.01546654 |
# |    clip_fraction        | 0.381      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -24.2      |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 10.4       |
# |    n_updates            | 1900       |
# |    policy_gradient_loss | 0.0242     |
# |    std                  | 0.961      |
# |    value_loss           | 38.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 991         |
# |    ep_rew_mean          | 775         |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 192         |
# |    time_elapsed         | 41277       |
# |    total_timesteps      | 4718592     |
# | train/                  |             |
# |    approx_kl            | 0.014500079 |
# |    clip_fraction        | 0.349       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -24.2       |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 6.69        |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | 0.0146      |
# |    std                  | 0.961       |
# |    value_loss           | 38.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 988         |
# |    ep_rew_mean          | 771         |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 193         |
# |    time_elapsed         | 41474       |
# |    total_timesteps      | 4743168     |
# | train/                  |             |
# |    approx_kl            | 0.013986476 |
# |    clip_fraction        | 0.387       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -24.2       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 9.1         |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | 0.0165      |
# |    std                  | 0.961       |
# |    value_loss           | 42.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 980         |
# |    ep_rew_mean          | 764         |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 194         |
# |    time_elapsed         | 41671       |
# |    total_timesteps      | 4767744     |
# | train/                  |             |
# |    approx_kl            | 0.012562868 |
# |    clip_fraction        | 0.346       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -24.2       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 9.48        |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | 0.0125      |
# |    std                  | 0.961       |
# |    value_loss           | 39.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 981        |
# |    ep_rew_mean          | 781        |
# | time/                   |            |
# |    fps                  | 114        |
# |    iterations           | 195        |
# |    time_elapsed         | 41869      |
# |    total_timesteps      | 4792320    |
# | train/                  |            |
# |    approx_kl            | 0.01267944 |
# |    clip_fraction        | 0.38       |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -24.2      |
# |    explained_variance   | 0.959      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 12.1       |
# |    n_updates            | 1940       |
# |    policy_gradient_loss | 0.0242     |
# |    std                  | 0.961      |
# |    value_loss           | 37.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 983         |
# |    ep_rew_mean          | 784         |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 196         |
# |    time_elapsed         | 42068       |
# |    total_timesteps      | 4816896     |
# | train/                  |             |
# |    approx_kl            | 0.015649164 |
# |    clip_fraction        | 0.405       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -24.3       |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 14.1        |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | 0.0203      |
# |    std                  | 0.961       |
# |    value_loss           | 46.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 987         |
# |    ep_rew_mean          | 781         |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 197         |
# |    time_elapsed         | 42266       |
# |    total_timesteps      | 4841472     |
# | train/                  |             |
# |    approx_kl            | 0.011043419 |
# |    clip_fraction        | 0.325       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -24.3       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 12.2        |
# |    n_updates            | 1960        |
# |    policy_gradient_loss | 0.0127      |
# |    std                  | 0.961       |
# |    value_loss           | 43.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 995         |
# |    ep_rew_mean          | 776         |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 198         |
# |    time_elapsed         | 42463       |
# |    total_timesteps      | 4866048     |
# | train/                  |             |
# |    approx_kl            | 0.010147306 |
# |    clip_fraction        | 0.339       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -24.3       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 14.3        |
# |    n_updates            | 1970        |
# |    policy_gradient_loss | 0.0135      |
# |    std                  | 0.961       |
# |    value_loss           | 40.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 996         |
# |    ep_rew_mean          | 757         |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 199         |
# |    time_elapsed         | 42661       |
# |    total_timesteps      | 4890624     |
# | train/                  |             |
# |    approx_kl            | 0.012487908 |
# |    clip_fraction        | 0.33        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -24.3       |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 15          |
# |    n_updates            | 1980        |
# |    policy_gradient_loss | 0.0111      |
# |    std                  | 0.961       |
# |    value_loss           | 45.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 995         |
# |    ep_rew_mean          | 773         |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 200         |
# |    time_elapsed         | 42858       |
# |    total_timesteps      | 4915200     |
# | train/                  |             |
# |    approx_kl            | 0.009914538 |
# |    clip_fraction        | 0.351       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -24.2       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 20.8        |
# |    n_updates            | 1990        |
# |    policy_gradient_loss | 0.0155      |
# |    std                  | 0.961       |
# |    value_loss           | 38.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 990         |
# |    ep_rew_mean          | 788         |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 201         |
# |    time_elapsed         | 43057       |
# |    total_timesteps      | 4939776     |
# | train/                  |             |
# |    approx_kl            | 0.009914037 |
# |    clip_fraction        | 0.345       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -24.3       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 9.65        |
# |    n_updates            | 2000        |
# |    policy_gradient_loss | 0.0159      |
# |    std                  | 0.961       |
# |    value_loss           | 35.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 990          |
# |    ep_rew_mean          | 807          |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 202          |
# |    time_elapsed         | 43254        |
# |    total_timesteps      | 4964352      |
# | train/                  |              |
# |    approx_kl            | 0.0094658565 |
# |    clip_fraction        | 0.331        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -24.3        |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 7.88         |
# |    n_updates            | 2010         |
# |    policy_gradient_loss | 0.0165       |
# |    std                  | 0.961        |
# |    value_loss           | 28.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 991         |
# |    ep_rew_mean          | 823         |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 203         |
# |    time_elapsed         | 43453       |
# |    total_timesteps      | 4988928     |
# | train/                  |             |
# |    approx_kl            | 0.009044463 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -24.3       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 6.94        |
# |    n_updates            | 2020        |
# |    policy_gradient_loss | 0.0123      |
# |    std                  | 0.961       |
# |    value_loss           | 32.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 992         |
# |    ep_rew_mean          | 821         |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 204         |
# |    time_elapsed         | 43650       |
# |    total_timesteps      | 5013504     |
# | train/                  |             |
# |    approx_kl            | 0.007902396 |
# |    clip_fraction        | 0.311       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -24.3       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 8.5         |
# |    n_updates            | 2030        |
# |    policy_gradient_loss | 0.0126      |
# |    std                  | 0.961       |
# |    value_loss           | 30.6        |
# -----------------------------------------

# %% [markdown]
# Visualize the agent

# %%
import numpy as np
import imageio
import tempfile
from IPython.display import Video, display

# Load the trained PPO agent
model = PPO.load("ppo_car_racing")

# Create evaluation env in rgb_array mode to capture frames
eval_env = gym.make("CarRacing-v3", render_mode="rgb_array")

frames = []

# Run one rollout
obs, info = eval_env.reset()
done = False
while not done:
    # For vector models, wrap obs into batch of size 1
    action, _ = model.predict(np.array(obs)[None, :], deterministic=True)
    obs, reward, terminated, truncated, info = eval_env.step(action[0])
    done = terminated or truncated

    # Get the rendered frame (RGB)
    frame = eval_env.render()
    if frame is not None:
        frames.append(frame)

eval_env.close()
print(f"Captured {len(frames)} frames.")

# Save captured frames to a temporary mp4 video
tmp_path = tempfile.NamedTemporaryFile(suffix=".mp4", delete=False).name
writer = imageio.get_writer(tmp_path, fps=30, codec="libx264")
for frame in frames:
    writer.append_data(frame)
writer.close()

# Display video inline
display(Video(tmp_path, embed=True))
# Out:
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Captured 762 frames.
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
