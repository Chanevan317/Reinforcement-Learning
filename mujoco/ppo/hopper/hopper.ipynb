# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.5.1
# CUDA available: True
# CUDA device count: 1
# GPU name: NVIDIA GeForce RTX 4080 SUPER

# %%
# Quick checks
import sys, platform
import torch
print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())
print("PyTorch:", torch.__version__, "| CUDA available:", torch.cuda.is_available())
import mujoco
print("MuJoCo package version:", mujoco.__version__)
# Out:
# Python: 3.10.19
# Platform: Windows-10-10.0.26200-SP0
# PyTorch: 2.5.1 | CUDA available: True
# MuJoCo package version: 3.4.0

# %%
# Imports
import os
import gymnasium as gym
import numpy as np
import torch
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecNormalize, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback
from stable_baselines3.common.evaluation import evaluate_policy

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Env setup
ENV_ID = "Hopper-v5"   # requires mujoco >= 2.3
n_envs = 4               # on Windows + single CPU, 4 is reasonable; reduce if CPU bound
seed = 0

# Make vectorized training envs
train_env = make_vec_env(
    ENV_ID,
    n_envs=n_envs,
    seed=seed,
    monitor_dir="./logs/train_monitor"
)

# VecNormalize (important for continuous control)
train_env = VecNormalize(train_env, norm_obs=True, norm_reward=True, clip_obs=10.0)

# eval env
eval_env = make_vec_env(
    ENV_ID,
    n_envs=1,
    seed=seed + 100,
    monitor_dir="./logs/eval_monitor"
)
eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

print("Obs space:", train_env.observation_space)
print("Act space:", train_env.action_space)
# Out:
# Obs space: Box(-inf, inf, (11,), float64)
# Act space: Box(-1.0, 1.0, (3,), float32)

# %%
# Create PPO
policy_kwargs = dict(net_arch=[dict(pi=[512,512], vf=[512,512])])

model = PPO(
    "MlpPolicy",
    train_env,
    verbose=1,
    device=device,
    n_steps=2048,
    batch_size=64,
    n_epochs=10,
    learning_rate=3e-4,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=1e-3,
    policy_kwargs=policy_kwargs,
)
# Out:
# Using cuda device

# %%
# Callbacks and save dirs
os.makedirs("./models", exist_ok=True)
os.makedirs("./checkpoints", exist_ok=True)
os.makedirs("./best_model", exist_ok=True)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./best_model/",
    log_path="./logs/eval",
    eval_freq=100_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False
)

checkpoint_callback = CheckpointCallback(save_freq=500_000, save_path="./checkpoints/", name_prefix="ppo_hopper")

# %%
# Train
TOTAL_TIMESTEPS = int(5e6)  # start with 5M; increase if you have time/resources
model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=[eval_callback, checkpoint_callback])
model.save("./models/ppo_hopper_final")
# save VecNormalize
train_env.save("./models/vecnormalize_train.pkl")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | 18       |
# | time/              |          |
# |    fps             | 1638     |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24          |
# |    ep_rew_mean          | 23.7        |
# | time/                   |             |
# |    fps                  | 949         |
# |    iterations           | 2           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013406093 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | -0.0435     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0346      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.976       |
# |    value_loss           | 0.33        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.5        |
# |    ep_rew_mean          | 47.9        |
# | time/                   |             |
# |    fps                  | 830         |
# |    iterations           | 3           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.017886557 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.48        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.171       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0283     |
# |    std                  | 0.957       |
# |    value_loss           | 0.373       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.3        |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 4           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.017432455 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | 0.368       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.19        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0281     |
# |    std                  | 0.945       |
# |    value_loss           | 0.506       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.2        |
# |    ep_rew_mean          | 135         |
# | time/                   |             |
# |    fps                  | 754         |
# |    iterations           | 5           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.014533994 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.217       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0198     |
# |    std                  | 0.93        |
# |    value_loss           | 0.42        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.4        |
# |    ep_rew_mean          | 147         |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 6           |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.013044229 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.119       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0179     |
# |    std                  | 0.92        |
# |    value_loss           | 0.314       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.5        |
# |    ep_rew_mean          | 198         |
# | time/                   |             |
# |    fps                  | 728         |
# |    iterations           | 7           |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.015793644 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.99       |
# |    explained_variance   | 0.453       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.107       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0219     |
# |    std                  | 0.915       |
# |    value_loss           | 0.263       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 107        |
# |    ep_rew_mean          | 233        |
# | time/                   |            |
# |    fps                  | 723        |
# |    iterations           | 8          |
# |    time_elapsed         | 90         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.01391794 |
# |    clip_fraction        | 0.181      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.99      |
# |    explained_variance   | 0.709      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.047      |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0173    |
# |    std                  | 0.914      |
# |    value_loss           | 0.113      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 112         |
# |    ep_rew_mean          | 247         |
# | time/                   |             |
# |    fps                  | 718         |
# |    iterations           | 9           |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.012525532 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.99       |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0108     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 0.914       |
# |    value_loss           | 0.054       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 113         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 716         |
# |    iterations           | 10          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011557385 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.99       |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.012      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.915       |
# |    value_loss           | 0.0316      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 116         |
# |    ep_rew_mean          | 261         |
# | time/                   |             |
# |    fps                  | 714         |
# |    iterations           | 11          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.013408637 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.97       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00631    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.906       |
# |    value_loss           | 0.0246      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 118        |
# |    ep_rew_mean          | 274        |
# | time/                   |            |
# |    fps                  | 709        |
# |    iterations           | 12         |
# |    time_elapsed         | 138        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.01645063 |
# |    clip_fraction        | 0.194      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.92      |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0383    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0168    |
# |    std                  | 0.889      |
# |    value_loss           | 0.0174     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 120         |
# |    ep_rew_mean          | 290         |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 13          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.016545998 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0234     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.877       |
# |    value_loss           | 0.0105      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 124         |
# |    ep_rew_mean          | 305         |
# | time/                   |             |
# |    fps                  | 677         |
# |    iterations           | 14          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.014351107 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.84       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0184     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0152     |
# |    std                  | 0.867       |
# |    value_loss           | 0.00822     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 124         |
# |    ep_rew_mean          | 316         |
# | time/                   |             |
# |    fps                  | 665         |
# |    iterations           | 15          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.015059342 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.79       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0327     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0145     |
# |    std                  | 0.852       |
# |    value_loss           | 0.00679     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 126         |
# |    ep_rew_mean          | 325         |
# | time/                   |             |
# |    fps                  | 654         |
# |    iterations           | 16          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.016100679 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.74       |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0393     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.839       |
# |    value_loss           | 0.019       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 128         |
# |    ep_rew_mean          | 335         |
# | time/                   |             |
# |    fps                  | 645         |
# |    iterations           | 17          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.012802375 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0416     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.831       |
# |    value_loss           | 0.00827     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | 344         |
# | time/                   |             |
# |    fps                  | 637         |
# |    iterations           | 18          |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.015781753 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.69       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.033      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0135     |
# |    std                  | 0.825       |
# |    value_loss           | 0.00527     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 132         |
# |    ep_rew_mean          | 352         |
# | time/                   |             |
# |    fps                  | 631         |
# |    iterations           | 19          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.017227624 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.65       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0255     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.813       |
# |    value_loss           | 0.0112      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 134       |
# |    ep_rew_mean          | 366       |
# | time/                   |           |
# |    fps                  | 626       |
# |    iterations           | 20        |
# |    time_elapsed         | 261       |
# |    total_timesteps      | 163840    |
# | train/                  |           |
# |    approx_kl            | 0.0168988 |
# |    clip_fraction        | 0.18      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.61     |
# |    explained_variance   | 0.976     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0404   |
# |    n_updates            | 190       |
# |    policy_gradient_loss | -0.0129   |
# |    std                  | 0.803     |
# |    value_loss           | 0.0107    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 138         |
# |    ep_rew_mean          | 379         |
# | time/                   |             |
# |    fps                  | 622         |
# |    iterations           | 21          |
# |    time_elapsed         | 276         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.018297292 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.56       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0162     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 0.789       |
# |    value_loss           | 0.00439     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 139         |
# |    ep_rew_mean          | 386         |
# | time/                   |             |
# |    fps                  | 617         |
# |    iterations           | 22          |
# |    time_elapsed         | 291         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.016866125 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.52       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0334     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.782       |
# |    value_loss           | 0.00216     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 139        |
# |    ep_rew_mean          | 390        |
# | time/                   |            |
# |    fps                  | 614        |
# |    iterations           | 23         |
# |    time_elapsed         | 306        |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.01745649 |
# |    clip_fraction        | 0.196      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.48      |
# |    explained_variance   | 0.984      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0134    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0123    |
# |    std                  | 0.769      |
# |    value_loss           | 0.00925    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 142         |
# |    ep_rew_mean          | 403         |
# | time/                   |             |
# |    fps                  | 611         |
# |    iterations           | 24          |
# |    time_elapsed         | 321         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.016874505 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.43       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0317     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00911    |
# |    std                  | 0.754       |
# |    value_loss           | 0.00905     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 144        |
# |    ep_rew_mean          | 407        |
# | time/                   |            |
# |    fps                  | 608        |
# |    iterations           | 25         |
# |    time_elapsed         | 336        |
# |    total_timesteps      | 204800     |
# | train/                  |            |
# |    approx_kl            | 0.01930236 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.38      |
# |    explained_variance   | 0.995      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0151    |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0118    |
# |    std                  | 0.746      |
# |    value_loss           | 0.00168    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | 411         |
# | time/                   |             |
# |    fps                  | 604         |
# |    iterations           | 26          |
# |    time_elapsed         | 352         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.018910756 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.35       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0624     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.74        |
# |    value_loss           | 0.000959    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 146         |
# |    ep_rew_mean          | 418         |
# | time/                   |             |
# |    fps                  | 602         |
# |    iterations           | 27          |
# |    time_elapsed         | 367         |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.018309224 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.3        |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0189     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.726       |
# |    value_loss           | 0.000834    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 425         |
# | time/                   |             |
# |    fps                  | 599         |
# |    iterations           | 28          |
# |    time_elapsed         | 382         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.019228209 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.25       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0206     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.714       |
# |    value_loss           | 0.000881    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 147         |
# |    ep_rew_mean          | 427         |
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 29          |
# |    time_elapsed         | 398         |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.020199277 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0297     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.699       |
# |    value_loss           | 0.000561    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 432         |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 30          |
# |    time_elapsed         | 413         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.020169755 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0127     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.695       |
# |    value_loss           | 0.000637    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 438         |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 31          |
# |    time_elapsed         | 428         |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.019545808 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.12       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0147     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.686       |
# |    value_loss           | 0.00065     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 442         |
# | time/                   |             |
# |    fps                  | 591         |
# |    iterations           | 32          |
# |    time_elapsed         | 443         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.019582264 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0254     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.667       |
# |    value_loss           | 0.000924    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 437         |
# | time/                   |             |
# |    fps                  | 589         |
# |    iterations           | 33          |
# |    time_elapsed         | 458         |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.020499267 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3          |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.021      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00881    |
# |    std                  | 0.657       |
# |    value_loss           | 0.00744     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 153        |
# |    ep_rew_mean          | 456        |
# | time/                   |            |
# |    fps                  | 588        |
# |    iterations           | 34         |
# |    time_elapsed         | 473        |
# |    total_timesteps      | 278528     |
# | train/                  |            |
# |    approx_kl            | 0.02201713 |
# |    clip_fraction        | 0.219      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.97      |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0228     |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.00728   |
# |    std                  | 0.651      |
# |    value_loss           | 0.0229     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | 474         |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 35          |
# |    time_elapsed         | 488         |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.020737123 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.94       |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0282     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00759    |
# |    std                  | 0.646       |
# |    value_loss           | 0.0036      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 156         |
# |    ep_rew_mean          | 470         |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 36          |
# |    time_elapsed         | 504         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.022034392 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0401     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00925    |
# |    std                  | 0.636       |
# |    value_loss           | 0.00162     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 156         |
# |    ep_rew_mean          | 474         |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 37          |
# |    time_elapsed         | 519         |
# |    total_timesteps      | 303104      |
# | train/                  |             |
# |    approx_kl            | 0.023409165 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0121     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0094     |
# |    std                  | 0.627       |
# |    value_loss           | 0.00736     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 160        |
# |    ep_rew_mean          | 487        |
# | time/                   |            |
# |    fps                  | 582        |
# |    iterations           | 38         |
# |    time_elapsed         | 534        |
# |    total_timesteps      | 311296     |
# | train/                  |            |
# |    approx_kl            | 0.02353785 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.82      |
# |    explained_variance   | 0.985      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0144     |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.00624   |
# |    std                  | 0.62       |
# |    value_loss           | 0.00914    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 165         |
# |    ep_rew_mean          | 508         |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 39          |
# |    time_elapsed         | 549         |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.026439762 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0056     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 0.611       |
# |    value_loss           | 0.00181     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 169         |
# |    ep_rew_mean          | 521         |
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 40          |
# |    time_elapsed         | 564         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.025885474 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.055      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.602       |
# |    value_loss           | 0.00205     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 174         |
# |    ep_rew_mean          | 540         |
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 41          |
# |    time_elapsed         | 579         |
# |    total_timesteps      | 335872      |
# | train/                  |             |
# |    approx_kl            | 0.025011837 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0242      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00962    |
# |    std                  | 0.597       |
# |    value_loss           | 0.00806     |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 180      |
# |    ep_rew_mean          | 562      |
# | time/                   |          |
# |    fps                  | 578      |
# |    iterations           | 42       |
# |    time_elapsed         | 594      |
# |    total_timesteps      | 344064   |
# | train/                  |          |
# |    approx_kl            | 0.024471 |
# |    clip_fraction        | 0.249    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -2.66    |
# |    explained_variance   | 0.993    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0167  |
# |    n_updates            | 410      |
# |    policy_gradient_loss | -0.00888 |
# |    std                  | 0.589    |
# |    value_loss           | 0.00202  |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 186         |
# |    ep_rew_mean          | 585         |
# | time/                   |             |
# |    fps                  | 577         |
# |    iterations           | 43          |
# |    time_elapsed         | 609         |
# |    total_timesteps      | 352256      |
# | train/                  |             |
# |    approx_kl            | 0.025553735 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.63       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00655    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00966    |
# |    std                  | 0.585       |
# |    value_loss           | 0.00175     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 191         |
# |    ep_rew_mean          | 601         |
# | time/                   |             |
# |    fps                  | 576         |
# |    iterations           | 44          |
# |    time_elapsed         | 625         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.027444523 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0241     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0089     |
# |    std                  | 0.581       |
# |    value_loss           | 0.00216     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 193         |
# |    ep_rew_mean          | 608         |
# | time/                   |             |
# |    fps                  | 575         |
# |    iterations           | 45          |
# |    time_elapsed         | 640         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.026511353 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.61       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00749    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0085     |
# |    std                  | 0.582       |
# |    value_loss           | 0.00191     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 193         |
# |    ep_rew_mean          | 610         |
# | time/                   |             |
# |    fps                  | 575         |
# |    iterations           | 46          |
# |    time_elapsed         | 655         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.025017982 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.59       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00254    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00865    |
# |    std                  | 0.575       |
# |    value_loss           | 0.00128     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 194       |
# |    ep_rew_mean          | 617       |
# | time/                   |           |
# |    fps                  | 574       |
# |    iterations           | 47        |
# |    time_elapsed         | 669       |
# |    total_timesteps      | 385024    |
# | train/                  |           |
# |    approx_kl            | 0.0263496 |
# |    clip_fraction        | 0.265     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.58     |
# |    explained_variance   | 0.984     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0234   |
# |    n_updates            | 460       |
# |    policy_gradient_loss | -0.00833  |
# |    std                  | 0.575     |
# |    value_loss           | 0.0105    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 193         |
# |    ep_rew_mean          | 616         |
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 48          |
# |    time_elapsed         | 685         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.026487673 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0115     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00689    |
# |    std                  | 0.573       |
# |    value_loss           | 0.00253     |
# -----------------------------------------
# Eval num_timesteps=400000, episode_reward=627.01 +/- 1.63
# Episode length: 195.20 +/- 0.40
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 195         |
# |    mean_reward          | 627         |
# | time/                   |             |
# |    total_timesteps      | 400000      |
# | train/                  |             |
# |    approx_kl            | 0.027614128 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.56       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0471     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00952    |
# |    std                  | 0.572       |
# |    value_loss           | 0.0017      |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | 623      |
# | time/              |          |
# |    fps             | 572      |
# |    iterations      | 49       |
# |    time_elapsed    | 701      |
# |    total_timesteps | 401408   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | 630         |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 50          |
# |    time_elapsed         | 717         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.029850148 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.54       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0379     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0093     |
# |    std                  | 0.569       |
# |    value_loss           | 0.002       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 195        |
# |    ep_rew_mean          | 634        |
# | time/                   |            |
# |    fps                  | 570        |
# |    iterations           | 51         |
# |    time_elapsed         | 732        |
# |    total_timesteps      | 417792     |
# | train/                  |            |
# |    approx_kl            | 0.03089665 |
# |    clip_fraction        | 0.283      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.52      |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0587    |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.00916   |
# |    std                  | 0.563      |
# |    value_loss           | 0.00161    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 195         |
# |    ep_rew_mean          | 637         |
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 52          |
# |    time_elapsed         | 747         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.029121727 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.48       |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000362    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00907    |
# |    std                  | 0.555       |
# |    value_loss           | 0.00129     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | 635         |
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 53          |
# |    time_elapsed         | 762         |
# |    total_timesteps      | 434176      |
# | train/                  |             |
# |    approx_kl            | 0.031632353 |
# |    clip_fraction        | 0.293       |
# ...
# |    total_timesteps      | 4866048    |
# | train/                  |            |
# |    approx_kl            | 0.08240526 |
# |    clip_fraction        | 0.429      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.44      |
# |    explained_variance   | 0.97       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.000496   |
# |    n_updates            | 5930       |
# |    policy_gradient_loss | -0.00116   |
# |    std                  | 0.395      |
# |    value_loss           | 0.00917    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 391        |
# |    ep_rew_mean          | 1.54e+03   |
# | time/                   |            |
# |    fps                  | 555        |
# |    iterations           | 595        |
# |    time_elapsed         | 8768       |
# |    total_timesteps      | 4874240    |
# | train/                  |            |
# |    approx_kl            | 0.08003765 |
# |    clip_fraction        | 0.431      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.44      |
# |    explained_variance   | 0.986      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0276    |
# |    n_updates            | 5940       |
# |    policy_gradient_loss | -0.00109   |
# |    std                  | 0.394      |
# |    value_loss           | 0.00247    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 397        |
# |    ep_rew_mean          | 1.57e+03   |
# | time/                   |            |
# |    fps                  | 556        |
# |    iterations           | 596        |
# |    time_elapsed         | 8777       |
# |    total_timesteps      | 4882432    |
# | train/                  |            |
# |    approx_kl            | 0.08159279 |
# |    clip_fraction        | 0.412      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.46      |
# |    explained_variance   | 0.974      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0337    |
# |    n_updates            | 5950       |
# |    policy_gradient_loss | 0.00157    |
# |    std                  | 0.397      |
# |    value_loss           | 0.00507    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 402        |
# |    ep_rew_mean          | 1.59e+03   |
# | time/                   |            |
# |    fps                  | 556        |
# |    iterations           | 597        |
# |    time_elapsed         | 8787       |
# |    total_timesteps      | 4890624    |
# | train/                  |            |
# |    approx_kl            | 0.06821607 |
# |    clip_fraction        | 0.408      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.48      |
# |    explained_variance   | 0.981      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0347    |
# |    n_updates            | 5960       |
# |    policy_gradient_loss | 3.52e-05   |
# |    std                  | 0.403      |
# |    value_loss           | 0.00388    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 393        |
# |    ep_rew_mean          | 1.55e+03   |
# | time/                   |            |
# |    fps                  | 556        |
# |    iterations           | 598        |
# |    time_elapsed         | 8796       |
# |    total_timesteps      | 4898816    |
# | train/                  |            |
# |    approx_kl            | 0.07346256 |
# |    clip_fraction        | 0.419      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.49      |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0217    |
# |    n_updates            | 5970       |
# |    policy_gradient_loss | 9.39e-05   |
# |    std                  | 0.4        |
# |    value_loss           | 0.00723    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 370       |
# |    ep_rew_mean          | 1.46e+03  |
# | time/                   |           |
# |    fps                  | 557       |
# |    iterations           | 599       |
# |    time_elapsed         | 8806      |
# |    total_timesteps      | 4907008   |
# | train/                  |           |
# |    approx_kl            | 0.0713073 |
# |    clip_fraction        | 0.417     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.5      |
# |    explained_variance   | 0.951     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0023   |
# |    n_updates            | 5980      |
# |    policy_gradient_loss | 0.00397   |
# |    std                  | 0.404     |
# |    value_loss           | 0.00861   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 369         |
# |    ep_rew_mean          | 1.46e+03    |
# | time/                   |             |
# |    fps                  | 557         |
# |    iterations           | 600         |
# |    time_elapsed         | 8815        |
# |    total_timesteps      | 4915200     |
# | train/                  |             |
# |    approx_kl            | 0.076840505 |
# |    clip_fraction        | 0.433       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00806    |
# |    n_updates            | 5990        |
# |    policy_gradient_loss | -0.00301    |
# |    std                  | 0.407       |
# |    value_loss           | 0.00837     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 366        |
# |    ep_rew_mean          | 1.45e+03   |
# | time/                   |            |
# |    fps                  | 557        |
# |    iterations           | 601        |
# |    time_elapsed         | 8824       |
# |    total_timesteps      | 4923392    |
# | train/                  |            |
# |    approx_kl            | 0.07134074 |
# |    clip_fraction        | 0.405      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.54      |
# |    explained_variance   | 0.952      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00493   |
# |    n_updates            | 6000       |
# |    policy_gradient_loss | 0.00389    |
# |    std                  | 0.409      |
# |    value_loss           | 0.0126     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 375         |
# |    ep_rew_mean          | 1.48e+03    |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 602         |
# |    time_elapsed         | 8833        |
# |    total_timesteps      | 4931584     |
# | train/                  |             |
# |    approx_kl            | 0.070747524 |
# |    clip_fraction        | 0.414       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.035      |
# |    n_updates            | 6010        |
# |    policy_gradient_loss | 0.00423     |
# |    std                  | 0.412       |
# |    value_loss           | 0.006       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 377         |
# |    ep_rew_mean          | 1.49e+03    |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 603         |
# |    time_elapsed         | 8842        |
# |    total_timesteps      | 4939776     |
# | train/                  |             |
# |    approx_kl            | 0.071284965 |
# |    clip_fraction        | 0.406       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0361     |
# |    n_updates            | 6020        |
# |    policy_gradient_loss | -0.00256    |
# |    std                  | 0.413       |
# |    value_loss           | 0.0034      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 396         |
# |    ep_rew_mean          | 1.57e+03    |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 604         |
# |    time_elapsed         | 8851        |
# |    total_timesteps      | 4947968     |
# | train/                  |             |
# |    approx_kl            | 0.076485835 |
# |    clip_fraction        | 0.412       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0327     |
# |    n_updates            | 6030        |
# |    policy_gradient_loss | -0.00217    |
# |    std                  | 0.413       |
# |    value_loss           | 0.00173     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 371        |
# |    ep_rew_mean          | 1.47e+03   |
# | time/                   |            |
# |    fps                  | 559        |
# |    iterations           | 605        |
# |    time_elapsed         | 8860       |
# |    total_timesteps      | 4956160    |
# | train/                  |            |
# |    approx_kl            | 0.07687596 |
# |    clip_fraction        | 0.425      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.58      |
# |    explained_variance   | 0.987      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0199    |
# |    n_updates            | 6040       |
# |    policy_gradient_loss | -0.00262   |
# |    std                  | 0.413      |
# |    value_loss           | 0.00155    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 366        |
# |    ep_rew_mean          | 1.45e+03   |
# | time/                   |            |
# |    fps                  | 559        |
# |    iterations           | 606        |
# |    time_elapsed         | 8868       |
# |    total_timesteps      | 4964352    |
# | train/                  |            |
# |    approx_kl            | 0.07133343 |
# |    clip_fraction        | 0.42       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.59      |
# |    explained_variance   | 0.97       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00667    |
# |    n_updates            | 6050       |
# |    policy_gradient_loss | -0.00318   |
# |    std                  | 0.413      |
# |    value_loss           | 0.0125     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 370        |
# |    ep_rew_mean          | 1.46e+03   |
# | time/                   |            |
# |    fps                  | 560        |
# |    iterations           | 607        |
# |    time_elapsed         | 8877       |
# |    total_timesteps      | 4972544    |
# | train/                  |            |
# |    approx_kl            | 0.06793978 |
# |    clip_fraction        | 0.394      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.58      |
# |    explained_variance   | 0.989      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00133   |
# |    n_updates            | 6060       |
# |    policy_gradient_loss | -0.00153   |
# |    std                  | 0.413      |
# |    value_loss           | 0.00151    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 350        |
# |    ep_rew_mean          | 1.39e+03   |
# | time/                   |            |
# |    fps                  | 560        |
# |    iterations           | 608        |
# |    time_elapsed         | 8886       |
# |    total_timesteps      | 4980736    |
# | train/                  |            |
# |    approx_kl            | 0.06538312 |
# |    clip_fraction        | 0.399      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.57      |
# |    explained_variance   | 0.995      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0183    |
# |    n_updates            | 6070       |
# |    policy_gradient_loss | 0.00365    |
# |    std                  | 0.41       |
# |    value_loss           | 0.00108    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 360        |
# |    ep_rew_mean          | 1.43e+03   |
# | time/                   |            |
# |    fps                  | 560        |
# |    iterations           | 609        |
# |    time_elapsed         | 8895       |
# |    total_timesteps      | 4988928    |
# | train/                  |            |
# |    approx_kl            | 0.06906273 |
# |    clip_fraction        | 0.411      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.54      |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0465     |
# |    n_updates            | 6080       |
# |    policy_gradient_loss | -0.00201   |
# |    std                  | 0.406      |
# |    value_loss           | 0.00089    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 361        |
# |    ep_rew_mean          | 1.43e+03   |
# | time/                   |            |
# |    fps                  | 561        |
# |    iterations           | 610        |
# |    time_elapsed         | 8904       |
# |    total_timesteps      | 4997120    |
# | train/                  |            |
# |    approx_kl            | 0.07051855 |
# |    clip_fraction        | 0.409      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.52      |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00967   |
# |    n_updates            | 6090       |
# |    policy_gradient_loss | -0.00292   |
# |    std                  | 0.405      |
# |    value_loss           | 0.00783    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 379        |
# |    ep_rew_mean          | 1.5e+03    |
# | time/                   |            |
# |    fps                  | 561        |
# |    iterations           | 611        |
# |    time_elapsed         | 8913       |
# |    total_timesteps      | 5005312    |
# | train/                  |            |
# |    approx_kl            | 0.07409677 |
# |    clip_fraction        | 0.415      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.49      |
# |    explained_variance   | 0.992      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0207    |
# |    n_updates            | 6100       |
# |    policy_gradient_loss | -0.00303   |
# |    std                  | 0.4        |
# |    value_loss           | 0.00139    |
# ----------------------------------------

# %%
# Load model and evaluate
model = PPO.load("./models/ppo_hopper_final", device=device)

venv = make_vec_env(ENV_ID, n_envs=1, seed=42)
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

mean_reward, std_reward = evaluate_policy(model, venv, n_eval_episodes=10, deterministic=True)
print(f"Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Mean reward: 1739.56 +/- 832.14

# %%
import os
os.environ["MUJOCO_GL"] = "glfw"

import gymnasium as gym
import imageio
import numpy as np
from IPython.display import Video, display
import tempfile

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

ENV_ID = "Hopper-v5"
N_EVAL_EPISODES = 10
MAX_STEPS = 1500
FPS = 30

# create env
env = gym.make(ENV_ID, render_mode="rgb_array")
venv = DummyVecEnv([lambda: env])
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

# load model
# model = PPO.load("./models/ppo_humanoid_final", device="cpu")
model = PPO.load("./best_model/best_model", device="cpu")

best_frames = []
best_length = 0

for ep in range(N_EVAL_EPISODES):
    obs = venv.reset()
    frames = []

    for step in range(MAX_STEPS):
        action, _ = model.predict(obs, deterministic=True)
        obs, rewards, dones, infos = venv.step(action)

        frame = env.render()
        if frame is not None:
            frames.append(frame)

        if dones[0]:
            break

    ep_length = len(frames)
    print(f"Episode {ep+1}: {ep_length} frames")

    if ep_length > best_length:
        best_length = ep_length
        best_frames = frames

print(f"\nLongest episode length: {best_length} frames")

# save and display only the longest episode
tmp = tempfile.NamedTemporaryFile(suffix=".mp4", delete=False).name
writer = imageio.get_writer(tmp, fps=FPS, codec="libx264")
for f in best_frames:
    writer.append_data(f)
writer.close()

display(Video(tmp, embed=True))
# Out:
# Episode 1: 231 frames
# Episode 2: 233 frames
# Episode 3: 291 frames
# Episode 4: 267 frames
# Episode 5: 217 frames
# Episode 6: 259 frames
# Episode 7: 212 frames
# Episode 8: 245 frames
# Episode 9: 259 frames
# Episode 10: 231 frames
#
# Longest episode length: 291 frames
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
