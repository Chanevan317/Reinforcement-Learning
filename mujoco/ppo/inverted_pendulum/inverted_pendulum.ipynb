# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.5.1
# CUDA available: True
# CUDA device count: 1
# GPU name: NVIDIA GeForce RTX 4080 SUPER

# %%
# Quick checks
import sys, platform
import torch
print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())
print("PyTorch:", torch.__version__, "| CUDA available:", torch.cuda.is_available())
import mujoco
print("MuJoCo package version:", mujoco.__version__)
# Out:
# Python: 3.10.19
# Platform: Windows-10-10.0.26200-SP0
# PyTorch: 2.5.1 | CUDA available: True
# MuJoCo package version: 3.4.0

# %%
# Imports
import os
import gymnasium as gym
import numpy as np
import torch
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecNormalize, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback
from stable_baselines3.common.evaluation import evaluate_policy

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Env setup
ENV_ID = "InvertedPendulum-v5"   # requires mujoco >= 2.3
n_envs = 4               # on Windows + single CPU, 4 is reasonable; reduce if CPU bound
seed = 0

# Make vectorized training envs
train_env = make_vec_env(
    ENV_ID,
    n_envs=n_envs,
    seed=seed,
    monitor_dir="./logs/train_monitor"
)

# VecNormalize (important for continuous control)
train_env = VecNormalize(train_env, norm_obs=True, norm_reward=True, clip_obs=10.0)

# eval env
eval_env = make_vec_env(
    ENV_ID,
    n_envs=1,
    seed=seed + 100,
    monitor_dir="./logs/eval_monitor"
)
eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

print("Obs space:", train_env.observation_space)
print("Act space:", train_env.action_space)
# Out:
# Obs space: Box(-inf, inf, (4,), float64)
# Act space: Box(-3.0, 3.0, (1,), float32)

# %%
# Create PPO
policy_kwargs = dict(net_arch=[dict(pi=[64, 64], vf=[64, 64])])

model = PPO(
    "MlpPolicy",
    train_env,
    n_steps=1024,
    batch_size=64,
    n_epochs=10,
    learning_rate=3e-4,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=0.0,
    policy_kwargs=policy_kwargs,
    device=device,
    verbose=1,
)
# Out:
# Using cuda device
# c:\Users\User\miniconda3\envs\env_rl\lib\site-packages\stable_baselines3\common\policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# c:\Users\User\miniconda3\envs\env_rl\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
# Callbacks and save dirs
os.makedirs("./models", exist_ok=True)
os.makedirs("./checkpoints", exist_ok=True)
os.makedirs("./best_model", exist_ok=True)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./best_model/",
    log_path="./logs/eval",
    eval_freq=100_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False
)

checkpoint_callback = CheckpointCallback(save_freq=500_000, save_path="./checkpoints/", name_prefix="ppo_inverted_pendulum")

# %%
# Train
TOTAL_TIMESTEPS = int(5e5)
model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=[eval_callback, checkpoint_callback])
model.save("./models/ppo_inverted_pendulum_final")
# save VecNormalize
train_env.save("./models/vecnormalize_train.pkl")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.89     |
# |    ep_rew_mean     | 6.89     |
# | time/              |          |
# |    fps             | 1834     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 4096     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.5        |
# |    ep_rew_mean          | 10.5        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.021736618 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.457      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.192       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0259     |
# |    std                  | 0.926       |
# |    value_loss           | 0.754       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 20.6      |
# |    ep_rew_mean          | 19.6      |
# | time/                   |           |
# |    fps                  | 814       |
# |    iterations           | 3         |
# |    time_elapsed         | 15        |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 0.0290104 |
# |    clip_fraction        | 0.294     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.29     |
# |    explained_variance   | 0.269     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.281     |
# |    n_updates            | 20        |
# |    policy_gradient_loss | -0.0439   |
# |    std                  | 0.854     |
# |    value_loss           | 0.671     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.7        |
# |    ep_rew_mean          | 36.7        |
# | time/                   |             |
# |    fps                  | 728         |
# |    iterations           | 4           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.023546886 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.275       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0365     |
# |    std                  | 0.792       |
# |    value_loss           | 0.799       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.2        |
# |    ep_rew_mean          | 47.2        |
# | time/                   |             |
# |    fps                  | 683         |
# |    iterations           | 5           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.016681526 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.301       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.314       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0242     |
# |    std                  | 0.737       |
# |    value_loss           | 0.611       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 72.3        |
# |    ep_rew_mean          | 71.3        |
# | time/                   |             |
# |    fps                  | 629         |
# |    iterations           | 6           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013584368 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.559       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.135       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0201     |
# |    std                  | 0.706       |
# |    value_loss           | 0.351       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.8        |
# |    ep_rew_mean          | 95.8        |
# | time/                   |             |
# |    fps                  | 597         |
# |    iterations           | 7           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.010450948 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0609      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0161     |
# |    std                  | 0.699       |
# |    value_loss           | 0.146       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 126         |
# |    ep_rew_mean          | 125         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 8           |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010587107 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0247      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0171     |
# |    std                  | 0.685       |
# |    value_loss           | 0.0826      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 159         |
# |    ep_rew_mean          | 158         |
# | time/                   |             |
# |    fps                  | 527         |
# |    iterations           | 9           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.011660635 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0595      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 0.657       |
# |    value_loss           | 0.0936      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 198          |
# |    ep_rew_mean          | 197          |
# | time/                   |              |
# |    fps                  | 497          |
# |    iterations           | 10           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0095018875 |
# |    clip_fraction        | 0.0896       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.965       |
# |    explained_variance   | 0.132        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00955     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0116      |
# |    std                  | 0.625        |
# |    value_loss           | 0.0267       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 235         |
# |    ep_rew_mean          | 234         |
# | time/                   |             |
# |    fps                  | 474         |
# |    iterations           | 11          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009734305 |
# |    clip_fraction        | 0.079       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.905      |
# |    explained_variance   | -0.58       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0052      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.584       |
# |    value_loss           | 0.00146     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 273         |
# |    ep_rew_mean          | 272         |
# | time/                   |             |
# |    fps                  | 455         |
# |    iterations           | 12          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008970063 |
# |    clip_fraction        | 0.0763      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.848      |
# |    explained_variance   | 0.144       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0182     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00826    |
# |    std                  | 0.555       |
# |    value_loss           | 0.000506    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 311         |
# |    ep_rew_mean          | 310         |
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 13          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009052553 |
# |    clip_fraction        | 0.068       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.804      |
# |    explained_variance   | -0.402      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00418     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00727    |
# |    std                  | 0.531       |
# |    value_loss           | 0.000254    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 359          |
# |    ep_rew_mean          | 358          |
# | time/                   |              |
# |    fps                  | 429          |
# |    iterations           | 14           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0074851997 |
# |    clip_fraction        | 0.0774       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.76        |
# |    explained_variance   | -0.509       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000911    |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00557     |
# |    std                  | 0.51         |
# |    value_loss           | 0.000183     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 396        |
# |    ep_rew_mean          | 396        |
# | time/                   |            |
# |    fps                  | 421        |
# |    iterations           | 15         |
# |    time_elapsed         | 145        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.00893995 |
# |    clip_fraction        | 0.0494     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.711     |
# |    explained_variance   | -0.571     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.92e-05   |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.00372   |
# |    std                  | 0.482      |
# |    value_loss           | 0.000131   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 434         |
# |    ep_rew_mean          | 433         |
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 16          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.005099023 |
# |    clip_fraction        | 0.0379      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | -0.469      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00331    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00155    |
# |    std                  | 0.462       |
# |    value_loss           | 7.76e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 470          |
# |    ep_rew_mean          | 469          |
# | time/                   |              |
# |    fps                  | 404          |
# |    iterations           | 17           |
# |    time_elapsed         | 171          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0042053023 |
# |    clip_fraction        | 0.0467       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.639       |
# |    explained_variance   | -0.206       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00531      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000212    |
# |    std                  | 0.457        |
# |    value_loss           | 4.71e-05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 506        |
# |    ep_rew_mean          | 505        |
# | time/                   |            |
# |    fps                  | 400        |
# |    iterations           | 18         |
# |    time_elapsed         | 184        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.00497235 |
# |    clip_fraction        | 0.0423     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.612     |
# |    explained_variance   | -0.432     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0208    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0011    |
# |    std                  | 0.44       |
# |    value_loss           | 4.17e-05   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 543          |
# |    ep_rew_mean          | 542          |
# | time/                   |              |
# |    fps                  | 395          |
# |    iterations           | 19           |
# |    time_elapsed         | 196          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0058781323 |
# |    clip_fraction        | 0.0618       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.585       |
# |    explained_variance   | -0.839       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0061      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00147     |
# |    std                  | 0.431        |
# |    value_loss           | 2.66e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 579          |
# |    ep_rew_mean          | 578          |
# | time/                   |              |
# |    fps                  | 390          |
# |    iterations           | 20           |
# |    time_elapsed         | 209          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0068804026 |
# |    clip_fraction        | 0.0528       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.557       |
# |    explained_variance   | -0.874       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3e-05        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00277     |
# |    std                  | 0.417        |
# |    value_loss           | 1.62e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 616         |
# |    ep_rew_mean          | 616         |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 21          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.004883918 |
# |    clip_fraction        | 0.044       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.531      |
# |    explained_variance   | -1.05       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0153      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00102    |
# |    std                  | 0.407       |
# |    value_loss           | 1.38e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 652         |
# |    ep_rew_mean          | 651         |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 22          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.004393137 |
# |    clip_fraction        | 0.0411      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.505      |
# |    explained_variance   | -2.2        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00514     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.000417    |
# |    std                  | 0.399       |
# |    value_loss           | 0.000104    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 688          |
# |    ep_rew_mean          | 687          |
# | time/                   |              |
# |    fps                  | 379          |
# |    iterations           | 23           |
# |    time_elapsed         | 247          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0054687755 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.476       |
# |    explained_variance   | -1.59        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.021        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00138     |
# |    std                  | 0.382        |
# |    value_loss           | 6.37e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 723          |
# |    ep_rew_mean          | 723          |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 24           |
# |    time_elapsed         | 260          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0054267426 |
# |    clip_fraction        | 0.064        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.449       |
# |    explained_variance   | -1.66        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0102       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00201     |
# |    std                  | 0.378        |
# |    value_loss           | 2.12e-05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 759        |
# |    ep_rew_mean          | 758        |
# | time/                   |            |
# |    fps                  | 373        |
# |    iterations           | 25         |
# |    time_elapsed         | 274        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.00533762 |
# |    clip_fraction        | 0.081      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.441     |
# |    explained_variance   | -0.58      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00613    |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.00147   |
# |    std                  | 0.375      |
# |    value_loss           | 9.12e-06   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 791          |
# |    ep_rew_mean          | 791          |
# | time/                   |              |
# |    fps                  | 371          |
# |    iterations           | 26           |
# |    time_elapsed         | 286          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0043837363 |
# |    clip_fraction        | 0.058        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.431       |
# |    explained_variance   | -1.26        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00117     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000621    |
# |    std                  | 0.371        |
# |    value_loss           | 2.72e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 827         |
# |    ep_rew_mean          | 827         |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 27          |
# |    time_elapsed         | 299         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.004426371 |
# |    clip_fraction        | 0.0579      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.417      |
# |    explained_variance   | -1.7        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0233     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00105    |
# |    std                  | 0.365       |
# |    value_loss           | 2.13e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 857          |
# |    ep_rew_mean          | 857          |
# | time/                   |              |
# |    fps                  | 367          |
# |    iterations           | 28           |
# |    time_elapsed         | 312          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0075295703 |
# |    clip_fraction        | 0.0549       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.419       |
# |    explained_variance   | -0.332       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0352       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | 0.000588     |
# |    std                  | 0.369        |
# |    value_loss           | 1.1e-05      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 891         |
# |    ep_rew_mean          | 891         |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 29          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.006561743 |
# |    clip_fraction        | 0.0603      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.421      |
# |    explained_variance   | -0.963      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0162     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00112    |
# |    std                  | 0.369       |
# |    value_loss           | 2.46e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 925          |
# |    ep_rew_mean          | 925          |
# | time/                   |              |
# |    fps                  | 364          |
# |    iterations           | 30           |
# |    time_elapsed         | 337          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0046080966 |
# |    clip_fraction        | 0.0545       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.42        |
# |    explained_variance   | -1.4         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0164      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0014      |
# |    std                  | 0.367        |
# |    value_loss           | 1.61e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 963          |
# |    ep_rew_mean          | 963          |
# | time/                   |              |
# |    fps                  | 362          |
# |    iterations           | 31           |
# |    time_elapsed         | 350          |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0041713538 |
# |    clip_fraction        | 0.0585       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.406       |
# |    explained_variance   | -0.85        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00663      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 0.000852     |
# |    std                  | 0.36         |
# |    value_loss           | 7.59e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 982          |
# |    ep_rew_mean          | 982          |
# | time/                   |              |
# |    fps                  | 361          |
# |    iterations           | 32           |
# |    time_elapsed         | 362          |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0049008303 |
# |    clip_fraction        | 0.0519       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.39        |
# |    explained_variance   | -0.509       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -3.32e-05    |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000859    |
# |    std                  | 0.355        |
# |    value_loss           | 2.32e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 33          |
# |    time_elapsed         | 376         |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.005262833 |
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.378      |
# |    explained_variance   | -0.436      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00827    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00241    |
# |    std                  | 0.352       |
# |    value_loss           | 2.39e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 1e+03        |
# | time/                   |              |
# |    fps                  | 358          |
# |    iterations           | 34           |
# |    time_elapsed         | 388          |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 0.0076950574 |
# |    clip_fraction        | 0.0842       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.367       |
# |    explained_variance   | -0.219       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00448      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000605    |
# |    std                  | 0.348        |
# |    value_loss           | 1.85e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 357         |
# |    iterations           | 35          |
# |    time_elapsed         | 401         |
# |    total_timesteps      | 143360      |
# | train/                  |             |
# |    approx_kl            | 0.003188929 |
# |    clip_fraction        | 0.0528      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.353      |
# |    explained_variance   | -0.232      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00636     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00098     |
# |    std                  | 0.342       |
# |    value_loss           | 6.16e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 36          |
# |    time_elapsed         | 414         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.012187883 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.348      |
# |    explained_variance   | -0.0698     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0104      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00555    |
# |    std                  | 0.343       |
# |    value_loss           | 2.47e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 355         |
# |    iterations           | 37          |
# |    time_elapsed         | 426         |
# |    total_timesteps      | 151552      |
# | train/                  |             |
# |    approx_kl            | 0.006809026 |
# |    clip_fraction        | 0.086       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.344      |
# |    explained_variance   | -0.168      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00496    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00191    |
# |    std                  | 0.341       |
# |    value_loss           | 3.3e-05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 1e+03        |
# | time/                   |              |
# |    fps                  | 353          |
# |    iterations           | 38           |
# |    time_elapsed         | 439          |
# |    total_timesteps      | 155648       |
# | train/                  |              |
# |    approx_kl            | 0.0075847963 |
# |    clip_fraction        | 0.0681       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.34        |
# |    explained_variance   | -0.239       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00425      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 0.000915     |
# |    std                  | 0.339        |
# |    value_loss           | 3.87e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 353         |
# |    iterations           | 39          |
# |    time_elapsed         | 452         |
# |    total_timesteps      | 159744      |
# | train/                  |             |
# |    approx_kl            | 0.004650605 |
# |    clip_fraction        | 0.0713      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.336      |
# |    explained_variance   | -0.387      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0234     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00224     |
# |    std                  | 0.338       |
# |    value_loss           | 1.68e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 1e+03        |
# | time/                   |              |
# |    fps                  | 352          |
# |    iterations           | 40           |
# |    time_elapsed         | 464          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0061669843 |
# |    clip_fraction        | 0.0743       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.333       |
# |    explained_variance   | -0.177       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0159      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000594    |
# |    std                  | 0.336        |
# |    value_loss           | 2.76e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 41          |
# |    time_elapsed         | 477         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.005184862 |
# |    clip_fraction        | 0.0783      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.333      |
# |    explained_variance   | -0.165      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00299    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 8.69e-05    |
# |    std                  | 0.339       |
# |    value_loss           | 4.21e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 1e+03        |
# | time/                   |              |
# |    fps                  | 350          |
# |    iterations           | 42           |
# |    time_elapsed         | 490          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0032012896 |
# |    clip_fraction        | 0.05         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.34        |
# |    explained_variance   | -0.478       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0123       |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.000832     |
# |    std                  | 0.34         |
# |    value_loss           | 2.23e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 350         |
# |    iterations           | 43          |
# |    time_elapsed         | 502         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.005538066 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.335      |
# |    explained_variance   | -0.666      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.046       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00044    |
# |    std                  | 0.339       |
# |    value_loss           | 4.03e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 1e+03        |
# | time/                   |              |
# |    fps                  | 349          |
# |    iterations           | 44           |
# |    time_elapsed         | 515          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0074551445 |
# |    clip_fraction        | 0.0427       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.333       |
# |    explained_variance   | -5.34        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0126      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | 0.00048      |
# |    std                  | 0.336        |
# |    value_loss           | 4.24e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 348         |
# |    iterations           | 45          |
# |    time_elapsed         | 528         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.011028615 |
# |    clip_fraction        | 0.0762      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.335      |
# |    explained_variance   | -0.0624     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0116     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.000996   |
# |    std                  | 0.34        |
# |    value_loss           | 3.24e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 1e+03        |
# | time/                   |              |
# |    fps                  | 348          |
# |    iterations           | 46           |
# |    time_elapsed         | 541          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0037641507 |
# |    clip_fraction        | 0.0419       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.33        |
# |    explained_variance   | -2.81        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0112      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 0.000494     |
# |    std                  | 0.334        |
# |    value_loss           | 3.47e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 1e+03        |
# | time/                   |              |
# |    fps                  | 347          |
# |    iterations           | 47           |
# |    time_elapsed         | 554          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0065508108 |
# |    clip_fraction        | 0.0698       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.341       |
# |    explained_variance   | -0.472       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0149       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | 0.000727     |
# |    std                  | 0.344        |
# |    value_loss           | 1.39e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 347         |
# |    iterations           | 48          |
# |    time_elapsed         | 566         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.004109964 |
# |    clip_fraction        | 0.051       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.345      |
# |    explained_variance   | -0.694      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0258     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.000347    |
# |    std                  | 0.34        |
# |    value_loss           | 2.02e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 49          |
# |    time_elapsed         | 579         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.005142214 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.339      |
# |    explained_variance   | -0.0649     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0049     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00148    |
# |    std                  | 0.34        |
# |    value_loss           | 3.86e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 345         |
# |    iterations           | 50          |
# |    time_elapsed         | 592         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.009791933 |
# |    clip_fraction        | 0.0915      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.345      |
# |    explained_variance   | 0.0507      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000634   |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00201    |
# |    std                  | 0.343       |
# |    value_loss           | 1.13e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 345         |
# |    iterations           | 51          |
# |    time_elapsed         | 604         |
# |    total_timesteps      | 208896      |
# | train/                  |             |
# |    approx_kl            | 0.004551419 |
# |    clip_fraction        | 0.0529      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.347      |
# |    explained_variance   | -0.873      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00127     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.00103     |
# |    std                  | 0.343       |
# |    value_loss           | 2.27e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 1e+03        |
# | time/                   |              |
# |    fps                  | 344          |
# |    iterations           | 52           |
# |    time_elapsed         | 617          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0062505067 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.34        |
# |    explained_variance   | 0.114        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00886     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00218     |
# |    std                  | 0.338        |
# |    value_loss           | 7.95e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# ...
# |    std                  | 0.28        |
# |    value_loss           | 8.88e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 1e+03        |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 107          |
# |    time_elapsed         | 1308         |
# |    total_timesteps      | 438272       |
# | train/                  |              |
# |    approx_kl            | 0.0073542045 |
# |    clip_fraction        | 0.0562       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.153       |
# |    explained_variance   | -2.59        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0188       |
# |    n_updates            | 1060         |
# |    policy_gradient_loss | 0.00108      |
# |    std                  | 0.283        |
# |    value_loss           | 1.07e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 108         |
# |    time_elapsed         | 1321        |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.004002826 |
# |    clip_fraction        | 0.0534      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.153      |
# |    explained_variance   | -10.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000976   |
# |    n_updates            | 1070        |
# |    policy_gradient_loss | 0.00163     |
# |    std                  | 0.283       |
# |    value_loss           | 1.41e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 109         |
# |    time_elapsed         | 1333        |
# |    total_timesteps      | 446464      |
# | train/                  |             |
# |    approx_kl            | 0.006194143 |
# |    clip_fraction        | 0.073       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.158      |
# |    explained_variance   | -1.5        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00258     |
# |    n_updates            | 1080        |
# |    policy_gradient_loss | -0.000204   |
# |    std                  | 0.283       |
# |    value_loss           | 7.56e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 110         |
# |    time_elapsed         | 1345        |
# |    total_timesteps      | 450560      |
# | train/                  |             |
# |    approx_kl            | 0.005221458 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.172      |
# |    explained_variance   | -13.4       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0142      |
# |    n_updates            | 1090        |
# |    policy_gradient_loss | 0.00108     |
# |    std                  | 0.291       |
# |    value_loss           | 3.24e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 111         |
# |    time_elapsed         | 1358        |
# |    total_timesteps      | 454656      |
# | train/                  |             |
# |    approx_kl            | 0.007843163 |
# |    clip_fraction        | 0.0815      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.18       |
# |    explained_variance   | -0.839      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000782   |
# |    n_updates            | 1100        |
# |    policy_gradient_loss | 0.000872    |
# |    std                  | 0.288       |
# |    value_loss           | 1.1e-05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 1e+03        |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 112          |
# |    time_elapsed         | 1371         |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0067014503 |
# |    clip_fraction        | 0.0747       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.158       |
# |    explained_variance   | -4           |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0136       |
# |    n_updates            | 1110         |
# |    policy_gradient_loss | 0.000183     |
# |    std                  | 0.282        |
# |    value_loss           | 5.14e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 113         |
# |    time_elapsed         | 1383        |
# |    total_timesteps      | 462848      |
# | train/                  |             |
# |    approx_kl            | 0.010069415 |
# |    clip_fraction        | 0.0963      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.146      |
# |    explained_variance   | -1.59       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00875    |
# |    n_updates            | 1120        |
# |    policy_gradient_loss | 5.33e-05    |
# |    std                  | 0.279       |
# |    value_loss           | 0.000101    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 114         |
# |    time_elapsed         | 1395        |
# |    total_timesteps      | 466944      |
# | train/                  |             |
# |    approx_kl            | 0.006688641 |
# |    clip_fraction        | 0.0769      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.132      |
# |    explained_variance   | -1.37       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0109      |
# |    n_updates            | 1130        |
# |    policy_gradient_loss | -3.75e-05   |
# |    std                  | 0.274       |
# |    value_loss           | 5.05e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 115         |
# |    time_elapsed         | 1408        |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.007276205 |
# |    clip_fraction        | 0.0879      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.111      |
# |    explained_variance   | -1.46       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00326     |
# |    n_updates            | 1140        |
# |    policy_gradient_loss | 0.000346    |
# |    std                  | 0.269       |
# |    value_loss           | 3.32e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 116         |
# |    time_elapsed         | 1419        |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.007765817 |
# |    clip_fraction        | 0.0946      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0934     |
# |    explained_variance   | -1.09       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00488    |
# |    n_updates            | 1150        |
# |    policy_gradient_loss | -0.000566   |
# |    std                  | 0.263       |
# |    value_loss           | 1.02e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 1e+03        |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 117          |
# |    time_elapsed         | 1432         |
# |    total_timesteps      | 479232       |
# | train/                  |              |
# |    approx_kl            | 0.0093064075 |
# |    clip_fraction        | 0.0899       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0781      |
# |    explained_variance   | -1.32        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00349     |
# |    n_updates            | 1160         |
# |    policy_gradient_loss | 0.00217      |
# |    std                  | 0.262        |
# |    value_loss           | 2.47e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 1e+03        |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 118          |
# |    time_elapsed         | 1444         |
# |    total_timesteps      | 483328       |
# | train/                  |              |
# |    approx_kl            | 0.0068188664 |
# |    clip_fraction        | 0.0929       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0633      |
# |    explained_variance   | -1.44        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00325      |
# |    n_updates            | 1170         |
# |    policy_gradient_loss | 0.001        |
# |    std                  | 0.256        |
# |    value_loss           | 5.67e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 119         |
# |    time_elapsed         | 1457        |
# |    total_timesteps      | 487424      |
# | train/                  |             |
# |    approx_kl            | 0.009922342 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0537     |
# |    explained_variance   | -0.839      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00995     |
# |    n_updates            | 1180        |
# |    policy_gradient_loss | 0.000795    |
# |    std                  | 0.256       |
# |    value_loss           | 2.01e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 120         |
# |    time_elapsed         | 1469        |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.005780442 |
# |    clip_fraction        | 0.0836      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0493     |
# |    explained_variance   | -7.56       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00811     |
# |    n_updates            | 1190        |
# |    policy_gradient_loss | 0.000724    |
# |    std                  | 0.252       |
# |    value_loss           | 1.38e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1e+03       |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 121         |
# |    time_elapsed         | 1482        |
# |    total_timesteps      | 495616      |
# | train/                  |             |
# |    approx_kl            | 0.005678783 |
# |    clip_fraction        | 0.0896      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0299     |
# |    explained_variance   | -4.5        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0116      |
# |    n_updates            | 1200        |
# |    policy_gradient_loss | 0.00143     |
# |    std                  | 0.248       |
# |    value_loss           | 3.89e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 1e+03        |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 122          |
# |    time_elapsed         | 1494         |
# |    total_timesteps      | 499712       |
# | train/                  |              |
# |    approx_kl            | 0.0120049175 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.00895      |
# |    explained_variance   | -4.88        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00301     |
# |    n_updates            | 1210         |
# |    policy_gradient_loss | 0.001        |
# |    std                  | 0.235        |
# |    value_loss           | 2.77e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 1e+03        |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 123          |
# |    time_elapsed         | 1506         |
# |    total_timesteps      | 503808       |
# | train/                  |              |
# |    approx_kl            | 0.0047999704 |
# |    clip_fraction        | 0.0964       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.028        |
# |    explained_variance   | -2.06        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00458     |
# |    n_updates            | 1220         |
# |    policy_gradient_loss | 0.00154      |
# |    std                  | 0.236        |
# |    value_loss           | 5.77e-06     |
# ------------------------------------------

# %%
# Load model and evaluate
model = PPO.load("./models/ppo_inverted_pendulum_final", device=device)

venv = make_vec_env(ENV_ID, n_envs=1, seed=42)
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

mean_reward, std_reward = evaluate_policy(model, venv, n_eval_episodes=10, deterministic=True)
print(f"Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Mean reward: 1000.00 +/- 0.00

# %%
# Visualize the agent
import os
os.environ["MUJOCO_GL"] = "glfw"

import gymnasium as gym
import imageio
import numpy as np
from IPython.display import Video, display
import tempfile

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

ENV_ID = "InvertedPendulum-v5"
N_EVAL_EPISODES = 10
MAX_STEPS = 1500
FPS = 30

# create env
env = gym.make(ENV_ID, render_mode="rgb_array")
venv = DummyVecEnv([lambda: env])
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

# load model
# model = PPO.load("./models/ppo_humanoid_final", device="cpu")
model = PPO.load("./best_model/best_model", device="cpu")

best_frames = []
best_length = 0

for ep in range(N_EVAL_EPISODES):
    obs = venv.reset()
    frames = []

    for step in range(MAX_STEPS):
        action, _ = model.predict(obs, deterministic=True)
        obs, rewards, dones, infos = venv.step(action)

        frame = env.render()
        if frame is not None:
            frames.append(frame)

        if dones[0]:
            break

    ep_length = len(frames)
    print(f"Episode {ep+1}: {ep_length} frames")

    if ep_length > best_length:
        best_length = ep_length
        best_frames = frames

print(f"\nLongest episode length: {best_length} frames")

# save and display only the longest episode
tmp = tempfile.NamedTemporaryFile(suffix=".mp4", delete=False).name
writer = imageio.get_writer(tmp, fps=FPS, codec="libx264")
for f in best_frames:
    writer.append_data(f)
writer.close()

display(Video(tmp, embed=True))
# Out:
# Episode 1: 1000 frames
# Episode 2: 1000 frames
# Episode 3: 1000 frames
# Episode 4: 1000 frames
# Episode 5: 1000 frames
# Episode 6: 1000 frames
# Episode 7: 1000 frames
# Episode 8: 1000 frames
# Episode 9: 1000 frames
# Episode 10: 1000 frames
#
# Longest episode length: 1000 frames
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
