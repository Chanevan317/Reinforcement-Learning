# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.5.1
# CUDA available: True
# CUDA device count: 1
# GPU name: NVIDIA GeForce RTX 4080 SUPER

# %%
# Quick checks
import sys, platform
import torch
print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())
print("PyTorch:", torch.__version__, "| CUDA available:", torch.cuda.is_available())
import mujoco
print("MuJoCo package version:", mujoco.__version__)
# Out:
# Python: 3.10.19
# Platform: Windows-10-10.0.26200-SP0
# PyTorch: 2.5.1 | CUDA available: True
# MuJoCo package version: 3.4.0

# %%
# Imports
import os
import gymnasium as gym
import numpy as np
import torch
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecNormalize, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback
from stable_baselines3.common.evaluation import evaluate_policy

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Env setup
ENV_ID = "Pusher-v5"   # requires mujoco >= 2.3
n_envs = 4               # on Windows + single CPU, 4 is reasonable; reduce if CPU bound
seed = 0

# Make vectorized training envs
train_env = make_vec_env(
    ENV_ID,
    n_envs=n_envs,
    seed=seed,
    monitor_dir="./logs/train_monitor"
)

# VecNormalize (important for continuous control)
train_env = VecNormalize(train_env, norm_obs=True, norm_reward=True, clip_obs=10.0)

# eval env
eval_env = make_vec_env(
    ENV_ID,
    n_envs=1,
    seed=seed + 100,
    monitor_dir="./logs/eval_monitor"
)
eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

print("Obs space:", train_env.observation_space)
print("Act space:", train_env.action_space)
# Out:
# Obs space: Box(-inf, inf, (23,), float64)
# Act space: Box(-2.0, 2.0, (7,), float32)

# %%
# Create PPO
policy_kwargs = dict(net_arch=[dict(pi=[512, 512], vf=[512, 512])])

model = PPO(
    "MlpPolicy",
    train_env,
    n_steps=4096,
    batch_size=256,
    n_epochs=20,
    learning_rate=1e-4,
    gamma=0.995,
    gae_lambda=0.97,
    clip_range=0.2,
    ent_coef=0.01,
    policy_kwargs=policy_kwargs,
    device=device,
    verbose=1,
)
# Out:
# Using cuda device
# c:\Users\User\miniconda3\envs\env_rl\lib\site-packages\stable_baselines3\common\policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# c:\Users\User\miniconda3\envs\env_rl\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
# Callbacks and save dirs
os.makedirs("./models", exist_ok=True)
os.makedirs("./checkpoints", exist_ok=True)
os.makedirs("./best_model", exist_ok=True)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./best_model/",
    log_path="./logs/eval",
    eval_freq=100_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False
)

checkpoint_callback = CheckpointCallback(save_freq=500_000, save_path="./checkpoints/", name_prefix="ppo_pusher")

# %%
# Train
TOTAL_TIMESTEPS = int(2e7)
model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=[eval_callback, checkpoint_callback])
model.save("./models/ppo_pusher_final")
# save VecNormalize
train_env.save("./models/vecnormalize_train.pkl")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -121     |
# | time/              |          |
# |    fps             | 1374     |
# |    iterations      | 1        |
# |    time_elapsed    | 11       |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 907         |
# |    iterations           | 2           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008224219 |
# |    clip_fraction        | 0.0971      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.91       |
# |    explained_variance   | -0.0485     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0493     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00727    |
# |    std                  | 0.996       |
# |    value_loss           | 0.391       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 729         |
# |    iterations           | 3           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007840039 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.88       |
# |    explained_variance   | 0.28        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0772     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.009      |
# |    std                  | 0.99        |
# |    value_loss           | 0.104       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 633         |
# |    iterations           | 4           |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009297308 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.82       |
# |    explained_variance   | 0.665       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0774     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0118     |
# |    std                  | 0.981       |
# |    value_loss           | 0.0684      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 5           |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010890035 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.76       |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0903     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 0.974       |
# |    value_loss           | 0.0566      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 6           |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011853592 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.71       |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.113      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0198     |
# |    std                  | 0.967       |
# |    value_loss           | 0.0502      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -111       |
# | time/                   |            |
# |    fps                  | 544        |
# |    iterations           | 7          |
# |    time_elapsed         | 210        |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.01249795 |
# |    clip_fraction        | 0.175      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.65      |
# |    explained_variance   | 0.913      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.102     |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0194    |
# |    std                  | 0.957      |
# |    value_loss           | 0.0422     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -111        |
# | time/                   |             |
# |    fps                  | 533         |
# |    iterations           | 8           |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.010269368 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.57       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0908     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.947       |
# |    value_loss           | 0.0336      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -111        |
# | time/                   |             |
# |    fps                  | 524         |
# |    iterations           | 9           |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.009533867 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.51       |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0897     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.939       |
# |    value_loss           | 0.0303      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 517         |
# |    iterations           | 10          |
# |    time_elapsed         | 316         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.009102572 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.43       |
# |    explained_variance   | 0.854       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0959     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.928       |
# |    value_loss           | 0.0259      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -108       |
# | time/                   |            |
# |    fps                  | 512        |
# |    iterations           | 11         |
# |    time_elapsed         | 351        |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.00996992 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.34      |
# |    explained_variance   | 0.888      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.103     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0145    |
# |    std                  | 0.915      |
# |    value_loss           | 0.0239     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 507         |
# |    iterations           | 12          |
# |    time_elapsed         | 387         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.011524536 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.25       |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.108      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0174     |
# |    std                  | 0.904       |
# |    value_loss           | 0.0223      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -102        |
# | time/                   |             |
# |    fps                  | 503         |
# |    iterations           | 13          |
# |    time_elapsed         | 423         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.011300623 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.16       |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.105      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0181     |
# |    std                  | 0.892       |
# |    value_loss           | 0.0216      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -99.7       |
# | time/                   |             |
# |    fps                  | 500         |
# |    iterations           | 14          |
# |    time_elapsed         | 458         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.011770492 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.04       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.112      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0182     |
# |    std                  | 0.877       |
# |    value_loss           | 0.0172      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -97.4       |
# | time/                   |             |
# |    fps                  | 497         |
# |    iterations           | 15          |
# |    time_elapsed         | 493         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.011897769 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.9        |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.103      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0175     |
# |    std                  | 0.858       |
# |    value_loss           | 0.0129      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -96.3       |
# | time/                   |             |
# |    fps                  | 495         |
# |    iterations           | 16          |
# |    time_elapsed         | 529         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.012523897 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.74       |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0912     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0175     |
# |    std                  | 0.839       |
# |    value_loss           | 0.0102      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -92.5       |
# | time/                   |             |
# |    fps                  | 493         |
# |    iterations           | 17          |
# |    time_elapsed         | 564         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.012662358 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.59       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.106      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0185     |
# |    std                  | 0.82        |
# |    value_loss           | 0.00809     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -90.8       |
# | time/                   |             |
# |    fps                  | 491         |
# |    iterations           | 18          |
# |    time_elapsed         | 600         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.013237416 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.4        |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.123      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0208     |
# |    std                  | 0.799       |
# |    value_loss           | 0.00671     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 100       |
# |    ep_rew_mean          | -87.9     |
# | time/                   |           |
# |    fps                  | 489       |
# |    iterations           | 19        |
# |    time_elapsed         | 635       |
# |    total_timesteps      | 311296    |
# | train/                  |           |
# |    approx_kl            | 0.0136225 |
# |    clip_fraction        | 0.162     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -8.21     |
# |    explained_variance   | 0.965     |
# |    learning_rate        | 0.0001    |
# |    loss                 | -0.121    |
# |    n_updates            | 360       |
# |    policy_gradient_loss | -0.0215   |
# |    std                  | 0.777     |
# |    value_loss           | 0.00519   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -85.9       |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 20          |
# |    time_elapsed         | 671         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.014515217 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.01       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.113      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0238     |
# |    std                  | 0.755       |
# |    value_loss           | 0.00434     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -82.3       |
# | time/                   |             |
# |    fps                  | 486         |
# |    iterations           | 21          |
# |    time_elapsed         | 707         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.014617775 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.81       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.116      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0246     |
# |    std                  | 0.734       |
# |    value_loss           | 0.00347     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -79.3       |
# | time/                   |             |
# |    fps                  | 485         |
# |    iterations           | 22          |
# |    time_elapsed         | 742         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.015525752 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.6        |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0953     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0269     |
# |    std                  | 0.712       |
# |    value_loss           | 0.00297     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -76.8       |
# | time/                   |             |
# |    fps                  | 484         |
# |    iterations           | 23          |
# |    time_elapsed         | 778         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.015798502 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.39       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.124      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0276     |
# |    std                  | 0.691       |
# |    value_loss           | 0.00241     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -74         |
# | time/                   |             |
# |    fps                  | 484         |
# |    iterations           | 24          |
# |    time_elapsed         | 812         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.015049201 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.2        |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.099      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0264     |
# |    std                  | 0.673       |
# |    value_loss           | 0.00245     |
# -----------------------------------------
# Eval num_timesteps=400000, episode_reward=-39.50 +/- 3.32
# Episode length: 100.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 100         |
# |    mean_reward          | -39.5       |
# | time/                   |             |
# |    total_timesteps      | 400000      |
# | train/                  |             |
# |    approx_kl            | 0.015869776 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.01       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.116      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0267     |
# |    std                  | 0.655       |
# |    value_loss           | 0.00247     |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -72.9    |
# | time/              |          |
# |    fps             | 482      |
# |    iterations      | 25       |
# |    time_elapsed    | 848      |
# |    total_timesteps | 409600   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -70.4       |
# | time/                   |             |
# |    fps                  | 482         |
# |    iterations           | 26          |
# |    time_elapsed         | 882         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.015535835 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.83       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.101      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0258     |
# |    std                  | 0.639       |
# |    value_loss           | 0.00238     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -69.5       |
# | time/                   |             |
# |    fps                  | 482         |
# |    iterations           | 27          |
# |    time_elapsed         | 917         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.016849693 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.64       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0981     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0277     |
# |    std                  | 0.621       |
# |    value_loss           | 0.00277     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -66.7       |
# | time/                   |             |
# |    fps                  | 481         |
# |    iterations           | 28          |
# |    time_elapsed         | 952         |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.015700657 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.47       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0955     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0265     |
# |    std                  | 0.607       |
# |    value_loss           | 0.00241     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -64.9      |
# | time/                   |            |
# |    fps                  | 481        |
# |    iterations           | 29         |
# |    time_elapsed         | 987        |
# |    total_timesteps      | 475136     |
# | train/                  |            |
# |    approx_kl            | 0.01472553 |
# |    clip_fraction        | 0.171      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.32      |
# |    explained_variance   | 0.981      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.103     |
# |    n_updates            | 560        |
# |    policy_gradient_loss | -0.0238    |
# |    std                  | 0.594      |
# |    value_loss           | 0.0029     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -63.9       |
# | time/                   |             |
# |    fps                  | 481         |
# |    iterations           | 30          |
# |    time_elapsed         | 1021        |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.015405934 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.17       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0914     |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0253     |
# |    std                  | 0.581       |
# |    value_loss           | 0.00287     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -61.6       |
# | time/                   |             |
# |    fps                  | 480         |
# |    iterations           | 31          |
# |    time_elapsed         | 1057        |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.015813187 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.02       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0847     |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0254     |
# |    std                  | 0.569       |
# |    value_loss           | 0.00377     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -60.1       |
# | time/                   |             |
# |    fps                  | 479         |
# |    iterations           | 32          |
# |    time_elapsed         | 1093        |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.015632696 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.88       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0872     |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.0248     |
# |    std                  | 0.558       |
# |    value_loss           | 0.00306     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -59.6       |
# | time/                   |             |
# |    fps                  | 479         |
# |    iterations           | 33          |
# |    time_elapsed         | 1127        |
# |    total_timesteps      | 540672      |
# | train/                  |             |
# |    approx_kl            | 0.016372515 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0938     |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.0247     |
# |    std                  | 0.547       |
# |    value_loss           | 0.00395     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -58.5       |
# | time/                   |             |
# |    fps                  | 478         |
# |    iterations           | 34          |
# |    time_elapsed         | 1163        |
# |    total_timesteps      | 557056      |
# | train/                  |             |
# |    approx_kl            | 0.016513087 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.61       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0853     |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.0246     |
# |    std                  | 0.537       |
# |    value_loss           | 0.00521     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -58.1       |
# | time/                   |             |
# |    fps                  | 478         |
# |    iterations           | 35          |
# |    time_elapsed         | 1198        |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.017016757 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.5        |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0807     |
# |    n_updates            | 680         |
# |    policy_gradient_loss | -0.025      |
# |    std                  | 0.529       |
# |    value_loss           | 0.00453     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -56.1       |
# | time/                   |             |
# |    fps                  | 478         |
# |    iterations           | 36          |
# |    time_elapsed         | 1233        |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.016180966 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.38       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.077      |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.0252     |
# |    std                  | 0.52        |
# |    value_loss           | 0.00455     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -56         |
# | time/                   |             |
# |    fps                  | 477         |
# |    iterations           | 37          |
# |    time_elapsed         | 1269        |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.016752481 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.27       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0659     |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.0228     |
# |    std                  | 0.512       |
# |    value_loss           | 0.00446     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -54.9      |
# | time/                   |            |
# |    fps                  | 477        |
# |    iterations           | 38         |
# |    time_elapsed         | 1304       |
# |    total_timesteps      | 622592     |
# | train/                  |            |
# |    approx_kl            | 0.01770394 |
# |    clip_fraction        | 0.219      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.17      |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0923    |
# |    n_updates            | 740        |
# |    policy_gradient_loss | -0.026     |
# |    std                  | 0.505      |
# |    value_loss           | 0.00612    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -54.2      |
# | time/                   |            |
# |    fps                  | 477        |
# |    iterations           | 39         |
# |    time_elapsed         | 1339       |
# |    total_timesteps      | 638976     |
# | train/                  |            |
# |    approx_kl            | 0.01640942 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.08      |
# |    explained_variance   | 0.969      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0818    |
# |    n_updates            | 760        |
# |    policy_gradient_loss | -0.0233    |
# |    std                  | 0.499      |
# |    value_loss           | 0.00552    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -54         |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 40          |
# |    time_elapsed         | 1374        |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.016453404 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.98       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0813     |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.0227     |
# |    std                  | 0.491       |
# |    value_loss           | 0.0053      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -53.7       |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 41          |
# |    time_elapsed         | 1409        |
# |    total_timesteps      | 671744      |
# | train/                  |             |
# |    approx_kl            | 0.016585695 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.89       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0676     |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.0241     |
# |    std                  | 0.485       |
# |    value_loss           | 0.00675     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -52.4       |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 42          |
# |    time_elapsed         | 1445        |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.016875787 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.82       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0771     |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.0236     |
# |    std                  | 0.48        |
# |    value_loss           | 0.00611     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -52.3       |
# | time/                   |             |
# |    fps                  | 475         |
# |    iterations           | 43          |
# |    time_elapsed         | 1480        |
# |    total_timesteps      | 704512      |
# | train/                  |             |
# |    approx_kl            | 0.016546752 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.74       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0831     |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0242     |
# |    std                  | 0.475       |
# |    value_loss           | 0.00603     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -51.5      |
# | time/                   |            |
# |    fps                  | 475        |
# |    iterations           | 44         |
# |    time_elapsed         | 1515       |
# |    total_timesteps      | 720896     |
# | train/                  |            |
# |    approx_kl            | 0.01691635 |
# |    clip_fraction        | 0.211      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.66      |
# |    explained_variance   | 0.974      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.078     |
# |    n_updates            | 860        |
# |    policy_gradient_loss | -0.0243    |
# |    std                  | 0.47       |
# |    value_loss           | 0.00496    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -51.1       |
# | time/                   |             |
# |    fps                  | 475         |
# |    iterations           | 45          |
# |    time_elapsed         | 1550        |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.017831095 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.57       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0723     |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0238     |
# |    std                  | 0.464       |
# |    value_loss           | 0.00695     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -50.4       |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 46          |
# |    time_elapsed         | 1580        |
# |    total_timesteps      | 753664      |
# | train/                  |             |
# |    approx_kl            | 0.015258717 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.49       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0916     |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0202     |
# |    std                  | 0.458       |
# |    value_loss           | 0.0072      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -49.2       |
# | time/                   |             |
# |    fps                  | 478         |
# |    iterations           | 47          |
# |    time_elapsed         | 1610        |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.015965417 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.42       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.062      |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 0.454       |
# |    value_loss           | 0.00498     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -50.3       |
# | time/                   |             |
# |    fps                  | 479         |
# |    iterations           | 48          |
# |    time_elapsed         | 1641        |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.016436044 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0806     |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0207     |
# |    std                  | 0.448       |
# |    value_loss           | 0.00696     |
# -----------------------------------------
# Eval num_timesteps=800000, episode_reward=-33.11 +/- 4.09
# Episode length: 100.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 100         |
# |    mean_reward          | -33.1       |
# | time/                   |             |
# |    total_timesteps      | 800000      |
# | train/                  |             |
# |    approx_kl            | 0.016127937 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0784     |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0201     |
# |    std                  | 0.443       |
# |    value_loss           | 0.00556     |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -49.3    |
# | time/              |          |
# |    fps             | 480      |
# |    iterations      | 49       |
# |    time_elapsed    | 1671     |
# |    total_timesteps | 802816   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -48.9       |
# | time/                   |             |
# |    fps                  | 481         |
# |    iterations           | 50          |
# |    time_elapsed         | 1702        |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.016242232 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0688     |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.0222     |
# |    std                  | 0.438       |
# |    value_loss           | 0.00515     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -48.2       |
# | time/                   |             |
# |    fps                  | 482         |
# |    iterations           | 51          |
# |    time_elapsed         | 1732        |
# |    total_timesteps      | 835584      |
# | train/                  |             |
# |    approx_kl            | 0.017333087 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.079      |
# |    n_updates            | 1000        |
# |    policy_gradient_loss | -0.0215     |
# |    std                  | 0.433       |
# |    value_loss           | 0.0063      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -48.3       |
# | time/                   |             |
# |    fps                  | 483         |
# |    iterations           | 52          |
# |    time_elapsed         | 1763        |
# |    total_timesteps      | 851968      |
# | train/                  |             |
# |    approx_kl            | 0.017982792 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0528     |
# |    n_updates            | 1020        |
# |    policy_gradient_loss | -0.0214     |
# |    std                  | 0.428       |
# |    value_loss           | 0.00439     |
# -----------------------------------------
# ----------------------------------------
# ...
# |    policy_gradient_loss | -0.029      |
# |    std                  | 0.21        |
# |    value_loss           | 0.00834     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -31.4      |
# | time/                   |            |
# |    fps                  | 916        |
# |    iterations           | 1205       |
# |    time_elapsed         | 21548      |
# |    total_timesteps      | 19742720   |
# | train/                  |            |
# |    approx_kl            | 0.04729682 |
# |    clip_fraction        | 0.414      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.01       |
# |    explained_variance   | 0.939      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0141    |
# |    n_updates            | 24080      |
# |    policy_gradient_loss | -0.0288    |
# |    std                  | 0.21       |
# |    value_loss           | 0.0267     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -31.9       |
# | time/                   |             |
# |    fps                  | 916         |
# |    iterations           | 1206        |
# |    time_elapsed         | 21561       |
# |    total_timesteps      | 19759104    |
# | train/                  |             |
# |    approx_kl            | 0.046832927 |
# |    clip_fraction        | 0.402       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.999       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0269     |
# |    n_updates            | 24100       |
# |    policy_gradient_loss | -0.0283     |
# |    std                  | 0.21        |
# |    value_loss           | 0.024       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -30.7      |
# | time/                   |            |
# |    fps                  | 916        |
# |    iterations           | 1207       |
# |    time_elapsed         | 21574      |
# |    total_timesteps      | 19775488   |
# | train/                  |            |
# |    approx_kl            | 0.04401404 |
# |    clip_fraction        | 0.389      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.01       |
# |    explained_variance   | 0.949      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.031     |
# |    n_updates            | 24120      |
# |    policy_gradient_loss | -0.0256    |
# |    std                  | 0.21       |
# |    value_loss           | 0.0124     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -31.3      |
# | time/                   |            |
# |    fps                  | 916        |
# |    iterations           | 1208       |
# |    time_elapsed         | 21588      |
# |    total_timesteps      | 19791872   |
# | train/                  |            |
# |    approx_kl            | 0.04307174 |
# |    clip_fraction        | 0.396      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.03       |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0225    |
# |    n_updates            | 24140      |
# |    policy_gradient_loss | -0.0293    |
# |    std                  | 0.209      |
# |    value_loss           | 0.00763    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -32        |
# | time/                   |            |
# |    fps                  | 916        |
# |    iterations           | 1209       |
# |    time_elapsed         | 21601      |
# |    total_timesteps      | 19808256   |
# | train/                  |            |
# |    approx_kl            | 0.05048866 |
# |    clip_fraction        | 0.398      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.02       |
# |    explained_variance   | 0.899      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0129    |
# |    n_updates            | 24160      |
# |    policy_gradient_loss | -0.0253    |
# |    std                  | 0.21       |
# |    value_loss           | 0.0562     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -31.7      |
# | time/                   |            |
# |    fps                  | 917        |
# |    iterations           | 1210       |
# |    time_elapsed         | 21615      |
# |    total_timesteps      | 19824640   |
# | train/                  |            |
# |    approx_kl            | 0.04772466 |
# |    clip_fraction        | 0.401      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.01       |
# |    explained_variance   | 0.917      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.00958   |
# |    n_updates            | 24180      |
# |    policy_gradient_loss | -0.0261    |
# |    std                  | 0.21       |
# |    value_loss           | 0.0319     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -32.3       |
# | time/                   |             |
# |    fps                  | 917         |
# |    iterations           | 1211        |
# |    time_elapsed         | 21628       |
# |    total_timesteps      | 19841024    |
# | train/                  |             |
# |    approx_kl            | 0.045374356 |
# |    clip_fraction        | 0.378       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1           |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.01       |
# |    n_updates            | 24200       |
# |    policy_gradient_loss | -0.0255     |
# |    std                  | 0.21        |
# |    value_loss           | 0.0115      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -31.4       |
# | time/                   |             |
# |    fps                  | 917         |
# |    iterations           | 1212        |
# |    time_elapsed         | 21641       |
# |    total_timesteps      | 19857408    |
# | train/                  |             |
# |    approx_kl            | 0.041546404 |
# |    clip_fraction        | 0.382       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.01        |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0169     |
# |    n_updates            | 24220       |
# |    policy_gradient_loss | -0.0233     |
# |    std                  | 0.21        |
# |    value_loss           | 0.0152      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -32.2      |
# | time/                   |            |
# |    fps                  | 917        |
# |    iterations           | 1213       |
# |    time_elapsed         | 21654      |
# |    total_timesteps      | 19873792   |
# | train/                  |            |
# |    approx_kl            | 0.04024335 |
# |    clip_fraction        | 0.387      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.01       |
# |    explained_variance   | 0.945      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0218    |
# |    n_updates            | 24240      |
# |    policy_gradient_loss | -0.0279    |
# |    std                  | 0.21       |
# |    value_loss           | 0.0174     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -31.3      |
# | time/                   |            |
# |    fps                  | 917        |
# |    iterations           | 1214       |
# |    time_elapsed         | 21667      |
# |    total_timesteps      | 19890176   |
# | train/                  |            |
# |    approx_kl            | 0.04508313 |
# |    clip_fraction        | 0.393      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.01       |
# |    explained_variance   | 0.942      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0204    |
# |    n_updates            | 24260      |
# |    policy_gradient_loss | -0.0284    |
# |    std                  | 0.21       |
# |    value_loss           | 0.0243     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -32        |
# | time/                   |            |
# |    fps                  | 918        |
# |    iterations           | 1215       |
# |    time_elapsed         | 21680      |
# |    total_timesteps      | 19906560   |
# | train/                  |            |
# |    approx_kl            | 0.04350821 |
# |    clip_fraction        | 0.384      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.03       |
# |    explained_variance   | 0.946      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0124    |
# |    n_updates            | 24280      |
# |    policy_gradient_loss | -0.0253    |
# |    std                  | 0.209      |
# |    value_loss           | 0.0159     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -31.9       |
# | time/                   |             |
# |    fps                  | 918         |
# |    iterations           | 1216        |
# |    time_elapsed         | 21694       |
# |    total_timesteps      | 19922944    |
# | train/                  |             |
# |    approx_kl            | 0.049623594 |
# |    clip_fraction        | 0.402       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.02        |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00836    |
# |    n_updates            | 24300       |
# |    policy_gradient_loss | -0.0234     |
# |    std                  | 0.21        |
# |    value_loss           | 0.0371      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -31.9      |
# | time/                   |            |
# |    fps                  | 918        |
# |    iterations           | 1217       |
# |    time_elapsed         | 21707      |
# |    total_timesteps      | 19939328   |
# | train/                  |            |
# |    approx_kl            | 0.04759062 |
# |    clip_fraction        | 0.381      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.04       |
# |    explained_variance   | 0.985      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.02      |
# |    n_updates            | 24320      |
# |    policy_gradient_loss | -0.0316    |
# |    std                  | 0.209      |
# |    value_loss           | 0.00415    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -32.6       |
# | time/                   |             |
# |    fps                  | 918         |
# |    iterations           | 1218        |
# |    time_elapsed         | 21721       |
# |    total_timesteps      | 19955712    |
# | train/                  |             |
# |    approx_kl            | 0.045399867 |
# |    clip_fraction        | 0.401       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.05        |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0288     |
# |    n_updates            | 24340       |
# |    policy_gradient_loss | -0.0274     |
# |    std                  | 0.209       |
# |    value_loss           | 0.0151      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -31.5       |
# | time/                   |             |
# |    fps                  | 918         |
# |    iterations           | 1219        |
# |    time_elapsed         | 21735       |
# |    total_timesteps      | 19972096    |
# | train/                  |             |
# |    approx_kl            | 0.049329847 |
# |    clip_fraction        | 0.4         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.06        |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.01       |
# |    n_updates            | 24360       |
# |    policy_gradient_loss | -0.0239     |
# |    std                  | 0.209       |
# |    value_loss           | 0.0195      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -31.9       |
# | time/                   |             |
# |    fps                  | 919         |
# |    iterations           | 1220        |
# |    time_elapsed         | 21748       |
# |    total_timesteps      | 19988480    |
# | train/                  |             |
# |    approx_kl            | 0.042418785 |
# |    clip_fraction        | 0.392       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.06        |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00777    |
# |    n_updates            | 24380       |
# |    policy_gradient_loss | -0.0232     |
# |    std                  | 0.209       |
# |    value_loss           | 0.00737     |
# -----------------------------------------
# Eval num_timesteps=20000000, episode_reward=-23.58 +/- 2.07
# Episode length: 100.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 100         |
# |    mean_reward          | -23.6       |
# | time/                   |             |
# |    total_timesteps      | 20000000    |
# | train/                  |             |
# |    approx_kl            | 0.046454497 |
# |    clip_fraction        | 0.401       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.07        |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.018      |
# |    n_updates            | 24400       |
# |    policy_gradient_loss | -0.0281     |
# |    std                  | 0.208       |
# |    value_loss           | 0.0091      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -31.8    |
# | time/              |          |
# |    fps             | 919      |
# |    iterations      | 1221     |
# |    time_elapsed    | 21762    |
# |    total_timesteps | 20004864 |
# ---------------------------------

# %%
# Load model and evaluate
model = PPO.load("./models/ppo_pusher_final", device=device)

venv = make_vec_env(ENV_ID, n_envs=1, seed=42)
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

mean_reward, std_reward = evaluate_policy(model, venv, n_eval_episodes=10, deterministic=True)
print(f"Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Mean reward: -29.25 +/- 5.30

# %%
# Visualize the agent
import os
os.environ["MUJOCO_GL"] = "glfw"

import gymnasium as gym
import imageio
import numpy as np
from IPython.display import Video, display
import tempfile

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

ENV_ID = "Pusher-v5"
N_EVAL_EPISODES = 10
MAX_STEPS = 1500
FPS = 30

# create env
env = gym.make(ENV_ID, render_mode="rgb_array")
venv = DummyVecEnv([lambda: env])
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

# load model
# model = PPO.load("./models/ppo_humanoid_final", device="cpu")
model = PPO.load("./best_model/best_model", device="cpu")

best_frames = []
best_length = 0

for ep in range(N_EVAL_EPISODES):
    obs = venv.reset()
    frames = []

    for step in range(MAX_STEPS):
        action, _ = model.predict(obs, deterministic=True)
        obs, rewards, dones, infos = venv.step(action)

        frame = env.render()
        if frame is not None:
            frames.append(frame)

        if dones[0]:
            break

    ep_length = len(frames)
    print(f"Episode {ep+1}: {ep_length} frames")

    if ep_length > best_length:
        best_length = ep_length
        best_frames = frames

print(f"\nLongest episode length: {best_length} frames")

# save and display only the longest episode
tmp = tempfile.NamedTemporaryFile(suffix=".mp4", delete=False).name
writer = imageio.get_writer(tmp, fps=FPS, codec="libx264")
for f in best_frames:
    writer.append_data(f)
writer.close()

display(Video(tmp, embed=True))
# Out:
# Episode 1: 100 frames
# Episode 2: 100 frames
# Episode 3: 100 frames
# Episode 4: 100 frames
# Episode 5: 100 frames
# Episode 6: 100 frames
# Episode 7: 100 frames
# Episode 8: 100 frames
# Episode 9: 100 frames
# Episode 10: 100 frames
#
# Longest episode length: 100 frames
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
