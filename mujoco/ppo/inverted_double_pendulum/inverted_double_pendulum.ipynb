# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.5.1
# CUDA available: True
# CUDA device count: 1
# GPU name: NVIDIA GeForce RTX 4080 SUPER

# %%
# Quick checks
import sys, platform
import torch
print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())
print("PyTorch:", torch.__version__, "| CUDA available:", torch.cuda.is_available())
import mujoco
print("MuJoCo package version:", mujoco.__version__)
# Out:
# Python: 3.10.19
# Platform: Windows-10-10.0.26200-SP0
# PyTorch: 2.5.1 | CUDA available: True
# MuJoCo package version: 3.4.0

# %%
# Imports
import os
import gymnasium as gym
import numpy as np
import torch
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecNormalize, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback
from stable_baselines3.common.evaluation import evaluate_policy

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Env setup
ENV_ID = "InvertedDoublePendulum-v5"   # requires mujoco >= 2.3
n_envs = 4               # on Windows + single CPU, 4 is reasonable; reduce if CPU bound
seed = 0

# Make vectorized training envs
train_env = make_vec_env(
    ENV_ID,
    n_envs=n_envs,
    seed=seed,
    monitor_dir="./logs/train_monitor"
)

# VecNormalize (important for continuous control)
train_env = VecNormalize(train_env, norm_obs=True, norm_reward=True, clip_obs=10.0)

# eval env
eval_env = make_vec_env(
    ENV_ID,
    n_envs=1,
    seed=seed + 100,
    monitor_dir="./logs/eval_monitor"
)
eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

print("Obs space:", train_env.observation_space)
print("Act space:", train_env.action_space)
# Out:
# Obs space: Box(-inf, inf, (9,), float64)
# Act space: Box(-1.0, 1.0, (1,), float32)

# %%
# Create PPO
policy_kwargs = dict(net_arch=[dict(pi=[256, 256], vf=[256, 256])])

model = PPO(
    "MlpPolicy",
    train_env,
    n_steps=2048,
    batch_size=64,
    n_epochs=10,
    learning_rate=3e-4,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=0.0,
    policy_kwargs=policy_kwargs,
    device=device,
    verbose=1,
)
# Out:
# Using cuda device
# c:\Users\User\miniconda3\envs\env_rl\lib\site-packages\stable_baselines3\common\policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# c:\Users\User\miniconda3\envs\env_rl\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
# Callbacks and save dirs
os.makedirs("./models", exist_ok=True)
os.makedirs("./checkpoints", exist_ok=True)
os.makedirs("./best_model", exist_ok=True)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./best_model/",
    log_path="./logs/eval",
    eval_freq=100_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False
)

checkpoint_callback = CheckpointCallback(save_freq=500_000, save_path="./checkpoints/", name_prefix="ppo_inverted_double_pendulum")

# %%
# Train
TOTAL_TIMESTEPS = int(1e6)
model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=[eval_callback, checkpoint_callback])
model.save("./models/ppo_inverted_double_pendulum_final")
# save VecNormalize
train_env.save("./models/vecnormalize_train.pkl")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.1      |
# |    ep_rew_mean     | 45.5     |
# | time/              |          |
# |    fps             | 2046     |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.72        |
# |    ep_rew_mean          | 51.1        |
# | time/                   |             |
# |    fps                  | 1171        |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.026421102 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.138      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0932      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0252     |
# |    std                  | 0.928       |
# |    value_loss           | 0.423       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.36       |
# |    ep_rew_mean          | 75.7       |
# | time/                   |            |
# |    fps                  | 1059       |
# |    iterations           | 3          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.08547955 |
# |    clip_fraction        | 0.451      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.22      |
# |    explained_variance   | 0.615      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.161      |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.06      |
# |    std                  | 0.785      |
# |    value_loss           | 0.486      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | 88.9        |
# | time/                   |             |
# |    fps                  | 1029        |
# |    iterations           | 4           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.050388657 |
# |    clip_fraction        | 0.338       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.238       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0479     |
# |    std                  | 0.678       |
# |    value_loss           | 0.456       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.7        |
# |    ep_rew_mean          | 107         |
# | time/                   |             |
# |    fps                  | 988         |
# |    iterations           | 5           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.048003852 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.927      |
# |    explained_variance   | 0.703       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.129       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0415     |
# |    std                  | 0.588       |
# |    value_loss           | 0.495       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.8       |
# |    ep_rew_mean          | 145        |
# | time/                   |            |
# |    fps                  | 965        |
# |    iterations           | 6          |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.04240097 |
# |    clip_fraction        | 0.296      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.795     |
# |    explained_variance   | 0.72       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.147      |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.036     |
# |    std                  | 0.518      |
# |    value_loss           | 0.518      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23          |
# |    ep_rew_mean          | 203         |
# | time/                   |             |
# |    fps                  | 953         |
# |    iterations           | 7           |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.029919347 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.691      |
# |    explained_variance   | 0.714       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.284       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0293     |
# |    std                  | 0.47        |
# |    value_loss           | 0.536       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.4        |
# |    ep_rew_mean          | 262         |
# | time/                   |             |
# |    fps                  | 946         |
# |    iterations           | 8           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.028995492 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.594      |
# |    explained_variance   | 0.712       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.202       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0227     |
# |    std                  | 0.426       |
# |    value_loss           | 0.601       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38          |
# |    ep_rew_mean          | 342         |
# | time/                   |             |
# |    fps                  | 936         |
# |    iterations           | 9           |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.023696767 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.501      |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.202       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.389       |
# |    value_loss           | 0.513       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.7        |
# |    ep_rew_mean          | 386         |
# | time/                   |             |
# |    fps                  | 929         |
# |    iterations           | 10          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.021573551 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.42       |
# |    explained_variance   | 0.798       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.23        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00976    |
# |    std                  | 0.362       |
# |    value_loss           | 0.35        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.2        |
# |    ep_rew_mean          | 391         |
# | time/                   |             |
# |    fps                  | 926         |
# |    iterations           | 11          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.018533025 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.357      |
# |    explained_variance   | 0.806       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.136       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00869    |
# |    std                  | 0.34        |
# |    value_loss           | 0.319       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.5       |
# |    ep_rew_mean          | 440        |
# | time/                   |            |
# |    fps                  | 921        |
# |    iterations           | 12         |
# |    time_elapsed         | 106        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.01539959 |
# |    clip_fraction        | 0.173      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.309     |
# |    explained_variance   | 0.82       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.129      |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.00938   |
# |    std                  | 0.326      |
# |    value_loss           | 0.296      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 55.2       |
# |    ep_rew_mean          | 503        |
# | time/                   |            |
# |    fps                  | 915        |
# |    iterations           | 13         |
# |    time_elapsed         | 116        |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.01655316 |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.27      |
# |    explained_variance   | 0.833      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.118      |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.00712   |
# |    std                  | 0.313      |
# |    value_loss           | 0.264      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 64.9        |
# |    ep_rew_mean          | 592         |
# | time/                   |             |
# |    fps                  | 907         |
# |    iterations           | 14          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.014528761 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.231      |
# |    explained_variance   | 0.843       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.127       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00599    |
# |    std                  | 0.301       |
# |    value_loss           | 0.252       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 88.8       |
# |    ep_rew_mean          | 815        |
# | time/                   |            |
# |    fps                  | 900        |
# |    iterations           | 15         |
# |    time_elapsed         | 136        |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.01670326 |
# |    clip_fraction        | 0.167      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.183     |
# |    explained_variance   | 0.79       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.166      |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.00731   |
# |    std                  | 0.287      |
# |    value_loss           | 0.338      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 96         |
# |    ep_rew_mean          | 882        |
# | time/                   |            |
# |    fps                  | 876        |
# |    iterations           | 16         |
# |    time_elapsed         | 149        |
# |    total_timesteps      | 131072     |
# | train/                  |            |
# |    approx_kl            | 0.01327537 |
# |    clip_fraction        | 0.146      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.15      |
# |    explained_variance   | 0.78       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.177      |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.00307   |
# |    std                  | 0.279      |
# |    value_loss           | 0.33       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 106         |
# |    ep_rew_mean          | 977         |
# | time/                   |             |
# |    fps                  | 843         |
# |    iterations           | 17          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.013809923 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.114      |
# |    explained_variance   | 0.778       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.213       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00312    |
# |    std                  | 0.269       |
# |    value_loss           | 0.338       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 117          |
# |    ep_rew_mean          | 1.08e+03     |
# | time/                   |              |
# |    fps                  | 802          |
# |    iterations           | 18           |
# |    time_elapsed         | 183          |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0141016925 |
# |    clip_fraction        | 0.157        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0688      |
# |    explained_variance   | 0.744        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.131        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00394     |
# |    std                  | 0.256        |
# |    value_loss           | 0.302        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 137         |
# |    ep_rew_mean          | 1.26e+03    |
# | time/                   |             |
# |    fps                  | 754         |
# |    iterations           | 19          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.016746154 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0307     |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.135       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00244    |
# |    std                  | 0.248       |
# |    value_loss           | 0.258       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 177         |
# |    ep_rew_mean          | 1.64e+03    |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 20          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.014464011 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0082      |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.121       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.000682   |
# |    std                  | 0.237       |
# |    value_loss           | 0.252       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 221         |
# |    ep_rew_mean          | 2.05e+03    |
# | time/                   |             |
# |    fps                  | 664         |
# |    iterations           | 21          |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.016094454 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0353      |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0388      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00251    |
# |    std                  | 0.232       |
# |    value_loss           | 0.162       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 257         |
# |    ep_rew_mean          | 2.38e+03    |
# | time/                   |             |
# |    fps                  | 633         |
# |    iterations           | 22          |
# |    time_elapsed         | 284         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.016401256 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0764      |
# |    explained_variance   | 0.699       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0857      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.000408   |
# |    std                  | 0.221       |
# |    value_loss           | 0.141       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 319         |
# |    ep_rew_mean          | 2.96e+03    |
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 23          |
# |    time_elapsed         | 310         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.015063534 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.111       |
# |    explained_variance   | 0.674       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0398      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00172     |
# |    std                  | 0.215       |
# |    value_loss           | 0.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 386         |
# |    ep_rew_mean          | 3.58e+03    |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 24          |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.016674438 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.137       |
# |    explained_variance   | 0.668       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0489      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.000797    |
# |    std                  | 0.209       |
# |    value_loss           | 0.0415      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 420         |
# |    ep_rew_mean          | 3.9e+03     |
# | time/                   |             |
# |    fps                  | 563         |
# |    iterations           | 25          |
# |    time_elapsed         | 363         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.015197324 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.145       |
# |    explained_variance   | 0.72        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0198      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0012      |
# |    std                  | 0.21        |
# |    value_loss           | 0.0425      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 466        |
# |    ep_rew_mean          | 4.33e+03   |
# | time/                   |            |
# |    fps                  | 547        |
# |    iterations           | 26         |
# |    time_elapsed         | 388        |
# |    total_timesteps      | 212992     |
# | train/                  |            |
# |    approx_kl            | 0.02739493 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.158      |
# |    explained_variance   | 0.665      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0072     |
# |    n_updates            | 250        |
# |    policy_gradient_loss | 0.00198    |
# |    std                  | 0.205      |
# |    value_loss           | 0.0541     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 515         |
# |    ep_rew_mean          | 4.79e+03    |
# | time/                   |             |
# |    fps                  | 532         |
# |    iterations           | 27          |
# |    time_elapsed         | 415         |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.015565165 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.174       |
# |    explained_variance   | 0.637       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0366      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.000391    |
# |    std                  | 0.202       |
# |    value_loss           | 0.0712      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 564         |
# |    ep_rew_mean          | 5.24e+03    |
# | time/                   |             |
# |    fps                  | 519         |
# |    iterations           | 28          |
# |    time_elapsed         | 441         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.019067619 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.196       |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0125     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00287     |
# |    std                  | 0.197       |
# |    value_loss           | 0.0255      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 617         |
# |    ep_rew_mean          | 5.74e+03    |
# | time/                   |             |
# |    fps                  | 508         |
# |    iterations           | 29          |
# |    time_elapsed         | 467         |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.016255211 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.208       |
# |    explained_variance   | 0.6         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00125     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.00278     |
# |    std                  | 0.197       |
# |    value_loss           | 0.0281      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 654         |
# |    ep_rew_mean          | 6.09e+03    |
# | time/                   |             |
# |    fps                  | 498         |
# |    iterations           | 30          |
# |    time_elapsed         | 493         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.019087458 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.206       |
# |    explained_variance   | 0.666       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0235      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.0022      |
# |    std                  | 0.197       |
# |    value_loss           | 0.0423      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 692         |
# |    ep_rew_mean          | 6.45e+03    |
# | time/                   |             |
# |    fps                  | 488         |
# |    iterations           | 31          |
# |    time_elapsed         | 519         |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.014358891 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.221       |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0072      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.00184     |
# |    std                  | 0.192       |
# |    value_loss           | 0.0106      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 689         |
# |    ep_rew_mean          | 6.41e+03    |
# | time/                   |             |
# |    fps                  | 480         |
# |    iterations           | 32          |
# |    time_elapsed         | 545         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.018094994 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.251       |
# |    explained_variance   | 0.262       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0138     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.00192     |
# |    std                  | 0.187       |
# |    value_loss           | 0.00737     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 729         |
# |    ep_rew_mean          | 6.79e+03    |
# | time/                   |             |
# |    fps                  | 472         |
# |    iterations           | 33          |
# |    time_elapsed         | 572         |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.019380257 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.24        |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0409      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00149     |
# |    std                  | 0.192       |
# |    value_loss           | 0.0203      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 764       |
# |    ep_rew_mean          | 7.11e+03  |
# | time/                   |           |
# |    fps                  | 466       |
# |    iterations           | 34        |
# |    time_elapsed         | 597       |
# |    total_timesteps      | 278528    |
# | train/                  |           |
# |    approx_kl            | 0.0201643 |
# |    clip_fraction        | 0.182     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.23      |
# |    explained_variance   | 0.617     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0255    |
# |    n_updates            | 330       |
# |    policy_gradient_loss | 0.00283   |
# |    std                  | 0.191     |
# |    value_loss           | 0.0174    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 781         |
# |    ep_rew_mean          | 7.28e+03    |
# | time/                   |             |
# |    fps                  | 459         |
# |    iterations           | 35          |
# |    time_elapsed         | 623         |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.019981371 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.251       |
# |    explained_variance   | 0.394       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00919    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00125     |
# |    std                  | 0.186       |
# |    value_loss           | 0.0118      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 794         |
# |    ep_rew_mean          | 7.4e+03     |
# | time/                   |             |
# |    fps                  | 454         |
# |    iterations           | 36          |
# |    time_elapsed         | 649         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.014481569 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.249       |
# |    explained_variance   | 0.615       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0213     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.00452     |
# |    std                  | 0.19        |
# |    value_loss           | 0.019       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 786         |
# |    ep_rew_mean          | 7.32e+03    |
# | time/                   |             |
# |    fps                  | 448         |
# |    iterations           | 37          |
# |    time_elapsed         | 675         |
# |    total_timesteps      | 303104      |
# | train/                  |             |
# |    approx_kl            | 0.026816165 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.245       |
# |    explained_variance   | 0.523       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0255     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.000275    |
# |    std                  | 0.189       |
# |    value_loss           | 0.0227      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 770         |
# |    ep_rew_mean          | 7.18e+03    |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 38          |
# |    time_elapsed         | 701         |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.017497327 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.24        |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00182    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00119     |
# |    std                  | 0.191       |
# |    value_loss           | 0.0143      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 777         |
# |    ep_rew_mean          | 7.23e+03    |
# | time/                   |             |
# |    fps                  | 438         |
# |    iterations           | 39          |
# |    time_elapsed         | 727         |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.015863039 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.24        |
# |    explained_variance   | 0.6         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000898    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00121     |
# |    std                  | 0.189       |
# |    value_loss           | 0.0274      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 760         |
# |    ep_rew_mean          | 7.07e+03    |
# | time/                   |             |
# |    fps                  | 434         |
# |    iterations           | 40          |
# |    time_elapsed         | 753         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.018249165 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.24        |
# |    explained_variance   | 0.559       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0597      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.000725    |
# |    std                  | 0.191       |
# |    value_loss           | 0.025       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 742         |
# |    ep_rew_mean          | 6.91e+03    |
# | time/                   |             |
# |    fps                  | 430         |
# |    iterations           | 41          |
# |    time_elapsed         | 779         |
# |    total_timesteps      | 335872      |
# | train/                  |             |
# |    approx_kl            | 0.015709467 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.229       |
# |    explained_variance   | 0.601       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00228    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00201     |
# |    std                  | 0.192       |
# |    value_loss           | 0.0221      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 742         |
# |    ep_rew_mean          | 6.91e+03    |
# | time/                   |             |
# |    fps                  | 427         |
# |    iterations           | 42          |
# |    time_elapsed         | 805         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.017388988 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.229       |
# |    explained_variance   | 0.706       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0264      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.000903    |
# |    std                  | 0.193       |
# |    value_loss           | 0.0239      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 727         |
# |    ep_rew_mean          | 6.77e+03    |
# | time/                   |             |
# |    fps                  | 423         |
# |    iterations           | 43          |
# |    time_elapsed         | 832         |
# |    total_timesteps      | 352256      |
# | train/                  |             |
# |    approx_kl            | 0.015739769 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.231       |
# |    explained_variance   | 0.571       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00163     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00174     |
# |    std                  | 0.191       |
# |    value_loss           | 0.0146      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 739         |
# |    ep_rew_mean          | 6.88e+03    |
# | time/                   |             |
# |    fps                  | 420         |
# |    iterations           | 44          |
# |    time_elapsed         | 856         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.018249735 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.235       |
# |    explained_variance   | 0.395       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00843    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00134     |
# |    std                  | 0.191       |
# |    value_loss           | 0.0218      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 748        |
# |    ep_rew_mean          | 6.97e+03   |
# | time/                   |            |
# |    fps                  | 417        |
# |    iterations           | 45         |
# |    time_elapsed         | 882        |
# |    total_timesteps      | 368640     |
# | train/                  |            |
# |    approx_kl            | 0.02080476 |
# |    clip_fraction        | 0.173      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.22       |
# |    explained_variance   | 0.473      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0121    |
# |    n_updates            | 440        |
# |    policy_gradient_loss | 0.00318    |
# |    std                  | 0.194      |
# |    value_loss           | 0.0108     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 733         |
# |    ep_rew_mean          | 6.83e+03    |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 46          |
# |    time_elapsed         | 907         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.019918263 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.195       |
# |    explained_variance   | 0.678       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00685     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.000943    |
# |    std                  | 0.203       |
# |    value_loss           | 0.0121      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 748         |
# |    ep_rew_mean          | 6.96e+03    |
# | time/                   |             |
# |    fps                  | 412         |
# |    iterations           | 47          |
# |    time_elapsed         | 934         |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.019036949 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.181       |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0599      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00169     |
# |    std                  | 0.202       |
# |    value_loss           | 0.0378      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 748         |
# |    ep_rew_mean          | 6.97e+03    |
# | time/                   |             |
# |    fps                  | 410         |
# |    iterations           | 48          |
# |    time_elapsed         | 958         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.018493704 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.191       |
# |    explained_variance   | 0.524       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00839     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.00121     |
# |    std                  | 0.199       |
# |    value_loss           | 0.0101      |
# -----------------------------------------
# Eval num_timesteps=400000, episode_reward=9337.23 +/- 1.26
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 9.34e+03    |
# | time/                   |             |
# |    total_timesteps      | 400000      |
# | train/                  |             |
# |    approx_kl            | 0.013021132 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.18        |
# |    explained_variance   | 0.49        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00317    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.002       |
# |    std                  | 0.204       |
# |    value_loss           | 0.0196      |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 760      |
# |    ep_rew_mean     | 7.08e+03 |
# | time/              |          |
# |    fps             | 404      |
# |    iterations      | 49       |
# |    time_elapsed    | 993      |
# |    total_timesteps | 401408   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 761         |
# |    ep_rew_mean          | 7.09e+03    |
# | time/                   |             |
# |    fps                  | 402         |
# |    iterations           | 50          |
# |    time_elapsed         | 1018        |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.017098393 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.16        |
# |    explained_variance   | 0.526       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0155      |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.00131     |
# |    std                  | 0.209       |
# |    value_loss           | 0.0301      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 767         |
# |    ep_rew_mean          | 7.15e+03    |
# | time/                   |             |
# |    fps                  | 400         |
# |    iterations           | 51          |
# |    time_elapsed         | 1044        |
# |    total_timesteps      | 417792      |
# | train/                  |             |
# |    approx_kl            | 0.021995125 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.144       |
# |    explained_variance   | 0.61        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0177     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.00191     |
# |    std                  | 0.21        |
# |    value_loss           | 0.0253      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 782         |
# |    ep_rew_mean          | 7.29e+03    |
# | time/                   |             |
# |    fps                  | 398         |
# |    iterations           | 52          |
# |    time_elapsed         | 1069        |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.018983763 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.148       |
# |    explained_variance   | 0.639       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0808      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.000318    |
# |    std                  | 0.208       |
# |    value_loss           | 0.0114      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 790         |
# |    ep_rew_mean          | 7.36e+03    |
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 53          |
# |    time_elapsed         | 1094        |
# |    total_timesteps      | 434176      |
# ...
# |    entropy_loss         | 0.185       |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00692    |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | -0.00107    |
# |    std                  | 0.2         |
# |    value_loss           | 0.0373      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 666        |
# |    ep_rew_mean          | 6.2e+03    |
# | time/                   |            |
# |    fps                  | 370        |
# |    iterations           | 107        |
# |    time_elapsed         | 2366       |
# |    total_timesteps      | 876544     |
# | train/                  |            |
# |    approx_kl            | 0.01629919 |
# |    clip_fraction        | 0.171      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.192      |
# |    explained_variance   | 0.731      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0529     |
# |    n_updates            | 1060       |
# |    policy_gradient_loss | -0.00436   |
# |    std                  | 0.2        |
# |    value_loss           | 0.0771     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 663        |
# |    ep_rew_mean          | 6.18e+03   |
# | time/                   |            |
# |    fps                  | 370        |
# |    iterations           | 108        |
# |    time_elapsed         | 2389       |
# |    total_timesteps      | 884736     |
# | train/                  |            |
# |    approx_kl            | 0.01655341 |
# |    clip_fraction        | 0.182      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.211      |
# |    explained_variance   | 0.726      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0066     |
# |    n_updates            | 1070       |
# |    policy_gradient_loss | -0.0027    |
# |    std                  | 0.194      |
# |    value_loss           | 0.0463     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 594         |
# |    ep_rew_mean          | 5.53e+03    |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 109         |
# |    time_elapsed         | 2410        |
# |    total_timesteps      | 892928      |
# | train/                  |             |
# |    approx_kl            | 0.022093758 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.216       |
# |    explained_variance   | 0.583       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0231      |
# |    n_updates            | 1080        |
# |    policy_gradient_loss | 0.000639    |
# |    std                  | 0.195       |
# |    value_loss           | 0.0359      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 609        |
# |    ep_rew_mean          | 5.67e+03   |
# | time/                   |            |
# |    fps                  | 370        |
# |    iterations           | 110        |
# |    time_elapsed         | 2433       |
# |    total_timesteps      | 901120     |
# | train/                  |            |
# |    approx_kl            | 0.02217149 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.211      |
# |    explained_variance   | 0.722      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00553    |
# |    n_updates            | 1090       |
# |    policy_gradient_loss | -0.00163   |
# |    std                  | 0.196      |
# |    value_loss           | 0.0624     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 630         |
# |    ep_rew_mean          | 5.87e+03    |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 111         |
# |    time_elapsed         | 2454        |
# |    total_timesteps      | 909312      |
# | train/                  |             |
# |    approx_kl            | 0.017437983 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.225       |
# |    explained_variance   | 0.662       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0172     |
# |    n_updates            | 1100        |
# |    policy_gradient_loss | -0.000891   |
# |    std                  | 0.191       |
# |    value_loss           | 0.0236      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 662         |
# |    ep_rew_mean          | 6.17e+03    |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 112         |
# |    time_elapsed         | 2476        |
# |    total_timesteps      | 917504      |
# | train/                  |             |
# |    approx_kl            | 0.016004387 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.27        |
# |    explained_variance   | -2.34       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0353     |
# |    n_updates            | 1110        |
# |    policy_gradient_loss | -0.00146    |
# |    std                  | 0.182       |
# |    value_loss           | 0.00146     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 684        |
# |    ep_rew_mean          | 6.37e+03   |
# | time/                   |            |
# |    fps                  | 370        |
# |    iterations           | 113        |
# |    time_elapsed         | 2498       |
# |    total_timesteps      | 925696     |
# | train/                  |            |
# |    approx_kl            | 0.01693049 |
# |    clip_fraction        | 0.168      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.278      |
# |    explained_variance   | 0.625      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00409   |
# |    n_updates            | 1120       |
# |    policy_gradient_loss | 0.00119    |
# |    std                  | 0.183      |
# |    value_loss           | 0.00403    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 729         |
# |    ep_rew_mean          | 6.79e+03    |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 114         |
# |    time_elapsed         | 2520        |
# |    total_timesteps      | 933888      |
# | train/                  |             |
# |    approx_kl            | 0.018662035 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.287       |
# |    explained_variance   | 0.377       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0104     |
# |    n_updates            | 1130        |
# |    policy_gradient_loss | 0.0017      |
# |    std                  | 0.179       |
# |    value_loss           | 0.00936     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 754         |
# |    ep_rew_mean          | 7.03e+03    |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 115         |
# |    time_elapsed         | 2541        |
# |    total_timesteps      | 942080      |
# | train/                  |             |
# |    approx_kl            | 0.015240103 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.336       |
# |    explained_variance   | -8.13       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0294     |
# |    n_updates            | 1140        |
# |    policy_gradient_loss | -0.00193    |
# |    std                  | 0.169       |
# |    value_loss           | 0.000184    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 776         |
# |    ep_rew_mean          | 7.24e+03    |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 116         |
# |    time_elapsed         | 2564        |
# |    total_timesteps      | 950272      |
# | train/                  |             |
# |    approx_kl            | 0.015153315 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.337       |
# |    explained_variance   | 0.402       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0158      |
# |    n_updates            | 1150        |
# |    policy_gradient_loss | 0.00132     |
# |    std                  | 0.175       |
# |    value_loss           | 0.00746     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 806         |
# |    ep_rew_mean          | 7.52e+03    |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 117         |
# |    time_elapsed         | 2585        |
# |    total_timesteps      | 958464      |
# | train/                  |             |
# |    approx_kl            | 0.018001735 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.291       |
# |    explained_variance   | 0.502       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00669     |
# |    n_updates            | 1160        |
# |    policy_gradient_loss | 0.00468     |
# |    std                  | 0.183       |
# |    value_loss           | 0.0191      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 800         |
# |    ep_rew_mean          | 7.46e+03    |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 118         |
# |    time_elapsed         | 2607        |
# |    total_timesteps      | 966656      |
# | train/                  |             |
# |    approx_kl            | 0.022130545 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.296       |
# |    explained_variance   | 0.418       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00812    |
# |    n_updates            | 1170        |
# |    policy_gradient_loss | 0.000585    |
# |    std                  | 0.178       |
# |    value_loss           | 0.00407     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 845         |
# |    ep_rew_mean          | 7.88e+03    |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 119         |
# |    time_elapsed         | 2628        |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.021659318 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.298       |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00383    |
# |    n_updates            | 1180        |
# |    policy_gradient_loss | 0.000904    |
# |    std                  | 0.18        |
# |    value_loss           | 0.0132      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 893         |
# |    ep_rew_mean          | 8.33e+03    |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 120         |
# |    time_elapsed         | 2651        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.017900862 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.316       |
# |    explained_variance   | 0.583       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0148     |
# |    n_updates            | 1190        |
# |    policy_gradient_loss | -0.000616   |
# |    std                  | 0.174       |
# |    value_loss           | 0.00324     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 883        |
# |    ep_rew_mean          | 8.24e+03   |
# | time/                   |            |
# |    fps                  | 370        |
# |    iterations           | 121        |
# |    time_elapsed         | 2672       |
# |    total_timesteps      | 991232     |
# | train/                  |            |
# |    approx_kl            | 0.01810185 |
# |    clip_fraction        | 0.166      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.343      |
# |    explained_variance   | -0.0632    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0105    |
# |    n_updates            | 1200       |
# |    policy_gradient_loss | 0.00103    |
# |    std                  | 0.17       |
# |    value_loss           | 0.00171    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 853         |
# |    ep_rew_mean          | 7.96e+03    |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 122         |
# |    time_elapsed         | 2694        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.028043794 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.315       |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0148     |
# |    n_updates            | 1210        |
# |    policy_gradient_loss | 0.00371     |
# |    std                  | 0.18        |
# |    value_loss           | 0.022       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 832         |
# |    ep_rew_mean          | 7.76e+03    |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 123         |
# |    time_elapsed         | 2716        |
# |    total_timesteps      | 1007616     |
# | train/                  |             |
# |    approx_kl            | 0.020398501 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.277       |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0261      |
# |    n_updates            | 1220        |
# |    policy_gradient_loss | -0.00146    |
# |    std                  | 0.184       |
# |    value_loss           | 0.02        |
# -----------------------------------------

# %%
# Load model and evaluate
model = PPO.load("./models/ppo_inverted_double_pendulum_final", device=device)

venv = make_vec_env(ENV_ID, n_envs=1, seed=42)
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

mean_reward, std_reward = evaluate_policy(model, venv, n_eval_episodes=10, deterministic=True)
print(f"Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Mean reward: 9345.58 +/- 0.84

# %%
# Visualize the agent
import os
os.environ["MUJOCO_GL"] = "glfw"

import gymnasium as gym
import imageio
import numpy as np
from IPython.display import Video, display
import tempfile

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

ENV_ID = "InvertedDoublePendulum-v5"
N_EVAL_EPISODES = 10
MAX_STEPS = 1500
FPS = 30

# create env
env = gym.make(ENV_ID, render_mode="rgb_array")
venv = DummyVecEnv([lambda: env])
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

# load model
# model = PPO.load("./models/ppo_humanoid_final", device="cpu")
model = PPO.load("./best_model/best_model", device="cpu")

best_frames = []
best_length = 0

for ep in range(N_EVAL_EPISODES):
    obs = venv.reset()
    frames = []

    for step in range(MAX_STEPS):
        action, _ = model.predict(obs, deterministic=True)
        obs, rewards, dones, infos = venv.step(action)

        frame = env.render()
        if frame is not None:
            frames.append(frame)

        if dones[0]:
            break

    ep_length = len(frames)
    print(f"Episode {ep+1}: {ep_length} frames")

    if ep_length > best_length:
        best_length = ep_length
        best_frames = frames

print(f"\nLongest episode length: {best_length} frames")

# save and display only the longest episode
tmp = tempfile.NamedTemporaryFile(suffix=".mp4", delete=False).name
writer = imageio.get_writer(tmp, fps=FPS, codec="libx264")
for f in best_frames:
    writer.append_data(f)
writer.close()

display(Video(tmp, embed=True))
# Out:
# Episode 1: 1000 frames
# Episode 2: 1000 frames
# Episode 3: 1000 frames
# Episode 4: 1000 frames
# Episode 5: 1000 frames
# Episode 6: 1000 frames
# Episode 7: 1000 frames
# Episode 8: 1000 frames
# Episode 9: 1000 frames
# Episode 10: 1000 frames
#
# Longest episode length: 1000 frames
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
