# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.5.1
# CUDA available: True
# CUDA device count: 1
# GPU name: NVIDIA GeForce RTX 4080 SUPER

# %%
# Quick checks
import sys, platform
import torch
print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())
print("PyTorch:", torch.__version__, "| CUDA available:", torch.cuda.is_available())
import mujoco
print("MuJoCo package version:", mujoco.__version__)
# Out:
# Python: 3.10.19
# Platform: Windows-10-10.0.26200-SP0
# PyTorch: 2.5.1 | CUDA available: True
# MuJoCo package version: 3.4.0

# %%
# Imports
import os
import gymnasium as gym
import numpy as np
import torch
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecNormalize, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback
from stable_baselines3.common.evaluation import evaluate_policy

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Env setup
ENV_ID = "Swimmer-v5"   # requires mujoco >= 2.3
n_envs = 4               # on Windows + single CPU, 4 is reasonable; reduce if CPU bound
seed = 0

# Make vectorized training envs
train_env = make_vec_env(
    ENV_ID,
    n_envs=n_envs,
    seed=seed,
    monitor_dir="./logs/train_monitor"
)

# VecNormalize (important for continuous control)
train_env = VecNormalize(train_env, norm_obs=True, norm_reward=True, clip_obs=10.0)

# eval env
eval_env = make_vec_env(
    ENV_ID,
    n_envs=1,
    seed=seed + 100,
    monitor_dir="./logs/eval_monitor"
)
eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

print("Obs space:", train_env.observation_space)
print("Act space:", train_env.action_space)
# Out:
# Obs space: Box(-inf, inf, (8,), float64)
# Act space: Box(-1.0, 1.0, (2,), float32)

# %%
# Create PPO
policy_kwargs = dict(net_arch=[dict(pi=[256, 256], vf=[256, 256])])

model = PPO(
    "MlpPolicy",
    train_env,
    n_steps=4096,
    batch_size=128,
    n_epochs=15,
    learning_rate=3e-4,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=0.0,
    policy_kwargs=policy_kwargs,
    device=device,
    verbose=1,
)
# Out:
# Using cuda device
# c:\Users\User\miniconda3\envs\env_rl\lib\site-packages\stable_baselines3\common\policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# c:\Users\User\miniconda3\envs\env_rl\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
# Callbacks and save dirs
os.makedirs("./models", exist_ok=True)
os.makedirs("./checkpoints", exist_ok=True)
os.makedirs("./best_model", exist_ok=True)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./best_model/",
    log_path="./logs/eval",
    eval_freq=100_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False
)

checkpoint_callback = CheckpointCallback(save_freq=500_000, save_path="./checkpoints/", name_prefix="ppo_swimmer")

# %%
# Train
TOTAL_TIMESTEPS = int(5e6) 
model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=[eval_callback, checkpoint_callback])
model.save("./models/ppo_swimmer_final")
# save VecNormalize
train_env.save("./models/vecnormalize_train.pkl")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -1.84    |
# | time/              |          |
# |    fps             | 945      |
# |    iterations      | 1        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 5.39        |
# | time/                   |             |
# |    fps                  | 539         |
# |    iterations           | 2           |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.012490826 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | -0.127      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0875      |
# |    n_updates            | 15          |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 0.994       |
# |    value_loss           | 0.28        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 10.8        |
# | time/                   |             |
# |    fps                  | 470         |
# |    iterations           | 3           |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.015104486 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.549       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0735      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0247     |
# |    std                  | 0.971       |
# |    value_loss           | 0.206       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 14.1        |
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 4           |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.017546153 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | 0.723       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0201      |
# |    n_updates            | 45          |
# |    policy_gradient_loss | -0.0254     |
# |    std                  | 0.94        |
# |    value_loss           | 0.0914      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 16.1         |
# | time/                   |              |
# |    fps                  | 424          |
# |    iterations           | 5            |
# |    time_elapsed         | 192          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0149483485 |
# |    clip_fraction        | 0.173        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | 0.85         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00284     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0152      |
# |    std                  | 0.905        |
# |    value_loss           | 0.024        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 17          |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 6           |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010542449 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0128     |
# |    n_updates            | 75          |
# |    policy_gradient_loss | -0.0072     |
# |    std                  | 0.869       |
# |    value_loss           | 0.00776     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 20.3        |
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 7           |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.010397477 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.49       |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00621    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00733    |
# |    std                  | 0.833       |
# |    value_loss           | 0.00457     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 22.8        |
# | time/                   |             |
# |    fps                  | 402         |
# |    iterations           | 8           |
# |    time_elapsed         | 325         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.008916497 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.43       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00499     |
# |    n_updates            | 105         |
# |    policy_gradient_loss | -0.00643    |
# |    std                  | 0.815       |
# |    value_loss           | 0.0025      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 23.8        |
# | time/                   |             |
# |    fps                  | 399         |
# |    iterations           | 9           |
# |    time_elapsed         | 369         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.010158499 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.42       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00453    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.812       |
# |    value_loss           | 0.0022      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 24.1        |
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 10          |
# |    time_elapsed         | 412         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.008837882 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.39       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00635    |
# |    n_updates            | 135         |
# |    policy_gradient_loss | -0.00991    |
# |    std                  | 0.804       |
# |    value_loss           | 0.00287     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 25.1       |
# | time/                   |            |
# |    fps                  | 394        |
# |    iterations           | 11         |
# |    time_elapsed         | 456        |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.01194372 |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.38      |
# |    explained_variance   | 0.984      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0289    |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0131    |
# |    std                  | 0.799      |
# |    value_loss           | 0.00407    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 26.6        |
# | time/                   |             |
# |    fps                  | 391         |
# |    iterations           | 12          |
# |    time_elapsed         | 501         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.013305018 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.36       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00578    |
# |    n_updates            | 165         |
# |    policy_gradient_loss | -0.0152     |
# |    std                  | 0.788       |
# |    value_loss           | 0.00509     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 28.1        |
# | time/                   |             |
# |    fps                  | 390         |
# |    iterations           | 13          |
# |    time_elapsed         | 545         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.013979385 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.33       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0256     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.774       |
# |    value_loss           | 0.00404     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 29.7        |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 14          |
# |    time_elapsed         | 590         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.010162699 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.31       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0178     |
# |    n_updates            | 195         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.767       |
# |    value_loss           | 0.00229     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 31.6        |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 15          |
# |    time_elapsed         | 634         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.008073604 |
# |    clip_fraction        | 0.0969      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00123     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00669    |
# |    std                  | 0.759       |
# |    value_loss           | 0.00114     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 33.9        |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 16          |
# |    time_elapsed         | 677         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.009234862 |
# |    clip_fraction        | 0.0999      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.24       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0363     |
# |    n_updates            | 225         |
# |    policy_gradient_loss | -0.00715    |
# |    std                  | 0.741       |
# |    value_loss           | 0.0012      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 35.8        |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 17          |
# |    time_elapsed         | 721         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.009191597 |
# |    clip_fraction        | 0.0993      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.2        |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0432      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00617    |
# |    std                  | 0.725       |
# |    value_loss           | 0.00125     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 37.4        |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 18          |
# |    time_elapsed         | 764         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.008506236 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00913    |
# |    n_updates            | 255         |
# |    policy_gradient_loss | -0.00734    |
# |    std                  | 0.712       |
# |    value_loss           | 0.00118     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 39.1        |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 19          |
# |    time_elapsed         | 807         |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.009453651 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00558    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00696    |
# |    std                  | 0.691       |
# |    value_loss           | 0.00143     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 40.5        |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 20          |
# |    time_elapsed         | 851         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.008969997 |
# |    clip_fraction        | 0.0918      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.05       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0153     |
# |    n_updates            | 285         |
# |    policy_gradient_loss | -0.00585    |
# |    std                  | 0.674       |
# |    value_loss           | 0.00141     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 42.6        |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 21          |
# |    time_elapsed         | 894         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.009269453 |
# |    clip_fraction        | 0.092       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.01       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0222     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00592    |
# |    std                  | 0.659       |
# |    value_loss           | 0.00104     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 44          |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 22          |
# |    time_elapsed         | 937         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.009634152 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0083     |
# |    n_updates            | 315         |
# |    policy_gradient_loss | -0.0067     |
# |    std                  | 0.644       |
# |    value_loss           | 0.00121     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 45.7        |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 23          |
# |    time_elapsed         | 980         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.010289092 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00549    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00656    |
# |    std                  | 0.632       |
# |    value_loss           | 0.00102     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 47.8        |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 24          |
# |    time_elapsed         | 1024        |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.011018937 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00246    |
# |    n_updates            | 345         |
# |    policy_gradient_loss | -0.00964    |
# |    std                  | 0.621       |
# |    value_loss           | 0.00104     |
# -----------------------------------------
# Eval num_timesteps=400000, episode_reward=45.60 +/- 1.43
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 45.6        |
# | time/                   |             |
# |    total_timesteps      | 400000      |
# | train/                  |             |
# |    approx_kl            | 0.011406319 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0127     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00947    |
# |    std                  | 0.608       |
# |    value_loss           | 0.00125     |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 50.5     |
# | time/              |          |
# |    fps             | 379      |
# |    iterations      | 25       |
# |    time_elapsed    | 1078     |
# |    total_timesteps | 409600   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 53.5        |
# | time/                   |             |
# |    fps                  | 379         |
# |    iterations           | 26          |
# |    time_elapsed         | 1121        |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.011515737 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00107     |
# |    n_updates            | 375         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.592       |
# |    value_loss           | 0.00178     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 57          |
# | time/                   |             |
# |    fps                  | 379         |
# |    iterations           | 27          |
# |    time_elapsed         | 1164        |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.012326479 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00184    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00928    |
# |    std                  | 0.577       |
# |    value_loss           | 0.00134     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 60.5        |
# | time/                   |             |
# |    fps                  | 379         |
# |    iterations           | 28          |
# |    time_elapsed         | 1208        |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.012112891 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00317     |
# |    n_updates            | 405         |
# |    policy_gradient_loss | -0.0089     |
# |    std                  | 0.561       |
# |    value_loss           | 0.0016      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 63.7        |
# | time/                   |             |
# |    fps                  | 379         |
# |    iterations           | 29          |
# |    time_elapsed         | 1251        |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.012967859 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.001      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00998    |
# |    std                  | 0.541       |
# |    value_loss           | 0.00148     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 68.3        |
# | time/                   |             |
# |    fps                  | 379         |
# |    iterations           | 30          |
# |    time_elapsed         | 1294        |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.013981669 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000139    |
# |    n_updates            | 435         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.521       |
# |    value_loss           | 0.00171     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 73.7       |
# | time/                   |            |
# |    fps                  | 379        |
# |    iterations           | 31         |
# |    time_elapsed         | 1338       |
# |    total_timesteps      | 507904     |
# | train/                  |            |
# |    approx_kl            | 0.01421853 |
# |    clip_fraction        | 0.15       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.47      |
# |    explained_variance   | 0.995      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00771   |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0102    |
# |    std                  | 0.504      |
# |    value_loss           | 0.00197    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 80.7         |
# | time/                   |              |
# |    fps                  | 379          |
# |    iterations           | 32           |
# |    time_elapsed         | 1382         |
# |    total_timesteps      | 524288       |
# | train/                  |              |
# |    approx_kl            | 0.0134424735 |
# |    clip_fraction        | 0.137        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.911        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.028       |
# |    n_updates            | 465          |
# |    policy_gradient_loss | -0.00373     |
# |    std                  | 0.494        |
# |    value_loss           | 0.00981      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 84.8        |
# | time/                   |             |
# |    fps                  | 379         |
# |    iterations           | 33          |
# |    time_elapsed         | 1424        |
# |    total_timesteps      | 540672      |
# | train/                  |             |
# |    approx_kl            | 0.012538075 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00562    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00768    |
# |    std                  | 0.48        |
# |    value_loss           | 0.00182     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 90.5       |
# | time/                   |            |
# |    fps                  | 379        |
# |    iterations           | 34         |
# |    time_elapsed         | 1468       |
# |    total_timesteps      | 557056     |
# | train/                  |            |
# |    approx_kl            | 0.00939168 |
# |    clip_fraction        | 0.1        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | 0.935      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00331    |
# |    n_updates            | 495        |
# |    policy_gradient_loss | -0.000732  |
# |    std                  | 0.474      |
# |    value_loss           | 0.00289    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 93.1        |
# | time/                   |             |
# |    fps                  | 379         |
# |    iterations           | 35          |
# |    time_elapsed         | 1510        |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.013396235 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0169     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00258    |
# |    std                  | 0.477       |
# |    value_loss           | 0.00171     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 92.5        |
# | time/                   |             |
# |    fps                  | 380         |
# |    iterations           | 36          |
# |    time_elapsed         | 1548        |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.010203525 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0125     |
# |    n_updates            | 525         |
# |    policy_gradient_loss | -0.00503    |
# |    std                  | 0.481       |
# |    value_loss           | 0.00411     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 91.5        |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 37          |
# |    time_elapsed         | 1585        |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.009470456 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0165     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00308    |
# |    std                  | 0.478       |
# |    value_loss           | 0.00154     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 86.5        |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 38          |
# |    time_elapsed         | 1623        |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.009184251 |
# |    clip_fraction        | 0.0954      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00846    |
# |    n_updates            | 555         |
# |    policy_gradient_loss | -0.00183    |
# |    std                  | 0.476       |
# |    value_loss           | 0.0014      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 85.7        |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 39          |
# |    time_elapsed         | 1660        |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.009675333 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0222     |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00272    |
# |    std                  | 0.47        |
# |    value_loss           | 0.00111     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 81         |
# | time/                   |            |
# |    fps                  | 386        |
# |    iterations           | 40         |
# |    time_elapsed         | 1697       |
# |    total_timesteps      | 655360     |
# | train/                  |            |
# |    approx_kl            | 0.00893555 |
# |    clip_fraction        | 0.0953     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00241    |
# |    n_updates            | 585        |
# |    policy_gradient_loss | -0.00143   |
# |    std                  | 0.467      |
# |    value_loss           | 0.000965   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 76.4        |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 41          |
# |    time_elapsed         | 1734        |
# |    total_timesteps      | 671744      |
# | train/                  |             |
# |    approx_kl            | 0.007647607 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0111      |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00197    |
# |    std                  | 0.469       |
# |    value_loss           | 0.000887    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 74          |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 42          |
# |    time_elapsed         | 1772        |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.012019964 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00237    |
# |    n_updates            | 615         |
# |    policy_gradient_loss | -0.00405    |
# |    std                  | 0.466       |
# |    value_loss           | 0.000971    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 72.5        |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 43          |
# |    time_elapsed         | 1809        |
# |    total_timesteps      | 704512      |
# | train/                  |             |
# |    approx_kl            | 0.009193885 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00872    |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.00151    |
# |    std                  | 0.462       |
# |    value_loss           | 0.000809    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 72          |
# | time/                   |             |
# |    fps                  | 390         |
# |    iterations           | 44          |
# |    time_elapsed         | 1846        |
# |    total_timesteps      | 720896      |
# | train/                  |             |
# |    approx_kl            | 0.009447948 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0061      |
# |    n_updates            | 645         |
# |    policy_gradient_loss | -0.00239    |
# |    std                  | 0.454       |
# |    value_loss           | 0.000809    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 71.6        |
# | time/                   |             |
# |    fps                  | 391         |
# |    iterations           | 45          |
# |    time_elapsed         | 1884        |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.008933367 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00411     |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.0027     |
# |    std                  | 0.445       |
# |    value_loss           | 0.000635    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 70.5        |
# | time/                   |             |
# |    fps                  | 392         |
# |    iterations           | 46          |
# |    time_elapsed         | 1921        |
# |    total_timesteps      | 753664      |
# | train/                  |             |
# |    approx_kl            | 0.012052728 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0138     |
# |    n_updates            | 675         |
# |    policy_gradient_loss | -0.00245    |
# |    std                  | 0.444       |
# |    value_loss           | 0.000697    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 73.9        |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 47          |
# |    time_elapsed         | 1958        |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.009053098 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0169      |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.00304    |
# |    std                  | 0.435       |
# |    value_loss           | 0.000613    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 75.8        |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 48          |
# |    time_elapsed         | 1995        |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.008848292 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00385    |
# |    n_updates            | 705         |
# |    policy_gradient_loss | -0.00193    |
# |    std                  | 0.428       |
# |    value_loss           | 0.00061     |
# -----------------------------------------
# Eval num_timesteps=800000, episode_reward=107.78 +/- 31.13
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 108         |
# | time/                   |             |
# |    total_timesteps      | 800000      |
# | train/                  |             |
# |    approx_kl            | 0.009465444 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00186    |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.00199    |
# |    std                  | 0.426       |
# |    value_loss           | 0.000551    |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 80.9     |
# | time/              |          |
# |    fps             | 393      |
# |    iterations      | 49       |
# |    time_elapsed    | 2041     |
# |    total_timesteps | 802816   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 85.8        |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 50          |
# |    time_elapsed         | 2078        |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.013976795 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0362     |
# |    n_updates            | 735         |
# |    policy_gradient_loss | -0.00585    |
# |    std                  | 0.423       |
# |    value_loss           | 0.00049     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 92.8         |
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 51           |
# |    time_elapsed         | 2116         |
# |    total_timesteps      | 835584       |
# | train/                  |              |
# |    approx_kl            | 0.0137625635 |
# |    clip_fraction        | 0.137        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00952     |
# |    n_updates            | 750          |
# |    policy_gradient_loss | -0.00389     |
# |    std                  | 0.419        |
# |    value_loss           | 0.00033      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 98.5       |
# | time/                   |            |
# |    fps                  | 395        |
# |    iterations           | 52         |
# |    time_elapsed         | 2153       |
# |    total_timesteps      | 851968     |
# | train/                  |            |
# |    approx_kl            | 0.01514013 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.006     |
# |    n_updates            | 765        |
# |    policy_gradient_loss | -0.00394   |
# |    std                  | 0.411      |
# ...
# |    fps                  | 486        |
# |    iterations           | 289        |
# |    time_elapsed         | 9723       |
# |    total_timesteps      | 4734976    |
# | train/                  |            |
# |    approx_kl            | 0.63009894 |
# |    clip_fraction        | 0.403      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 3          |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00771   |
# |    n_updates            | 4320       |
# |    policy_gradient_loss | 0.0112     |
# |    std                  | 0.0553     |
# |    value_loss           | 0.000209   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 121       |
# | time/                   |           |
# |    fps                  | 487       |
# |    iterations           | 290       |
# |    time_elapsed         | 9754      |
# |    total_timesteps      | 4751360   |
# | train/                  |           |
# |    approx_kl            | 0.9481144 |
# |    clip_fraction        | 0.392     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 3.02      |
# |    explained_variance   | 0.997     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00622  |
# |    n_updates            | 4335      |
# |    policy_gradient_loss | 0.000671  |
# |    std                  | 0.0548    |
# |    value_loss           | 0.000105  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 121       |
# | time/                   |           |
# |    fps                  | 487       |
# |    iterations           | 291       |
# |    time_elapsed         | 9786      |
# |    total_timesteps      | 4767744   |
# | train/                  |           |
# |    approx_kl            | 2.2658787 |
# |    clip_fraction        | 0.522     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 2.95      |
# |    explained_variance   | 0.996     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0266    |
# |    n_updates            | 4350      |
# |    policy_gradient_loss | 0.0385    |
# |    std                  | 0.057     |
# |    value_loss           | 0.000215  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 122       |
# | time/                   |           |
# |    fps                  | 487       |
# |    iterations           | 292       |
# |    time_elapsed         | 9817      |
# |    total_timesteps      | 4784128   |
# | train/                  |           |
# |    approx_kl            | 1.5825781 |
# |    clip_fraction        | 0.478     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 2.92      |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0633    |
# |    n_updates            | 4365      |
# |    policy_gradient_loss | 0.0284    |
# |    std                  | 0.0575    |
# |    value_loss           | 4.28e-05  |
# ---------------------------------------
# Eval num_timesteps=4800000, episode_reward=123.99 +/- 1.46
# Episode length: 1000.00 +/- 0.00
# ---------------------------------------
# | eval/                   |           |
# |    mean_ep_length       | 1e+03     |
# |    mean_reward          | 124       |
# | time/                   |           |
# |    total_timesteps      | 4800000   |
# | train/                  |           |
# |    approx_kl            | 1.0498879 |
# |    clip_fraction        | 0.436     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 2.93      |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0187   |
# |    n_updates            | 4380      |
# |    policy_gradient_loss | 0.0154    |
# |    std                  | 0.0572    |
# |    value_loss           | 5.37e-05  |
# ---------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 123      |
# | time/              |          |
# |    fps             | 487      |
# |    iterations      | 293      |
# |    time_elapsed    | 9856     |
# |    total_timesteps | 4800512  |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 123       |
# | time/                   |           |
# |    fps                  | 487       |
# |    iterations           | 294       |
# |    time_elapsed         | 9887      |
# |    total_timesteps      | 4816896   |
# | train/                  |           |
# |    approx_kl            | 4.417108  |
# |    clip_fraction        | 0.507     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 2.98      |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0311    |
# |    n_updates            | 4395      |
# |    policy_gradient_loss | -0.000137 |
# |    std                  | 0.0553    |
# |    value_loss           | 4.93e-05  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 124        |
# | time/                   |            |
# |    fps                  | 487        |
# |    iterations           | 295        |
# |    time_elapsed         | 9918       |
# |    total_timesteps      | 4833280    |
# | train/                  |            |
# |    approx_kl            | 0.14975184 |
# |    clip_fraction        | 0.387      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 3.01       |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0611     |
# |    n_updates            | 4410       |
# |    policy_gradient_loss | 0.0303     |
# |    std                  | 0.0553     |
# |    value_loss           | 3.01e-05   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 124       |
# | time/                   |           |
# |    fps                  | 487       |
# |    iterations           | 296       |
# |    time_elapsed         | 9949      |
# |    total_timesteps      | 4849664   |
# | train/                  |           |
# |    approx_kl            | 7.2095304 |
# |    clip_fraction        | 0.505     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 3.02      |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0258   |
# |    n_updates            | 4425      |
# |    policy_gradient_loss | 0.0207    |
# |    std                  | 0.0546    |
# |    value_loss           | 6.59e-05  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 123       |
# | time/                   |           |
# |    fps                  | 487       |
# |    iterations           | 297       |
# |    time_elapsed         | 9981      |
# |    total_timesteps      | 4866048   |
# | train/                  |           |
# |    approx_kl            | 6.1954384 |
# |    clip_fraction        | 0.528     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 3.08      |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0281   |
# |    n_updates            | 4440      |
# |    policy_gradient_loss | -0.00688  |
# |    std                  | 0.0529    |
# |    value_loss           | 4.1e-05   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 122       |
# | time/                   |           |
# |    fps                  | 487       |
# |    iterations           | 298       |
# |    time_elapsed         | 10013     |
# |    total_timesteps      | 4882432   |
# | train/                  |           |
# |    approx_kl            | 12.880947 |
# |    clip_fraction        | 0.527     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 3.12      |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0434   |
# |    n_updates            | 4455      |
# |    policy_gradient_loss | -0.000284 |
# |    std                  | 0.052     |
# |    value_loss           | 4.93e-05  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 121       |
# | time/                   |           |
# |    fps                  | 487       |
# |    iterations           | 299       |
# |    time_elapsed         | 10041     |
# |    total_timesteps      | 4898816   |
# | train/                  |           |
# |    approx_kl            | 0.4913321 |
# |    clip_fraction        | 0.417     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 3.12      |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0553    |
# |    n_updates            | 4470      |
# |    policy_gradient_loss | 0.0359    |
# |    std                  | 0.0525    |
# |    value_loss           | 4.18e-05  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 120       |
# | time/                   |           |
# |    fps                  | 488       |
# |    iterations           | 300       |
# |    time_elapsed         | 10066     |
# |    total_timesteps      | 4915200   |
# | train/                  |           |
# |    approx_kl            | 2.8247242 |
# |    clip_fraction        | 0.489     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 3.11      |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0208    |
# |    n_updates            | 4485      |
# |    policy_gradient_loss | 0.0399    |
# |    std                  | 0.0521    |
# |    value_loss           | 3.93e-05  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 119        |
# | time/                   |            |
# |    fps                  | 488        |
# |    iterations           | 301        |
# |    time_elapsed         | 10091      |
# |    total_timesteps      | 4931584    |
# | train/                  |            |
# |    approx_kl            | 0.15486112 |
# |    clip_fraction        | 0.409      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 3.09       |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0636     |
# |    n_updates            | 4500       |
# |    policy_gradient_loss | 0.0406     |
# |    std                  | 0.0535     |
# |    value_loss           | 2.91e-05   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 118       |
# | time/                   |           |
# |    fps                  | 489       |
# |    iterations           | 302       |
# |    time_elapsed         | 10116     |
# |    total_timesteps      | 4947968   |
# | train/                  |           |
# |    approx_kl            | 1.6180675 |
# |    clip_fraction        | 0.46      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 3.08      |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00632  |
# |    n_updates            | 4515      |
# |    policy_gradient_loss | 0.0216    |
# |    std                  | 0.0527    |
# |    value_loss           | 4.47e-05  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 118       |
# | time/                   |           |
# |    fps                  | 489       |
# |    iterations           | 303       |
# |    time_elapsed         | 10142     |
# |    total_timesteps      | 4964352   |
# | train/                  |           |
# |    approx_kl            | 2.0668333 |
# |    clip_fraction        | 0.482     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 3.17      |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0276   |
# |    n_updates            | 4530      |
# |    policy_gradient_loss | -0.0148   |
# |    std                  | 0.0508    |
# |    value_loss           | 0.000209  |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1e+03    |
# |    ep_rew_mean          | 119      |
# | time/                   |          |
# |    fps                  | 489      |
# |    iterations           | 304      |
# |    time_elapsed         | 10168    |
# |    total_timesteps      | 4980736  |
# | train/                  |          |
# |    approx_kl            | 2.250128 |
# |    clip_fraction        | 0.535    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 3.14     |
# |    explained_variance   | 1        |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.037    |
# |    n_updates            | 4545     |
# |    policy_gradient_loss | 0.05     |
# |    std                  | 0.0517   |
# |    value_loss           | 3.56e-05 |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 119       |
# | time/                   |           |
# |    fps                  | 490       |
# |    iterations           | 305       |
# |    time_elapsed         | 10193     |
# |    total_timesteps      | 4997120   |
# | train/                  |           |
# |    approx_kl            | 1.0156186 |
# |    clip_fraction        | 0.494     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 3.14      |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.000949 |
# |    n_updates            | 4560      |
# |    policy_gradient_loss | 0.025     |
# |    std                  | 0.0519    |
# |    value_loss           | 5.6e-05   |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1e+03    |
# |    ep_rew_mean          | 119      |
# | time/                   |          |
# |    fps                  | 490      |
# |    iterations           | 306      |
# |    time_elapsed         | 10218    |
# |    total_timesteps      | 5013504  |
# | train/                  |          |
# |    approx_kl            | 1.441294 |
# |    clip_fraction        | 0.499    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 3.13     |
# |    explained_variance   | 1        |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0251   |
# |    n_updates            | 4575     |
# |    policy_gradient_loss | 0.0414   |
# |    std                  | 0.0515   |
# |    value_loss           | 5.37e-05 |
# --------------------------------------

# %%
# Load model and evaluate
model = PPO.load("./models/ppo_swimmer_final", device=device)

venv = make_vec_env(ENV_ID, n_envs=1, seed=42)
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

mean_reward, std_reward = evaluate_policy(model, venv, n_eval_episodes=10, deterministic=True)
print(f"Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Mean reward: 123.92 +/- 2.03

# %%
# Visualize the agent
import os
os.environ["MUJOCO_GL"] = "glfw"

import gymnasium as gym
import imageio
import numpy as np
from IPython.display import Video, display
import tempfile

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

ENV_ID = "Swimmer-v5"
N_EVAL_EPISODES = 10
MAX_STEPS = 1500
FPS = 30

# create env
env = gym.make(ENV_ID, render_mode="rgb_array")
venv = DummyVecEnv([lambda: env])
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

# load model
# model = PPO.load("./models/ppo_humanoid_final", device="cpu")
model = PPO.load("./best_model/best_model", device="cpu")

best_frames = []
best_length = 0

for ep in range(N_EVAL_EPISODES):
    obs = venv.reset()
    frames = []

    for step in range(MAX_STEPS):
        action, _ = model.predict(obs, deterministic=True)
        obs, rewards, dones, infos = venv.step(action)

        frame = env.render()
        if frame is not None:
            frames.append(frame)

        if dones[0]:
            break

    ep_length = len(frames)
    print(f"Episode {ep+1}: {ep_length} frames")

    if ep_length > best_length:
        best_length = ep_length
        best_frames = frames

print(f"\nLongest episode length: {best_length} frames")

# save and display only the longest episode
tmp = tempfile.NamedTemporaryFile(suffix=".mp4", delete=False).name
writer = imageio.get_writer(tmp, fps=FPS, codec="libx264")
for f in best_frames:
    writer.append_data(f)
writer.close()

display(Video(tmp, embed=True))
# Out:
# Episode 1: 1000 frames
# Episode 2: 1000 frames
# Episode 3: 1000 frames
# Episode 4: 1000 frames
# Episode 5: 1000 frames
# Episode 6: 1000 frames
# Episode 7: 1000 frames
# Episode 8: 1000 frames
# Episode 9: 1000 frames
# Episode 10: 1000 frames
#
# Longest episode length: 1000 frames
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
