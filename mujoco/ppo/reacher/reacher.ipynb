# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.5.1
# CUDA available: True
# CUDA device count: 1
# GPU name: NVIDIA GeForce RTX 4080 SUPER

# %%
# Quick checks
import sys, platform
import torch
print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())
print("PyTorch:", torch.__version__, "| CUDA available:", torch.cuda.is_available())
import mujoco
print("MuJoCo package version:", mujoco.__version__)
# Out:
# Python: 3.10.19
# Platform: Windows-10-10.0.26200-SP0
# PyTorch: 2.5.1 | CUDA available: True
# MuJoCo package version: 3.4.0

# %%
# Imports
import os
import gymnasium as gym
import numpy as np
import torch
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecNormalize, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback
from stable_baselines3.common.evaluation import evaluate_policy

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Env setup
ENV_ID = "Reacher-v5"   # requires mujoco >= 2.3
n_envs = 4               # on Windows + single CPU, 4 is reasonable; reduce if CPU bound
seed = 0

# Make vectorized training envs
train_env = make_vec_env(
    ENV_ID,
    n_envs=n_envs,
    seed=seed,
    monitor_dir="./logs/train_monitor"
)

# VecNormalize (important for continuous control)
train_env = VecNormalize(train_env, norm_obs=True, norm_reward=True, clip_obs=10.0)

# eval env
eval_env = make_vec_env(
    ENV_ID,
    n_envs=1,
    seed=seed + 100,
    monitor_dir="./logs/eval_monitor"
)
eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

print("Obs space:", train_env.observation_space)
print("Act space:", train_env.action_space)
# Out:
# Obs space: Box(-inf, inf, (10,), float64)
# Act space: Box(-1.0, 1.0, (2,), float32)

# %%
# Create PPO
policy_kwargs = dict(net_arch=[dict(pi=[256, 256], vf=[256, 256])])

model = PPO(
    "MlpPolicy",
    train_env,
    n_steps=2048,
    batch_size=128,
    n_epochs=15,
    learning_rate=3e-4,
    gamma=0.98,
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=0.01,
    policy_kwargs=policy_kwargs,
    device=device,
    verbose=1,
)
# Out:
# Using cuda device
# c:\Users\User\miniconda3\envs\env_rl\lib\site-packages\stable_baselines3\common\policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# c:\Users\User\miniconda3\envs\env_rl\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
# Callbacks and save dirs
os.makedirs("./models", exist_ok=True)
os.makedirs("./checkpoints", exist_ok=True)
os.makedirs("./best_model", exist_ok=True)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./best_model/",
    log_path="./logs/eval",
    eval_freq=100_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False
)

checkpoint_callback = CheckpointCallback(save_freq=500_000, save_path="./checkpoints/", name_prefix="ppo_reacher")

# %%
# Train
TOTAL_TIMESTEPS = int(5e6)
model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=[eval_callback, checkpoint_callback])
model.save("./models/ppo_reacher_final")
# save VecNormalize
train_env.save("./models/vecnormalize_train.pkl")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -60.5    |
# | time/              |          |
# |    fps             | 1132     |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -58.8       |
# | time/                   |             |
# |    fps                  | 684         |
# |    iterations           | 2           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009496949 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | -0.0616     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0311      |
# |    n_updates            | 15          |
# |    policy_gradient_loss | -0.00691    |
# |    std                  | 0.957       |
# |    value_loss           | 0.219       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -56.8      |
# | time/                   |            |
# |    fps                  | 570        |
# |    iterations           | 3          |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01578632 |
# |    clip_fraction        | 0.0919     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.63      |
# |    explained_variance   | 0.219      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00456    |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0098    |
# |    std                  | 0.885      |
# |    value_loss           | 0.0641     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -53.1       |
# | time/                   |             |
# |    fps                  | 502         |
# |    iterations           | 4           |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.019674063 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.47       |
# |    explained_variance   | 0.467       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0281     |
# |    n_updates            | 45          |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 0.815       |
# |    value_loss           | 0.0411      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -49         |
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 5           |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.020464517 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0.456       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0224     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0224     |
# |    std                  | 0.745       |
# |    value_loss           | 0.0296      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -45.1       |
# | time/                   |             |
# |    fps                  | 450         |
# |    iterations           | 6           |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.021854179 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.472       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0576     |
# |    n_updates            | 75          |
# |    policy_gradient_loss | -0.0251     |
# |    std                  | 0.68        |
# |    value_loss           | 0.0205      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -41.1       |
# | time/                   |             |
# |    fps                  | 436         |
# |    iterations           | 7           |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.025273785 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 0.493       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0534     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0318     |
# |    std                  | 0.616       |
# |    value_loss           | 0.0156      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -37.3       |
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 8           |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.026642952 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0614     |
# |    n_updates            | 105         |
# |    policy_gradient_loss | -0.036      |
# |    std                  | 0.556       |
# |    value_loss           | 0.0112      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -33.2       |
# | time/                   |             |
# |    fps                  | 420         |
# |    iterations           | 9           |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.026786212 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.555       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0453     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0362     |
# |    std                  | 0.502       |
# |    value_loss           | 0.00932     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -29.4       |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 10          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.027692476 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.542       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0425     |
# |    n_updates            | 135         |
# |    policy_gradient_loss | -0.0377     |
# |    std                  | 0.453       |
# |    value_loss           | 0.00759     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -26.4       |
# | time/                   |             |
# |    fps                  | 411         |
# |    iterations           | 11          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.028086986 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.562       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0716     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0372     |
# |    std                  | 0.411       |
# |    value_loss           | 0.00701     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -22.9       |
# | time/                   |             |
# |    fps                  | 406         |
# |    iterations           | 12          |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.027459327 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0228     |
# |    n_updates            | 165         |
# |    policy_gradient_loss | -0.0341     |
# |    std                  | 0.373       |
# |    value_loss           | 0.00695     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -20.5       |
# | time/                   |             |
# |    fps                  | 404         |
# |    iterations           | 13          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.026981328 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.712      |
# |    explained_variance   | 0.704       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00833    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0327     |
# |    std                  | 0.34        |
# |    value_loss           | 0.00619     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -18.4      |
# | time/                   |            |
# |    fps                  | 401        |
# |    iterations           | 14         |
# |    time_elapsed         | 285        |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.02530124 |
# |    clip_fraction        | 0.214      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.534     |
# |    explained_variance   | 0.775      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0547    |
# |    n_updates            | 195        |
# |    policy_gradient_loss | -0.0306    |
# |    std                  | 0.311      |
# |    value_loss           | 0.00548    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -16.1       |
# | time/                   |             |
# |    fps                  | 399         |
# |    iterations           | 15          |
# |    time_elapsed         | 307         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.024007954 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.37       |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.034      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0262     |
# |    std                  | 0.286       |
# |    value_loss           | 0.005       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -15         |
# | time/                   |             |
# |    fps                  | 398         |
# |    iterations           | 16          |
# |    time_elapsed         | 328         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.023197478 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.209      |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0232     |
# |    n_updates            | 225         |
# |    policy_gradient_loss | -0.0254     |
# |    std                  | 0.264       |
# |    value_loss           | 0.00433     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -13.7      |
# | time/                   |            |
# |    fps                  | 396        |
# |    iterations           | 17         |
# |    time_elapsed         | 351        |
# |    total_timesteps      | 139264     |
# | train/                  |            |
# |    approx_kl            | 0.02143931 |
# |    clip_fraction        | 0.193      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0633    |
# |    explained_variance   | 0.871      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0394    |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0242    |
# |    std                  | 0.246      |
# |    value_loss           | 0.004      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -12.4       |
# | time/                   |             |
# |    fps                  | 395         |
# |    iterations           | 18          |
# |    time_elapsed         | 373         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.023420665 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0848      |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0364     |
# |    n_updates            | 255         |
# |    policy_gradient_loss | -0.0243     |
# |    std                  | 0.228       |
# |    value_loss           | 0.00341     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -11.6       |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 19          |
# |    time_elapsed         | 395         |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.021463376 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.223       |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.044      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0226     |
# |    std                  | 0.213       |
# |    value_loss           | 0.00325     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -10.8       |
# | time/                   |             |
# |    fps                  | 392         |
# |    iterations           | 20          |
# |    time_elapsed         | 417         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.022769406 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.356       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0227     |
# |    n_updates            | 285         |
# |    policy_gradient_loss | -0.0202     |
# |    std                  | 0.199       |
# |    value_loss           | 0.00284     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -9.68       |
# | time/                   |             |
# |    fps                  | 391         |
# |    iterations           | 21          |
# |    time_elapsed         | 439         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.021798884 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.496       |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0138     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 0.186       |
# |    value_loss           | 0.00238     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -9.15       |
# | time/                   |             |
# |    fps                  | 390         |
# |    iterations           | 22          |
# |    time_elapsed         | 461         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.018697852 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.605       |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0071     |
# |    n_updates            | 315         |
# |    policy_gradient_loss | -0.0205     |
# |    std                  | 0.177       |
# |    value_loss           | 0.00203     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -9.05       |
# | time/                   |             |
# |    fps                  | 390         |
# |    iterations           | 23          |
# |    time_elapsed         | 482         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.022719864 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.723       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0403     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.166       |
# |    value_loss           | 0.00177     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.3        |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 24          |
# |    time_elapsed         | 505         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.023443084 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.851       |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0202     |
# |    n_updates            | 345         |
# |    policy_gradient_loss | -0.0196     |
# |    std                  | 0.156       |
# |    value_loss           | 0.00136     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.31       |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 25          |
# |    time_elapsed         | 527         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.022736825 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.982       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00182     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0172     |
# |    std                  | 0.146       |
# |    value_loss           | 0.00113     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -7.74       |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 26          |
# |    time_elapsed         | 549         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.023616046 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.1         |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0125      |
# |    n_updates            | 375         |
# |    policy_gradient_loss | -0.0186     |
# |    std                  | 0.138       |
# |    value_loss           | 0.00103     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -7.1        |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 27          |
# |    time_elapsed         | 571         |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.023887085 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.22        |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0134     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 0.13        |
# |    value_loss           | 0.000843    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -6.78       |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 28          |
# |    time_elapsed         | 593         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.023926519 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.34        |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0109     |
# |    n_updates            | 405         |
# |    policy_gradient_loss | -0.0162     |
# |    std                  | 0.122       |
# |    value_loss           | 0.000648    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -6.81       |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 29          |
# |    time_elapsed         | 614         |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.020860843 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.45        |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0218     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.116       |
# |    value_loss           | 0.000634    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -6.57       |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 30          |
# |    time_elapsed         | 637         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.020084232 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.53        |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00368    |
# |    n_updates            | 435         |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 0.111       |
# |    value_loss           | 0.000635    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 50        |
# |    ep_rew_mean          | -6.47     |
# | time/                   |           |
# |    fps                  | 385       |
# |    iterations           | 31        |
# |    time_elapsed         | 659       |
# |    total_timesteps      | 253952    |
# | train/                  |           |
# |    approx_kl            | 0.0221977 |
# |    clip_fraction        | 0.208     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 1.63      |
# |    explained_variance   | 0.967     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0119   |
# |    n_updates            | 450       |
# |    policy_gradient_loss | -0.0116   |
# |    std                  | 0.106     |
# |    value_loss           | 0.000634  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -6.22       |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 32          |
# |    time_elapsed         | 680         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.023585768 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.71        |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00232     |
# |    n_updates            | 465         |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.102       |
# |    value_loss           | 0.000455    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -6.31       |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 33          |
# |    time_elapsed         | 701         |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.022344362 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.8         |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000281   |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.0974      |
# |    value_loss           | 0.000395    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -5.69      |
# | time/                   |            |
# |    fps                  | 384        |
# |    iterations           | 34         |
# |    time_elapsed         | 723        |
# |    total_timesteps      | 278528     |
# | train/                  |            |
# |    approx_kl            | 0.02157256 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.9        |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0183    |
# |    n_updates            | 495        |
# |    policy_gradient_loss | -0.0101    |
# |    std                  | 0.0926     |
# |    value_loss           | 0.000353   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -5.82       |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 35          |
# |    time_elapsed         | 744         |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.023624629 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2           |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0232      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.0875      |
# |    value_loss           | 0.000318    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -5.82       |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 36          |
# |    time_elapsed         | 767         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.024426937 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.1         |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0193      |
# |    n_updates            | 525         |
# |    policy_gradient_loss | -0.00793    |
# |    std                  | 0.0838      |
# |    value_loss           | 0.000265    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -5.66       |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 37          |
# |    time_elapsed         | 787         |
# |    total_timesteps      | 303104      |
# | train/                  |             |
# |    approx_kl            | 0.027034158 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.19        |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0236      |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00757    |
# |    std                  | 0.08        |
# |    value_loss           | 0.000237    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -5.67      |
# | time/                   |            |
# |    fps                  | 384        |
# |    iterations           | 38         |
# |    time_elapsed         | 810        |
# |    total_timesteps      | 311296     |
# | train/                  |            |
# |    approx_kl            | 0.03131558 |
# |    clip_fraction        | 0.249      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.29       |
# |    explained_variance   | 0.985      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00777   |
# |    n_updates            | 555        |
# |    policy_gradient_loss | -0.00535   |
# |    std                  | 0.0763     |
# |    value_loss           | 0.000245   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -5.35       |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 39          |
# |    time_elapsed         | 830         |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.022519128 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.38        |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0284      |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00574    |
# |    std                  | 0.0729      |
# |    value_loss           | 0.000246    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -5.58      |
# | time/                   |            |
# |    fps                  | 384        |
# |    iterations           | 40         |
# |    time_elapsed         | 852        |
# |    total_timesteps      | 327680     |
# | train/                  |            |
# |    approx_kl            | 0.02675025 |
# |    clip_fraction        | 0.264      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.47       |
# |    explained_variance   | 0.982      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0305     |
# |    n_updates            | 585        |
# |    policy_gradient_loss | -0.00603   |
# |    std                  | 0.0695     |
# |    value_loss           | 0.000245   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -5.24       |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 41          |
# |    time_elapsed         | 874         |
# |    total_timesteps      | 335872      |
# | train/                  |             |
# |    approx_kl            | 0.029140834 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.54        |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0193      |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00427    |
# |    std                  | 0.0671      |
# |    value_loss           | 0.000232    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -5.35       |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 42          |
# |    time_elapsed         | 895         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.026040886 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.61        |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00176     |
# |    n_updates            | 615         |
# |    policy_gradient_loss | -0.00338    |
# |    std                  | 0.0651      |
# |    value_loss           | 0.000179    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -5.17       |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 43          |
# |    time_elapsed         | 917         |
# |    total_timesteps      | 352256      |
# | train/                  |             |
# |    approx_kl            | 0.030436676 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.69        |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00444     |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.00583    |
# |    std                  | 0.0622      |
# |    value_loss           | 0.000159    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -4.96       |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 44          |
# |    time_elapsed         | 938         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.028760659 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.76        |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0267      |
# |    n_updates            | 645         |
# |    policy_gradient_loss | -0.00193    |
# |    std                  | 0.0602      |
# |    value_loss           | 0.000152    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -5.05      |
# | time/                   |            |
# |    fps                  | 384        |
# |    iterations           | 45         |
# |    time_elapsed         | 959        |
# |    total_timesteps      | 368640     |
# | train/                  |            |
# |    approx_kl            | 0.03348431 |
# |    clip_fraction        | 0.305      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 2.82       |
# |    explained_variance   | 0.985      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0427     |
# |    n_updates            | 660        |
# |    policy_gradient_loss | -0.00548   |
# |    std                  | 0.0586     |
# |    value_loss           | 0.00022    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -5          |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 46          |
# |    time_elapsed         | 982         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.030408835 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.86        |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0589      |
# |    n_updates            | 675         |
# |    policy_gradient_loss | -0.00362    |
# |    std                  | 0.0575      |
# |    value_loss           | 0.00018     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -4.94       |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 47          |
# |    time_elapsed         | 1002        |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.029960103 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.92        |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0256      |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.00102    |
# |    std                  | 0.0555      |
# |    value_loss           | 0.000153    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -5.03       |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 48          |
# |    time_elapsed         | 1025        |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.028959442 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.98        |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00909     |
# |    n_updates            | 705         |
# |    policy_gradient_loss | -0.00202    |
# |    std                  | 0.0544      |
# |    value_loss           | 0.000104    |
# -----------------------------------------
# Eval num_timesteps=400000, episode_reward=-4.28 +/- 2.99
# Episode length: 50.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 50         |
# |    mean_reward          | -4.28      |
# | time/                   |            |
# |    total_timesteps      | 400000     |
# | train/                  |            |
# |    approx_kl            | 0.12767982 |
# |    clip_fraction        | 0.344      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 3.02       |
# |    explained_variance   | 0.97       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0419     |
# |    n_updates            | 720        |
# |    policy_gradient_loss | 0.0207     |
# |    std                  | 0.0527     |
# |    value_loss           | 0.000419   |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -4.99    |
# | time/              |          |
# |    fps             | 383      |
# |    iterations      | 49       |
# |    time_elapsed    | 1046     |
# |    total_timesteps | 401408   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -5.02       |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 50          |
# |    time_elapsed         | 1068        |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.034038153 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 3.07        |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0186      |
# |    n_updates            | 735         |
# |    policy_gradient_loss | 0.00364     |
# |    std                  | 0.0518      |
# |    value_loss           | 0.000179    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -4.6       |
# | time/                   |            |
# |    fps                  | 383        |
# |    iterations           | 51         |
# |    time_elapsed         | 1089       |
# |    total_timesteps      | 417792     |
# | train/                  |            |
# |    approx_kl            | 0.03186877 |
# |    clip_fraction        | 0.306      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 3.1        |
# |    explained_variance   | 0.985      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00848   |
# |    n_updates            | 750        |
# |    policy_gradient_loss | 0.00027    |
# |    std                  | 0.0511     |
# |    value_loss           | 0.000236   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -4.87       |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 52          |
# |    time_elapsed         | 1110        |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.038905505 |
# |    clip_fraction        | 0.309       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 3.15        |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0447      |
# |    n_updates            | 765         |
# |    policy_gradient_loss | 0.00135     |
# |    std                  | 0.0495      |
# |    value_loss           | 0.000128    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -4.9        |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 53          |
# |    time_elapsed         | 1132        |
# |    total_timesteps      | 434176      |
# | train/                  |             |
# ...
# | train/                  |           |
# |    approx_kl            | 0.1144152 |
# |    clip_fraction        | 0.441     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 4.96      |
# |    explained_variance   | 0.998     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0672    |
# |    n_updates            | 8895      |
# |    policy_gradient_loss | 0.015     |
# |    std                  | 0.0203    |
# |    value_loss           | 8.26e-05  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -3.67      |
# | time/                   |            |
# |    fps                  | 497        |
# |    iterations           | 595        |
# |    time_elapsed         | 9790       |
# |    total_timesteps      | 4874240    |
# | train/                  |            |
# |    approx_kl            | 0.12797284 |
# |    clip_fraction        | 0.464      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 4.94       |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0542     |
# |    n_updates            | 8910       |
# |    policy_gradient_loss | 0.0406     |
# |    std                  | 0.0203     |
# |    value_loss           | 0.000123   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -3.5        |
# | time/                   |             |
# |    fps                  | 497         |
# |    iterations           | 596         |
# |    time_elapsed         | 9805        |
# |    total_timesteps      | 4882432     |
# | train/                  |             |
# |    approx_kl            | 0.101692304 |
# |    clip_fraction        | 0.452       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.94        |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0559      |
# |    n_updates            | 8925        |
# |    policy_gradient_loss | 0.0224      |
# |    std                  | 0.0205      |
# |    value_loss           | 7.53e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -3.4       |
# | time/                   |            |
# |    fps                  | 497        |
# |    iterations           | 597        |
# |    time_elapsed         | 9821       |
# |    total_timesteps      | 4890624    |
# | train/                  |            |
# |    approx_kl            | 0.06819757 |
# |    clip_fraction        | 0.417      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 4.96       |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0892     |
# |    n_updates            | 8940       |
# |    policy_gradient_loss | 0.0177     |
# |    std                  | 0.0202     |
# |    value_loss           | 5.51e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -3.7        |
# | time/                   |             |
# |    fps                  | 498         |
# |    iterations           | 598         |
# |    time_elapsed         | 9836        |
# |    total_timesteps      | 4898816     |
# | train/                  |             |
# |    approx_kl            | 0.065518916 |
# |    clip_fraction        | 0.444       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.95        |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0548      |
# |    n_updates            | 8955        |
# |    policy_gradient_loss | 0.0219      |
# |    std                  | 0.0205      |
# |    value_loss           | 8.83e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -3.81      |
# | time/                   |            |
# |    fps                  | 498        |
# |    iterations           | 599        |
# |    time_elapsed         | 9852       |
# |    total_timesteps      | 4907008    |
# | train/                  |            |
# |    approx_kl            | 0.06457191 |
# |    clip_fraction        | 0.447      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 4.93       |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.106      |
# |    n_updates            | 8970       |
# |    policy_gradient_loss | 0.0231     |
# |    std                  | 0.0207     |
# |    value_loss           | 7.01e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -3.6       |
# | time/                   |            |
# |    fps                  | 498        |
# |    iterations           | 600        |
# |    time_elapsed         | 9867       |
# |    total_timesteps      | 4915200    |
# | train/                  |            |
# |    approx_kl            | 0.09725855 |
# |    clip_fraction        | 0.442      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 4.91       |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0874     |
# |    n_updates            | 8985       |
# |    policy_gradient_loss | 0.0232     |
# |    std                  | 0.0208     |
# |    value_loss           | 8.19e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -3.82       |
# | time/                   |             |
# |    fps                  | 498         |
# |    iterations           | 601         |
# |    time_elapsed         | 9882        |
# |    total_timesteps      | 4923392     |
# | train/                  |             |
# |    approx_kl            | 0.081621654 |
# |    clip_fraction        | 0.457       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.91        |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0332      |
# |    n_updates            | 9000        |
# |    policy_gradient_loss | 0.0224      |
# |    std                  | 0.0206      |
# |    value_loss           | 6.7e-05     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -3.9       |
# | time/                   |            |
# |    fps                  | 498        |
# |    iterations           | 602        |
# |    time_elapsed         | 9898       |
# |    total_timesteps      | 4931584    |
# | train/                  |            |
# |    approx_kl            | 0.20005026 |
# |    clip_fraction        | 0.484      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 4.89       |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0791     |
# |    n_updates            | 9015       |
# |    policy_gradient_loss | 0.0203     |
# |    std                  | 0.0209     |
# |    value_loss           | 0.000131   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -3.73       |
# | time/                   |             |
# |    fps                  | 498         |
# |    iterations           | 603         |
# |    time_elapsed         | 9913        |
# |    total_timesteps      | 4939776     |
# | train/                  |             |
# |    approx_kl            | 0.085027464 |
# |    clip_fraction        | 0.447       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.85        |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.067       |
# |    n_updates            | 9030        |
# |    policy_gradient_loss | 0.0298      |
# |    std                  | 0.0217      |
# |    value_loss           | 0.000202    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -3.58      |
# | time/                   |            |
# |    fps                  | 498        |
# |    iterations           | 604        |
# |    time_elapsed         | 9928       |
# |    total_timesteps      | 4947968    |
# | train/                  |            |
# |    approx_kl            | 0.17203605 |
# |    clip_fraction        | 0.464      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 4.8        |
# |    explained_variance   | 0.995      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0521     |
# |    n_updates            | 9045       |
# |    policy_gradient_loss | 0.0243     |
# |    std                  | 0.022      |
# |    value_loss           | 0.000323   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 50        |
# |    ep_rew_mean          | -3.63     |
# | time/                   |           |
# |    fps                  | 498       |
# |    iterations           | 605       |
# |    time_elapsed         | 9944      |
# |    total_timesteps      | 4956160   |
# | train/                  |           |
# |    approx_kl            | 0.0870403 |
# |    clip_fraction        | 0.453     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 4.78      |
# |    explained_variance   | 0.996     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0334    |
# |    n_updates            | 9060      |
# |    policy_gradient_loss | 0.0269    |
# |    std                  | 0.0222    |
# |    value_loss           | 0.00014   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -3.35      |
# | time/                   |            |
# |    fps                  | 498        |
# |    iterations           | 606        |
# |    time_elapsed         | 9960       |
# |    total_timesteps      | 4964352    |
# | train/                  |            |
# |    approx_kl            | 0.07466601 |
# |    clip_fraction        | 0.445      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 4.76       |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.127      |
# |    n_updates            | 9075       |
# |    policy_gradient_loss | 0.0203     |
# |    std                  | 0.0225     |
# |    value_loss           | 0.000121   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -3.27      |
# | time/                   |            |
# |    fps                  | 498        |
# |    iterations           | 607        |
# |    time_elapsed         | 9975       |
# |    total_timesteps      | 4972544    |
# | train/                  |            |
# |    approx_kl            | 0.06850617 |
# |    clip_fraction        | 0.42       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 4.76       |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0478     |
# |    n_updates            | 9090       |
# |    policy_gradient_loss | 0.018      |
# |    std                  | 0.0224     |
# |    value_loss           | 9.02e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -3.86       |
# | time/                   |             |
# |    fps                  | 498         |
# |    iterations           | 608         |
# |    time_elapsed         | 9991        |
# |    total_timesteps      | 4980736     |
# | train/                  |             |
# |    approx_kl            | 0.052925423 |
# |    clip_fraction        | 0.404       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.8         |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0376      |
# |    n_updates            | 9105        |
# |    policy_gradient_loss | 0.0113      |
# |    std                  | 0.0218      |
# |    value_loss           | 7.87e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -3.5        |
# | time/                   |             |
# |    fps                  | 498         |
# |    iterations           | 609         |
# |    time_elapsed         | 10006       |
# |    total_timesteps      | 4988928     |
# | train/                  |             |
# |    approx_kl            | 0.055536367 |
# |    clip_fraction        | 0.419       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.78        |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0519      |
# |    n_updates            | 9120        |
# |    policy_gradient_loss | 0.0139      |
# |    std                  | 0.0222      |
# |    value_loss           | 0.000122    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -3.73      |
# | time/                   |            |
# |    fps                  | 498        |
# |    iterations           | 610        |
# |    time_elapsed         | 10022      |
# |    total_timesteps      | 4997120    |
# | train/                  |            |
# |    approx_kl            | 0.07377988 |
# |    clip_fraction        | 0.431      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 4.78       |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.104      |
# |    n_updates            | 9135       |
# |    policy_gradient_loss | 0.0172     |
# |    std                  | 0.0221     |
# |    value_loss           | 7.96e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -3.33      |
# | time/                   |            |
# |    fps                  | 498        |
# |    iterations           | 611        |
# |    time_elapsed         | 10037      |
# |    total_timesteps      | 5005312    |
# | train/                  |            |
# |    approx_kl            | 0.07817091 |
# |    clip_fraction        | 0.429      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 4.8        |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0779     |
# |    n_updates            | 9150       |
# |    policy_gradient_loss | 0.0147     |
# |    std                  | 0.022      |
# |    value_loss           | 0.000111   |
# ----------------------------------------

# %%
# Load model and evaluate
model = PPO.load("./models/ppo_reacher_final", device=device)

venv = make_vec_env(ENV_ID, n_envs=1, seed=42)
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

mean_reward, std_reward = evaluate_policy(model, venv, n_eval_episodes=10, deterministic=True)
print(f"Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Mean reward: -3.72 +/- 1.25

# %%
# Visualize the agent
import os
os.environ["MUJOCO_GL"] = "glfw"

import gymnasium as gym
import imageio
import numpy as np
from IPython.display import Video, display
import tempfile

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

ENV_ID = "Reacher-v5"
N_EVAL_EPISODES = 10
MAX_STEPS = 1500
FPS = 30

# create env
env = gym.make(ENV_ID, render_mode="rgb_array")
venv = DummyVecEnv([lambda: env])
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

# load model
# model = PPO.load("./models/ppo_humanoid_final", device="cpu")
model = PPO.load("./best_model/best_model", device="cpu")

best_frames = []
best_length = 0

for ep in range(N_EVAL_EPISODES):
    obs = venv.reset()
    frames = []

    for step in range(MAX_STEPS):
        action, _ = model.predict(obs, deterministic=True)
        obs, rewards, dones, infos = venv.step(action)

        frame = env.render()
        if frame is not None:
            frames.append(frame)

        if dones[0]:
            break

    ep_length = len(frames)
    print(f"Episode {ep+1}: {ep_length} frames")

    if ep_length > best_length:
        best_length = ep_length
        best_frames = frames

print(f"\nLongest episode length: {best_length} frames")

# save and display only the longest episode
tmp = tempfile.NamedTemporaryFile(suffix=".mp4", delete=False).name
writer = imageio.get_writer(tmp, fps=FPS, codec="libx264")
for f in best_frames:
    writer.append_data(f)
writer.close()

display(Video(tmp, embed=True))
# Out:
# Episode 1: 50 frames
# Episode 2: 50 frames
# Episode 3: 50 frames
# Episode 4: 50 frames
# Episode 5: 50 frames
# Episode 6: 50 frames
# Episode 7: 50 frames
# Episode 8: 50 frames
# Episode 9: 50 frames
# Episode 10: 50 frames
#
# Longest episode length: 50 frames
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
