# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.5.1
# CUDA available: True
# CUDA device count: 1
# GPU name: NVIDIA GeForce RTX 4080 SUPER

# %%
# Quick checks
import sys, platform
import torch
print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())
print("PyTorch:", torch.__version__, "| CUDA available:", torch.cuda.is_available())
import mujoco
print("MuJoCo package version:", mujoco.__version__)
# Out:
# Python: 3.10.19
# Platform: Windows-10-10.0.26200-SP0
# PyTorch: 2.5.1 | CUDA available: True
# MuJoCo package version: 3.4.0

# %%
# Imports
import os
import gymnasium as gym
import numpy as np
import torch
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecNormalize, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback
from stable_baselines3.common.evaluation import evaluate_policy

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Env setup
ENV_ID = "Walker2d-v5"   # requires mujoco >= 2.3
n_envs = 4               # on Windows + single CPU, 4 is reasonable; reduce if CPU bound
seed = 0

# Make vectorized training envs
train_env = make_vec_env(
    ENV_ID,
    n_envs=n_envs,
    seed=seed,
    monitor_dir="./logs/train_monitor"
)

# VecNormalize (important for continuous control)
train_env = VecNormalize(train_env, norm_obs=True, norm_reward=True, clip_obs=10.0)

# eval env
eval_env = make_vec_env(
    ENV_ID,
    n_envs=1,
    seed=seed + 100,
    monitor_dir="./logs/eval_monitor"
)
eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

print("Obs space:", train_env.observation_space)
print("Act space:", train_env.action_space)
# Out:
# Obs space: Box(-inf, inf, (17,), float64)
# Act space: Box(-1.0, 1.0, (6,), float32)

# %%
# Create PPO
policy_kwargs = dict(net_arch=[dict(pi=[512, 512], vf=[512, 512])])

model = PPO(
    "MlpPolicy",
    train_env,
    n_steps=4096,
    batch_size=128,
    n_epochs=20,
    learning_rate=2.5e-4,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=0.0,
    policy_kwargs=policy_kwargs,
    device=device,
    verbose=1,
)
# Out:
# Using cuda device
# c:\Users\User\miniconda3\envs\env_rl\lib\site-packages\stable_baselines3\common\policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# c:\Users\User\miniconda3\envs\env_rl\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
# Callbacks and save dirs
os.makedirs("./models", exist_ok=True)
os.makedirs("./checkpoints", exist_ok=True)
os.makedirs("./best_model", exist_ok=True)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./best_model/",
    log_path="./logs/eval",
    eval_freq=100_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False
)

checkpoint_callback = CheckpointCallback(save_freq=500_000, save_path="./checkpoints/", name_prefix="ppo_walker2d")

# %%
# Train
TOTAL_TIMESTEPS = int(5e6) 
model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=[eval_callback, checkpoint_callback])
model.save("./models/ppo_walker2d_final")
# save VecNormalize
train_env.save("./models/vecnormalize_train.pkl")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.2     |
# |    ep_rew_mean     | -0.0337  |
# | time/              |          |
# |    fps             | 790      |
# |    iterations      | 1        |
# |    time_elapsed    | 20       |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.4        |
# |    ep_rew_mean          | 4.02        |
# | time/                   |             |
# |    fps                  | 446         |
# |    iterations           | 2           |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.017925218 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.46       |
# |    explained_variance   | -0.0185     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.174       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0301     |
# |    std                  | 0.99        |
# |    value_loss           | 0.453       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.4        |
# |    ep_rew_mean          | 12.6        |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 3           |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.023225747 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.39       |
# |    explained_variance   | 0.372       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.203       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0377     |
# |    std                  | 0.978       |
# |    value_loss           | 0.562       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.7        |
# |    ep_rew_mean          | 36.5        |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 4           |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.019008748 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.3        |
# |    explained_variance   | 0.499       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.209       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0297     |
# |    std                  | 0.964       |
# |    value_loss           | 0.481       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 81.8      |
# |    ep_rew_mean          | 74.7      |
# | time/                   |           |
# |    fps                  | 353       |
# |    iterations           | 5         |
# |    time_elapsed         | 232       |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 0.0158587 |
# |    clip_fraction        | 0.205     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -8.25     |
# |    explained_variance   | 0.689     |
# |    learning_rate        | 0.00025   |
# |    loss                 | 0.18      |
# |    n_updates            | 80        |
# |    policy_gradient_loss | -0.0222   |
# |    std                  | 0.956     |
# |    value_loss           | 0.489     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 124         |
# |    ep_rew_mean          | 140         |
# | time/                   |             |
# |    fps                  | 344         |
# |    iterations           | 6           |
# |    time_elapsed         | 285         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.015792325 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.21       |
# |    explained_variance   | 0.741       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.127       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0187     |
# |    std                  | 0.95        |
# |    value_loss           | 0.352       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 153         |
# |    ep_rew_mean          | 197         |
# | time/                   |             |
# |    fps                  | 339         |
# |    iterations           | 7           |
# |    time_elapsed         | 337         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.016010279 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.16       |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0734      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0197     |
# |    std                  | 0.943       |
# |    value_loss           | 0.285       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 143         |
# |    ep_rew_mean          | 187         |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 8           |
# |    time_elapsed         | 390         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.015702566 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.11       |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0433      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0183     |
# |    std                  | 0.935       |
# |    value_loss           | 0.195       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 158       |
# |    ep_rew_mean          | 237       |
# | time/                   |           |
# |    fps                  | 332       |
# |    iterations           | 9         |
# |    time_elapsed         | 443       |
# |    total_timesteps      | 147456    |
# | train/                  |           |
# |    approx_kl            | 0.0169701 |
# |    clip_fraction        | 0.187     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -8.06     |
# |    explained_variance   | 0.647     |
# |    learning_rate        | 0.00025   |
# |    loss                 | 0.00658   |
# |    n_updates            | 160       |
# |    policy_gradient_loss | -0.0198   |
# |    std                  | 0.927     |
# |    value_loss           | 0.157     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 154         |
# |    ep_rew_mean          | 237         |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 10          |
# |    time_elapsed         | 495         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.018783277 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.03       |
# |    explained_variance   | 0.68        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.00358     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0201     |
# |    std                  | 0.923       |
# |    value_loss           | 0.1         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 154       |
# |    ep_rew_mean          | 245       |
# | time/                   |           |
# |    fps                  | 328       |
# |    iterations           | 11        |
# |    time_elapsed         | 548       |
# |    total_timesteps      | 180224    |
# | train/                  |           |
# |    approx_kl            | 0.0196082 |
# |    clip_fraction        | 0.211     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -8        |
# |    explained_variance   | 0.757     |
# |    learning_rate        | 0.00025   |
# |    loss                 | -0.0202   |
# |    n_updates            | 200       |
# |    policy_gradient_loss | -0.0199   |
# |    std                  | 0.919     |
# |    value_loss           | 0.0626    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 141         |
# |    ep_rew_mean          | 234         |
# | time/                   |             |
# |    fps                  | 326         |
# |    iterations           | 12          |
# |    time_elapsed         | 602         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.019809142 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.99       |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0126     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0209     |
# |    std                  | 0.916       |
# |    value_loss           | 0.0427      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 139         |
# |    ep_rew_mean          | 235         |
# | time/                   |             |
# |    fps                  | 325         |
# |    iterations           | 13          |
# |    time_elapsed         | 654         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.019738587 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.97       |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0167      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.913       |
# |    value_loss           | 0.0312      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 140         |
# |    ep_rew_mean          | 245         |
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 14          |
# |    time_elapsed         | 706         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.020859808 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.94       |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0204     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0202     |
# |    std                  | 0.909       |
# |    value_loss           | 0.0247      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 138         |
# |    ep_rew_mean          | 243         |
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 15          |
# |    time_elapsed         | 757         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.021402318 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.92       |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.036      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0204     |
# |    std                  | 0.905       |
# |    value_loss           | 0.0151      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 134         |
# |    ep_rew_mean          | 236         |
# | time/                   |             |
# |    fps                  | 323         |
# |    iterations           | 16          |
# |    time_elapsed         | 809         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.022216221 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.87       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00854    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0204     |
# |    std                  | 0.898       |
# |    value_loss           | 0.013       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 133       |
# |    ep_rew_mean          | 238       |
# | time/                   |           |
# |    fps                  | 323       |
# |    iterations           | 17        |
# |    time_elapsed         | 860       |
# |    total_timesteps      | 278528    |
# | train/                  |           |
# |    approx_kl            | 0.0247417 |
# |    clip_fraction        | 0.256     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.84     |
# |    explained_variance   | 0.945     |
# |    learning_rate        | 0.00025   |
# |    loss                 | -0.00608  |
# |    n_updates            | 320       |
# |    policy_gradient_loss | -0.0217   |
# |    std                  | 0.893     |
# |    value_loss           | 0.0174    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 141         |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 323         |
# |    iterations           | 18          |
# |    time_elapsed         | 912         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.025641747 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.81       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0362     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0239     |
# |    std                  | 0.888       |
# |    value_loss           | 0.0179      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 138         |
# |    ep_rew_mean          | 262         |
# | time/                   |             |
# |    fps                  | 322         |
# |    iterations           | 19          |
# |    time_elapsed         | 964         |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.026071936 |
# |    clip_fraction        | 0.281       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.77       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0259     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0232     |
# |    std                  | 0.883       |
# |    value_loss           | 0.0154      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 137         |
# |    ep_rew_mean          | 266         |
# | time/                   |             |
# |    fps                  | 322         |
# |    iterations           | 20          |
# |    time_elapsed         | 1017        |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.026951661 |
# |    clip_fraction        | 0.282       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.74       |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0214     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.023      |
# |    std                  | 0.878       |
# |    value_loss           | 0.013       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 147         |
# |    ep_rew_mean          | 292         |
# | time/                   |             |
# |    fps                  | 321         |
# |    iterations           | 21          |
# |    time_elapsed         | 1069        |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.026644737 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.7        |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0239     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0229     |
# |    std                  | 0.873       |
# |    value_loss           | 0.0143      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 297         |
# | time/                   |             |
# |    fps                  | 321         |
# |    iterations           | 22          |
# |    time_elapsed         | 1121        |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.026881207 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.66       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00928    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0222     |
# |    std                  | 0.866       |
# |    value_loss           | 0.0165      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | 301         |
# | time/                   |             |
# |    fps                  | 321         |
# |    iterations           | 23          |
# |    time_elapsed         | 1173        |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.028448448 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.62       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0202     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0215     |
# |    std                  | 0.861       |
# |    value_loss           | 0.017       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 145         |
# |    ep_rew_mean          | 305         |
# | time/                   |             |
# |    fps                  | 320         |
# |    iterations           | 24          |
# |    time_elapsed         | 1225        |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.029688956 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.57       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0383     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0225     |
# |    std                  | 0.854       |
# |    value_loss           | 0.0171      |
# -----------------------------------------
# Eval num_timesteps=400000, episode_reward=388.28 +/- 3.77
# Episode length: 156.80 +/- 1.94
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 157         |
# |    mean_reward          | 388         |
# | time/                   |             |
# |    total_timesteps      | 400000      |
# | train/                  |             |
# |    approx_kl            | 0.027876662 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.53       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.02       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0215     |
# |    std                  | 0.848       |
# |    value_loss           | 0.0207      |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | 306      |
# | time/              |          |
# |    fps             | 320      |
# |    iterations      | 25       |
# |    time_elapsed    | 1279     |
# |    total_timesteps | 409600   |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 141       |
# |    ep_rew_mean          | 308       |
# | time/                   |           |
# |    fps                  | 319       |
# |    iterations           | 26        |
# |    time_elapsed         | 1331      |
# |    total_timesteps      | 425984    |
# | train/                  |           |
# |    approx_kl            | 0.0294297 |
# |    clip_fraction        | 0.301     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.48     |
# |    explained_variance   | 0.953     |
# |    learning_rate        | 0.00025   |
# |    loss                 | -0.0439   |
# |    n_updates            | 500       |
# |    policy_gradient_loss | -0.0215   |
# |    std                  | 0.841     |
# |    value_loss           | 0.0206    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 139         |
# |    ep_rew_mean          | 313         |
# | time/                   |             |
# |    fps                  | 319         |
# |    iterations           | 27          |
# |    time_elapsed         | 1383        |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.030023985 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.43       |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0327     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0215     |
# |    std                  | 0.834       |
# |    value_loss           | 0.0174      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 140         |
# |    ep_rew_mean          | 318         |
# | time/                   |             |
# |    fps                  | 319         |
# |    iterations           | 28          |
# |    time_elapsed         | 1435        |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.031688247 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.38       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00688    |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.021      |
# |    std                  | 0.827       |
# |    value_loss           | 0.0171      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 140       |
# |    ep_rew_mean          | 320       |
# | time/                   |           |
# |    fps                  | 319       |
# |    iterations           | 29        |
# |    time_elapsed         | 1486      |
# |    total_timesteps      | 475136    |
# | train/                  |           |
# |    approx_kl            | 0.0328177 |
# |    clip_fraction        | 0.33      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.33     |
# |    explained_variance   | 0.965     |
# |    learning_rate        | 0.00025   |
# |    loss                 | -0.0274   |
# |    n_updates            | 560       |
# |    policy_gradient_loss | -0.0236   |
# |    std                  | 0.819     |
# |    value_loss           | 0.0128    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 139        |
# |    ep_rew_mean          | 326        |
# | time/                   |            |
# |    fps                  | 320        |
# |    iterations           | 30         |
# |    time_elapsed         | 1531       |
# |    total_timesteps      | 491520     |
# | train/                  |            |
# |    approx_kl            | 0.03493233 |
# |    clip_fraction        | 0.338      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.29      |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0249    |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.0226    |
# |    std                  | 0.814      |
# |    value_loss           | 0.017      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 146         |
# |    ep_rew_mean          | 348         |
# | time/                   |             |
# |    fps                  | 322         |
# |    iterations           | 31          |
# |    time_elapsed         | 1576        |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.034476064 |
# |    clip_fraction        | 0.341       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.25       |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0204     |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0222     |
# |    std                  | 0.809       |
# |    value_loss           | 0.0196      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 144        |
# |    ep_rew_mean          | 350        |
# | time/                   |            |
# |    fps                  | 323        |
# |    iterations           | 32         |
# |    time_elapsed         | 1621       |
# |    total_timesteps      | 524288     |
# | train/                  |            |
# |    approx_kl            | 0.03352803 |
# |    clip_fraction        | 0.328      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.22      |
# |    explained_variance   | 0.955      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0213    |
# |    n_updates            | 620        |
# |    policy_gradient_loss | -0.0199    |
# |    std                  | 0.805      |
# |    value_loss           | 0.0202     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 143         |
# |    ep_rew_mean          | 351         |
# | time/                   |             |
# |    fps                  | 324         |
# |    iterations           | 33          |
# |    time_elapsed         | 1666        |
# |    total_timesteps      | 540672      |
# | train/                  |             |
# |    approx_kl            | 0.033693235 |
# |    clip_fraction        | 0.333       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.18       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00892    |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.0209     |
# |    std                  | 0.8         |
# |    value_loss           | 0.015       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 143         |
# |    ep_rew_mean          | 353         |
# | time/                   |             |
# |    fps                  | 325         |
# |    iterations           | 34          |
# |    time_elapsed         | 1710        |
# |    total_timesteps      | 557056      |
# | train/                  |             |
# |    approx_kl            | 0.037048213 |
# |    clip_fraction        | 0.356       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.11       |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00257    |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.0222     |
# |    std                  | 0.791       |
# |    value_loss           | 0.0178      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 144        |
# |    ep_rew_mean          | 360        |
# | time/                   |            |
# |    fps                  | 326        |
# |    iterations           | 35         |
# |    time_elapsed         | 1755       |
# |    total_timesteps      | 573440     |
# | train/                  |            |
# |    approx_kl            | 0.03473663 |
# |    clip_fraction        | 0.345      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.04      |
# |    explained_variance   | 0.972      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.032     |
# |    n_updates            | 680        |
# |    policy_gradient_loss | -0.0212    |
# |    std                  | 0.781      |
# |    value_loss           | 0.0129     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 142         |
# |    ep_rew_mean          | 359         |
# | time/                   |             |
# |    fps                  | 327         |
# |    iterations           | 36          |
# |    time_elapsed         | 1800        |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.038269285 |
# |    clip_fraction        | 0.352       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.98       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0191     |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.0205     |
# |    std                  | 0.773       |
# |    value_loss           | 0.013       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 145         |
# |    ep_rew_mean          | 370         |
# | time/                   |             |
# |    fps                  | 328         |
# |    iterations           | 37          |
# |    time_elapsed         | 1845        |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.039398752 |
# |    clip_fraction        | 0.36        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.93       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.016      |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.0225     |
# |    std                  | 0.767       |
# |    value_loss           | 0.0128      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 143         |
# |    ep_rew_mean          | 370         |
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 38          |
# |    time_elapsed         | 1890        |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.040114097 |
# |    clip_fraction        | 0.369       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.87       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00849    |
# |    n_updates            | 740         |
# |    policy_gradient_loss | -0.0236     |
# |    std                  | 0.759       |
# |    value_loss           | 0.00979     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 145        |
# |    ep_rew_mean          | 385        |
# | time/                   |            |
# |    fps                  | 330        |
# |    iterations           | 39         |
# |    time_elapsed         | 1935       |
# |    total_timesteps      | 638976     |
# | train/                  |            |
# |    approx_kl            | 0.04170978 |
# |    clip_fraction        | 0.375      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.78      |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0194    |
# |    n_updates            | 760        |
# |    policy_gradient_loss | -0.0216    |
# |    std                  | 0.749      |
# |    value_loss           | 0.0121     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 142       |
# |    ep_rew_mean          | 379       |
# | time/                   |           |
# |    fps                  | 331       |
# |    iterations           | 40        |
# |    time_elapsed         | 1979      |
# |    total_timesteps      | 655360    |
# | train/                  |           |
# |    approx_kl            | 0.0421288 |
# |    clip_fraction        | 0.379     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.71     |
# |    explained_variance   | 0.981     |
# |    learning_rate        | 0.00025   |
# |    loss                 | -0.0219   |
# |    n_updates            | 780       |
# |    policy_gradient_loss | -0.022    |
# |    std                  | 0.739     |
# |    value_loss           | 0.00891   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 140        |
# |    ep_rew_mean          | 379        |
# | time/                   |            |
# |    fps                  | 331        |
# |    iterations           | 41         |
# |    time_elapsed         | 2024       |
# |    total_timesteps      | 671744     |
# | train/                  |            |
# |    approx_kl            | 0.04178624 |
# |    clip_fraction        | 0.387      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.64      |
# |    explained_variance   | 0.974      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.000275   |
# |    n_updates            | 800        |
# |    policy_gradient_loss | -0.0199    |
# |    std                  | 0.732      |
# |    value_loss           | 0.0124     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 142         |
# |    ep_rew_mean          | 387         |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 42          |
# |    time_elapsed         | 2068        |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.041500762 |
# |    clip_fraction        | 0.381       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.58       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0392     |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.0205     |
# |    std                  | 0.725       |
# |    value_loss           | 0.00979     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 136         |
# |    ep_rew_mean          | 374         |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 43          |
# |    time_elapsed         | 2114        |
# |    total_timesteps      | 704512      |
# | train/                  |             |
# |    approx_kl            | 0.045131974 |
# |    clip_fraction        | 0.391       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.51       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0251     |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0223     |
# |    std                  | 0.717       |
# |    value_loss           | 0.00674     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 139        |
# |    ep_rew_mean          | 393        |
# | time/                   |            |
# |    fps                  | 333        |
# |    iterations           | 44         |
# |    time_elapsed         | 2159       |
# |    total_timesteps      | 720896     |
# | train/                  |            |
# |    approx_kl            | 0.04291126 |
# |    clip_fraction        | 0.383      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.45      |
# |    explained_variance   | 0.977      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0277    |
# |    n_updates            | 860        |
# |    policy_gradient_loss | -0.0178    |
# |    std                  | 0.71       |
# |    value_loss           | 0.0135     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 139         |
# |    ep_rew_mean          | 393         |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 45          |
# |    time_elapsed         | 2203        |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.044954065 |
# |    clip_fraction        | 0.398       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.41       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0507     |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0195     |
# |    std                  | 0.704       |
# |    value_loss           | 0.00966     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 138         |
# |    ep_rew_mean          | 394         |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 46          |
# |    time_elapsed         | 2248        |
# |    total_timesteps      | 753664      |
# | train/                  |             |
# |    approx_kl            | 0.048652735 |
# |    clip_fraction        | 0.407       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.35       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0278     |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0188     |
# |    std                  | 0.698       |
# |    value_loss           | 0.0122      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 140         |
# |    ep_rew_mean          | 405         |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 47          |
# |    time_elapsed         | 2293        |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.044030137 |
# |    clip_fraction        | 0.407       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.29       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.011      |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0173     |
# |    std                  | 0.692       |
# |    value_loss           | 0.0151      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 138        |
# |    ep_rew_mean          | 406        |
# | time/                   |            |
# |    fps                  | 336        |
# |    iterations           | 48         |
# |    time_elapsed         | 2338       |
# |    total_timesteps      | 786432     |
# | train/                  |            |
# |    approx_kl            | 0.04349181 |
# |    clip_fraction        | 0.399      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.25      |
# |    explained_variance   | 0.981      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0248    |
# |    n_updates            | 940        |
# |    policy_gradient_loss | -0.0199    |
# |    std                  | 0.687      |
# |    value_loss           | 0.00845    |
# ----------------------------------------
# Eval num_timesteps=800000, episode_reward=452.02 +/- 7.66
# Episode length: 137.80 +/- 2.79
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 138        |
# |    mean_reward          | 452        |
# | time/                   |            |
# |    total_timesteps      | 800000     |
# | train/                  |            |
# |    approx_kl            | 0.04637424 |
# |    clip_fraction        | 0.409      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.2       |
# |    explained_variance   | 0.989      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0293    |
# |    n_updates            | 960        |
# |    policy_gradient_loss | -0.0219    |
# |    std                  | 0.682      |
# |    value_loss           | 0.00648    |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 139      |
# |    ep_rew_mean     | 409      |
# | time/              |          |
# |    fps             | 336      |
# |    iterations      | 49       |
# |    time_elapsed    | 2384     |
# |    total_timesteps | 802816   |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 140       |
# |    ep_rew_mean          | 418       |
# | time/                   |           |
# |    fps                  | 337       |
# |    iterations           | 50        |
# |    time_elapsed         | 2428      |
# |    total_timesteps      | 819200    |
# | train/                  |           |
# |    approx_kl            | 0.0489202 |
# |    clip_fraction        | 0.416     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.15     |
# |    explained_variance   | 0.978     |
# |    learning_rate        | 0.00025   |
# |    loss                 | -0.0348   |
# |    n_updates            | 980       |
# |    policy_gradient_loss | -0.0198   |
# |    std                  | 0.676     |
# |    value_loss           | 0.011     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 140        |
# |    ep_rew_mean          | 420        |
# | time/                   |            |
# |    fps                  | 337        |
# |    iterations           | 51         |
# |    time_elapsed         | 2473       |
# |    total_timesteps      | 835584     |
# | train/                  |            |
# |    approx_kl            | 0.04828642 |
# |    clip_fraction        | 0.414      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.09      |
# |    explained_variance   | 0.98       |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.00715   |
# |    n_updates            | 1000       |
# |    policy_gradient_loss | -0.0189    |
# |    std                  | 0.67       |
# |    value_loss           | 0.00684    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 141        |
# |    ep_rew_mean          | 427        |
# | time/                   |            |
# |    fps                  | 338        |
# |    iterations           | 52         |
# |    time_elapsed         | 2518       |
# |    total_timesteps      | 851968     |
# | train/                  |            |
# |    approx_kl            | 0.04552875 |
# |    clip_fraction        | 0.411      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.06      |
# |    explained_variance   | 0.984      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0241    |
# |    n_updates            | 1020       |
# |    policy_gradient_loss | -0.0189    |
# |    std                  | 0.667      |
# |    value_loss           | 0.0079     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 137         |
# |    ep_rew_mean          | 420         |
# | time/                   |             |
# |    fps                  | 338         |
# |    iterations           | 53          |
# |    time_elapsed         | 2564        |
# |    total_timesteps      | 868352      |
# | train/                  |             |
# ...
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.425     |
# |    explained_variance   | 0.995      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0305    |
# |    n_updates            | 5760       |
# |    policy_gradient_loss | -0.00123   |
# |    std                  | 0.261      |
# |    value_loss           | 0.00188    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 198        |
# |    ep_rew_mean          | 904        |
# | time/                   |            |
# |    fps                  | 432        |
# |    iterations           | 290        |
# |    time_elapsed         | 10995      |
# |    total_timesteps      | 4751360    |
# | train/                  |            |
# |    approx_kl            | 0.21360952 |
# |    clip_fraction        | 0.668      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.436     |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0256    |
# |    n_updates            | 5780       |
# |    policy_gradient_loss | -0.00344   |
# |    std                  | 0.261      |
# |    value_loss           | 0.00285    |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 195      |
# |    ep_rew_mean          | 894      |
# | time/                   |          |
# |    fps                  | 432      |
# |    iterations           | 291      |
# |    time_elapsed         | 11020    |
# |    total_timesteps      | 4767744  |
# | train/                  |          |
# |    approx_kl            | 0.199391 |
# |    clip_fraction        | 0.666    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.45    |
# |    explained_variance   | 0.996    |
# |    learning_rate        | 0.00025  |
# |    loss                 | -0.0248  |
# |    n_updates            | 5800     |
# |    policy_gradient_loss | -0.0031  |
# |    std                  | 0.261    |
# |    value_loss           | 0.00201  |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 199        |
# |    ep_rew_mean          | 921        |
# | time/                   |            |
# |    fps                  | 433        |
# |    iterations           | 292        |
# |    time_elapsed         | 11044      |
# |    total_timesteps      | 4784128    |
# | train/                  |            |
# |    approx_kl            | 0.18161444 |
# |    clip_fraction        | 0.66       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.431     |
# |    explained_variance   | 0.993      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.032     |
# |    n_updates            | 5820       |
# |    policy_gradient_loss | -0.00275   |
# |    std                  | 0.26       |
# |    value_loss           | 0.00326    |
# ----------------------------------------
# Eval num_timesteps=4800000, episode_reward=953.83 +/- 12.28
# Episode length: 204.40 +/- 4.54
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 204        |
# |    mean_reward          | 954        |
# | time/                   |            |
# |    total_timesteps      | 4800000    |
# | train/                  |            |
# |    approx_kl            | 0.22850777 |
# |    clip_fraction        | 0.669      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.388     |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.00989   |
# |    n_updates            | 5840       |
# |    policy_gradient_loss | 0.000351   |
# |    std                  | 0.258      |
# |    value_loss           | 0.00161    |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 194      |
# |    ep_rew_mean     | 896      |
# | time/              |          |
# |    fps             | 433      |
# |    iterations      | 293      |
# |    time_elapsed    | 11069    |
# |    total_timesteps | 4800512  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 191        |
# |    ep_rew_mean          | 882        |
# | time/                   |            |
# |    fps                  | 434        |
# |    iterations           | 294        |
# |    time_elapsed         | 11093      |
# |    total_timesteps      | 4816896    |
# | train/                  |            |
# |    approx_kl            | 0.19802745 |
# |    clip_fraction        | 0.676      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.405     |
# |    explained_variance   | 0.991      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.00192    |
# |    n_updates            | 5860       |
# |    policy_gradient_loss | -0.000447  |
# |    std                  | 0.259      |
# |    value_loss           | 0.00354    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 184        |
# |    ep_rew_mean          | 845        |
# | time/                   |            |
# |    fps                  | 434        |
# |    iterations           | 295        |
# |    time_elapsed         | 11116      |
# |    total_timesteps      | 4833280    |
# | train/                  |            |
# |    approx_kl            | 0.19499755 |
# |    clip_fraction        | 0.672      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.41      |
# |    explained_variance   | 0.985      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0266    |
# |    n_updates            | 5880       |
# |    policy_gradient_loss | -0.00141   |
# |    std                  | 0.259      |
# |    value_loss           | 0.00951    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 197        |
# |    ep_rew_mean          | 909        |
# | time/                   |            |
# |    fps                  | 435        |
# |    iterations           | 296        |
# |    time_elapsed         | 11140      |
# |    total_timesteps      | 4849664    |
# | train/                  |            |
# |    approx_kl            | 0.21934181 |
# |    clip_fraction        | 0.655      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.406     |
# |    explained_variance   | 0.962      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.145      |
# |    n_updates            | 5900       |
# |    policy_gradient_loss | 0.00265    |
# |    std                  | 0.259      |
# |    value_loss           | 0.0235     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 193        |
# |    ep_rew_mean          | 894        |
# | time/                   |            |
# |    fps                  | 435        |
# |    iterations           | 297        |
# |    time_elapsed         | 11164      |
# |    total_timesteps      | 4866048    |
# | train/                  |            |
# |    approx_kl            | 0.27528983 |
# |    clip_fraction        | 0.673      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.372     |
# |    explained_variance   | 0.995      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0384    |
# |    n_updates            | 5920       |
# |    policy_gradient_loss | 0.0066     |
# |    std                  | 0.257      |
# |    value_loss           | 0.00156    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 193        |
# |    ep_rew_mean          | 891        |
# | time/                   |            |
# |    fps                  | 436        |
# |    iterations           | 298        |
# |    time_elapsed         | 11188      |
# |    total_timesteps      | 4882432    |
# | train/                  |            |
# |    approx_kl            | 0.19471362 |
# |    clip_fraction        | 0.664      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.342     |
# |    explained_variance   | 0.984      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.0516     |
# |    n_updates            | 5940       |
# |    policy_gradient_loss | 0.00385    |
# |    std                  | 0.256      |
# |    value_loss           | 0.0101     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 194        |
# |    ep_rew_mean          | 901        |
# | time/                   |            |
# |    fps                  | 436        |
# |    iterations           | 299        |
# |    time_elapsed         | 11212      |
# |    total_timesteps      | 4898816    |
# | train/                  |            |
# |    approx_kl            | 0.27705446 |
# |    clip_fraction        | 0.671      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.307     |
# |    explained_variance   | 0.984      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.0318     |
# |    n_updates            | 5960       |
# |    policy_gradient_loss | 0.00518    |
# |    std                  | 0.254      |
# |    value_loss           | 0.0113     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 196        |
# |    ep_rew_mean          | 905        |
# | time/                   |            |
# |    fps                  | 437        |
# |    iterations           | 300        |
# |    time_elapsed         | 11236      |
# |    total_timesteps      | 4915200    |
# | train/                  |            |
# |    approx_kl            | 0.27288306 |
# |    clip_fraction        | 0.697      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.288     |
# |    explained_variance   | 0.983      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.0351     |
# |    n_updates            | 5980       |
# |    policy_gradient_loss | 0.00658    |
# |    std                  | 0.255      |
# |    value_loss           | 0.00391    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 196        |
# |    ep_rew_mean          | 900        |
# | time/                   |            |
# |    fps                  | 437        |
# |    iterations           | 301        |
# |    time_elapsed         | 11261      |
# |    total_timesteps      | 4931584    |
# | train/                  |            |
# |    approx_kl            | 0.21971232 |
# |    clip_fraction        | 0.684      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.293     |
# |    explained_variance   | 0.991      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0222    |
# |    n_updates            | 6000       |
# |    policy_gradient_loss | -0.000109  |
# |    std                  | 0.254      |
# |    value_loss           | 0.00385    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 198        |
# |    ep_rew_mean          | 906        |
# | time/                   |            |
# |    fps                  | 438        |
# |    iterations           | 302        |
# |    time_elapsed         | 11284      |
# |    total_timesteps      | 4947968    |
# | train/                  |            |
# |    approx_kl            | 0.23632535 |
# |    clip_fraction        | 0.686      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.332     |
# |    explained_variance   | 0.992      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0287    |
# |    n_updates            | 6020       |
# |    policy_gradient_loss | -0.00399   |
# |    std                  | 0.256      |
# |    value_loss           | 0.00336    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 194       |
# |    ep_rew_mean          | 898       |
# | time/                   |           |
# |    fps                  | 438       |
# |    iterations           | 303       |
# |    time_elapsed         | 11309     |
# |    total_timesteps      | 4964352   |
# | train/                  |           |
# |    approx_kl            | 0.3422467 |
# |    clip_fraction        | 0.686     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.309    |
# |    explained_variance   | 0.995     |
# |    learning_rate        | 0.00025   |
# |    loss                 | -0.0116   |
# |    n_updates            | 6040      |
# |    policy_gradient_loss | 0.00078   |
# |    std                  | 0.254     |
# |    value_loss           | 0.00233   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 200       |
# |    ep_rew_mean          | 927       |
# | time/                   |           |
# |    fps                  | 439       |
# |    iterations           | 304       |
# |    time_elapsed         | 11332     |
# |    total_timesteps      | 4980736   |
# | train/                  |           |
# |    approx_kl            | 0.2976582 |
# |    clip_fraction        | 0.693     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.302    |
# |    explained_variance   | 0.988     |
# |    learning_rate        | 0.00025   |
# |    loss                 | -0.0113   |
# |    n_updates            | 6060      |
# |    policy_gradient_loss | 0.00222   |
# |    std                  | 0.254     |
# |    value_loss           | 0.00406   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 201        |
# |    ep_rew_mean          | 923        |
# | time/                   |            |
# |    fps                  | 439        |
# |    iterations           | 305        |
# |    time_elapsed         | 11357      |
# |    total_timesteps      | 4997120    |
# | train/                  |            |
# |    approx_kl            | 0.21743517 |
# |    clip_fraction        | 0.678      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.306     |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0411    |
# |    n_updates            | 6080       |
# |    policy_gradient_loss | 0.0019     |
# |    std                  | 0.255      |
# |    value_loss           | 0.0011     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 197        |
# |    ep_rew_mean          | 906        |
# | time/                   |            |
# |    fps                  | 440        |
# |    iterations           | 306        |
# |    time_elapsed         | 11381      |
# |    total_timesteps      | 5013504    |
# | train/                  |            |
# |    approx_kl            | 0.22243488 |
# |    clip_fraction        | 0.688      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.305     |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0195    |
# |    n_updates            | 6100       |
# |    policy_gradient_loss | -0.00535   |
# |    std                  | 0.254      |
# |    value_loss           | 0.00179    |
# ----------------------------------------

# %%
# Load model and evaluate
model = PPO.load("./models/ppo_walker2d_final", device=device)

venv = make_vec_env(ENV_ID, n_envs=1, seed=42)
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

mean_reward, std_reward = evaluate_policy(model, venv, n_eval_episodes=10, deterministic=True)
print(f"Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Mean reward: 939.21 +/- 36.64

# %%
# Visualize the agent
import os
os.environ["MUJOCO_GL"] = "glfw"

import gymnasium as gym
import imageio
import numpy as np
from IPython.display import Video, display
import tempfile

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

ENV_ID = "Walker2d-v5"
N_EVAL_EPISODES = 10
MAX_STEPS = 1500
FPS = 30

# create env
env = gym.make(ENV_ID, render_mode="rgb_array")
venv = DummyVecEnv([lambda: env])
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

# load model
# model = PPO.load("./models/ppo_humanoid_final", device="cpu")
model = PPO.load("./best_model/best_model", device="cpu")

best_frames = []
best_length = 0

for ep in range(N_EVAL_EPISODES):
    obs = venv.reset()
    frames = []

    for step in range(MAX_STEPS):
        action, _ = model.predict(obs, deterministic=True)
        obs, rewards, dones, infos = venv.step(action)

        frame = env.render()
        if frame is not None:
            frames.append(frame)

        if dones[0]:
            break

    ep_length = len(frames)
    print(f"Episode {ep+1}: {ep_length} frames")

    if ep_length > best_length:
        best_length = ep_length
        best_frames = frames

print(f"\nLongest episode length: {best_length} frames")

# save and display only the longest episode
tmp = tempfile.NamedTemporaryFile(suffix=".mp4", delete=False).name
writer = imageio.get_writer(tmp, fps=FPS, codec="libx264")
for f in best_frames:
    writer.append_data(f)
writer.close()

display(Video(tmp, embed=True))
# Out:
# Episode 1: 180 frames
# Episode 2: 201 frames
# Episode 3: 206 frames
# Episode 4: 183 frames
# Episode 5: 200 frames
# Episode 6: 204 frames
# Episode 7: 201 frames
# Episode 8: 202 frames
# Episode 9: 200 frames
# Episode 10: 206 frames
#
# Longest episode length: 206 frames
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
