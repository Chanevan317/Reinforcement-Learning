# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.5.1
# CUDA available: True
# CUDA device count: 1
# GPU name: NVIDIA GeForce RTX 4080 SUPER

# %%
# Quick checks
import sys, platform
import torch
print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())
print("PyTorch:", torch.__version__, "| CUDA available:", torch.cuda.is_available())
import mujoco
print("MuJoCo package version:", mujoco.__version__)
# Out:
# Python: 3.10.19
# Platform: Windows-10-10.0.26200-SP0
# PyTorch: 2.5.1 | CUDA available: True
# MuJoCo package version: 3.4.0

# %%
# Imports
import os
import gymnasium as gym
import numpy as np
import torch
from stable_baselines3 import SAC
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecNormalize, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback
from stable_baselines3.common.evaluation import evaluate_policy

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Env setup
ENV_ID = "Ant-v5"   # requires mujoco >= 2.3
n_envs = 4               # on Windows + single CPU, 4 is reasonable; reduce if CPU bound
seed = 0

# Make vectorized training envs
train_env = make_vec_env(
    ENV_ID,
    n_envs=n_envs,
    seed=seed,
    monitor_dir="./logs/train_monitor"
)

# VecNormalize (important for continuous control)
train_env = VecNormalize(train_env, norm_obs=True, norm_reward=True, clip_obs=10.0)

# eval env
eval_env = make_vec_env(
    ENV_ID,
    n_envs=1,
    seed=seed + 100,
    monitor_dir="./logs/eval_monitor"
)
eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

print("Obs space:", train_env.observation_space)
print("Act space:", train_env.action_space)
# Out:
# Obs space: Box(-inf, inf, (105,), float64)
# Act space: Box(-1.0, 1.0, (8,), float32)

# %%
# Create SAC
model = SAC(
    "MlpPolicy", 
    train_env,
    learning_rate=3e-4,
    buffer_size=int(1e6),
    batch_size=256,
    gamma=0.99,
    tau=0.005,
    ent_coef="auto",
    train_freq=1,
    gradient_steps=1,
    policy_kwargs=dict(net_arch=[256, 256]),
    device=device,
    verbose=1,
)
# Out:
# Using cuda device

# %%
# Callbacks and save dirs
os.makedirs("./models", exist_ok=True)
os.makedirs("./checkpoints", exist_ok=True)
os.makedirs("./best_model", exist_ok=True)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./best_model/",
    log_path="./logs/eval",
    eval_freq=100_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False
)

checkpoint_callback = CheckpointCallback(save_freq=500_000, save_path="./checkpoints/", name_prefix="sac_ant")

# %%
# Train
TOTAL_TIMESTEPS = int(5e6)  
model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=[eval_callback, checkpoint_callback])
model.save("./models/sac_ant_final")
# save VecNormalize
train_env.save("./models/vecnormalize_train.pkl")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 37.5     |
# |    ep_rew_mean     | -14.5    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 435      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 540      |
# | train/             |          |
# |    actor_loss      | -11.1    |
# |    critic_loss     | 1.08     |
# |    ent_coef        | 0.968    |
# |    ent_coef_loss   | -0.435   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 109      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51       |
# |    ep_rew_mean     | -7.98    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 390      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1572     |
# | train/             |          |
# |    actor_loss      | -15.2    |
# |    critic_loss     | 0.863    |
# |    ent_coef        | 0.896    |
# |    ent_coef_loss   | -1.48    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 367      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 197      |
# |    ep_rew_mean     | -81.7    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 391      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 1.92     |
# |    ent_coef        | 0.747    |
# |    ent_coef_loss   | -3.91    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 974      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 225      |
# |    ep_rew_mean     | -95.9    |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 391      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 4076     |
# | train/             |          |
# |    actor_loss      | -24.1    |
# |    critic_loss     | 2.32     |
# |    ent_coef        | 0.743    |
# |    ent_coef_loss   | -4       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 993      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 189      |
# |    ep_rew_mean     | -78.5    |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 392      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 4568     |
# | train/             |          |
# |    actor_loss      | -26      |
# |    critic_loss     | 0.85     |
# |    ent_coef        | 0.716    |
# |    ent_coef_loss   | -4.49    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1116     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 173      |
# |    ep_rew_mean     | -75.9    |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 393      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 4916     |
# | train/             |          |
# |    actor_loss      | -26.9    |
# |    critic_loss     | 1.03     |
# |    ent_coef        | 0.697    |
# |    ent_coef_loss   | -4.81    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1203     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 196      |
# |    ep_rew_mean     | -90.1    |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 398      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 6268     |
# | train/             |          |
# |    actor_loss      | -31.5    |
# |    critic_loss     | 0.797    |
# |    ent_coef        | 0.631    |
# |    ent_coef_loss   | -6.09    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1541     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 176      |
# |    ep_rew_mean     | -82.3    |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 399      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 6652     |
# | train/             |          |
# |    actor_loss      | -32.3    |
# |    critic_loss     | 2.53     |
# |    ent_coef        | 0.613    |
# |    ent_coef_loss   | -6.44    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1637     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 162      |
# |    ep_rew_mean     | -76      |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 398      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 7492     |
# | train/             |          |
# |    actor_loss      | -34.3    |
# |    critic_loss     | 1.41     |
# |    ent_coef        | 0.576    |
# |    ent_coef_loss   | -7.26    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1847     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 202      |
# |    ep_rew_mean     | -98.2    |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 396      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 9528     |
# | train/             |          |
# |    actor_loss      | -39.1    |
# |    critic_loss     | 1.33     |
# |    ent_coef        | 0.495    |
# |    ent_coef_loss   | -9.16    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2356     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 213      |
# |    ep_rew_mean     | -108     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 395      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 10592    |
# | train/             |          |
# |    actor_loss      | -40.4    |
# |    critic_loss     | 3.51     |
# |    ent_coef        | 0.458    |
# |    ent_coef_loss   | -10.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2622     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -103     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 393      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 11440    |
# | train/             |          |
# |    actor_loss      | -42.1    |
# |    critic_loss     | 2.72     |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -10.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2834     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 208      |
# |    ep_rew_mean     | -107     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 388      |
# |    time_elapsed    | 31       |
# |    total_timesteps | 12348    |
# | train/             |          |
# |    actor_loss      | -43.6    |
# |    critic_loss     | 2.68     |
# |    ent_coef        | 0.402    |
# |    ent_coef_loss   | -11.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3061     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 212      |
# |    ep_rew_mean     | -112     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 383      |
# |    time_elapsed    | 33       |
# |    total_timesteps | 13024    |
# | train/             |          |
# |    actor_loss      | -44      |
# |    critic_loss     | 3.96     |
# |    ent_coef        | 0.383    |
# |    ent_coef_loss   | -12.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3230     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 202      |
# |    ep_rew_mean     | -108     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 377      |
# |    time_elapsed    | 37       |
# |    total_timesteps | 14008    |
# | train/             |          |
# |    actor_loss      | -45.9    |
# |    critic_loss     | 3.45     |
# |    ent_coef        | 0.356    |
# |    ent_coef_loss   | -13      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3476     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 216      |
# |    ep_rew_mean     | -118     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 376      |
# |    time_elapsed    | 39       |
# |    total_timesteps | 14964    |
# | train/             |          |
# |    actor_loss      | -46.3    |
# |    critic_loss     | 1.35     |
# |    ent_coef        | 0.332    |
# |    ent_coef_loss   | -14.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3715     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 209      |
# |    ep_rew_mean     | -116     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 374      |
# |    time_elapsed    | 40       |
# |    total_timesteps | 15260    |
# | train/             |          |
# |    actor_loss      | -46.6    |
# |    critic_loss     | 2.06     |
# |    ent_coef        | 0.325    |
# |    ent_coef_loss   | -14.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3789     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 214      |
# |    ep_rew_mean     | -122     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 374      |
# |    time_elapsed    | 41       |
# |    total_timesteps | 15500    |
# | train/             |          |
# |    actor_loss      | -46.3    |
# |    critic_loss     | 1.59     |
# |    ent_coef        | 0.319    |
# |    ent_coef_loss   | -14.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3849     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 206      |
# |    ep_rew_mean     | -119     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 374      |
# |    time_elapsed    | 41       |
# |    total_timesteps | 15700    |
# | train/             |          |
# |    actor_loss      | -47      |
# |    critic_loss     | 3.16     |
# |    ent_coef        | 0.314    |
# |    ent_coef_loss   | -14.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 199      |
# |    ep_rew_mean     | -115     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 374      |
# |    time_elapsed    | 42       |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -47.3    |
# |    critic_loss     | 1.83     |
# |    ent_coef        | 0.307    |
# |    ent_coef_loss   | -15.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3974     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 192      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 374      |
# |    time_elapsed    | 43       |
# |    total_timesteps | 16136    |
# | train/             |          |
# |    actor_loss      | -47.6    |
# |    critic_loss     | 2.18     |
# |    ent_coef        | 0.304    |
# |    ent_coef_loss   | -15.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4008     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 184      |
# |    ep_rew_mean     | -107     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 374      |
# |    time_elapsed    | 43       |
# |    total_timesteps | 16280    |
# | train/             |          |
# |    actor_loss      | -47.4    |
# |    critic_loss     | 6.05     |
# |    ent_coef        | 0.301    |
# |    ent_coef_loss   | -15.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4044     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | -105     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 374      |
# |    time_elapsed    | 44       |
# |    total_timesteps | 16792    |
# | train/             |          |
# |    actor_loss      | -47.2    |
# |    critic_loss     | 4.78     |
# |    ent_coef        | 0.29     |
# |    ent_coef_loss   | -15.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4172     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 177      |
# |    ep_rew_mean     | -104     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 373      |
# |    time_elapsed    | 45       |
# |    total_timesteps | 17044    |
# | train/             |          |
# |    actor_loss      | -47.2    |
# |    critic_loss     | 3.81     |
# |    ent_coef        | 0.285    |
# |    ent_coef_loss   | -15.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4235     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 170      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 373      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 17204    |
# | train/             |          |
# |    actor_loss      | -47.9    |
# |    critic_loss     | 3.03     |
# |    ent_coef        | 0.281    |
# |    ent_coef_loss   | -15.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4275     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 171      |
# |    ep_rew_mean     | -102     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 372      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 17424    |
# | train/             |          |
# |    actor_loss      | -48.2    |
# |    critic_loss     | 3.11     |
# |    ent_coef        | 0.277    |
# |    ent_coef_loss   | -16.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4330     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 170      |
# |    ep_rew_mean     | -103     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 372      |
# |    time_elapsed    | 47       |
# |    total_timesteps | 17612    |
# | train/             |          |
# |    actor_loss      | -47.8    |
# |    critic_loss     | 1.94     |
# |    ent_coef        | 0.273    |
# |    ent_coef_loss   | -16.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4377     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 161      |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 371      |
# |    time_elapsed    | 47       |
# |    total_timesteps | 17832    |
# | train/             |          |
# |    actor_loss      | -48.5    |
# |    critic_loss     | 3.32     |
# |    ent_coef        | 0.269    |
# |    ent_coef_loss   | -16.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4432     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | -90.9    |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 371      |
# |    time_elapsed    | 48       |
# |    total_timesteps | 18004    |
# | train/             |          |
# |    actor_loss      | -47.8    |
# |    critic_loss     | 4.96     |
# |    ent_coef        | 0.265    |
# |    ent_coef_loss   | -16.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4475     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | -91.9    |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 370      |
# |    time_elapsed    | 49       |
# |    total_timesteps | 18240    |
# | train/             |          |
# |    actor_loss      | -47.6    |
# |    critic_loss     | 2.99     |
# |    ent_coef        | 0.261    |
# |    ent_coef_loss   | -16.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4534     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | -91.7    |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 369      |
# |    time_elapsed    | 52       |
# |    total_timesteps | 19252    |
# | train/             |          |
# |    actor_loss      | -48.5    |
# |    critic_loss     | 8.17     |
# |    ent_coef        | 0.242    |
# |    ent_coef_loss   | -17.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4787     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 132      |
# |    ep_rew_mean     | -88.1    |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 368      |
# |    time_elapsed    | 57       |
# |    total_timesteps | 21172    |
# | train/             |          |
# |    actor_loss      | -48.9    |
# |    critic_loss     | 2.59     |
# |    ent_coef        | 0.211    |
# |    ent_coef_loss   | -18.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5267     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | -95.3    |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 368      |
# |    time_elapsed    | 58       |
# |    total_timesteps | 21716    |
# | train/             |          |
# |    actor_loss      | -48.5    |
# |    critic_loss     | 6.98     |
# |    ent_coef        | 0.202    |
# |    ent_coef_loss   | -18.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5403     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 152      |
# |    ep_rew_mean     | -102     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 368      |
# |    time_elapsed    | 59       |
# |    total_timesteps | 22064    |
# | train/             |          |
# |    actor_loss      | -48.6    |
# |    critic_loss     | 5.28     |
# |    ent_coef        | 0.197    |
# |    ent_coef_loss   | -18.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5490     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | -98.9    |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 367      |
# |    time_elapsed    | 60       |
# |    total_timesteps | 22312    |
# | train/             |          |
# |    actor_loss      | -48.8    |
# |    critic_loss     | 1.8      |
# |    ent_coef        | 0.194    |
# |    ent_coef_loss   | -19.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5552     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 132      |
# |    ep_rew_mean     | -93.4    |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 367      |
# |    time_elapsed    | 61       |
# |    total_timesteps | 22660    |
# | train/             |          |
# |    actor_loss      | -49.2    |
# |    critic_loss     | 2.75     |
# |    ent_coef        | 0.189    |
# |    ent_coef_loss   | -20.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5639     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | -93.2    |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 367      |
# |    time_elapsed    | 63       |
# |    total_timesteps | 23228    |
# | train/             |          |
# |    actor_loss      | -48.3    |
# |    critic_loss     | 2.33     |
# |    ent_coef        | 0.182    |
# |    ent_coef_loss   | -20.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5781     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | -96.9    |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 366      |
# |    time_elapsed    | 72       |
# |    total_timesteps | 26636    |
# | train/             |          |
# |    actor_loss      | -47.6    |
# |    critic_loss     | 3.41     |
# |    ent_coef        | 0.142    |
# |    ent_coef_loss   | -21.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6633     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | -98.8    |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 366      |
# |    time_elapsed    | 73       |
# |    total_timesteps | 26972    |
# | train/             |          |
# |    actor_loss      | -48.3    |
# |    critic_loss     | 1.83     |
# |    ent_coef        | 0.139    |
# |    ent_coef_loss   | -22.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6717     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | -99.1    |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 366      |
# |    time_elapsed    | 74       |
# |    total_timesteps | 27344    |
# | train/             |          |
# |    actor_loss      | -47.2    |
# |    critic_loss     | 2.08     |
# |    ent_coef        | 0.135    |
# |    ent_coef_loss   | -21.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6810     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 136      |
# |    ep_rew_mean     | -104     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 366      |
# |    time_elapsed    | 75       |
# |    total_timesteps | 27552    |
# | train/             |          |
# |    actor_loss      | -47.3    |
# |    critic_loss     | 4.14     |
# |    ent_coef        | 0.133    |
# |    ent_coef_loss   | -21.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6862     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 144      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 367      |
# |    time_elapsed    | 85       |
# |    total_timesteps | 31344    |
# | train/             |          |
# |    actor_loss      | -46      |
# |    critic_loss     | 1.87     |
# |    ent_coef        | 0.102    |
# |    ent_coef_loss   | -23.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7810     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 163      |
# |    ep_rew_mean     | -128     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 367      |
# |    time_elapsed    | 86       |
# |    total_timesteps | 31772    |
# | train/             |          |
# |    actor_loss      | -46.6    |
# |    critic_loss     | 4.75     |
# |    ent_coef        | 0.0989   |
# |    ent_coef_loss   | -24.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7917     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 172      |
# |    ep_rew_mean     | -136     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 365      |
# |    time_elapsed    | 97       |
# |    total_timesteps | 35644    |
# | train/             |          |
# |    actor_loss      | -44.2    |
# |    critic_loss     | 2.27     |
# |    ent_coef        | 0.0753   |
# |    ent_coef_loss   | -24      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8885     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | -154     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 365      |
# |    time_elapsed    | 98       |
# |    total_timesteps | 35992    |
# | train/             |          |
# |    actor_loss      | -44      |
# |    critic_loss     | 4.67     |
# |    ent_coef        | 0.0735   |
# |    ent_coef_loss   | -25.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8972     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -163     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 364      |
# |    time_elapsed    | 100      |
# |    total_timesteps | 36572    |
# | train/             |          |
# |    actor_loss      | -44.3    |
# |    critic_loss     | 1.31     |
# |    ent_coef        | 0.0706   |
# |    ent_coef_loss   | -24.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9117     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 207      |
# |    ep_rew_mean     | -173     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 364      |
# |    time_elapsed    | 105      |
# |    total_timesteps | 38452    |
# | train/             |          |
# |    actor_loss      | -43.3    |
# |    critic_loss     | 1.71     |
# |    ent_coef        | 0.0618   |
# |    ent_coef_loss   | -25.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9587     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 224      |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 364      |
# |    time_elapsed    | 109      |
# |    total_timesteps | 40072    |
# | train/             |          |
# |    actor_loss      | -42.9    |
# |    critic_loss     | 1.07     |
# |    ent_coef        | 0.0552   |
# |    ent_coef_loss   | -26.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9992     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 224      |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 364      |
# |    time_elapsed    | 111      |
# |    total_timesteps | 40696    |
# | train/             |          |
# |    actor_loss      | -41.9    |
# |    critic_loss     | 4.32     |
# |    ent_coef        | 0.0528   |
# |    ent_coef_loss   | -23.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10148    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 244      |
# |    ep_rew_mean     | -210     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 363      |
# |    time_elapsed    | 117      |
# |    total_timesteps | 42840    |
# | train/             |          |
# |    actor_loss      | -41.1    |
# |    critic_loss     | 5.22     |
# |    ent_coef        | 0.0455   |
# |    ent_coef_loss   | -27.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10684    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 256      |
# |    ep_rew_mean     | -223     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 361      |
# |    time_elapsed    | 123      |
# |    total_timesteps | 44664    |
# | train/             |          |
# |    actor_loss      | -40      |
# |    critic_loss     | 1.21     |
# |    ent_coef        | 0.0401   |
# |    ent_coef_loss   | -25.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11140    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 267      |
# |    ep_rew_mean     | -235     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 361      |
# |    time_elapsed    | 125      |
# |    total_timesteps | 45212    |
# | train/             |          |
# |    actor_loss      | -39.8    |
# |    critic_loss     | 1.11     |
# |    ent_coef        | 0.0386   |
# |    ent_coef_loss   | -23.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11277    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 277      |
# |    ep_rew_mean     | -246     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 360      |
# |    time_elapsed    | 127      |
# |    total_timesteps | 45820    |
# | train/             |          |
# |    actor_loss      | -39.4    |
# |    critic_loss     | 1.8      |
# |    ent_coef        | 0.037    |
# |    ent_coef_loss   | -23.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11429    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 282      |
# |    ep_rew_mean     | -252     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 359      |
# |    time_elapsed    | 131      |
# |    total_timesteps | 47116    |
# | train/             |          |
# |    actor_loss      | -39.1    |
# |    critic_loss     | 1.05     |
# |    ent_coef        | 0.0339   |
# |    ent_coef_loss   | -26.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11753    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 314      |
# |    ep_rew_mean     | -283     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 355      |
# |    time_elapsed    | 140      |
# |    total_timesteps | 49948    |
# | train/             |          |
# |    actor_loss      | -37.3    |
# |    critic_loss     | 1.99     |
# |    ent_coef        | 0.0279   |
# |    ent_coef_loss   | -25.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12461    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 318      |
# |    ep_rew_mean     | -288     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 354      |
# |    time_elapsed    | 143      |
# |    total_timesteps | 50892    |
# | train/             |          |
# |    actor_loss      | -37.2    |
# |    critic_loss     | 2.21     |
# |    ent_coef        | 0.0261   |
# |    ent_coef_loss   | -26.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12697    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 322      |
# |    ep_rew_mean     | -295     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 353      |
# |    time_elapsed    | 147      |
# |    total_timesteps | 52264    |
# | train/             |          |
# |    actor_loss      | -36.6    |
# |    critic_loss     | 1.22     |
# |    ent_coef        | 0.0238   |
# |    ent_coef_loss   | -24.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13040    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 323      |
# |    ep_rew_mean     | -301     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 352      |
# |    time_elapsed    | 150      |
# |    total_timesteps | 53108    |
# | train/             |          |
# |    actor_loss      | -35.9    |
# |    critic_loss     | 0.571    |
# |    ent_coef        | 0.0225   |
# |    ent_coef_loss   | -23.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13251    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 316      |
# |    ep_rew_mean     | -297     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 351      |
# |    time_elapsed    | 154      |
# |    total_timesteps | 54304    |
# | train/             |          |
# |    actor_loss      | -35.3    |
# |    critic_loss     | 0.804    |
# |    ent_coef        | 0.0208   |
# |    ent_coef_loss   | -23.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13550    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 318      |
# |    ep_rew_mean     | -302     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 349      |
# |    time_elapsed    | 158      |
# |    total_timesteps | 55616    |
# | train/             |          |
# |    actor_loss      | -34.9    |
# |    critic_loss     | 0.994    |
# |    ent_coef        | 0.019    |
# |    ent_coef_loss   | -27.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13878    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 354      |
# |    ep_rew_mean     | -341     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 341      |
# |    time_elapsed    | 174      |
# |    total_timesteps | 59616    |
# | train/             |          |
# |    actor_loss      | -32.6    |
# |    critic_loss     | 1.05     |
# |    ent_coef        | 0.0146   |
# |    ent_coef_loss   | -22.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14878    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 364      |
# |    ep_rew_mean     | -353     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 338      |
# |    time_elapsed    | 179      |
# |    total_timesteps | 60800    |
# | train/             |          |
# |    actor_loss      | -32.3    |
# |    critic_loss     | 0.626    |
# |    ent_coef        | 0.0135   |
# |    ent_coef_loss   | -24.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15174    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 364      |
# |    ep_rew_mean     | -357     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 335      |
# |    time_elapsed    | 184      |
# |    total_timesteps | 61868    |
# | train/             |          |
# |    actor_loss      | -31.2    |
# |    critic_loss     | 0.915    |
# |    ent_coef        | 0.0126   |
# |    ent_coef_loss   | -21      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15441    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 367      |
# |    ep_rew_mean     | -362     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 331      |
# |    time_elapsed    | 189      |
# |    total_timesteps | 62820    |
# | train/             |          |
# |    actor_loss      | -31.1    |
# |    critic_loss     | 0.667    |
# |    ent_coef        | 0.0118   |
# |    ent_coef_loss   | -21      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15679    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 377      |
# |    ep_rew_mean     | -373     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 327      |
# |    time_elapsed    | 196      |
# |    total_timesteps | 64264    |
# | train/             |          |
# |    actor_loss      | -30.4    |
# |    critic_loss     | 0.614    |
# |    ent_coef        | 0.0108   |
# |    ent_coef_loss   | -21.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16040    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 368      |
# |    ep_rew_mean     | -370     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 321      |
# |    time_elapsed    | 205      |
# |    total_timesteps | 65884    |
# | train/             |          |
# |    actor_loss      | -29.4    |
# |    critic_loss     | 1        |
# |    ent_coef        | 0.00972  |
# |    ent_coef_loss   | -16.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16445    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 378      |
# |    ep_rew_mean     | -384     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 314      |
# |    time_elapsed    | 215      |
# |    total_timesteps | 67652    |
# | train/             |          |
# |    actor_loss      | -29.2    |
# |    critic_loss     | 0.311    |
# |    ent_coef        | 0.0087   |
# |    ent_coef_loss   | -19.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16887    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 368      |
# |    ep_rew_mean     | -380     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 304      |
# |    time_elapsed    | 229      |
# |    total_timesteps | 70012    |
# | train/             |          |
# |    actor_loss      | -28      |
# |    critic_loss     | 0.41     |
# |    ent_coef        | 0.00751  |
# |    ent_coef_loss   | -19.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17477    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 359      |
# |    ep_rew_mean     | -371     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 300      |
# |    time_elapsed    | 236      |
# |    total_timesteps | 70896    |
# | train/             |          |
# |    actor_loss      | -27.9    |
# |    critic_loss     | 0.382    |
# |    ent_coef        | 0.00712  |
# |    ent_coef_loss   | -16.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17698    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 360      |
# |    ep_rew_mean     | -373     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 296      |
# |    time_elapsed    | 241      |
# |    total_timesteps | 71708    |
# | train/             |          |
# |    actor_loss      | -27.3    |
# |    critic_loss     | 0.91     |
# |    ent_coef        | 0.00677  |
# |    ent_coef_loss   | -17.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17901    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 349      |
# |    ep_rew_mean     | -364     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 294      |
# |    time_elapsed    | 244      |
# |    total_timesteps | 72076    |
# | train/             |          |
# |    actor_loss      | -27.3    |
# |    critic_loss     | 0.466    |
# |    ent_coef        | 0.00661  |
# |    ent_coef_loss   | -14.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17993    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 354      |
# |    ep_rew_mean     | -367     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 289      |
# |    time_elapsed    | 252      |
# |    total_timesteps | 73288    |
# | train/             |          |
# |    actor_loss      | -26.9    |
# |    critic_loss     | 0.433    |
# |    ent_coef        | 0.00614  |
# |    ent_coef_loss   | -21.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18296    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 337      |
# |    ep_rew_mean     | -354     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 283      |
# |    time_elapsed    | 263      |
# |    total_timesteps | 74800    |
# | train/             |          |
# |    actor_loss      | -26.3    |
# |    critic_loss     | 0.357    |
# |    ent_coef        | 0.00562  |
# |    ent_coef_loss   | -15.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18674    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 345      |
# |    ep_rew_mean     | -362     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 281      |
# |    time_elapsed    | 267      |
# |    total_timesteps | 75396    |
# | train/             |          |
# |    actor_loss      | -26.1    |
# |    critic_loss     | 0.502    |
# |    ent_coef        | 0.00542  |
# |    ent_coef_loss   | -17.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18823    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 344      |
# |    ep_rew_mean     | -365     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 273      |
# |    time_elapsed    | 284      |
# |    total_timesteps | 77748    |
# | train/             |          |
# |    actor_loss      | -24.7    |
# |    critic_loss     | 0.408    |
# |    ent_coef        | 0.00471  |
# |    ent_coef_loss   | -13.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19411    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 361      |
# |    ep_rew_mean     | -381     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 267      |
# |    time_elapsed    | 298      |
# |    total_timesteps | 79708    |
# | train/             |          |
# |    actor_loss      | -24.1    |
# |    critic_loss     | 0.302    |
# |    ent_coef        | 0.00421  |
# |    ent_coef_loss   | -13.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19901    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 353      |
# |    ep_rew_mean     | -375     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 261      |
# |    time_elapsed    | 312      |
# |    total_timesteps | 81712    |
# | train/             |          |
# |    actor_loss      | -23.4    |
# |    critic_loss     | 0.31     |
# |    ent_coef        | 0.00378  |
# |    ent_coef_loss   | -11.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20402    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 361      |
# |    ep_rew_mean     | -386     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 258      |
# |    time_elapsed    | 321      |
# |    total_timesteps | 82976    |
# | train/             |          |
# |    actor_loss      | -23      |
# |    critic_loss     | 0.329    |
# |    ent_coef        | 0.00352  |
# |    ent_coef_loss   | -10.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20718    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 395      |
# |    ep_rew_mean     | -424     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 249      |
# |    time_elapsed    | 348      |
# |    total_timesteps | 86976    |
# | train/             |          |
# |    actor_loss      | -21.5    |
# |    critic_loss     | 0.264    |
# |    ent_coef        | 0.00291  |
# |    ent_coef_loss   | 0.917    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21718    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 377      |
# |    ep_rew_mean     | -408     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 245      |
# |    time_elapsed    | 359      |
# |    total_timesteps | 88284    |
# | train/             |          |
# |    actor_loss      | -21.1    |
# |    critic_loss     | 0.186    |
# |    ent_coef        | 0.00271  |
# |    ent_coef_loss   | -6.74    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22045    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 382      |
# |    ep_rew_mean     | -413     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 241      |
# |    time_elapsed    | 371      |
# |    total_timesteps | 89804    |
# | train/             |          |
# |    actor_loss      | -20.8    |
# |    critic_loss     | 0.152    |
# |    ent_coef        | 0.00252  |
# |    ent_coef_loss   | -11.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22425    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 387      |
# |    ep_rew_mean     | -416     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 240      |
# |    time_elapsed    | 374      |
# |    total_timesteps | 90160    |
# | train/             |          |
# |    actor_loss      | -20.4    |
# |    critic_loss     | 0.203    |
# |    ent_coef        | 0.00248  |
# |    ent_coef_loss   | -6.26    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22514    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 379      |
# |    ep_rew_mean     | -409     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 237      |
# |    time_elapsed    | 385      |
# |    total_timesteps | 91508    |
# | train/             |          |
# |    actor_loss      | -20.2    |
# |    critic_loss     | 0.254    |
# |    ent_coef        | 0.00232  |
# |    ent_coef_loss   | -5.42    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22851    |
# ---------------------------------
# ...
# |    fps             | 135      |
# |    time_elapsed    | 36277    |
# |    total_timesteps | 4910056  |
# | train/             |          |
# |    actor_loss      | -1.8     |
# |    critic_loss     | 0.00239  |
# |    ent_coef        | 0.000399 |
# |    ent_coef_loss   | -0.826   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1227488  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 821      |
# |    ep_rew_mean     | 3.43e+03 |
# | time/              |          |
# |    episodes        | 6572     |
# |    fps             | 135      |
# |    time_elapsed    | 36301    |
# |    total_timesteps | 4914056  |
# | train/             |          |
# |    actor_loss      | -1.83    |
# |    critic_loss     | 0.00164  |
# |    ent_coef        | 0.000404 |
# |    ent_coef_loss   | -3.64    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1228488  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 816      |
# |    ep_rew_mean     | 3.41e+03 |
# | time/              |          |
# |    episodes        | 6576     |
# |    fps             | 135      |
# |    time_elapsed    | 36319    |
# |    total_timesteps | 4917136  |
# | train/             |          |
# |    actor_loss      | -1.82    |
# |    critic_loss     | 0.00166  |
# |    ent_coef        | 0.000406 |
# |    ent_coef_loss   | -5.69    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1229258  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 818      |
# |    ep_rew_mean     | 3.42e+03 |
# | time/              |          |
# |    episodes        | 6580     |
# |    fps             | 135      |
# |    time_elapsed    | 36338    |
# |    total_timesteps | 4920188  |
# | train/             |          |
# |    actor_loss      | -1.79    |
# |    critic_loss     | 0.002    |
# |    ent_coef        | 0.000403 |
# |    ent_coef_loss   | 2.19     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1230021  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 818      |
# |    ep_rew_mean     | 3.43e+03 |
# | time/              |          |
# |    episodes        | 6584     |
# |    fps             | 135      |
# |    time_elapsed    | 36358    |
# |    total_timesteps | 4923368  |
# | train/             |          |
# |    actor_loss      | -1.74    |
# |    critic_loss     | 0.00266  |
# |    ent_coef        | 0.000408 |
# |    ent_coef_loss   | -0.561   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1230816  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 809      |
# |    ep_rew_mean     | 3.38e+03 |
# | time/              |          |
# |    episodes        | 6588     |
# |    fps             | 135      |
# |    time_elapsed    | 36378    |
# |    total_timesteps | 4926744  |
# | train/             |          |
# |    actor_loss      | -1.78    |
# |    critic_loss     | 0.00185  |
# |    ent_coef        | 0.000412 |
# |    ent_coef_loss   | 0.871    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1231660  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 812      |
# |    ep_rew_mean     | 3.39e+03 |
# | time/              |          |
# |    episodes        | 6592     |
# |    fps             | 135      |
# |    time_elapsed    | 36403    |
# |    total_timesteps | 4930744  |
# | train/             |          |
# |    actor_loss      | -1.81    |
# |    critic_loss     | 0.00278  |
# |    ent_coef        | 0.000418 |
# |    ent_coef_loss   | 1.32     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1232660  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 821      |
# |    ep_rew_mean     | 3.38e+03 |
# | time/              |          |
# |    episodes        | 6596     |
# |    fps             | 135      |
# |    time_elapsed    | 36417    |
# |    total_timesteps | 4932940  |
# | train/             |          |
# |    actor_loss      | -1.79    |
# |    critic_loss     | 0.00216  |
# |    ent_coef        | 0.000417 |
# |    ent_coef_loss   | -1.22    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1233209  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 813      |
# |    ep_rew_mean     | 3.36e+03 |
# | time/              |          |
# |    episodes        | 6600     |
# |    fps             | 135      |
# |    time_elapsed    | 36430    |
# |    total_timesteps | 4935148  |
# | train/             |          |
# |    actor_loss      | -1.82    |
# |    critic_loss     | 0.00131  |
# |    ent_coef        | 0.000416 |
# |    ent_coef_loss   | 1.16     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1233761  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 814      |
# |    ep_rew_mean     | 3.33e+03 |
# | time/              |          |
# |    episodes        | 6604     |
# |    fps             | 135      |
# |    time_elapsed    | 36447    |
# |    total_timesteps | 4937944  |
# | train/             |          |
# |    actor_loss      | -1.75    |
# |    critic_loss     | 0.00179  |
# |    ent_coef        | 0.0004   |
# |    ent_coef_loss   | -3.17    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1234460  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 813      |
# |    ep_rew_mean     | 3.33e+03 |
# | time/              |          |
# |    episodes        | 6608     |
# |    fps             | 135      |
# |    time_elapsed    | 36472    |
# |    total_timesteps | 4941944  |
# | train/             |          |
# |    actor_loss      | -1.8     |
# |    critic_loss     | 0.00434  |
# |    ent_coef        | 0.000396 |
# |    ent_coef_loss   | 0.988    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1235460  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 807      |
# |    ep_rew_mean     | 3.31e+03 |
# | time/              |          |
# |    episodes        | 6612     |
# |    fps             | 135      |
# |    time_elapsed    | 36495    |
# |    total_timesteps | 4945616  |
# | train/             |          |
# |    actor_loss      | -1.82    |
# |    critic_loss     | 0.00165  |
# |    ent_coef        | 0.000401 |
# |    ent_coef_loss   | 0.39     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1236378  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 796      |
# |    ep_rew_mean     | 3.27e+03 |
# | time/              |          |
# |    episodes        | 6616     |
# |    fps             | 135      |
# |    time_elapsed    | 36510    |
# |    total_timesteps | 4948204  |
# | train/             |          |
# |    actor_loss      | -1.79    |
# |    critic_loss     | 0.00256  |
# |    ent_coef        | 0.000403 |
# |    ent_coef_loss   | -0.839   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1237025  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 801      |
# |    ep_rew_mean     | 3.29e+03 |
# | time/              |          |
# |    episodes        | 6620     |
# |    fps             | 135      |
# |    time_elapsed    | 36532    |
# |    total_timesteps | 4951664  |
# | train/             |          |
# |    actor_loss      | -1.76    |
# |    critic_loss     | 0.00375  |
# |    ent_coef        | 0.000406 |
# |    ent_coef_loss   | 4.49     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1237890  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 800      |
# |    ep_rew_mean     | 3.29e+03 |
# | time/              |          |
# |    episodes        | 6624     |
# |    fps             | 135      |
# |    time_elapsed    | 36556    |
# |    total_timesteps | 4955664  |
# | train/             |          |
# |    actor_loss      | -1.82    |
# |    critic_loss     | 0.00271  |
# |    ent_coef        | 0.000416 |
# |    ent_coef_loss   | -1.16    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1238890  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 799      |
# |    ep_rew_mean     | 3.28e+03 |
# | time/              |          |
# |    episodes        | 6628     |
# |    fps             | 135      |
# |    time_elapsed    | 36570    |
# |    total_timesteps | 4958012  |
# | train/             |          |
# |    actor_loss      | -1.81    |
# |    critic_loss     | 0.00236  |
# |    ent_coef        | 0.000414 |
# |    ent_coef_loss   | 0.454    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1239477  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 803      |
# |    ep_rew_mean     | 3.3e+03  |
# | time/              |          |
# |    episodes        | 6632     |
# |    fps             | 135      |
# |    time_elapsed    | 36584    |
# |    total_timesteps | 4960204  |
# | train/             |          |
# |    actor_loss      | -1.79    |
# |    critic_loss     | 0.00163  |
# |    ent_coef        | 0.000398 |
# |    ent_coef_loss   | -1.07    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1240025  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 797      |
# |    ep_rew_mean     | 3.28e+03 |
# | time/              |          |
# |    episodes        | 6636     |
# |    fps             | 135      |
# |    time_elapsed    | 36605    |
# |    total_timesteps | 4963664  |
# | train/             |          |
# |    actor_loss      | -1.79    |
# |    critic_loss     | 0.0027   |
# |    ent_coef        | 0.000413 |
# |    ent_coef_loss   | 1.92     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1240890  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 799      |
# |    ep_rew_mean     | 3.28e+03 |
# | time/              |          |
# |    episodes        | 6640     |
# |    fps             | 135      |
# |    time_elapsed    | 36629    |
# |    total_timesteps | 4967664  |
# | train/             |          |
# |    actor_loss      | -1.78    |
# |    critic_loss     | 0.0019   |
# |    ent_coef        | 0.000408 |
# |    ent_coef_loss   | -1.61    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1241890  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 786      |
# |    ep_rew_mean     | 3.22e+03 |
# | time/              |          |
# |    episodes        | 6644     |
# |    fps             | 135      |
# |    time_elapsed    | 36644    |
# |    total_timesteps | 4970252  |
# | train/             |          |
# |    actor_loss      | -1.82    |
# |    critic_loss     | 0.0154   |
# |    ent_coef        | 0.000407 |
# |    ent_coef_loss   | -2.88    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1242537  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 791      |
# |    ep_rew_mean     | 3.24e+03 |
# | time/              |          |
# |    episodes        | 6648     |
# |    fps             | 135      |
# |    time_elapsed    | 36657    |
# |    total_timesteps | 4972824  |
# | train/             |          |
# |    actor_loss      | -1.75    |
# |    critic_loss     | 0.00239  |
# |    ent_coef        | 0.000407 |
# |    ent_coef_loss   | -0.904   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1243180  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 796      |
# |    ep_rew_mean     | 3.25e+03 |
# | time/              |          |
# |    episodes        | 6652     |
# |    fps             | 135      |
# |    time_elapsed    | 36679    |
# |    total_timesteps | 4976824  |
# | train/             |          |
# |    actor_loss      | -1.8     |
# |    critic_loss     | 0.00297  |
# |    ent_coef        | 0.000403 |
# |    ent_coef_loss   | 4.99     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1244180  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 798      |
# |    ep_rew_mean     | 3.26e+03 |
# | time/              |          |
# |    episodes        | 6656     |
# |    fps             | 135      |
# |    time_elapsed    | 36697    |
# |    total_timesteps | 4980188  |
# | train/             |          |
# |    actor_loss      | -1.8     |
# |    critic_loss     | 0.00164  |
# |    ent_coef        | 0.0004   |
# |    ent_coef_loss   | 0.53     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1245021  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 816      |
# |    ep_rew_mean     | 3.33e+03 |
# | time/              |          |
# |    episodes        | 6660     |
# |    fps             | 135      |
# |    time_elapsed    | 36718    |
# |    total_timesteps | 4984188  |
# | train/             |          |
# |    actor_loss      | -1.79    |
# |    critic_loss     | 0.00371  |
# |    ent_coef        | 0.000414 |
# |    ent_coef_loss   | 3.81     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1246021  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 820      |
# |    ep_rew_mean     | 3.35e+03 |
# | time/              |          |
# |    episodes        | 6664     |
# |    fps             | 135      |
# |    time_elapsed    | 36737    |
# |    total_timesteps | 4988188  |
# | train/             |          |
# |    actor_loss      | -1.83    |
# |    critic_loss     | 0.00195  |
# |    ent_coef        | 0.000412 |
# |    ent_coef_loss   | -0.228   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1247021  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 810      |
# |    ep_rew_mean     | 3.34e+03 |
# | time/              |          |
# |    episodes        | 6668     |
# |    fps             | 135      |
# |    time_elapsed    | 36747    |
# |    total_timesteps | 4990252  |
# | train/             |          |
# |    actor_loss      | -1.82    |
# |    critic_loss     | 0.00508  |
# |    ent_coef        | 0.000408 |
# |    ent_coef_loss   | 1.74     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1247537  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 804      |
# |    ep_rew_mean     | 3.31e+03 |
# | time/              |          |
# |    episodes        | 6672     |
# |    fps             | 135      |
# |    time_elapsed    | 36764    |
# |    total_timesteps | 4994128  |
# | train/             |          |
# |    actor_loss      | -1.81    |
# |    critic_loss     | 0.00183  |
# |    ent_coef        | 0.000412 |
# |    ent_coef_loss   | -0.874   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1248506  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 798      |
# |    ep_rew_mean     | 3.28e+03 |
# | time/              |          |
# |    episodes        | 6676     |
# |    fps             | 135      |
# |    time_elapsed    | 36779    |
# |    total_timesteps | 4997660  |
# | train/             |          |
# |    actor_loss      | -1.78    |
# |    critic_loss     | 0.0033   |
# |    ent_coef        | 0.000413 |
# |    ent_coef_loss   | 0.169    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1249389  |
# ---------------------------------

# %%
# Load model and evaluate
model = SAC.load("./models/sac_ant_final", device=device)

venv = make_vec_env(ENV_ID, n_envs=1, seed=42)
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

mean_reward, std_reward = evaluate_policy(model, venv, n_eval_episodes=10, deterministic=True)
print(f"Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Mean reward: 3101.92 +/- 1610.28

# %%
import os
os.environ["MUJOCO_GL"] = "glfw"

import gymnasium as gym
import imageio
import numpy as np
from IPython.display import Video, display
import tempfile

from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

ENV_ID = "Ant-v5"
N_EVAL_EPISODES = 10
MAX_STEPS = 1500
FPS = 30

# create env
env = gym.make(ENV_ID, render_mode="rgb_array")
venv = DummyVecEnv([lambda: env])
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

# load model
# model = SAC.load("./models/sac_humanoid_final", device="cpu")
model = SAC.load("./best_model/best_model", device="cpu")

best_frames = []
best_length = 0

for ep in range(N_EVAL_EPISODES):
    obs = venv.reset()
    frames = []

    for step in range(MAX_STEPS):
        action, _ = model.predict(obs, deterministic=True)
        obs, rewards, dones, infos = venv.step(action)

        frame = env.render()
        if frame is not None:
            frames.append(frame)

        if dones[0]:
            break

    ep_length = len(frames)
    print(f"Episode {ep+1}: {ep_length} frames")

    if ep_length > best_length:
        best_length = ep_length
        best_frames = frames

print(f"\nLongest episode length: {best_length} frames")

# save and display only the longest episode
tmp = tempfile.NamedTemporaryFile(suffix=".mp4", delete=False).name
writer = imageio.get_writer(tmp, fps=FPS, codec="libx264")
for f in best_frames:
    writer.append_data(f)
writer.close()

display(Video(tmp, embed=True))
# Out:
# Episode 1: 900 frames
# Episode 2: 348 frames
# Episode 3: 1000 frames
# Episode 4: 1000 frames
# Episode 5: 521 frames
# Episode 6: 1000 frames
# Episode 7: 1000 frames
# Episode 8: 888 frames
# Episode 9: 1000 frames
# Episode 10: 997 frames
#
# Longest episode length: 1000 frames
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
