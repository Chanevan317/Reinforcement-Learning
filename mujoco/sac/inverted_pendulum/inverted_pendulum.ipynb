# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.5.1
# CUDA available: True
# CUDA device count: 1
# GPU name: NVIDIA GeForce RTX 4080 SUPER

# %%
# Quick checks
import sys, platform
import torch
print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())
print("PyTorch:", torch.__version__, "| CUDA available:", torch.cuda.is_available())
import mujoco
print("MuJoCo package version:", mujoco.__version__)
# Out:
# Python: 3.10.19
# Platform: Windows-10-10.0.26200-SP0
# PyTorch: 2.5.1 | CUDA available: True
# MuJoCo package version: 3.4.0

# %%
# Imports
import os
import gymnasium as gym
import numpy as np
import torch
from stable_baselines3 import SAC
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecNormalize, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback
from stable_baselines3.common.evaluation import evaluate_policy

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Env setup
ENV_ID = "InvertedPendulum-v5"   # requires mujoco >= 2.3
n_envs = 4               # on Windows + single CPU, 4 is reasonable; reduce if CPU bound
seed = 0

# Make vectorized training envs
train_env = make_vec_env(
    ENV_ID,
    n_envs=n_envs,
    seed=seed,
    monitor_dir="./logs/train_monitor"
)

# VecNormalize (important for continuous control)
train_env = VecNormalize(train_env, norm_obs=True, norm_reward=True, clip_obs=10.0)

# eval env
eval_env = make_vec_env(
    ENV_ID,
    n_envs=1,
    seed=seed + 100,
    monitor_dir="./logs/eval_monitor"
)
eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

print("Obs space:", train_env.observation_space)
print("Act space:", train_env.action_space)
# Out:
# Obs space: Box(-inf, inf, (4,), float64)
# Act space: Box(-3.0, 3.0, (1,), float32)

# %%
# Create SAC
policy_kwargs = dict(net_arch=[dict(pi=[64, 64], vf=[64, 64])])

model = SAC(
    "MlpPolicy", 
    train_env,
    learning_rate=3e-4,
    buffer_size=int(5e5),
    batch_size=128,
    gamma=0.99,
    tau=0.005,
    ent_coef="auto",
    policy_kwargs=dict(net_arch=[128, 128]),
    device=device,
    verbose=1,
)
# Out:
# Using cuda device

# %%
# Callbacks and save dirs
os.makedirs("./models", exist_ok=True)
os.makedirs("./checkpoints", exist_ok=True)
os.makedirs("./best_model", exist_ok=True)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./best_model/",
    log_path="./logs/eval",
    eval_freq=100_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False
)

checkpoint_callback = CheckpointCallback(save_freq=500_000, save_path="./checkpoints/", name_prefix="sac_inverted_pendulum")

# %%
# Train
TOTAL_TIMESTEPS = int(5e5)
model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=[eval_callback, checkpoint_callback])
model.save("./models/sac_inverted_pendulum_final")
# save VecNormalize
train_env.save("./models/vecnormalize_train.pkl")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6        |
# |    ep_rew_mean     | 5        |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 4000     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 40       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.88     |
# |    ep_rew_mean     | 5.88     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 3999     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 64       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.23     |
# |    ep_rew_mean     | 5.23     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 4000     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 84       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.75     |
# |    ep_rew_mean     | 4.75     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 4000     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 100      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.52     |
# |    ep_rew_mean     | 4.52     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 421      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 124      |
# | train/             |          |
# |    actor_loss      | -0.769   |
# |    critic_loss     | 0.715    |
# |    ent_coef        | 0.999    |
# |    ent_coef_loss   | -0.00203 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5        |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.79     |
# |    ep_rew_mean     | 4.79     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 312      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 156      |
# | train/             |          |
# |    actor_loss      | -0.975   |
# |    critic_loss     | 0.514    |
# |    ent_coef        | 0.996    |
# |    ent_coef_loss   | -0.00601 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.29     |
# |    ep_rew_mean     | 5.29     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 277      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 180      |
# | train/             |          |
# |    actor_loss      | -1.13    |
# |    critic_loss     | 0.398    |
# |    ent_coef        | 0.995    |
# |    ent_coef_loss   | -0.00913 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6        |
# |    ep_rew_mean     | 5        |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 252      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | -1.23    |
# |    critic_loss     | 0.372    |
# |    ent_coef        | 0.993    |
# |    ent_coef_loss   | -0.0117  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.97     |
# |    ep_rew_mean     | 4.97     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 230      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 228      |
# | train/             |          |
# |    actor_loss      | -1.35    |
# |    critic_loss     | 0.299    |
# |    ent_coef        | 0.991    |
# |    ent_coef_loss   | -0.0152  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.8      |
# |    ep_rew_mean     | 4.8      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 221      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 252      |
# | train/             |          |
# |    actor_loss      | -1.4     |
# |    critic_loss     | 0.306    |
# |    ent_coef        | 0.989    |
# |    ent_coef_loss   | -0.0185  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.98     |
# |    ep_rew_mean     | 4.98     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 214      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 276      |
# | train/             |          |
# |    actor_loss      | -1.34    |
# |    critic_loss     | 0.242    |
# |    ent_coef        | 0.987    |
# |    ent_coef_loss   | -0.0211  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.82     |
# |    ep_rew_mean     | 4.82     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 209      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 292      |
# | train/             |          |
# |    actor_loss      | -1.33    |
# |    critic_loss     | 0.193    |
# |    ent_coef        | 0.986    |
# |    ent_coef_loss   | -0.0232  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.73     |
# |    ep_rew_mean     | 4.73     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 206      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 304      |
# | train/             |          |
# |    actor_loss      | -1.34    |
# |    critic_loss     | 0.165    |
# |    ent_coef        | 0.985    |
# |    ent_coef_loss   | -0.0246  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 50       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.64     |
# |    ep_rew_mean     | 4.64     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 202      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 324      |
# | train/             |          |
# |    actor_loss      | -1.36    |
# |    critic_loss     | 0.219    |
# |    ent_coef        | 0.984    |
# |    ent_coef_loss   | -0.0277  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 55       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.6      |
# |    ep_rew_mean     | 4.6      |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 200      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 340      |
# | train/             |          |
# |    actor_loss      | -1.34    |
# |    critic_loss     | 0.16     |
# |    ent_coef        | 0.983    |
# |    ent_coef_loss   | -0.0293  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 59       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.56     |
# |    ep_rew_mean     | 4.56     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 195      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 376      |
# | train/             |          |
# |    actor_loss      | -1.4     |
# |    critic_loss     | 0.168    |
# |    ent_coef        | 0.98     |
# |    ent_coef_loss   | -0.0332  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 68       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.56     |
# |    ep_rew_mean     | 4.56     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 191      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 404      |
# | train/             |          |
# |    actor_loss      | -1.49    |
# |    critic_loss     | 0.0928   |
# |    ent_coef        | 0.978    |
# |    ent_coef_loss   | -0.0371  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 75       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.71     |
# |    ep_rew_mean     | 4.71     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 187      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 428      |
# | train/             |          |
# |    actor_loss      | -1.45    |
# |    critic_loss     | 0.124    |
# |    ent_coef        | 0.976    |
# |    ent_coef_loss   | -0.0404  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 81       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.74     |
# |    ep_rew_mean     | 4.74     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 186      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 444      |
# | train/             |          |
# |    actor_loss      | -1.45    |
# |    critic_loss     | 0.108    |
# |    ent_coef        | 0.975    |
# |    ent_coef_loss   | -0.0425  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 85       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.7      |
# |    ep_rew_mean     | 4.7      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 184      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 464      |
# | train/             |          |
# |    actor_loss      | -1.47    |
# |    critic_loss     | 0.132    |
# |    ent_coef        | 0.974    |
# |    ent_coef_loss   | -0.0449  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 90       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.68     |
# |    ep_rew_mean     | 4.68     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 182      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 492      |
# | train/             |          |
# |    actor_loss      | -1.52    |
# |    critic_loss     | 0.109    |
# |    ent_coef        | 0.972    |
# |    ent_coef_loss   | -0.0488  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 97       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.73     |
# |    ep_rew_mean     | 4.73     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 180      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 520      |
# | train/             |          |
# |    actor_loss      | -1.55    |
# |    critic_loss     | 0.0797   |
# |    ent_coef        | 0.97     |
# |    ent_coef_loss   | -0.0515  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 104      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.66     |
# |    ep_rew_mean     | 4.66     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 179      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 532      |
# | train/             |          |
# |    actor_loss      | -1.56    |
# |    critic_loss     | 0.103    |
# |    ent_coef        | 0.969    |
# |    ent_coef_loss   | -0.0537  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 107      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.68     |
# |    ep_rew_mean     | 4.68     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 178      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 560      |
# | train/             |          |
# |    actor_loss      | -1.57    |
# |    critic_loss     | 0.107    |
# |    ent_coef        | 0.967    |
# |    ent_coef_loss   | -0.0563  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 114      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.67     |
# |    ep_rew_mean     | 4.67     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 177      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 572      |
# | train/             |          |
# |    actor_loss      | -1.57    |
# |    critic_loss     | 0.115    |
# |    ent_coef        | 0.966    |
# |    ent_coef_loss   | -0.0589  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 117      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.58     |
# |    ep_rew_mean     | 4.58     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 176      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 584      |
# | train/             |          |
# |    actor_loss      | -1.6     |
# |    critic_loss     | 0.069    |
# |    ent_coef        | 0.965    |
# |    ent_coef_loss   | -0.0595  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 120      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.43     |
# |    ep_rew_mean     | 4.43     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 175      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 608      |
# | train/             |          |
# |    actor_loss      | -1.63    |
# |    critic_loss     | 0.0809   |
# |    ent_coef        | 0.963    |
# |    ent_coef_loss   | -0.0637  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 126      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.57     |
# |    ep_rew_mean     | 4.57     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 174      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 644      |
# | train/             |          |
# |    actor_loss      | -1.65    |
# |    critic_loss     | 0.0751   |
# |    ent_coef        | 0.961    |
# |    ent_coef_loss   | -0.0679  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 135      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.73     |
# |    ep_rew_mean     | 4.73     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 173      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 672      |
# | train/             |          |
# |    actor_loss      | -1.64    |
# |    critic_loss     | 0.104    |
# |    ent_coef        | 0.959    |
# |    ent_coef_loss   | -0.0704  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 142      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.77     |
# |    ep_rew_mean     | 4.77     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 172      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 704      |
# | train/             |          |
# |    actor_loss      | -1.67    |
# |    critic_loss     | 0.114    |
# |    ent_coef        | 0.956    |
# |    ent_coef_loss   | -0.0747  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 150      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.73     |
# |    ep_rew_mean     | 4.73     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 171      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 720      |
# | train/             |          |
# |    actor_loss      | -1.62    |
# |    critic_loss     | 0.116    |
# |    ent_coef        | 0.955    |
# |    ent_coef_loss   | -0.0759  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 154      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.53     |
# |    ep_rew_mean     | 4.53     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 170      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 736      |
# | train/             |          |
# |    actor_loss      | -1.6     |
# |    critic_loss     | 0.117    |
# |    ent_coef        | 0.954    |
# |    ent_coef_loss   | -0.0785  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 158      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.58     |
# |    ep_rew_mean     | 4.58     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 170      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 760      |
# | train/             |          |
# |    actor_loss      | -1.74    |
# |    critic_loss     | 0.0805   |
# |    ent_coef        | 0.952    |
# |    ent_coef_loss   | -0.0826  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 164      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.57     |
# |    ep_rew_mean     | 4.57     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 170      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 784      |
# | train/             |          |
# |    actor_loss      | -1.69    |
# |    critic_loss     | 0.106    |
# |    ent_coef        | 0.951    |
# |    ent_coef_loss   | -0.0855  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 170      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.67     |
# |    ep_rew_mean     | 4.67     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 168      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 812      |
# | train/             |          |
# |    actor_loss      | -1.68    |
# |    critic_loss     | 0.082    |
# |    ent_coef        | 0.949    |
# |    ent_coef_loss   | -0.0879  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 177      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.73     |
# |    ep_rew_mean     | 4.73     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 168      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 832      |
# | train/             |          |
# |    actor_loss      | -1.72    |
# |    critic_loss     | 0.0717   |
# |    ent_coef        | 0.947    |
# |    ent_coef_loss   | -0.0913  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 182      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.59     |
# |    ep_rew_mean     | 4.59     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 166      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 868      |
# | train/             |          |
# |    actor_loss      | -1.71    |
# |    critic_loss     | 0.0894   |
# |    ent_coef        | 0.945    |
# |    ent_coef_loss   | -0.0941  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 191      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.93     |
# |    ep_rew_mean     | 4.93     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 166      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 904      |
# | train/             |          |
# |    actor_loss      | -1.83    |
# |    critic_loss     | 0.077    |
# |    ent_coef        | 0.942    |
# |    ent_coef_loss   | -0.0995  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 200      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.97     |
# |    ep_rew_mean     | 4.97     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 166      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 924      |
# | train/             |          |
# |    actor_loss      | -1.76    |
# |    critic_loss     | 0.101    |
# |    ent_coef        | 0.941    |
# |    ent_coef_loss   | -0.103   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 205      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.94     |
# |    ep_rew_mean     | 4.94     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 166      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 936      |
# | train/             |          |
# |    actor_loss      | -1.72    |
# |    critic_loss     | 0.12     |
# |    ent_coef        | 0.94     |
# |    ent_coef_loss   | -0.104   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 208      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.91     |
# |    ep_rew_mean     | 4.91     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 164      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 964      |
# | train/             |          |
# |    actor_loss      | -1.8     |
# |    critic_loss     | 0.0786   |
# |    ent_coef        | 0.938    |
# |    ent_coef_loss   | -0.106   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 215      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.94     |
# |    ep_rew_mean     | 4.94     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 164      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 988      |
# | train/             |          |
# |    actor_loss      | -1.75    |
# |    critic_loss     | 0.0993   |
# |    ent_coef        | 0.936    |
# |    ent_coef_loss   | -0.11    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 221      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.86     |
# |    ep_rew_mean     | 4.86     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 163      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1016     |
# | train/             |          |
# |    actor_loss      | -1.83    |
# |    critic_loss     | 0.0627   |
# |    ent_coef        | 0.934    |
# |    ent_coef_loss   | -0.114   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 228      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.94     |
# |    ep_rew_mean     | 4.94     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 163      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1048     |
# | train/             |          |
# |    actor_loss      | -1.83    |
# |    critic_loss     | 0.0879   |
# |    ent_coef        | 0.932    |
# |    ent_coef_loss   | -0.118   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 236      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.97     |
# |    ep_rew_mean     | 4.97     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 162      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1060     |
# | train/             |          |
# |    actor_loss      | -1.82    |
# |    critic_loss     | 0.0748   |
# |    ent_coef        | 0.931    |
# |    ent_coef_loss   | -0.119   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 239      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.95     |
# |    ep_rew_mean     | 4.95     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 162      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1080     |
# | train/             |          |
# |    actor_loss      | -1.7     |
# |    critic_loss     | 0.0821   |
# |    ent_coef        | 0.93     |
# |    ent_coef_loss   | -0.123   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 244      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.13     |
# |    ep_rew_mean     | 5.13     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 162      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1124     |
# | train/             |          |
# |    actor_loss      | -1.89    |
# |    critic_loss     | 0.0814   |
# |    ent_coef        | 0.927    |
# |    ent_coef_loss   | -0.129   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 255      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.16     |
# |    ep_rew_mean     | 5.16     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 162      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 1160     |
# | train/             |          |
# |    actor_loss      | -1.82    |
# |    critic_loss     | 0.111    |
# |    ent_coef        | 0.924    |
# |    ent_coef_loss   | -0.132   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 264      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.27     |
# |    ep_rew_mean     | 5.27     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 162      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 1180     |
# | train/             |          |
# |    actor_loss      | -1.88    |
# |    critic_loss     | 0.0787   |
# |    ent_coef        | 0.923    |
# |    ent_coef_loss   | -0.135   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 269      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.31     |
# |    ep_rew_mean     | 5.31     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 162      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 1208     |
# | train/             |          |
# |    actor_loss      | -1.83    |
# |    critic_loss     | 0.114    |
# |    ent_coef        | 0.921    |
# |    ent_coef_loss   | -0.136   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 276      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.42     |
# |    ep_rew_mean     | 5.42     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 162      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 1236     |
# | train/             |          |
# |    actor_loss      | -1.85    |
# |    critic_loss     | 0.0708   |
# |    ent_coef        | 0.919    |
# |    ent_coef_loss   | -0.141   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 283      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.58     |
# |    ep_rew_mean     | 5.58     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 162      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 1268     |
# | train/             |          |
# |    actor_loss      | -1.84    |
# |    critic_loss     | 0.078    |
# |    ent_coef        | 0.917    |
# |    ent_coef_loss   | -0.143   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 291      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.47     |
# |    ep_rew_mean     | 5.47     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 162      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1316     |
# | train/             |          |
# |    actor_loss      | -1.95    |
# |    critic_loss     | 0.0589   |
# |    ent_coef        | 0.914    |
# |    ent_coef_loss   | -0.151   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 303      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.47     |
# |    ep_rew_mean     | 5.47     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 162      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1340     |
# | train/             |          |
# |    actor_loss      | -1.93    |
# |    critic_loss     | 0.0456   |
# |    ent_coef        | 0.912    |
# |    ent_coef_loss   | -0.151   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 309      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.74     |
# |    ep_rew_mean     | 5.74     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 161      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1384     |
# | train/             |          |
# |    actor_loss      | -1.97    |
# |    critic_loss     | 0.0697   |
# |    ent_coef        | 0.909    |
# |    ent_coef_loss   | -0.162   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 320      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.82     |
# |    ep_rew_mean     | 5.82     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 161      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1404     |
# | train/             |          |
# |    actor_loss      | -1.99    |
# |    critic_loss     | 0.0722   |
# |    ent_coef        | 0.908    |
# |    ent_coef_loss   | -0.166   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 325      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.84     |
# |    ep_rew_mean     | 5.84     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 161      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1420     |
# | train/             |          |
# |    actor_loss      | -1.93    |
# |    critic_loss     | 0.0787   |
# |    ent_coef        | 0.907    |
# |    ent_coef_loss   | -0.162   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 329      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.87     |
# |    ep_rew_mean     | 5.87     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 161      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1452     |
# | train/             |          |
# |    actor_loss      | -2.03    |
# |    critic_loss     | 0.0702   |
# |    ent_coef        | 0.904    |
# |    ent_coef_loss   | -0.164   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 337      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.12     |
# |    ep_rew_mean     | 6.12     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 160      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1504     |
# | train/             |          |
# |    actor_loss      | -2.02    |
# |    critic_loss     | 0.0871   |
# |    ent_coef        | 0.901    |
# |    ent_coef_loss   | -0.178   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 350      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.11     |
# |    ep_rew_mean     | 6.11     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 160      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1536     |
# | train/             |          |
# |    actor_loss      | -2.03    |
# |    critic_loss     | 0.0725   |
# |    ent_coef        | 0.899    |
# |    ent_coef_loss   | -0.171   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 358      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.23     |
# |    ep_rew_mean     | 6.23     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 160      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1552     |
# | train/             |          |
# |    actor_loss      | -2.1     |
# |    critic_loss     | 0.0721   |
# |    ent_coef        | 0.898    |
# |    ent_coef_loss   | -0.181   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 362      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.28     |
# |    ep_rew_mean     | 6.28     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 159      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1612     |
# | train/             |          |
# |    actor_loss      | -2.14    |
# |    critic_loss     | 0.0872   |
# |    ent_coef        | 0.894    |
# |    ent_coef_loss   | -0.186   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 377      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.38     |
# |    ep_rew_mean     | 6.38     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 159      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1632     |
# | train/             |          |
# |    actor_loss      | -1.98    |
# |    critic_loss     | 0.0907   |
# |    ent_coef        | 0.892    |
# |    ent_coef_loss   | -0.184   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 382      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.25     |
# |    ep_rew_mean     | 6.25     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 159      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1656     |
# | train/             |          |
# |    actor_loss      | -2.12    |
# |    critic_loss     | 0.0886   |
# |    ent_coef        | 0.891    |
# |    ent_coef_loss   | -0.188   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 388      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.36     |
# |    ep_rew_mean     | 6.36     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 159      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1696     |
# | train/             |          |
# |    actor_loss      | -2.13    |
# |    critic_loss     | 0.104    |
# |    ent_coef        | 0.888    |
# |    ent_coef_loss   | -0.194   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 398      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.43     |
# |    ep_rew_mean     | 6.43     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 160      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1712     |
# | train/             |          |
# |    actor_loss      | -2.19    |
# |    critic_loss     | 0.0609   |
# |    ent_coef        | 0.887    |
# |    ent_coef_loss   | -0.197   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 402      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.68     |
# |    ep_rew_mean     | 6.68     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 159      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1748     |
# | train/             |          |
# |    actor_loss      | -2.06    |
# |    critic_loss     | 0.0839   |
# |    ent_coef        | 0.885    |
# |    ent_coef_loss   | -0.197   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 411      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.71     |
# |    ep_rew_mean     | 6.71     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 159      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 1784     |
# | train/             |          |
# |    actor_loss      | -2.11    |
# |    critic_loss     | 0.0667   |
# |    ent_coef        | 0.882    |
# |    ent_coef_loss   | -0.207   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 420      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7.72     |
# |    ep_rew_mean     | 6.72     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 159      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 1816     |
# | train/             |          |
# |    actor_loss      | -2.07    |
# |    critic_loss     | 0.0517   |
# |    ent_coef        | 0.88     |
# |    ent_coef_loss   | -0.21    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 428      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.08     |
# |    ep_rew_mean     | 7.08     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 159      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 1876     |
# | train/             |          |
# |    actor_loss      | -2.16    |
# |    critic_loss     | 0.077    |
# |    ent_coef        | 0.876    |
# |    ent_coef_loss   | -0.215   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 443      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.26     |
# |    ep_rew_mean     | 7.26     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 159      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 1916     |
# | train/             |          |
# |    actor_loss      | -2.21    |
# |    critic_loss     | 0.118    |
# |    ent_coef        | 0.874    |
# |    ent_coef_loss   | -0.218   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 453      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.17     |
# |    ep_rew_mean     | 7.17     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 159      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 1944     |
# | train/             |          |
# |    actor_loss      | -2.16    |
# |    critic_loss     | 0.105    |
# |    ent_coef        | 0.872    |
# |    ent_coef_loss   | -0.221   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 460      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.23     |
# |    ep_rew_mean     | 7.23     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 159      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 1980     |
# | train/             |          |
# |    actor_loss      | -2.27    |
# |    critic_loss     | 0.0501   |
# |    ent_coef        | 0.87     |
# |    ent_coef_loss   | -0.229   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 469      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.25     |
# |    ep_rew_mean     | 7.25     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 159      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 2012     |
# | train/             |          |
# |    actor_loss      | -2.16    |
# |    critic_loss     | 0.107    |
# |    ent_coef        | 0.868    |
# |    ent_coef_loss   | -0.231   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 477      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.27     |
# |    ep_rew_mean     | 7.27     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 158      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 2056     |
# | train/             |          |
# |    actor_loss      | -2.22    |
# |    critic_loss     | 0.0846   |
# |    ent_coef        | 0.865    |
# |    ent_coef_loss   | -0.237   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 488      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.56     |
# |    ep_rew_mean     | 7.56     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 158      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 2096     |
# | train/             |          |
# |    actor_loss      | -2.33    |
# |    critic_loss     | 0.0449   |
# |    ent_coef        | 0.862    |
# |    ent_coef_loss   | -0.232   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 498      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.67     |
# |    ep_rew_mean     | 7.67     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 158      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 2148     |
# | train/             |          |
# |    actor_loss      | -2.23    |
# |    critic_loss     | 0.0635   |
# |    ent_coef        | 0.859    |
# |    ent_coef_loss   | -0.242   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 511      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.76     |
# |    ep_rew_mean     | 7.76     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 158      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 2172     |
# | train/             |          |
# |    actor_loss      | -2.29    |
# |    critic_loss     | 0.0991   |
# |    ent_coef        | 0.858    |
# |    ent_coef_loss   | -0.248   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 517      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.89     |
# |    ep_rew_mean     | 7.89     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 158      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 2216     |
# | train/             |          |
# |    actor_loss      | -2.28    |
# |    critic_loss     | 0.0478   |
# |    ent_coef        | 0.855    |
# |    ent_coef_loss   | -0.256   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 528      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.69     |
# |    ep_rew_mean     | 7.69     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 158      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 2248     |
# | train/             |          |
# |    actor_loss      | -2.25    |
# |    critic_loss     | 0.0567   |
# |    ent_coef        | 0.853    |
# |    ent_coef_loss   | -0.249   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 536      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.05     |
# |    ep_rew_mean     | 8.05     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 158      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 2328     |
# | train/             |          |
# |    actor_loss      | -2.28    |
# |    critic_loss     | 0.103    |
# |    ent_coef        | 0.848    |
# |    ent_coef_loss   | -0.265   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 556      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.33     |
# |    ep_rew_mean     | 8.33     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 158      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 2412     |
# | train/             |          |
# |    actor_loss      | -2.37    |
# |    critic_loss     | 0.0923   |
# |    ent_coef        | 0.843    |
# |    ent_coef_loss   | -0.258   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 577      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.9      |
# |    ep_rew_mean     | 8.9      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 158      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 2444     |
# | train/             |          |
# |    actor_loss      | -2.33    |
# |    critic_loss     | 0.071    |
# |    ent_coef        | 0.841    |
# |    ent_coef_loss   | -0.285   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 585      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.88     |
# |    ep_rew_mean     | 8.88     |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 158      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 2508     |
# | train/             |          |
# |    actor_loss      | -2.37    |
# |    critic_loss     | 0.0783   |
# |    ent_coef        | 0.837    |
# |    ent_coef_loss   | -0.28    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 601      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.6     |
# |    ep_rew_mean     | 9.55     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 157      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 2576     |
# | train/             |          |
# |    actor_loss      | -2.5     |
# ...
# |    fps             | 103      |
# |    time_elapsed    | 4141     |
# |    total_timesteps | 430620   |
# | train/             |          |
# |    actor_loss      | -3.79    |
# |    critic_loss     | 0.00463  |
# |    ent_coef        | 0.000421 |
# |    ent_coef_loss   | -0.52    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 107629   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 539      |
# |    ep_rew_mean     | 538      |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 103      |
# |    time_elapsed    | 4177     |
# |    total_timesteps | 434176   |
# | train/             |          |
# |    actor_loss      | -3.77    |
# |    critic_loss     | 0.00213  |
# |    ent_coef        | 0.000504 |
# |    ent_coef_loss   | 4.62     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 108518   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 514      |
# |    ep_rew_mean     | 513      |
# | time/              |          |
# |    episodes        | 1204     |
# |    fps             | 103      |
# |    time_elapsed    | 4185     |
# |    total_timesteps | 435052   |
# | train/             |          |
# |    actor_loss      | -3.83    |
# |    critic_loss     | 0.000742 |
# |    ent_coef        | 0.00054  |
# |    ent_coef_loss   | 1.67     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 108737   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 481      |
# |    ep_rew_mean     | 480      |
# | time/              |          |
# |    episodes        | 1208     |
# |    fps             | 103      |
# |    time_elapsed    | 4192     |
# |    total_timesteps | 435708   |
# | train/             |          |
# |    actor_loss      | -3.83    |
# |    critic_loss     | 0.00142  |
# |    ent_coef        | 0.000567 |
# |    ent_coef_loss   | 1.56     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 108901   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 459      |
# |    ep_rew_mean     | 458      |
# | time/              |          |
# |    episodes        | 1212     |
# |    fps             | 103      |
# |    time_elapsed    | 4199     |
# |    total_timesteps | 436452   |
# | train/             |          |
# |    actor_loss      | -3.82    |
# |    critic_loss     | 0.000704 |
# |    ent_coef        | 0.000598 |
# |    ent_coef_loss   | 1.31     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 109087   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 459      |
# |    ep_rew_mean     | 458      |
# | time/              |          |
# |    episodes        | 1216     |
# |    fps             | 103      |
# |    time_elapsed    | 4205     |
# |    total_timesteps | 437056   |
# | train/             |          |
# |    actor_loss      | -3.82    |
# |    critic_loss     | 0.00116  |
# |    ent_coef        | 0.000624 |
# |    ent_coef_loss   | 2.04     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 109238   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 460      |
# |    ep_rew_mean     | 459      |
# | time/              |          |
# |    episodes        | 1220     |
# |    fps             | 103      |
# |    time_elapsed    | 4215     |
# |    total_timesteps | 438020   |
# | train/             |          |
# |    actor_loss      | -3.76    |
# |    critic_loss     | 0.00525  |
# |    ent_coef        | 0.000679 |
# |    ent_coef_loss   | 1.27     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 109479   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 461      |
# |    ep_rew_mean     | 460      |
# | time/              |          |
# |    episodes        | 1224     |
# |    fps             | 103      |
# |    time_elapsed    | 4224     |
# |    total_timesteps | 438984   |
# | train/             |          |
# |    actor_loss      | -3.86    |
# |    critic_loss     | 0.00356  |
# |    ent_coef        | 0.000733 |
# |    ent_coef_loss   | 3.25     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 109720   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 463      |
# |    ep_rew_mean     | 462      |
# | time/              |          |
# |    episodes        | 1228     |
# |    fps             | 103      |
# |    time_elapsed    | 4230     |
# |    total_timesteps | 439616   |
# | train/             |          |
# |    actor_loss      | -3.84    |
# |    critic_loss     | 0.000669 |
# |    ent_coef        | 0.000775 |
# |    ent_coef_loss   | 1.82     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 109878   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 465      |
# |    ep_rew_mean     | 464      |
# | time/              |          |
# |    episodes        | 1232     |
# |    fps             | 103      |
# |    time_elapsed    | 4242     |
# |    total_timesteps | 440792   |
# | train/             |          |
# |    actor_loss      | -3.78    |
# |    critic_loss     | 0.000688 |
# |    ent_coef        | 0.000834 |
# |    ent_coef_loss   | 3.03     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 110172   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 458      |
# |    ep_rew_mean     | 457      |
# | time/              |          |
# |    episodes        | 1236     |
# |    fps             | 103      |
# |    time_elapsed    | 4247     |
# |    total_timesteps | 441240   |
# | train/             |          |
# |    actor_loss      | -3.8     |
# |    critic_loss     | 0.00245  |
# |    ent_coef        | 0.000854 |
# |    ent_coef_loss   | 2.28     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 110284   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 442      |
# |    ep_rew_mean     | 441      |
# | time/              |          |
# |    episodes        | 1240     |
# |    fps             | 103      |
# |    time_elapsed    | 4260     |
# |    total_timesteps | 442592   |
# | train/             |          |
# |    actor_loss      | -3.83    |
# |    critic_loss     | 0.000593 |
# |    ent_coef        | 0.000874 |
# |    ent_coef_loss   | 0.0397   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 110622   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 413      |
# |    ep_rew_mean     | 412      |
# | time/              |          |
# |    episodes        | 1244     |
# |    fps             | 103      |
# |    time_elapsed    | 4265     |
# |    total_timesteps | 443092   |
# | train/             |          |
# |    actor_loss      | -3.68    |
# |    critic_loss     | 0.00544  |
# |    ent_coef        | 0.000893 |
# |    ent_coef_loss   | -0.832   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 110747   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 378      |
# |    ep_rew_mean     | 377      |
# | time/              |          |
# |    episodes        | 1248     |
# |    fps             | 103      |
# |    time_elapsed    | 4272     |
# |    total_timesteps | 443812   |
# | train/             |          |
# |    actor_loss      | -3.86    |
# |    critic_loss     | 0.0116   |
# |    ent_coef        | 0.000892 |
# |    ent_coef_loss   | -1.08    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 110927   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 386      |
# |    ep_rew_mean     | 385      |
# | time/              |          |
# |    episodes        | 1252     |
# |    fps             | 103      |
# |    time_elapsed    | 4311     |
# |    total_timesteps | 447812   |
# | train/             |          |
# |    actor_loss      | -3.84    |
# |    critic_loss     | 0.00119  |
# |    ent_coef        | 0.000789 |
# |    ent_coef_loss   | -1.98    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 111927   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 416      |
# |    ep_rew_mean     | 415      |
# | time/              |          |
# |    episodes        | 1256     |
# |    fps             | 103      |
# |    time_elapsed    | 4351     |
# |    total_timesteps | 451812   |
# | train/             |          |
# |    actor_loss      | -3.79    |
# |    critic_loss     | 0.000531 |
# |    ent_coef        | 0.000663 |
# |    ent_coef_loss   | -0.409   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 112927   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 442      |
# |    ep_rew_mean     | 442      |
# | time/              |          |
# |    episodes        | 1260     |
# |    fps             | 103      |
# |    time_elapsed    | 4390     |
# |    total_timesteps | 455812   |
# | train/             |          |
# |    actor_loss      | -3.84    |
# |    critic_loss     | 0.00446  |
# |    ent_coef        | 0.000552 |
# |    ent_coef_loss   | -0.878   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 113927   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 472      |
# |    ep_rew_mean     | 472      |
# | time/              |          |
# |    episodes        | 1264     |
# |    fps             | 103      |
# |    time_elapsed    | 4430     |
# |    total_timesteps | 459812   |
# | train/             |          |
# |    actor_loss      | -3.84    |
# |    critic_loss     | 0.00236  |
# |    ent_coef        | 0.000524 |
# |    ent_coef_loss   | -1.31    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 114927   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 499      |
# |    ep_rew_mean     | 498      |
# | time/              |          |
# |    episodes        | 1268     |
# |    fps             | 103      |
# |    time_elapsed    | 4469     |
# |    total_timesteps | 463812   |
# | train/             |          |
# |    actor_loss      | -3.81    |
# |    critic_loss     | 0.0014   |
# |    ent_coef        | 0.000474 |
# |    ent_coef_loss   | -0.232   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 115927   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 527      |
# |    ep_rew_mean     | 526      |
# | time/              |          |
# |    episodes        | 1272     |
# |    fps             | 103      |
# |    time_elapsed    | 4509     |
# |    total_timesteps | 467812   |
# | train/             |          |
# |    actor_loss      | -3.79    |
# |    critic_loss     | 0.00725  |
# |    ent_coef        | 0.000516 |
# |    ent_coef_loss   | -0.325   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 116927   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 560      |
# |    ep_rew_mean     | 560      |
# | time/              |          |
# |    episodes        | 1276     |
# |    fps             | 103      |
# |    time_elapsed    | 4548     |
# |    total_timesteps | 471812   |
# | train/             |          |
# |    actor_loss      | -3.77    |
# |    critic_loss     | 0.00122  |
# |    ent_coef        | 0.000539 |
# |    ent_coef_loss   | 0.809    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 117927   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 585      |
# |    ep_rew_mean     | 585      |
# | time/              |          |
# |    episodes        | 1280     |
# |    fps             | 103      |
# |    time_elapsed    | 4588     |
# |    total_timesteps | 475812   |
# | train/             |          |
# |    actor_loss      | -3.73    |
# |    critic_loss     | 0.000808 |
# |    ent_coef        | 0.000539 |
# |    ent_coef_loss   | 1.54     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 118927   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 608      |
# |    ep_rew_mean     | 607      |
# | time/              |          |
# |    episodes        | 1284     |
# |    fps             | 103      |
# |    time_elapsed    | 4627     |
# |    total_timesteps | 479812   |
# | train/             |          |
# |    actor_loss      | -3.79    |
# |    critic_loss     | 0.000485 |
# |    ent_coef        | 0.000537 |
# |    ent_coef_loss   | -0.111   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 119927   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 616      |
# |    ep_rew_mean     | 616      |
# | time/              |          |
# |    episodes        | 1288     |
# |    fps             | 103      |
# |    time_elapsed    | 4667     |
# |    total_timesteps | 483812   |
# | train/             |          |
# |    actor_loss      | -3.75    |
# |    critic_loss     | 0.00113  |
# |    ent_coef        | 0.000535 |
# |    ent_coef_loss   | 0.136    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 120927   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 616      |
# |    ep_rew_mean     | 616      |
# | time/              |          |
# |    episodes        | 1292     |
# |    fps             | 103      |
# |    time_elapsed    | 4706     |
# |    total_timesteps | 487812   |
# | train/             |          |
# |    actor_loss      | -3.8     |
# |    critic_loss     | 0.00365  |
# |    ent_coef        | 0.000568 |
# |    ent_coef_loss   | -0.262   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 121927   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 616      |
# |    ep_rew_mean     | 616      |
# | time/              |          |
# |    episodes        | 1296     |
# |    fps             | 103      |
# |    time_elapsed    | 4746     |
# |    total_timesteps | 491812   |
# | train/             |          |
# |    actor_loss      | -3.84    |
# |    critic_loss     | 0.000714 |
# |    ent_coef        | 0.000654 |
# |    ent_coef_loss   | 0.38     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 122927   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 620      |
# |    ep_rew_mean     | 619      |
# | time/              |          |
# |    episodes        | 1300     |
# |    fps             | 103      |
# |    time_elapsed    | 4786     |
# |    total_timesteps | 495812   |
# | train/             |          |
# |    actor_loss      | -3.81    |
# |    critic_loss     | 0.00151  |
# |    ent_coef        | 0.000743 |
# |    ent_coef_loss   | 1.05     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 123927   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 645      |
# |    ep_rew_mean     | 644      |
# | time/              |          |
# |    episodes        | 1304     |
# |    fps             | 103      |
# |    time_elapsed    | 4825     |
# |    total_timesteps | 499812   |
# | train/             |          |
# |    actor_loss      | -3.76    |
# |    critic_loss     | 0.000841 |
# |    ent_coef        | 0.000567 |
# |    ent_coef_loss   | 0.249    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 124927   |
# ---------------------------------

# %%
# Load model and evaluate
model = SAC.load("./models/sac_inverted_pendulum_final", device=device)

venv = make_vec_env(ENV_ID, n_envs=1, seed=42)
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

mean_reward, std_reward = evaluate_policy(model, venv, n_eval_episodes=10, deterministic=True)
print(f"Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Mean reward: 1000.00 +/- 0.00

# %%
# Visualize the agent
import os
os.environ["MUJOCO_GL"] = "glfw"

import gymnasium as gym
import imageio
import numpy as np
from IPython.display import Video, display
import tempfile

from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

ENV_ID = "InvertedPendulum-v5"
N_EVAL_EPISODES = 10
MAX_STEPS = 1500
FPS = 30

# create env
env = gym.make(ENV_ID, render_mode="rgb_array")
venv = DummyVecEnv([lambda: env])
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

# load model
# model = SAC.load("./models/sac_humanoid_final", device="cpu")
model = SAC.load("./best_model/best_model", device="cpu")

best_frames = []
best_length = 0

for ep in range(N_EVAL_EPISODES):
    obs = venv.reset()
    frames = []

    for step in range(MAX_STEPS):
        action, _ = model.predict(obs, deterministic=True)
        obs, rewards, dones, infos = venv.step(action)

        frame = env.render()
        if frame is not None:
            frames.append(frame)

        if dones[0]:
            break

    ep_length = len(frames)
    print(f"Episode {ep+1}: {ep_length} frames")

    if ep_length > best_length:
        best_length = ep_length
        best_frames = frames

print(f"\nLongest episode length: {best_length} frames")

# save and display only the longest episode
tmp = tempfile.NamedTemporaryFile(suffix=".mp4", delete=False).name
writer = imageio.get_writer(tmp, fps=FPS, codec="libx264")
for f in best_frames:
    writer.append_data(f)
writer.close()

display(Video(tmp, embed=True))
# Out:
# Episode 1: 140 frames
# Episode 2: 160 frames
# Episode 3: 166 frames
# Episode 4: 139 frames
# Episode 5: 185 frames
# Episode 6: 330 frames
# Episode 7: 160 frames
# Episode 8: 138 frames
# Episode 9: 219 frames
# Episode 10: 139 frames
#
# Longest episode length: 330 frames
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
