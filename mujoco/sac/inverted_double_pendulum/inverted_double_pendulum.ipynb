# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.5.1
# CUDA available: True
# CUDA device count: 1
# GPU name: NVIDIA GeForce RTX 4080 SUPER

# %%
# Quick checks
import sys, platform
import torch
print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())
print("PyTorch:", torch.__version__, "| CUDA available:", torch.cuda.is_available())
import mujoco
print("MuJoCo package version:", mujoco.__version__)
# Out:
# Python: 3.10.19
# Platform: Windows-10-10.0.26200-SP0
# PyTorch: 2.5.1 | CUDA available: True
# MuJoCo package version: 3.4.0

# %%
# Imports
import os
import gymnasium as gym
import numpy as np
import torch
from stable_baselines3 import SAC
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecNormalize, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback
from stable_baselines3.common.evaluation import evaluate_policy

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Env setup
ENV_ID = "InvertedDoublePendulum-v5"   # requires mujoco >= 2.3
n_envs = 4               # on Windows + single CPU, 4 is reasonable; reduce if CPU bound
seed = 0

# Make vectorized training envs
train_env = make_vec_env(
    ENV_ID,
    n_envs=n_envs,
    seed=seed,
    monitor_dir="./logs/train_monitor"
)

# VecNormalize (important for continuous control)
train_env = VecNormalize(train_env, norm_obs=True, norm_reward=True, clip_obs=10.0)

# eval env
eval_env = make_vec_env(
    ENV_ID,
    n_envs=1,
    seed=seed + 100,
    monitor_dir="./logs/eval_monitor"
)
eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

print("Obs space:", train_env.observation_space)
print("Act space:", train_env.action_space)
# Out:
# Obs space: Box(-inf, inf, (9,), float64)
# Act space: Box(-1.0, 1.0, (1,), float32)

# %%
# Create SAC
model = SAC(
    "MlpPolicy", 
    train_env,
    learning_rate=3e-4,
    buffer_size=int(5e5),
    batch_size=128,
    gamma=0.99,
    tau=0.005,
    ent_coef="auto",
    policy_kwargs=dict(net_arch=[128, 128]),
    device=device,
    verbose=1,
)
# Out:
# Using cuda device

# %%
# Callbacks and save dirs
os.makedirs("./models", exist_ok=True)
os.makedirs("./checkpoints", exist_ok=True)
os.makedirs("./best_model", exist_ok=True)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./best_model/",
    log_path="./logs/eval",
    eval_freq=100_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False
)

checkpoint_callback = CheckpointCallback(save_freq=500_000, save_path="./checkpoints/", name_prefix="sac_inverted_double_pendulum")

# %%
# Train
TOTAL_TIMESTEPS = int(1e6)
model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=[eval_callback, checkpoint_callback])
model.save("./models/sac_inverted_double_pendulum_final")
# save VecNormalize
train_env.save("./models/vecnormalize_train.pkl")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.17     |
# |    ep_rew_mean     | 45.9     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 1538     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 40       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6        |
# |    ep_rew_mean     | 44.4     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 1103     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 64       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.5      |
# |    ep_rew_mean     | 49.1     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 1292     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 84       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.19     |
# |    ep_rew_mean     | 46.2     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 816      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 104      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.05     |
# |    ep_rew_mean     | 44.9     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 372      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 128      |
# | train/             |          |
# |    actor_loss      | -0.747   |
# |    critic_loss     | 0.946    |
# |    ent_coef        | 0.999    |
# |    ent_coef_loss   | -0.00247 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6        |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.88     |
# |    ep_rew_mean     | 43.2     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 315      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 152      |
# | train/             |          |
# |    actor_loss      | -0.917   |
# |    critic_loss     | 0.806    |
# |    ent_coef        | 0.997    |
# |    ent_coef_loss   | -0.00555 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.86     |
# |    ep_rew_mean     | 43       |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 288      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 176      |
# | train/             |          |
# |    actor_loss      | -1.01    |
# |    critic_loss     | 0.686    |
# |    ent_coef        | 0.995    |
# |    ent_coef_loss   | -0.00849 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.06     |
# |    ep_rew_mean     | 44.9     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 267      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 204      |
# | train/             |          |
# |    actor_loss      | -1.19    |
# |    critic_loss     | 0.499    |
# |    ent_coef        | 0.993    |
# |    ent_coef_loss   | -0.0122  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6        |
# |    ep_rew_mean     | 44.4     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 255      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 224      |
# | train/             |          |
# |    actor_loss      | -1.28    |
# |    critic_loss     | 0.453    |
# |    ent_coef        | 0.991    |
# |    ent_coef_loss   | -0.0149  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 30       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.08     |
# |    ep_rew_mean     | 45.1     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 244      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 248      |
# | train/             |          |
# |    actor_loss      | -1.3     |
# |    critic_loss     | 0.341    |
# |    ent_coef        | 0.99     |
# |    ent_coef_loss   | -0.0176  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 36       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.02     |
# |    ep_rew_mean     | 44.6     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 237      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 268      |
# | train/             |          |
# |    actor_loss      | -1.39    |
# |    critic_loss     | 0.275    |
# |    ent_coef        | 0.988    |
# |    ent_coef_loss   | -0.0202  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 41       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.02     |
# |    ep_rew_mean     | 44.6     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 231      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 292      |
# | train/             |          |
# |    actor_loss      | -1.46    |
# |    critic_loss     | 0.207    |
# |    ent_coef        | 0.986    |
# |    ent_coef_loss   | -0.0236  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.92     |
# |    ep_rew_mean     | 43.7     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 225      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 320      |
# | train/             |          |
# |    actor_loss      | -1.53    |
# |    critic_loss     | 0.152    |
# |    ent_coef        | 0.984    |
# |    ent_coef_loss   | -0.0267  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 54       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.02     |
# |    ep_rew_mean     | 44.6     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 222      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 344      |
# | train/             |          |
# |    actor_loss      | -1.58    |
# |    critic_loss     | 0.122    |
# |    ent_coef        | 0.982    |
# |    ent_coef_loss   | -0.0297  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 60       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.07     |
# |    ep_rew_mean     | 45       |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 217      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 376      |
# | train/             |          |
# |    actor_loss      | -1.57    |
# |    critic_loss     | 0.113    |
# |    ent_coef        | 0.98     |
# |    ent_coef_loss   | -0.034   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 68       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.02     |
# |    ep_rew_mean     | 44.5     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 215      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 392      |
# | train/             |          |
# |    actor_loss      | -1.63    |
# |    critic_loss     | 0.142    |
# |    ent_coef        | 0.979    |
# |    ent_coef_loss   | -0.0357  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 72       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.97     |
# |    ep_rew_mean     | 44.1     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 211      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 420      |
# | train/             |          |
# |    actor_loss      | -1.74    |
# |    critic_loss     | 0.0906   |
# |    ent_coef        | 0.977    |
# |    ent_coef_loss   | -0.0392  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 79       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.04     |
# |    ep_rew_mean     | 44.8     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 208      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 448      |
# | train/             |          |
# |    actor_loss      | -1.7     |
# |    critic_loss     | 0.0848   |
# |    ent_coef        | 0.975    |
# |    ent_coef_loss   | -0.0433  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 86       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.12     |
# |    ep_rew_mean     | 45.5     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 206      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 472      |
# | train/             |          |
# |    actor_loss      | -1.86    |
# |    critic_loss     | 0.0597   |
# |    ent_coef        | 0.973    |
# |    ent_coef_loss   | -0.0467  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 92       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.14     |
# |    ep_rew_mean     | 45.7     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 204      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 496      |
# | train/             |          |
# |    actor_loss      | -1.78    |
# |    critic_loss     | 0.156    |
# |    ent_coef        | 0.971    |
# |    ent_coef_loss   | -0.0491  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 98       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.13     |
# |    ep_rew_mean     | 45.6     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 202      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 520      |
# | train/             |          |
# |    actor_loss      | -1.72    |
# |    critic_loss     | 0.0796   |
# |    ent_coef        | 0.97     |
# |    ent_coef_loss   | -0.0521  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 104      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.12     |
# |    ep_rew_mean     | 45.6     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 201      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 548      |
# | train/             |          |
# |    actor_loss      | -1.77    |
# |    critic_loss     | 0.0869   |
# |    ent_coef        | 0.967    |
# |    ent_coef_loss   | -0.0555  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 111      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.16     |
# |    ep_rew_mean     | 45.9     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 198      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 576      |
# | train/             |          |
# |    actor_loss      | -1.8     |
# |    critic_loss     | 0.0782   |
# |    ent_coef        | 0.965    |
# |    ent_coef_loss   | -0.0592  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 118      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.2      |
# |    ep_rew_mean     | 46.3     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 197      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 612      |
# | train/             |          |
# |    actor_loss      | -1.81    |
# |    critic_loss     | 0.0567   |
# |    ent_coef        | 0.963    |
# |    ent_coef_loss   | -0.0635  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 127      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.28     |
# |    ep_rew_mean     | 47       |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 196      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 640      |
# | train/             |          |
# |    actor_loss      | -1.85    |
# |    critic_loss     | 0.0592   |
# |    ent_coef        | 0.961    |
# |    ent_coef_loss   | -0.0677  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 134      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.26     |
# |    ep_rew_mean     | 46.9     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 195      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 656      |
# | train/             |          |
# |    actor_loss      | -1.83    |
# |    critic_loss     | 0.0427   |
# |    ent_coef        | 0.96     |
# |    ent_coef_loss   | -0.0696  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 138      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.24     |
# |    ep_rew_mean     | 46.7     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 194      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 684      |
# | train/             |          |
# |    actor_loss      | -1.85    |
# |    critic_loss     | 0.0637   |
# |    ent_coef        | 0.958    |
# |    ent_coef_loss   | -0.0731  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 145      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.14     |
# |    ep_rew_mean     | 45.7     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 193      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 708      |
# | train/             |          |
# |    actor_loss      | -1.93    |
# |    critic_loss     | 0.0787   |
# |    ent_coef        | 0.956    |
# |    ent_coef_loss   | -0.0762  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 151      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.22     |
# |    ep_rew_mean     | 46.5     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 193      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 728      |
# | train/             |          |
# |    actor_loss      | -1.9     |
# |    critic_loss     | 0.0777   |
# |    ent_coef        | 0.954    |
# |    ent_coef_loss   | -0.0779  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 156      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.29     |
# |    ep_rew_mean     | 47.2     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 191      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 756      |
# | train/             |          |
# |    actor_loss      | -1.84    |
# |    critic_loss     | 0.0485   |
# |    ent_coef        | 0.952    |
# |    ent_coef_loss   | -0.0806  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 163      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.32     |
# |    ep_rew_mean     | 47.5     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 190      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 780      |
# | train/             |          |
# |    actor_loss      | -1.92    |
# |    critic_loss     | 0.0521   |
# |    ent_coef        | 0.951    |
# |    ent_coef_loss   | -0.0841  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 169      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.32     |
# |    ep_rew_mean     | 47.5     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 190      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 812      |
# | train/             |          |
# |    actor_loss      | -1.97    |
# |    critic_loss     | 0.0583   |
# |    ent_coef        | 0.948    |
# |    ent_coef_loss   | -0.0885  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 177      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.29     |
# |    ep_rew_mean     | 47.2     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 188      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 836      |
# | train/             |          |
# |    actor_loss      | -1.88    |
# |    critic_loss     | 0.0519   |
# |    ent_coef        | 0.947    |
# |    ent_coef_loss   | -0.0923  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 183      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.27     |
# |    ep_rew_mean     | 47       |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 188      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 852      |
# | train/             |          |
# |    actor_loss      | -2.02    |
# |    critic_loss     | 0.0425   |
# |    ent_coef        | 0.946    |
# |    ent_coef_loss   | -0.0945  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 187      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.23     |
# |    ep_rew_mean     | 46.6     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 188      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 880      |
# | train/             |          |
# |    actor_loss      | -1.88    |
# |    critic_loss     | 0.082    |
# |    ent_coef        | 0.944    |
# |    ent_coef_loss   | -0.0979  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 194      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.21     |
# |    ep_rew_mean     | 46.5     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 188      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 896      |
# | train/             |          |
# |    actor_loss      | -1.95    |
# |    critic_loss     | 0.0522   |
# |    ent_coef        | 0.943    |
# |    ent_coef_loss   | -0.0998  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 198      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.17     |
# |    ep_rew_mean     | 46.1     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 188      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 912      |
# | train/             |          |
# |    actor_loss      | -1.99    |
# |    critic_loss     | 0.0483   |
# |    ent_coef        | 0.941    |
# |    ent_coef_loss   | -0.103   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 202      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.18     |
# |    ep_rew_mean     | 46.2     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 187      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 932      |
# | train/             |          |
# |    actor_loss      | -1.94    |
# |    critic_loss     | 0.0575   |
# |    ent_coef        | 0.94     |
# |    ent_coef_loss   | -0.105   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 207      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.12     |
# |    ep_rew_mean     | 45.6     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 187      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 960      |
# | train/             |          |
# |    actor_loss      | -2.04    |
# |    critic_loss     | 0.0573   |
# |    ent_coef        | 0.938    |
# |    ent_coef_loss   | -0.108   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 214      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.15     |
# |    ep_rew_mean     | 45.9     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 187      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 984      |
# | train/             |          |
# |    actor_loss      | -2.06    |
# |    critic_loss     | 0.0467   |
# |    ent_coef        | 0.936    |
# |    ent_coef_loss   | -0.11    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 220      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.16     |
# |    ep_rew_mean     | 46       |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 186      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1012     |
# | train/             |          |
# |    actor_loss      | -2.02    |
# |    critic_loss     | 0.0756   |
# |    ent_coef        | 0.934    |
# |    ent_coef_loss   | -0.114   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 227      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.17     |
# |    ep_rew_mean     | 46.1     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 186      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1032     |
# | train/             |          |
# |    actor_loss      | -2.04    |
# |    critic_loss     | 0.0622   |
# |    ent_coef        | 0.933    |
# |    ent_coef_loss   | -0.117   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 232      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.2      |
# |    ep_rew_mean     | 46.4     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 186      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1068     |
# | train/             |          |
# |    actor_loss      | -2.1     |
# |    critic_loss     | 0.0471   |
# |    ent_coef        | 0.93     |
# |    ent_coef_loss   | -0.122   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 241      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.21     |
# |    ep_rew_mean     | 46.5     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 185      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1092     |
# | train/             |          |
# |    actor_loss      | -2.07    |
# |    critic_loss     | 0.0484   |
# |    ent_coef        | 0.929    |
# |    ent_coef_loss   | -0.125   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 247      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.15     |
# |    ep_rew_mean     | 45.9     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 185      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1112     |
# | train/             |          |
# |    actor_loss      | -2.03    |
# |    critic_loss     | 0.0413   |
# |    ent_coef        | 0.927    |
# |    ent_coef_loss   | -0.126   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 252      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.15     |
# |    ep_rew_mean     | 45.9     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 185      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1144     |
# | train/             |          |
# |    actor_loss      | -2.02    |
# |    critic_loss     | 0.0405   |
# |    ent_coef        | 0.925    |
# |    ent_coef_loss   | -0.13    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 260      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.18     |
# |    ep_rew_mean     | 46.2     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 185      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1164     |
# | train/             |          |
# |    actor_loss      | -2.24    |
# |    critic_loss     | 0.0598   |
# |    ent_coef        | 0.924    |
# |    ent_coef_loss   | -0.132   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 265      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.23     |
# |    ep_rew_mean     | 46.7     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 184      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1200     |
# | train/             |          |
# |    actor_loss      | -1.99    |
# |    critic_loss     | 0.0472   |
# |    ent_coef        | 0.921    |
# |    ent_coef_loss   | -0.137   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 274      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.18     |
# |    ep_rew_mean     | 46.2     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 184      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1224     |
# | train/             |          |
# |    actor_loss      | -2.12    |
# |    critic_loss     | 0.0387   |
# |    ent_coef        | 0.92     |
# |    ent_coef_loss   | -0.141   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 280      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.08     |
# |    ep_rew_mean     | 45.3     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 183      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1244     |
# | train/             |          |
# |    actor_loss      | -2.13    |
# |    critic_loss     | 0.0465   |
# |    ent_coef        | 0.918    |
# |    ent_coef_loss   | -0.144   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 285      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.16     |
# |    ep_rew_mean     | 46       |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 183      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1276     |
# | train/             |          |
# |    actor_loss      | -2.12    |
# |    critic_loss     | 0.0364   |
# |    ent_coef        | 0.916    |
# |    ent_coef_loss   | -0.146   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 293      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.12     |
# |    ep_rew_mean     | 45.6     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 182      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 1296     |
# | train/             |          |
# |    actor_loss      | -2.13    |
# |    critic_loss     | 0.0528   |
# |    ent_coef        | 0.915    |
# |    ent_coef_loss   | -0.151   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 298      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.17     |
# |    ep_rew_mean     | 46.1     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 182      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 1324     |
# | train/             |          |
# |    actor_loss      | -2.12    |
# |    critic_loss     | 0.0714   |
# |    ent_coef        | 0.913    |
# |    ent_coef_loss   | -0.154   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 305      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.1      |
# |    ep_rew_mean     | 45.4     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 182      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 1344     |
# | train/             |          |
# |    actor_loss      | -2.21    |
# |    critic_loss     | 0.0927   |
# |    ent_coef        | 0.911    |
# |    ent_coef_loss   | -0.153   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 310      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.04     |
# |    ep_rew_mean     | 44.9     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 182      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 1368     |
# | train/             |          |
# |    actor_loss      | -2.34    |
# |    critic_loss     | 0.0444   |
# |    ent_coef        | 0.91     |
# |    ent_coef_loss   | -0.157   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 316      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.08     |
# |    ep_rew_mean     | 45.2     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 182      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 1396     |
# | train/             |          |
# |    actor_loss      | -2.19    |
# |    critic_loss     | 0.0295   |
# |    ent_coef        | 0.908    |
# |    ent_coef_loss   | -0.161   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 323      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.11     |
# |    ep_rew_mean     | 45.5     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 182      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 1416     |
# | train/             |          |
# |    actor_loss      | -2.28    |
# |    critic_loss     | 0.0464   |
# |    ent_coef        | 0.906    |
# |    ent_coef_loss   | -0.164   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 328      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.13     |
# |    ep_rew_mean     | 45.7     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 181      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 1452     |
# | train/             |          |
# |    actor_loss      | -2.19    |
# |    critic_loss     | 0.0365   |
# |    ent_coef        | 0.904    |
# |    ent_coef_loss   | -0.169   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 337      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.19     |
# |    ep_rew_mean     | 46.3     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 182      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1472     |
# | train/             |          |
# |    actor_loss      | -2.3     |
# |    critic_loss     | 0.0347   |
# |    ent_coef        | 0.903    |
# |    ent_coef_loss   | -0.175   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 342      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.22     |
# |    ep_rew_mean     | 46.5     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 182      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1492     |
# | train/             |          |
# |    actor_loss      | -2.38    |
# |    critic_loss     | 0.0405   |
# |    ent_coef        | 0.901    |
# |    ent_coef_loss   | -0.177   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 347      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.2      |
# |    ep_rew_mean     | 46.4     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 182      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1520     |
# | train/             |          |
# |    actor_loss      | -2.35    |
# |    critic_loss     | 0.0469   |
# |    ent_coef        | 0.899    |
# |    ent_coef_loss   | -0.18    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 354      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.25     |
# |    ep_rew_mean     | 46.8     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 182      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1548     |
# | train/             |          |
# |    actor_loss      | -2.29    |
# |    critic_loss     | 0.0413   |
# |    ent_coef        | 0.898    |
# |    ent_coef_loss   | -0.181   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 361      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.36     |
# |    ep_rew_mean     | 47.8     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 182      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1572     |
# | train/             |          |
# |    actor_loss      | -2.4     |
# |    critic_loss     | 0.0402   |
# |    ent_coef        | 0.896    |
# |    ent_coef_loss   | -0.184   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 367      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.41     |
# |    ep_rew_mean     | 48.3     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 182      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1600     |
# | train/             |          |
# |    actor_loss      | -2.24    |
# |    critic_loss     | 0.0418   |
# |    ent_coef        | 0.894    |
# |    ent_coef_loss   | -0.186   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 374      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.43     |
# |    ep_rew_mean     | 48.5     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 181      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1632     |
# | train/             |          |
# |    actor_loss      | -2.31    |
# |    critic_loss     | 0.0267   |
# |    ent_coef        | 0.892    |
# |    ent_coef_loss   | -0.189   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 382      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.48     |
# |    ep_rew_mean     | 49       |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 181      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1672     |
# | train/             |          |
# |    actor_loss      | -2.22    |
# |    critic_loss     | 0.031    |
# |    ent_coef        | 0.889    |
# |    ent_coef_loss   | -0.196   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 392      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.59     |
# |    ep_rew_mean     | 50       |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 181      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1692     |
# | train/             |          |
# |    actor_loss      | -2.34    |
# |    critic_loss     | 0.037    |
# |    ent_coef        | 0.888    |
# |    ent_coef_loss   | -0.197   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 397      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.47     |
# |    ep_rew_mean     | 48.9     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 181      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1712     |
# | train/             |          |
# |    actor_loss      | -2.28    |
# |    critic_loss     | 0.0624   |
# |    ent_coef        | 0.887    |
# |    ent_coef_loss   | -0.204   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 402      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.42     |
# |    ep_rew_mean     | 48.4     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 181      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1732     |
# | train/             |          |
# |    actor_loss      | -2.42    |
# |    critic_loss     | 0.0314   |
# |    ent_coef        | 0.885    |
# |    ent_coef_loss   | -0.206   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 407      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.42     |
# |    ep_rew_mean     | 48.4     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 181      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1760     |
# | train/             |          |
# |    actor_loss      | -2.37    |
# |    critic_loss     | 0.0496   |
# |    ent_coef        | 0.883    |
# |    ent_coef_loss   | -0.208   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 414      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.5      |
# |    ep_rew_mean     | 49.1     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 181      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1788     |
# | train/             |          |
# |    actor_loss      | -2.35    |
# |    critic_loss     | 0.0704   |
# |    ent_coef        | 0.882    |
# |    ent_coef_loss   | -0.214   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 421      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.42     |
# |    ep_rew_mean     | 48.4     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 181      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1812     |
# | train/             |          |
# |    actor_loss      | -2.33    |
# |    critic_loss     | 0.0678   |
# |    ent_coef        | 0.88     |
# |    ent_coef_loss   | -0.214   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 427      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.38     |
# |    ep_rew_mean     | 48       |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 181      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1844     |
# | train/             |          |
# |    actor_loss      | -2.36    |
# |    critic_loss     | 0.0604   |
# |    ent_coef        | 0.878    |
# |    ent_coef_loss   | -0.216   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 435      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.45     |
# |    ep_rew_mean     | 48.7     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 181      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1868     |
# | train/             |          |
# |    actor_loss      | -2.44    |
# |    critic_loss     | 0.0615   |
# |    ent_coef        | 0.876    |
# |    ent_coef_loss   | -0.219   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 441      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.46     |
# |    ep_rew_mean     | 48.8     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 181      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1892     |
# | train/             |          |
# |    actor_loss      | -2.35    |
# |    critic_loss     | 0.0524   |
# |    ent_coef        | 0.875    |
# |    ent_coef_loss   | -0.224   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 447      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.42     |
# |    ep_rew_mean     | 48.4     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 181      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1920     |
# | train/             |          |
# |    actor_loss      | -2.24    |
# |    critic_loss     | 0.0653   |
# |    ent_coef        | 0.873    |
# |    ent_coef_loss   | -0.228   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 454      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.48     |
# |    ep_rew_mean     | 48.9     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 181      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1948     |
# | train/             |          |
# |    actor_loss      | -2.44    |
# |    critic_loss     | 0.0376   |
# |    ent_coef        | 0.871    |
# |    ent_coef_loss   | -0.229   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 461      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.53     |
# |    ep_rew_mean     | 49.4     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 181      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1984     |
# | train/             |          |
# |    actor_loss      | -2.47    |
# |    critic_loss     | 0.0366   |
# |    ent_coef        | 0.869    |
# |    ent_coef_loss   | -0.238   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 470      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.62     |
# |    ep_rew_mean     | 50.2     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 181      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 2008     |
# | train/             |          |
# |    actor_loss      | -2.53    |
# |    critic_loss     | 0.0536   |
# |    ent_coef        | 0.867    |
# |    ent_coef_loss   | -0.236   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 476      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.64     |
# |    ep_rew_mean     | 50.4     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 181      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 2032     |
# | train/             |          |
# |    actor_loss      | -2.44    |
# |    critic_loss     | 0.0309   |
# |    ent_coef        | 0.866    |
# |    ent_coef_loss   | -0.237   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 482      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.65     |
# |    ep_rew_mean     | 50.5     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 180      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 2052     |
# | train/             |          |
# |    actor_loss      | -2.63    |
# |    critic_loss     | 0.0454   |
# |    ent_coef        | 0.864    |
# |    ent_coef_loss   | -0.242   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 487      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.63     |
# |    ep_rew_mean     | 50.3     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 180      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 2080     |
# | train/             |          |
# |    actor_loss      | -2.62    |
# |    critic_loss     | 0.0443   |
# |    ent_coef        | 0.863    |
# |    ent_coef_loss   | -0.246   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 494      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.63     |
# |    ep_rew_mean     | 50.3     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 180      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 2104     |
# | train/             |          |
# |    actor_loss      | -2.56    |
# |    critic_loss     | 0.08     |
# |    ent_coef        | 0.861    |
# |    ent_coef_loss   | -0.252   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 500      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.58     |
# |    ep_rew_mean     | 49.9     |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 180      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 2128     |
# | train/             |          |
# |    actor_loss      | -2.4     |
# |    critic_loss     | 0.0421   |
# |    ent_coef        | 0.859    |
# |    ent_coef_loss   | -0.252   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 506      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.53     |
# |    ep_rew_mean     | 49.4     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 180      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 2148     |
# | train/             |          |
# |    actor_loss      | -2.46    |
# ...
# |    fps             | 105      |
# |    time_elapsed    | 8442     |
# |    total_timesteps | 890304   |
# | train/             |          |
# |    actor_loss      | -3.95    |
# |    critic_loss     | 4.39e-05 |
# |    ent_coef        | 0.000305 |
# |    ent_coef_loss   | 1.6      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 222550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 968      |
# |    ep_rew_mean     | 9.05e+03 |
# | time/              |          |
# |    episodes        | 2596     |
# |    fps             | 105      |
# |    time_elapsed    | 8478     |
# |    total_timesteps | 894304   |
# | train/             |          |
# |    actor_loss      | -3.96    |
# |    critic_loss     | 1.12e-05 |
# |    ent_coef        | 0.000299 |
# |    ent_coef_loss   | -1.45    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 223550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 968      |
# |    ep_rew_mean     | 9.05e+03 |
# | time/              |          |
# |    episodes        | 2600     |
# |    fps             | 105      |
# |    time_elapsed    | 8515     |
# |    total_timesteps | 898304   |
# | train/             |          |
# |    actor_loss      | -3.96    |
# |    critic_loss     | 1.95e-05 |
# |    ent_coef        | 0.000331 |
# |    ent_coef_loss   | 0.774    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 224550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 968      |
# |    ep_rew_mean     | 9.05e+03 |
# | time/              |          |
# |    episodes        | 2604     |
# |    fps             | 105      |
# |    time_elapsed    | 8551     |
# |    total_timesteps | 902304   |
# | train/             |          |
# |    actor_loss      | -3.93    |
# |    critic_loss     | 4.64e-05 |
# |    ent_coef        | 0.000323 |
# |    ent_coef_loss   | 0.00439  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 225550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 968      |
# |    ep_rew_mean     | 9.05e+03 |
# | time/              |          |
# |    episodes        | 2608     |
# |    fps             | 105      |
# |    time_elapsed    | 8588     |
# |    total_timesteps | 906304   |
# | train/             |          |
# |    actor_loss      | -3.97    |
# |    critic_loss     | 2.7e-05  |
# |    ent_coef        | 0.000302 |
# |    ent_coef_loss   | -0.586   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 226550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 968      |
# |    ep_rew_mean     | 9.05e+03 |
# | time/              |          |
# |    episodes        | 2612     |
# |    fps             | 105      |
# |    time_elapsed    | 8624     |
# |    total_timesteps | 910304   |
# | train/             |          |
# |    actor_loss      | -3.97    |
# |    critic_loss     | 1.06e-05 |
# |    ent_coef        | 0.00033  |
# |    ent_coef_loss   | 0.536    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 227550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 968      |
# |    ep_rew_mean     | 9.05e+03 |
# | time/              |          |
# |    episodes        | 2616     |
# |    fps             | 105      |
# |    time_elapsed    | 8661     |
# |    total_timesteps | 914304   |
# | train/             |          |
# |    actor_loss      | -3.94    |
# |    critic_loss     | 5.56e-05 |
# |    ent_coef        | 0.000328 |
# |    ent_coef_loss   | 0.908    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 228550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 968      |
# |    ep_rew_mean     | 9.05e+03 |
# | time/              |          |
# |    episodes        | 2620     |
# |    fps             | 105      |
# |    time_elapsed    | 8697     |
# |    total_timesteps | 918304   |
# | train/             |          |
# |    actor_loss      | -3.98    |
# |    critic_loss     | 1.63e-05 |
# |    ent_coef        | 0.000276 |
# |    ent_coef_loss   | -0.433   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 229550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 968      |
# |    ep_rew_mean     | 9.05e+03 |
# | time/              |          |
# |    episodes        | 2624     |
# |    fps             | 105      |
# |    time_elapsed    | 8734     |
# |    total_timesteps | 922304   |
# | train/             |          |
# |    actor_loss      | -3.98    |
# |    critic_loss     | 0.000101 |
# |    ent_coef        | 0.000258 |
# |    ent_coef_loss   | 0.894    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 230550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 968      |
# |    ep_rew_mean     | 9.05e+03 |
# | time/              |          |
# |    episodes        | 2628     |
# |    fps             | 105      |
# |    time_elapsed    | 8770     |
# |    total_timesteps | 926304   |
# | train/             |          |
# |    actor_loss      | -3.98    |
# |    critic_loss     | 4.68e-05 |
# |    ent_coef        | 0.000296 |
# |    ent_coef_loss   | 0.545    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 231550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 968      |
# |    ep_rew_mean     | 9.05e+03 |
# | time/              |          |
# |    episodes        | 2632     |
# |    fps             | 105      |
# |    time_elapsed    | 8806     |
# |    total_timesteps | 930304   |
# | train/             |          |
# |    actor_loss      | -3.98    |
# |    critic_loss     | 6.28e-05 |
# |    ent_coef        | 0.000303 |
# |    ent_coef_loss   | 0.708    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 232550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 968      |
# |    ep_rew_mean     | 9.05e+03 |
# | time/              |          |
# |    episodes        | 2636     |
# |    fps             | 105      |
# |    time_elapsed    | 8843     |
# |    total_timesteps | 934304   |
# | train/             |          |
# |    actor_loss      | -4       |
# |    critic_loss     | 0.000125 |
# |    ent_coef        | 0.000293 |
# |    ent_coef_loss   | 1.87     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 233550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 968      |
# |    ep_rew_mean     | 9.05e+03 |
# | time/              |          |
# |    episodes        | 2640     |
# |    fps             | 105      |
# |    time_elapsed    | 8879     |
# |    total_timesteps | 938304   |
# | train/             |          |
# |    actor_loss      | -4       |
# |    critic_loss     | 1.34e-05 |
# |    ent_coef        | 0.000315 |
# |    ent_coef_loss   | 1.15     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 234550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 968      |
# |    ep_rew_mean     | 9.05e+03 |
# | time/              |          |
# |    episodes        | 2644     |
# |    fps             | 105      |
# |    time_elapsed    | 8916     |
# |    total_timesteps | 942304   |
# | train/             |          |
# |    actor_loss      | -4       |
# |    critic_loss     | 8.22e-06 |
# |    ent_coef        | 0.000313 |
# |    ent_coef_loss   | -0.533   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 235550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 968      |
# |    ep_rew_mean     | 9.05e+03 |
# | time/              |          |
# |    episodes        | 2648     |
# |    fps             | 105      |
# |    time_elapsed    | 8952     |
# |    total_timesteps | 946304   |
# | train/             |          |
# |    actor_loss      | -4       |
# |    critic_loss     | 3.09e-05 |
# |    ent_coef        | 0.000349 |
# |    ent_coef_loss   | 1.39     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 236550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 968      |
# |    ep_rew_mean     | 9.05e+03 |
# | time/              |          |
# |    episodes        | 2652     |
# |    fps             | 105      |
# |    time_elapsed    | 8988     |
# |    total_timesteps | 950304   |
# | train/             |          |
# |    actor_loss      | -3.97    |
# |    critic_loss     | 0.0444   |
# |    ent_coef        | 0.000338 |
# |    ent_coef_loss   | -0.736   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 237550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 968      |
# |    ep_rew_mean     | 9.05e+03 |
# | time/              |          |
# |    episodes        | 2656     |
# |    fps             | 105      |
# |    time_elapsed    | 9025     |
# |    total_timesteps | 954304   |
# | train/             |          |
# |    actor_loss      | -4.01    |
# |    critic_loss     | 9.12e-06 |
# |    ent_coef        | 0.000345 |
# |    ent_coef_loss   | -0.202   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 238550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 968      |
# |    ep_rew_mean     | 9.05e+03 |
# | time/              |          |
# |    episodes        | 2660     |
# |    fps             | 105      |
# |    time_elapsed    | 9061     |
# |    total_timesteps | 958304   |
# | train/             |          |
# |    actor_loss      | -4.01    |
# |    critic_loss     | 5.01e-06 |
# |    ent_coef        | 0.000357 |
# |    ent_coef_loss   | 1.39     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 239550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 968      |
# |    ep_rew_mean     | 9.05e+03 |
# | time/              |          |
# |    episodes        | 2664     |
# |    fps             | 105      |
# |    time_elapsed    | 9098     |
# |    total_timesteps | 962304   |
# | train/             |          |
# |    actor_loss      | -4.01    |
# |    critic_loss     | 1.61e-05 |
# |    ent_coef        | 0.000357 |
# |    ent_coef_loss   | 0.745    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 240550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 968      |
# |    ep_rew_mean     | 9.05e+03 |
# | time/              |          |
# |    episodes        | 2668     |
# |    fps             | 105      |
# |    time_elapsed    | 9134     |
# |    total_timesteps | 966304   |
# | train/             |          |
# |    actor_loss      | -4.01    |
# |    critic_loss     | 2.05e-05 |
# |    ent_coef        | 0.000311 |
# |    ent_coef_loss   | 0.295    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 241550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 979      |
# |    ep_rew_mean     | 9.15e+03 |
# | time/              |          |
# |    episodes        | 2672     |
# |    fps             | 105      |
# |    time_elapsed    | 9171     |
# |    total_timesteps | 970304   |
# | train/             |          |
# |    actor_loss      | -4.02    |
# |    critic_loss     | 1.48e-05 |
# |    ent_coef        | 0.000359 |
# |    ent_coef_loss   | -0.147   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 242550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 9.35e+03 |
# | time/              |          |
# |    episodes        | 2676     |
# |    fps             | 105      |
# |    time_elapsed    | 9207     |
# |    total_timesteps | 974304   |
# | train/             |          |
# |    actor_loss      | -4.02    |
# |    critic_loss     | 5.82e-06 |
# |    ent_coef        | 0.000488 |
# |    ent_coef_loss   | 0.833    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 243550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 9.35e+03 |
# | time/              |          |
# |    episodes        | 2680     |
# |    fps             | 105      |
# |    time_elapsed    | 9244     |
# |    total_timesteps | 978304   |
# | train/             |          |
# |    actor_loss      | -4.03    |
# |    critic_loss     | 0.000151 |
# |    ent_coef        | 0.000679 |
# |    ent_coef_loss   | 1.45     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 244550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 9.35e+03 |
# | time/              |          |
# |    episodes        | 2684     |
# |    fps             | 105      |
# |    time_elapsed    | 9280     |
# |    total_timesteps | 982304   |
# | train/             |          |
# |    actor_loss      | -4.03    |
# |    critic_loss     | 2.72e-05 |
# |    ent_coef        | 0.000731 |
# |    ent_coef_loss   | 0.796    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 245550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 9.35e+03 |
# | time/              |          |
# |    episodes        | 2688     |
# |    fps             | 105      |
# |    time_elapsed    | 9316     |
# |    total_timesteps | 986304   |
# | train/             |          |
# |    actor_loss      | -4.03    |
# |    critic_loss     | 9.08e-06 |
# |    ent_coef        | 0.000792 |
# |    ent_coef_loss   | -0.554   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 246550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 9.35e+03 |
# | time/              |          |
# |    episodes        | 2692     |
# |    fps             | 105      |
# |    time_elapsed    | 9353     |
# |    total_timesteps | 990304   |
# | train/             |          |
# |    actor_loss      | -4.04    |
# |    critic_loss     | 4.82e-05 |
# |    ent_coef        | 0.000735 |
# |    ent_coef_loss   | -0.857   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 247550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 9.35e+03 |
# | time/              |          |
# |    episodes        | 2696     |
# |    fps             | 105      |
# |    time_elapsed    | 9390     |
# |    total_timesteps | 994304   |
# | train/             |          |
# |    actor_loss      | -4.04    |
# |    critic_loss     | 2.46e-05 |
# |    ent_coef        | 0.00055  |
# |    ent_coef_loss   | -1.38    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 248550   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 9.35e+03 |
# | time/              |          |
# |    episodes        | 2700     |
# |    fps             | 105      |
# |    time_elapsed    | 9426     |
# |    total_timesteps | 998304   |
# | train/             |          |
# |    actor_loss      | -4.03    |
# |    critic_loss     | 9.52e-05 |
# |    ent_coef        | 0.000476 |
# |    ent_coef_loss   | 0.515    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 249550   |
# ---------------------------------

# %%
# Load model and evaluate
model = SAC.load("./models/sac_inverted_double_pendulum_final", device=device)

venv = make_vec_env(ENV_ID, n_envs=1, seed=42)
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

mean_reward, std_reward = evaluate_policy(model, venv, n_eval_episodes=10, deterministic=True)
print(f"Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Mean reward: 9359.68 +/- 0.14

# %%
# Visualize the agent
import os
os.environ["MUJOCO_GL"] = "glfw"

import gymnasium as gym
import imageio
import numpy as np
from IPython.display import Video, display
import tempfile

from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

ENV_ID = "InvertedDoublePendulum-v5"
N_EVAL_EPISODES = 10
MAX_STEPS = 1500
FPS = 30

# create env
env = gym.make(ENV_ID, render_mode="rgb_array")
venv = DummyVecEnv([lambda: env])
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

# load model
# model = SAC.load("./models/sac_humanoid_final", device="cpu")
model = SAC.load("./best_model/best_model", device="cpu")

best_frames = []
best_length = 0

for ep in range(N_EVAL_EPISODES):
    obs = venv.reset()
    frames = []

    for step in range(MAX_STEPS):
        action, _ = model.predict(obs, deterministic=True)
        obs, rewards, dones, infos = venv.step(action)

        frame = env.render()
        if frame is not None:
            frames.append(frame)

        if dones[0]:
            break

    ep_length = len(frames)
    print(f"Episode {ep+1}: {ep_length} frames")

    if ep_length > best_length:
        best_length = ep_length
        best_frames = frames

print(f"\nLongest episode length: {best_length} frames")

# save and display only the longest episode
tmp = tempfile.NamedTemporaryFile(suffix=".mp4", delete=False).name
writer = imageio.get_writer(tmp, fps=FPS, codec="libx264")
for f in best_frames:
    writer.append_data(f)
writer.close()

display(Video(tmp, embed=True))
# Out:
# Episode 1: 1000 frames
# Episode 2: 1000 frames
# Episode 3: 1000 frames
# Episode 4: 1000 frames
# Episode 5: 1000 frames
# Episode 6: 1000 frames
# Episode 7: 1000 frames
# Episode 8: 1000 frames
# Episode 9: 1000 frames
# Episode 10: 1000 frames
#
# Longest episode length: 1000 frames
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
