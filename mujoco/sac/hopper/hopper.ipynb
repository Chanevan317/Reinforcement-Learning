# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.5.1
# CUDA available: True
# CUDA device count: 1
# GPU name: NVIDIA GeForce RTX 4080 SUPER

# %%
# Quick checks
import sys, platform
import torch
print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())
print("PyTorch:", torch.__version__, "| CUDA available:", torch.cuda.is_available())
import mujoco
print("MuJoCo package version:", mujoco.__version__)
# Out:
# Python: 3.10.19
# Platform: Windows-10-10.0.26200-SP0
# PyTorch: 2.5.1 | CUDA available: True
# MuJoCo package version: 3.4.0

# %%
# Imports
import os
import gymnasium as gym
import numpy as np
import torch
from stable_baselines3 import SAC
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecNormalize, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback
from stable_baselines3.common.evaluation import evaluate_policy

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Env setup
ENV_ID = "Hopper-v5"   # requires mujoco >= 2.3
n_envs = 4               # on Windows + single CPU, 4 is reasonable; reduce if CPU bound
seed = 0

# Make vectorized training envs
train_env = make_vec_env(
    ENV_ID,
    n_envs=n_envs,
    seed=seed,
    monitor_dir="./logs/train_monitor"
)

# VecNormalize (important for continuous control)
train_env = VecNormalize(train_env, norm_obs=True, norm_reward=True, clip_obs=10.0)

# eval env
eval_env = make_vec_env(
    ENV_ID,
    n_envs=1,
    seed=seed + 100,
    monitor_dir="./logs/eval_monitor"
)
eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

print("Obs space:", train_env.observation_space)
print("Act space:", train_env.action_space)
# Out:
# Obs space: Box(-inf, inf, (11,), float64)
# Act space: Box(-1.0, 1.0, (3,), float32)

# %%
# Create SAC
model = SAC(
    "MlpPolicy", 
    train_env,
    learning_rate=3e-4,
    buffer_size=int(1e6),
    batch_size=256,
    gamma=0.99,
    tau=0.005,
    ent_coef="auto",
    policy_kwargs=dict(net_arch=[256, 256]),
    device=device,
    verbose=1,
)
# Out:
# Using cuda device

# %%
# Callbacks and save dirs
os.makedirs("./models", exist_ok=True)
os.makedirs("./checkpoints", exist_ok=True)
os.makedirs("./best_model", exist_ok=True)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./best_model/",
    log_path="./logs/eval",
    eval_freq=100_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False
)

checkpoint_callback = CheckpointCallback(save_freq=500_000, save_path="./checkpoints/", name_prefix="sac_hopper")

# %%
# Train
TOTAL_TIMESTEPS = int(5e6)  
model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=[eval_callback, checkpoint_callback])
model.save("./models/sac_hopper_final")
# save VecNormalize
train_env.save("./models/vecnormalize_train.pkl")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | 14.3     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 503      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 160      |
# | train/             |          |
# |    actor_loss      | -3.03    |
# |    critic_loss     | 1.58     |
# |    ent_coef        | 0.996    |
# |    ent_coef_loss   | -0.0197  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.1     |
# |    ep_rew_mean     | 21.1     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 449      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 208      |
# | train/             |          |
# |    actor_loss      | -3.82    |
# |    critic_loss     | 0.65     |
# |    ent_coef        | 0.993    |
# |    ent_coef_loss   | -0.0379  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 26       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.9     |
# |    ep_rew_mean     | 18.2     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 403      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 276      |
# | train/             |          |
# |    actor_loss      | -4.11    |
# |    critic_loss     | 0.511    |
# |    ent_coef        | 0.987    |
# |    ent_coef_loss   | -0.0636  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | 18.1     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 379      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 392      |
# | train/             |          |
# |    actor_loss      | -4.31    |
# |    critic_loss     | 0.442    |
# |    ent_coef        | 0.979    |
# |    ent_coef_loss   | -0.108   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 72       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.3     |
# |    ep_rew_mean     | 19.8     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 370      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 484      |
# | train/             |          |
# |    actor_loss      | -4.32    |
# |    critic_loss     | 0.289    |
# |    ent_coef        | 0.972    |
# |    ent_coef_loss   | -0.142   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 95       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.7     |
# |    ep_rew_mean     | 17.9     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 361      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 572      |
# | train/             |          |
# |    actor_loss      | -4.52    |
# |    critic_loss     | 0.427    |
# |    ent_coef        | 0.966    |
# |    ent_coef_loss   | -0.176   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 117      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.3     |
# |    ep_rew_mean     | 19.2     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 358      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 700      |
# | train/             |          |
# |    actor_loss      | -4.69    |
# |    critic_loss     | 0.426    |
# |    ent_coef        | 0.957    |
# |    ent_coef_loss   | -0.223   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 149      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23       |
# |    ep_rew_mean     | 19.4     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 355      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 768      |
# | train/             |          |
# |    actor_loss      | -4.73    |
# |    critic_loss     | 0.446    |
# |    ent_coef        | 0.952    |
# |    ent_coef_loss   | -0.249   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 166      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | 19.9     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 343      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 928      |
# | train/             |          |
# |    actor_loss      | -5.02    |
# |    critic_loss     | 0.357    |
# |    ent_coef        | 0.94     |
# |    ent_coef_loss   | -0.311   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 206      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.4     |
# |    ep_rew_mean     | 20.9     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 335      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1044     |
# | train/             |          |
# |    actor_loss      | -5.12    |
# |    critic_loss     | 0.455    |
# |    ent_coef        | 0.932    |
# |    ent_coef_loss   | -0.354   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 235      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.5     |
# |    ep_rew_mean     | 19.8     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 329      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1140     |
# | train/             |          |
# |    actor_loss      | -5.34    |
# |    critic_loss     | 0.262    |
# |    ent_coef        | 0.925    |
# |    ent_coef_loss   | -0.389   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 259      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.1     |
# |    ep_rew_mean     | 22.6     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 329      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1236     |
# | train/             |          |
# |    actor_loss      | -5.49    |
# |    critic_loss     | 0.29     |
# |    ent_coef        | 0.919    |
# |    ent_coef_loss   | -0.425   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 283      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.5     |
# |    ep_rew_mean     | 22.6     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 326      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1396     |
# | train/             |          |
# |    actor_loss      | -5.63    |
# |    critic_loss     | 0.368    |
# |    ent_coef        | 0.908    |
# |    ent_coef_loss   | -0.487   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 323      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 22.2     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 325      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1476     |
# | train/             |          |
# |    actor_loss      | -5.75    |
# |    critic_loss     | 0.282    |
# |    ent_coef        | 0.902    |
# |    ent_coef_loss   | -0.517   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 343      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.8     |
# |    ep_rew_mean     | 23       |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 324      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1584     |
# | train/             |          |
# |    actor_loss      | -5.89    |
# |    critic_loss     | 0.27     |
# |    ent_coef        | 0.895    |
# |    ent_coef_loss   | -0.563   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 370      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.6     |
# |    ep_rew_mean     | 23.4     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 322      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1668     |
# | train/             |          |
# |    actor_loss      | -5.92    |
# |    critic_loss     | 0.287    |
# |    ent_coef        | 0.89     |
# |    ent_coef_loss   | -0.59    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 391      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 23       |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 322      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1720     |
# | train/             |          |
# |    actor_loss      | -6.02    |
# |    critic_loss     | 0.324    |
# |    ent_coef        | 0.886    |
# |    ent_coef_loss   | -0.613   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 404      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.7     |
# |    ep_rew_mean     | 22.4     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 322      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1832     |
# | train/             |          |
# |    actor_loss      | -6.12    |
# |    critic_loss     | 0.354    |
# |    ent_coef        | 0.879    |
# |    ent_coef_loss   | -0.653   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 432      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.2     |
# |    ep_rew_mean     | 23.4     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 322      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1924     |
# | train/             |          |
# |    actor_loss      | -6.3     |
# |    critic_loss     | 0.663    |
# |    ent_coef        | 0.873    |
# |    ent_coef_loss   | -0.685   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 455      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.9     |
# |    ep_rew_mean     | 22.7     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 321      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2060     |
# | train/             |          |
# |    actor_loss      | -6.42    |
# |    critic_loss     | 0.245    |
# |    ent_coef        | 0.864    |
# |    ent_coef_loss   | -0.734   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 489      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.3     |
# |    ep_rew_mean     | 23.3     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 321      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2268     |
# | train/             |          |
# |    actor_loss      | -6.71    |
# |    critic_loss     | 0.353    |
# |    ent_coef        | 0.851    |
# |    ent_coef_loss   | -0.808   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 541      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.2     |
# |    ep_rew_mean     | 25.5     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 320      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2320     |
# | train/             |          |
# |    actor_loss      | -6.77    |
# |    critic_loss     | 0.306    |
# |    ent_coef        | 0.847    |
# |    ent_coef_loss   | -0.832   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 554      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.1     |
# |    ep_rew_mean     | 25.1     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 320      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2476     |
# | train/             |          |
# |    actor_loss      | -7.15    |
# |    critic_loss     | 0.212    |
# |    ent_coef        | 0.837    |
# |    ent_coef_loss   | -0.893   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 593      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.3     |
# |    ep_rew_mean     | 24.6     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 320      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2584     |
# | train/             |          |
# |    actor_loss      | -7.12    |
# |    critic_loss     | 0.309    |
# |    ent_coef        | 0.831    |
# |    ent_coef_loss   | -0.928   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 620      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.3     |
# |    ep_rew_mean     | 24.4     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 319      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2712     |
# | train/             |          |
# |    actor_loss      | -7.32    |
# |    critic_loss     | 0.178    |
# |    ent_coef        | 0.823    |
# |    ent_coef_loss   | -0.974   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 652      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.9     |
# |    ep_rew_mean     | 25.1     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 320      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2820     |
# | train/             |          |
# |    actor_loss      | -7.38    |
# |    critic_loss     | 0.185    |
# |    ent_coef        | 0.816    |
# |    ent_coef_loss   | -1.01    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 679      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.4     |
# |    ep_rew_mean     | 25.2     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 320      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 3028     |
# | train/             |          |
# |    actor_loss      | -7.52    |
# |    critic_loss     | 0.232    |
# |    ent_coef        | 0.804    |
# |    ent_coef_loss   | -1.09    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 731      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.2     |
# |    ep_rew_mean     | 26.6     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 321      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 3164     |
# | train/             |          |
# |    actor_loss      | -7.91    |
# |    critic_loss     | 0.254    |
# |    ent_coef        | 0.795    |
# |    ent_coef_loss   | -1.14    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 765      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.8     |
# |    ep_rew_mean     | 26.3     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 322      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 3244     |
# | train/             |          |
# |    actor_loss      | -7.81    |
# |    critic_loss     | 0.235    |
# |    ent_coef        | 0.791    |
# |    ent_coef_loss   | -1.16    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 785      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.2     |
# |    ep_rew_mean     | 26.5     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 323      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 3348     |
# | train/             |          |
# |    actor_loss      | -7.91    |
# |    critic_loss     | 0.329    |
# |    ent_coef        | 0.785    |
# |    ent_coef_loss   | -1.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 811      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.8     |
# |    ep_rew_mean     | 26.6     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 323      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 3428     |
# | train/             |          |
# |    actor_loss      | -7.97    |
# |    critic_loss     | 0.839    |
# |    ent_coef        | 0.78     |
# |    ent_coef_loss   | -1.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 831      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.2     |
# |    ep_rew_mean     | 27.8     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 324      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 3680     |
# | train/             |          |
# |    actor_loss      | -8.54    |
# |    critic_loss     | 0.249    |
# |    ent_coef        | 0.766    |
# |    ent_coef_loss   | -1.33    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 894      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.8     |
# |    ep_rew_mean     | 28.4     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 324      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 3852     |
# | train/             |          |
# |    actor_loss      | -8.52    |
# |    critic_loss     | 0.497    |
# |    ent_coef        | 0.756    |
# |    ent_coef_loss   | -1.38    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 937      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.1     |
# |    ep_rew_mean     | 30.4     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 323      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 4100     |
# | train/             |          |
# |    actor_loss      | -9.05    |
# |    critic_loss     | 0.125    |
# |    ent_coef        | 0.742    |
# |    ent_coef_loss   | -1.47    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 999      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.8     |
# |    ep_rew_mean     | 36.9     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 323      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 4588     |
# | train/             |          |
# |    actor_loss      | -9.62    |
# |    critic_loss     | 0.484    |
# |    ent_coef        | 0.716    |
# |    ent_coef_loss   | -1.63    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1121     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.3     |
# |    ep_rew_mean     | 38.6     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 323      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 4844     |
# | train/             |          |
# |    actor_loss      | -9.87    |
# |    critic_loss     | 1.01     |
# |    ent_coef        | 0.702    |
# |    ent_coef_loss   | -1.72    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1185     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.4     |
# |    ep_rew_mean     | 42.5     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 322      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 5232     |
# | train/             |          |
# |    actor_loss      | -10.4    |
# |    critic_loss     | 0.202    |
# |    ent_coef        | 0.683    |
# |    ent_coef_loss   | -1.86    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1282     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.4     |
# |    ep_rew_mean     | 48.1     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 322      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 5756     |
# | train/             |          |
# |    actor_loss      | -10.8    |
# |    critic_loss     | 0.244    |
# |    ent_coef        | 0.657    |
# |    ent_coef_loss   | -2.01    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1413     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.7     |
# |    ep_rew_mean     | 54.9     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 321      |
# |    time_elapsed    | 19       |
# |    total_timesteps | 6136     |
# | train/             |          |
# |    actor_loss      | -11.1    |
# |    critic_loss     | 1.05     |
# |    ent_coef        | 0.639    |
# |    ent_coef_loss   | -2.15    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1508     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.3     |
# |    ep_rew_mean     | 57       |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 321      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 6612     |
# | train/             |          |
# |    actor_loss      | -11.1    |
# |    critic_loss     | 0.408    |
# |    ent_coef        | 0.618    |
# |    ent_coef_loss   | -2.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1627     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 52.1     |
# |    ep_rew_mean     | 66.8     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 322      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 7076     |
# | train/             |          |
# |    actor_loss      | -11.8    |
# |    critic_loss     | 0.224    |
# |    ent_coef        | 0.597    |
# |    ent_coef_loss   | -2.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1743     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56       |
# |    ep_rew_mean     | 74.5     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 322      |
# |    time_elapsed    | 22       |
# |    total_timesteps | 7388     |
# | train/             |          |
# |    actor_loss      | -12.2    |
# |    critic_loss     | 0.624    |
# |    ent_coef        | 0.584    |
# |    ent_coef_loss   | -2.52    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1821     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 61       |
# |    ep_rew_mean     | 84.7     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 321      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 7988     |
# | train/             |          |
# |    actor_loss      | -13      |
# |    critic_loss     | 0.64     |
# |    ent_coef        | 0.559    |
# |    ent_coef_loss   | -2.75    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1971     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 63.8     |
# |    ep_rew_mean     | 89.1     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 321      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 8532     |
# | train/             |          |
# |    actor_loss      | -13.5    |
# |    critic_loss     | 0.202    |
# |    ent_coef        | 0.538    |
# |    ent_coef_loss   | -2.92    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2107     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 69       |
# |    ep_rew_mean     | 98.5     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 322      |
# |    time_elapsed    | 28       |
# |    total_timesteps | 9168     |
# | train/             |          |
# |    actor_loss      | -13.7    |
# |    critic_loss     | 0.687    |
# |    ent_coef        | 0.513    |
# |    ent_coef_loss   | -3.05    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2266     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.1     |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 322      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 9888     |
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 0.448    |
# |    ent_coef        | 0.487    |
# |    ent_coef_loss   | -3.28    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2446     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 77.7     |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 321      |
# |    time_elapsed    | 32       |
# |    total_timesteps | 10328    |
# | train/             |          |
# |    actor_loss      | -14.7    |
# |    critic_loss     | 0.347    |
# |    ent_coef        | 0.472    |
# |    ent_coef_loss   | -3.34    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2556     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.9     |
# |    ep_rew_mean     | 126      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 321      |
# |    time_elapsed    | 35       |
# |    total_timesteps | 11248    |
# | train/             |          |
# |    actor_loss      | -15      |
# |    critic_loss     | 0.309    |
# |    ent_coef        | 0.442    |
# |    ent_coef_loss   | -3.67    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2786     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.8     |
# |    ep_rew_mean     | 137      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 319      |
# |    time_elapsed    | 37       |
# |    total_timesteps | 11880    |
# | train/             |          |
# |    actor_loss      | -15.6    |
# |    critic_loss     | 0.695    |
# |    ent_coef        | 0.422    |
# |    ent_coef_loss   | -3.85    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2944     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 97.2     |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 317      |
# |    time_elapsed    | 39       |
# |    total_timesteps | 12444    |
# | train/             |          |
# |    actor_loss      | -15.7    |
# |    critic_loss     | 0.399    |
# |    ent_coef        | 0.405    |
# |    ent_coef_loss   | -3.99    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3085     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | 159      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 315      |
# |    time_elapsed    | 41       |
# |    total_timesteps | 13076    |
# | train/             |          |
# |    actor_loss      | -16.2    |
# |    critic_loss     | 0.23     |
# |    ent_coef        | 0.386    |
# |    ent_coef_loss   | -4.34    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3243     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 107      |
# |    ep_rew_mean     | 168      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 311      |
# |    time_elapsed    | 45       |
# |    total_timesteps | 14132    |
# | train/             |          |
# |    actor_loss      | -16.7    |
# |    critic_loss     | 0.302    |
# |    ent_coef        | 0.357    |
# |    ent_coef_loss   | -4.76    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3507     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 113      |
# |    ep_rew_mean     | 179      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 309      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 14560    |
# | train/             |          |
# |    actor_loss      | -16.6    |
# |    critic_loss     | 0.404    |
# |    ent_coef        | 0.346    |
# |    ent_coef_loss   | -4.75    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3614     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 118      |
# |    ep_rew_mean     | 189      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 306      |
# |    time_elapsed    | 49       |
# |    total_timesteps | 15184    |
# | train/             |          |
# |    actor_loss      | -17.1    |
# |    critic_loss     | 0.188    |
# |    ent_coef        | 0.331    |
# |    ent_coef_loss   | -4.93    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3770     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | 198      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 304      |
# |    time_elapsed    | 51       |
# |    total_timesteps | 15692    |
# | train/             |          |
# |    actor_loss      | -17.1    |
# |    critic_loss     | 0.274    |
# |    ent_coef        | 0.319    |
# |    ent_coef_loss   | -5.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3897     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 127      |
# |    ep_rew_mean     | 209      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 304      |
# |    time_elapsed    | 53       |
# |    total_timesteps | 16212    |
# | train/             |          |
# |    actor_loss      | -17.6    |
# |    critic_loss     | 0.147    |
# |    ent_coef        | 0.307    |
# |    ent_coef_loss   | -5.39    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4027     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 130      |
# |    ep_rew_mean     | 216      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 302      |
# |    time_elapsed    | 55       |
# |    total_timesteps | 16756    |
# | train/             |          |
# |    actor_loss      | -17.4    |
# |    critic_loss     | 0.311    |
# |    ent_coef        | 0.295    |
# |    ent_coef_loss   | -5.55    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4163     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | 225      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 301      |
# |    time_elapsed    | 57       |
# |    total_timesteps | 17256    |
# | train/             |          |
# |    actor_loss      | -17.4    |
# |    critic_loss     | 0.371    |
# |    ent_coef        | 0.284    |
# |    ent_coef_loss   | -5.59    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4288     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 136      |
# |    ep_rew_mean     | 232      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 298      |
# |    time_elapsed    | 59       |
# |    total_timesteps | 17716    |
# | train/             |          |
# |    actor_loss      | -17.4    |
# |    critic_loss     | 0.256    |
# |    ent_coef        | 0.274    |
# |    ent_coef_loss   | -5.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4403     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 136      |
# |    ep_rew_mean     | 235      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 295      |
# |    time_elapsed    | 61       |
# |    total_timesteps | 18212    |
# | train/             |          |
# |    actor_loss      | -18.2    |
# |    critic_loss     | 0.186    |
# |    ent_coef        | 0.264    |
# |    ent_coef_loss   | -5.86    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4527     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 139      |
# |    ep_rew_mean     | 244      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 291      |
# |    time_elapsed    | 64       |
# |    total_timesteps | 18772    |
# | train/             |          |
# |    actor_loss      | -17.7    |
# |    critic_loss     | 0.495    |
# |    ent_coef        | 0.254    |
# |    ent_coef_loss   | -6.26    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4667     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | 249      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 288      |
# |    time_elapsed    | 66       |
# |    total_timesteps | 19264    |
# | train/             |          |
# |    actor_loss      | -17.6    |
# |    critic_loss     | 0.222    |
# |    ent_coef        | 0.245    |
# |    ent_coef_loss   | -5.99    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4790     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | 253      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 287      |
# |    time_elapsed    | 68       |
# |    total_timesteps | 19720    |
# | train/             |          |
# |    actor_loss      | -18.5    |
# |    critic_loss     | 0.162    |
# |    ent_coef        | 0.236    |
# |    ent_coef_loss   | -6.41    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4904     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | 255      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 285      |
# |    time_elapsed    | 70       |
# |    total_timesteps | 20148    |
# | train/             |          |
# |    actor_loss      | -18.2    |
# |    critic_loss     | 0.433    |
# |    ent_coef        | 0.229    |
# |    ent_coef_loss   | -6.64    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5011     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 143      |
# |    ep_rew_mean     | 264      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 282      |
# |    time_elapsed    | 73       |
# |    total_timesteps | 20704    |
# | train/             |          |
# |    actor_loss      | -18.1    |
# |    critic_loss     | 0.207    |
# |    ent_coef        | 0.22     |
# |    ent_coef_loss   | -6.71    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5150     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | 262      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 279      |
# |    time_elapsed    | 75       |
# |    total_timesteps | 21152    |
# | train/             |          |
# |    actor_loss      | -18.2    |
# |    critic_loss     | 0.166    |
# |    ent_coef        | 0.213    |
# |    ent_coef_loss   | -6.82    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5262     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | 264      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 275      |
# |    time_elapsed    | 78       |
# |    total_timesteps | 21664    |
# | train/             |          |
# |    actor_loss      | -18.3    |
# |    critic_loss     | 0.273    |
# |    ent_coef        | 0.205    |
# |    ent_coef_loss   | -6.89    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5390     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | 264      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 272      |
# |    time_elapsed    | 81       |
# |    total_timesteps | 22224    |
# | train/             |          |
# |    actor_loss      | -18.1    |
# |    critic_loss     | 0.213    |
# |    ent_coef        | 0.196    |
# |    ent_coef_loss   | -7.16    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5530     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | 268      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 269      |
# |    time_elapsed    | 84       |
# |    total_timesteps | 22804    |
# | train/             |          |
# |    actor_loss      | -18.3    |
# |    critic_loss     | 0.146    |
# |    ent_coef        | 0.188    |
# |    ent_coef_loss   | -7.35    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5675     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | 269      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 266      |
# |    time_elapsed    | 87       |
# |    total_timesteps | 23388    |
# | train/             |          |
# |    actor_loss      | -18.5    |
# |    critic_loss     | 0.175    |
# |    ent_coef        | 0.18     |
# |    ent_coef_loss   | -7.32    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5821     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 263      |
# |    time_elapsed    | 90       |
# |    total_timesteps | 23920    |
# | train/             |          |
# |    actor_loss      | -17.6    |
# |    critic_loss     | 0.218    |
# |    ent_coef        | 0.173    |
# |    ent_coef_loss   | -7.59    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5954     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 260      |
# |    time_elapsed    | 93       |
# |    total_timesteps | 24412    |
# | train/             |          |
# |    actor_loss      | -18.4    |
# |    critic_loss     | 0.111    |
# |    ent_coef        | 0.167    |
# |    ent_coef_loss   | -7.95    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6077     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 138      |
# |    ep_rew_mean     | 270      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 257      |
# |    time_elapsed    | 97       |
# |    total_timesteps | 25000    |
# | train/             |          |
# |    actor_loss      | -18.4    |
# |    critic_loss     | 0.217    |
# |    ent_coef        | 0.16     |
# |    ent_coef_loss   | -8.06    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6224     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 136      |
# |    ep_rew_mean     | 269      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 253      |
# |    time_elapsed    | 100      |
# |    total_timesteps | 25520    |
# | train/             |          |
# |    actor_loss      | -18.6    |
# |    critic_loss     | 0.146    |
# |    ent_coef        | 0.154    |
# |    ent_coef_loss   | -8.26    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6354     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 134      |
# |    ep_rew_mean     | 269      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 250      |
# |    time_elapsed    | 103      |
# |    total_timesteps | 26012    |
# | train/             |          |
# |    actor_loss      | -18.2    |
# |    critic_loss     | 0.174    |
# |    ent_coef        | 0.148    |
# |    ent_coef_loss   | -8.58    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6477     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | 270      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 247      |
# |    time_elapsed    | 107      |
# |    total_timesteps | 26644    |
# | train/             |          |
# |    actor_loss      | -18.1    |
# |    critic_loss     | 0.184    |
# |    ent_coef        | 0.142    |
# |    ent_coef_loss   | -8.21    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6635     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 133      |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 244      |
# |    time_elapsed    | 110      |
# |    total_timesteps | 27068    |
# | train/             |          |
# |    actor_loss      | -18.3    |
# |    critic_loss     | 0.101    |
# |    ent_coef        | 0.137    |
# |    ent_coef_loss   | -8.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6741     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 130      |
# |    ep_rew_mean     | 272      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 240      |
# |    time_elapsed    | 115      |
# |    total_timesteps | 27700    |
# | train/             |          |
# |    actor_loss      | -17.9    |
# |    critic_loss     | 0.201    |
# |    ent_coef        | 0.131    |
# |    ent_coef_loss   | -8.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 130      |
# |    ep_rew_mean     | 274      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 237      |
# |    time_elapsed    | 118      |
# |    total_timesteps | 28232    |
# | train/             |          |
# |    actor_loss      | -17.2    |
# |    critic_loss     | 0.153    |
# |    ent_coef        | 0.126    |
# |    ent_coef_loss   | -9.12    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7032     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 130      |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 234      |
# |    time_elapsed    | 122      |
# |    total_timesteps | 28744    |
# | train/             |          |
# |    actor_loss      | -18.3    |
# |    critic_loss     | 0.104    |
# |    ent_coef        | 0.121    |
# |    ent_coef_loss   | -9.51    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7160     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 130      |
# |    ep_rew_mean     | 278      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 231      |
# |    time_elapsed    | 126      |
# |    total_timesteps | 29256    |
# | train/             |          |
# |    actor_loss      | -17.7    |
# |    critic_loss     | 0.167    |
# |    ent_coef        | 0.117    |
# |    ent_coef_loss   | -8.98    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7288     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 131      |
# |    ep_rew_mean     | 282      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 228      |
# |    time_elapsed    | 130      |
# |    total_timesteps | 29848    |
# | train/             |          |
# |    actor_loss      | -17.7    |
# |    critic_loss     | 0.072    |
# |    ent_coef        | 0.112    |
# |    ent_coef_loss   | -9.21    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7436     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 131      |
# |    ep_rew_mean     | 285      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 225      |
# |    time_elapsed    | 135      |
# |    total_timesteps | 30512    |
# | train/             |          |
# |    actor_loss      | -18.1    |
# |    critic_loss     | 0.272    |
# |    ent_coef        | 0.106    |
# |    ent_coef_loss   | -9.71    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7602     |
# ---------------------------------
# ...
# |    fps             | 135      |
# |    time_elapsed    | 36574    |
# |    total_timesteps | 4946604  |
# | train/             |          |
# |    actor_loss      | -2.69    |
# |    critic_loss     | 5.81e-05 |
# |    ent_coef        | 0.000174 |
# |    ent_coef_loss   | 1.77     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1236625  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 617      |
# |    ep_rew_mean     | 2.69e+03 |
# | time/              |          |
# |    episodes        | 9008     |
# |    fps             | 135      |
# |    time_elapsed    | 36589    |
# |    total_timesteps | 4949436  |
# | train/             |          |
# |    actor_loss      | -2.81    |
# |    critic_loss     | 0.000256 |
# |    ent_coef        | 0.000176 |
# |    ent_coef_loss   | -0.582   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1237333  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 616      |
# |    ep_rew_mean     | 2.69e+03 |
# | time/              |          |
# |    episodes        | 9012     |
# |    fps             | 135      |
# |    time_elapsed    | 36597    |
# |    total_timesteps | 4950984  |
# | train/             |          |
# |    actor_loss      | -2.74    |
# |    critic_loss     | 5.07e-05 |
# |    ent_coef        | 0.000178 |
# |    ent_coef_loss   | -1.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1237720  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 609      |
# |    ep_rew_mean     | 2.66e+03 |
# | time/              |          |
# |    episodes        | 9016     |
# |    fps             | 135      |
# |    time_elapsed    | 36610    |
# |    total_timesteps | 4953604  |
# | train/             |          |
# |    actor_loss      | -2.73    |
# |    critic_loss     | 5.31e-05 |
# |    ent_coef        | 0.000177 |
# |    ent_coef_loss   | -2.78    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1238375  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 597      |
# |    ep_rew_mean     | 2.6e+03  |
# | time/              |          |
# |    episodes        | 9020     |
# |    fps             | 135      |
# |    time_elapsed    | 36620    |
# |    total_timesteps | 4955716  |
# | train/             |          |
# |    actor_loss      | -2.74    |
# |    critic_loss     | 6.12e-05 |
# |    ent_coef        | 0.000175 |
# |    ent_coef_loss   | -1.81    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1238903  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 589      |
# |    ep_rew_mean     | 2.56e+03 |
# | time/              |          |
# |    episodes        | 9024     |
# |    fps             | 135      |
# |    time_elapsed    | 36627    |
# |    total_timesteps | 4957556  |
# | train/             |          |
# |    actor_loss      | -2.7     |
# |    critic_loss     | 5.12e-05 |
# |    ent_coef        | 0.00017  |
# |    ent_coef_loss   | -3.66    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1239363  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 586      |
# |    ep_rew_mean     | 2.55e+03 |
# | time/              |          |
# |    episodes        | 9028     |
# |    fps             | 135      |
# |    time_elapsed    | 36636    |
# |    total_timesteps | 4959424  |
# | train/             |          |
# |    actor_loss      | -2.81    |
# |    critic_loss     | 0.000169 |
# |    ent_coef        | 0.000173 |
# |    ent_coef_loss   | 2.77     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1239830  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 583      |
# |    ep_rew_mean     | 2.54e+03 |
# | time/              |          |
# |    episodes        | 9032     |
# |    fps             | 135      |
# |    time_elapsed    | 36644    |
# |    total_timesteps | 4961244  |
# | train/             |          |
# |    actor_loss      | -2.77    |
# |    critic_loss     | 5.04e-05 |
# |    ent_coef        | 0.000169 |
# |    ent_coef_loss   | -0.891   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1240285  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 576      |
# |    ep_rew_mean     | 2.51e+03 |
# | time/              |          |
# |    episodes        | 9036     |
# |    fps             | 135      |
# |    time_elapsed    | 36650    |
# |    total_timesteps | 4962608  |
# | train/             |          |
# |    actor_loss      | -2.65    |
# |    critic_loss     | 6.29e-05 |
# |    ent_coef        | 0.000177 |
# |    ent_coef_loss   | 2.93     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1240626  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 570      |
# |    ep_rew_mean     | 2.48e+03 |
# | time/              |          |
# |    episodes        | 9040     |
# |    fps             | 135      |
# |    time_elapsed    | 36659    |
# |    total_timesteps | 4964832  |
# | train/             |          |
# |    actor_loss      | -2.81    |
# |    critic_loss     | 0.000111 |
# |    ent_coef        | 0.000184 |
# |    ent_coef_loss   | 0.954    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1241182  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 555      |
# |    ep_rew_mean     | 2.42e+03 |
# | time/              |          |
# |    episodes        | 9044     |
# |    fps             | 135      |
# |    time_elapsed    | 36666    |
# |    total_timesteps | 4966336  |
# | train/             |          |
# |    actor_loss      | -2.81    |
# |    critic_loss     | 0.000254 |
# |    ent_coef        | 0.000177 |
# |    ent_coef_loss   | 0.552    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1241558  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 558      |
# |    ep_rew_mean     | 2.43e+03 |
# | time/              |          |
# |    episodes        | 9048     |
# |    fps             | 135      |
# |    time_elapsed    | 36675    |
# |    total_timesteps | 4968448  |
# | train/             |          |
# |    actor_loss      | -2.74    |
# |    critic_loss     | 0.000124 |
# |    ent_coef        | 0.000174 |
# |    ent_coef_loss   | 2.13     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1242086  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 550      |
# |    ep_rew_mean     | 2.4e+03  |
# | time/              |          |
# |    episodes        | 9052     |
# |    fps             | 135      |
# |    time_elapsed    | 36684    |
# |    total_timesteps | 4970572  |
# | train/             |          |
# |    actor_loss      | -2.76    |
# |    critic_loss     | 7.14e-05 |
# |    ent_coef        | 0.000179 |
# |    ent_coef_loss   | -0.711   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1242617  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 553      |
# |    ep_rew_mean     | 2.41e+03 |
# | time/              |          |
# |    episodes        | 9056     |
# |    fps             | 135      |
# |    time_elapsed    | 36691    |
# |    total_timesteps | 4972376  |
# | train/             |          |
# |    actor_loss      | -2.74    |
# |    critic_loss     | 7.87e-05 |
# |    ent_coef        | 0.000176 |
# |    ent_coef_loss   | 4.49     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1243068  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 542      |
# |    ep_rew_mean     | 2.36e+03 |
# | time/              |          |
# |    episodes        | 9060     |
# |    fps             | 135      |
# |    time_elapsed    | 36698    |
# |    total_timesteps | 4974116  |
# | train/             |          |
# |    actor_loss      | -2.69    |
# |    critic_loss     | 0.000246 |
# |    ent_coef        | 0.000182 |
# |    ent_coef_loss   | 0.49     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1243503  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 527      |
# |    ep_rew_mean     | 2.3e+03  |
# | time/              |          |
# |    episodes        | 9064     |
# |    fps             | 135      |
# |    time_elapsed    | 36704    |
# |    total_timesteps | 4975492  |
# | train/             |          |
# |    actor_loss      | -2.76    |
# |    critic_loss     | 6.52e-05 |
# |    ent_coef        | 0.000184 |
# |    ent_coef_loss   | -2.25    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1243847  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 522      |
# |    ep_rew_mean     | 2.28e+03 |
# | time/              |          |
# |    episodes        | 9068     |
# |    fps             | 135      |
# |    time_elapsed    | 36714    |
# |    total_timesteps | 4978100  |
# | train/             |          |
# |    actor_loss      | -2.7     |
# |    critic_loss     | 0.000171 |
# |    ent_coef        | 0.000183 |
# |    ent_coef_loss   | 3.63     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1244499  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 515      |
# |    ep_rew_mean     | 2.25e+03 |
# | time/              |          |
# |    episodes        | 9072     |
# |    fps             | 135      |
# |    time_elapsed    | 36721    |
# |    total_timesteps | 4979852  |
# | train/             |          |
# |    actor_loss      | -2.79    |
# |    critic_loss     | 0.000144 |
# |    ent_coef        | 0.000183 |
# |    ent_coef_loss   | -0.989   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1244937  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 507      |
# |    ep_rew_mean     | 2.22e+03 |
# | time/              |          |
# |    episodes        | 9076     |
# |    fps             | 135      |
# |    time_elapsed    | 36727    |
# |    total_timesteps | 4981516  |
# | train/             |          |
# |    actor_loss      | -2.79    |
# |    critic_loss     | 8.88e-05 |
# |    ent_coef        | 0.000184 |
# |    ent_coef_loss   | -1.36    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1245353  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 490      |
# |    ep_rew_mean     | 2.14e+03 |
# | time/              |          |
# |    episodes        | 9080     |
# |    fps             | 135      |
# |    time_elapsed    | 36734    |
# |    total_timesteps | 4983584  |
# | train/             |          |
# |    actor_loss      | -2.78    |
# |    critic_loss     | 5.26e-05 |
# |    ent_coef        | 0.000176 |
# |    ent_coef_loss   | -1.32    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1245870  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 487      |
# |    ep_rew_mean     | 2.13e+03 |
# | time/              |          |
# |    episodes        | 9084     |
# |    fps             | 135      |
# |    time_elapsed    | 36739    |
# |    total_timesteps | 4985060  |
# | train/             |          |
# |    actor_loss      | -2.84    |
# |    critic_loss     | 0.000111 |
# |    ent_coef        | 0.000171 |
# |    ent_coef_loss   | 2.03     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1246239  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 484      |
# |    ep_rew_mean     | 2.11e+03 |
# | time/              |          |
# |    episodes        | 9088     |
# |    fps             | 135      |
# |    time_elapsed    | 36746    |
# |    total_timesteps | 4986924  |
# | train/             |          |
# |    actor_loss      | -2.68    |
# |    critic_loss     | 0.000148 |
# |    ent_coef        | 0.000169 |
# |    ent_coef_loss   | 0.656    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1246705  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 479      |
# |    ep_rew_mean     | 2.09e+03 |
# | time/              |          |
# |    episodes        | 9092     |
# |    fps             | 135      |
# |    time_elapsed    | 36752    |
# |    total_timesteps | 4988356  |
# | train/             |          |
# |    actor_loss      | -2.81    |
# |    critic_loss     | 9.41e-05 |
# |    ent_coef        | 0.000173 |
# |    ent_coef_loss   | -0.79    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1247063  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 478      |
# |    ep_rew_mean     | 2.09e+03 |
# | time/              |          |
# |    episodes        | 9096     |
# |    fps             | 135      |
# |    time_elapsed    | 36757    |
# |    total_timesteps | 4989844  |
# | train/             |          |
# |    actor_loss      | -2.76    |
# |    critic_loss     | 0.0001   |
# |    ent_coef        | 0.000175 |
# |    ent_coef_loss   | 0.931    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1247435  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 479      |
# |    ep_rew_mean     | 2.09e+03 |
# | time/              |          |
# |    episodes        | 9100     |
# |    fps             | 135      |
# |    time_elapsed    | 36764    |
# |    total_timesteps | 4991832  |
# | train/             |          |
# |    actor_loss      | -2.76    |
# |    critic_loss     | 8.11e-05 |
# |    ent_coef        | 0.000173 |
# |    ent_coef_loss   | 2.22     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1247932  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 469      |
# |    ep_rew_mean     | 2.05e+03 |
# | time/              |          |
# |    episodes        | 9104     |
# |    fps             | 135      |
# |    time_elapsed    | 36770    |
# |    total_timesteps | 4993316  |
# | train/             |          |
# |    actor_loss      | -2.74    |
# |    critic_loss     | 0.0256   |
# |    ent_coef        | 0.000174 |
# |    ent_coef_loss   | 1.29     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1248303  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 454      |
# |    ep_rew_mean     | 1.98e+03 |
# | time/              |          |
# |    episodes        | 9108     |
# |    fps             | 135      |
# |    time_elapsed    | 36776    |
# |    total_timesteps | 4994936  |
# | train/             |          |
# |    actor_loss      | -2.69    |
# |    critic_loss     | 0.000212 |
# |    ent_coef        | 0.000178 |
# |    ent_coef_loss   | 1.52     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1248708  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 458      |
# |    ep_rew_mean     | 2e+03    |
# | time/              |          |
# |    episodes        | 9112     |
# |    fps             | 135      |
# |    time_elapsed    | 36784    |
# |    total_timesteps | 4997216  |
# | train/             |          |
# |    actor_loss      | -2.78    |
# |    critic_loss     | 0.000303 |
# |    ent_coef        | 0.000179 |
# |    ent_coef_loss   | 0.98     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1249278  |
# ---------------------------------

# %%
# Load model and evaluate
model = SAC.load("./models/sac_hopper_final", device=device)

venv = make_vec_env(ENV_ID, n_envs=1, seed=42)
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

mean_reward, std_reward = evaluate_policy(model, venv, n_eval_episodes=10, deterministic=True)
print(f"Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Mean reward: 2484.67 +/- 531.35

# %%
import os
os.environ["MUJOCO_GL"] = "glfw"

import gymnasium as gym
import imageio
import numpy as np
from IPython.display import Video, display
import tempfile

from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

ENV_ID = "Hopper-v5"
N_EVAL_EPISODES = 10
MAX_STEPS = 1500
FPS = 30

# create env
env = gym.make(ENV_ID, render_mode="rgb_array")
venv = DummyVecEnv([lambda: env])
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

# load model
# model = SAC.load("./models/sac_humanoid_final", device="cpu")
model = SAC.load("./best_model/best_model", device="cpu")

best_frames = []
best_length = 0

for ep in range(N_EVAL_EPISODES):
    obs = venv.reset()
    frames = []

    for step in range(MAX_STEPS):
        action, _ = model.predict(obs, deterministic=True)
        obs, rewards, dones, infos = venv.step(action)

        frame = env.render()
        if frame is not None:
            frames.append(frame)

        if dones[0]:
            break

    ep_length = len(frames)
    print(f"Episode {ep+1}: {ep_length} frames")

    if ep_length > best_length:
        best_length = ep_length
        best_frames = frames

print(f"\nLongest episode length: {best_length} frames")

# save and display only the longest episode
tmp = tempfile.NamedTemporaryFile(suffix=".mp4", delete=False).name
writer = imageio.get_writer(tmp, fps=FPS, codec="libx264")
for f in best_frames:
    writer.append_data(f)
writer.close()

display(Video(tmp, embed=True))
# Out:
# Episode 1: 18 frames
# Episode 2: 18 frames
# Episode 3: 18 frames
# Episode 4: 18 frames
# Episode 5: 18 frames
# Episode 6: 17 frames
# Episode 7: 18 frames
# Episode 8: 18 frames
# Episode 9: 18 frames
# Episode 10: 17 frames
#
# Longest episode length: 18 frames
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
