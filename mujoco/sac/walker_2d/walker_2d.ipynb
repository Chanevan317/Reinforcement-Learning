# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.5.1
# CUDA available: True
# CUDA device count: 1
# GPU name: NVIDIA GeForce RTX 4080 SUPER

# %%
# Quick checks
import sys, platform
import torch
print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())
print("PyTorch:", torch.__version__, "| CUDA available:", torch.cuda.is_available())
import mujoco
print("MuJoCo package version:", mujoco.__version__)
# Out:
# Python: 3.10.19
# Platform: Windows-10-10.0.26200-SP0
# PyTorch: 2.5.1 | CUDA available: True
# MuJoCo package version: 3.4.0

# %%
# Imports
import os
import gymnasium as gym
import numpy as np
import torch
from stable_baselines3 import SAC
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecNormalize, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback
from stable_baselines3.common.evaluation import evaluate_policy

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Env setup
ENV_ID = "Walker2d-v5"   # requires mujoco >= 2.3
n_envs = 4               # on Windows + single CPU, 4 is reasonable; reduce if CPU bound
seed = 0

# Make vectorized training envs
train_env = make_vec_env(
    ENV_ID,
    n_envs=n_envs,
    seed=seed,
    monitor_dir="./logs/train_monitor"
)

# VecNormalize (important for continuous control)
train_env = VecNormalize(train_env, norm_obs=True, norm_reward=True, clip_obs=10.0)

# eval env
eval_env = make_vec_env(
    ENV_ID,
    n_envs=1,
    seed=seed + 100,
    monitor_dir="./logs/eval_monitor"
)
eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

print("Obs space:", train_env.observation_space)
print("Act space:", train_env.action_space)
# Out:
# Obs space: Box(-inf, inf, (17,), float64)
# Act space: Box(-1.0, 1.0, (6,), float32)

# %%
# Create SAC
model = SAC(
    "MlpPolicy", 
    train_env,
    learning_rate=3e-4,
    buffer_size=int(1e6),
    batch_size=256,
    gamma=0.99,
    tau=0.005,
    ent_coef="auto",
    policy_kwargs=dict(net_arch=[256, 256]),
    device=device,
    verbose=1,
)
# Out:
# Using cuda device

# %%
# Callbacks and save dirs
os.makedirs("./models", exist_ok=True)
os.makedirs("./checkpoints", exist_ok=True)
os.makedirs("./best_model", exist_ok=True)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./best_model/",
    log_path="./logs/eval",
    eval_freq=100_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False
)

checkpoint_callback = CheckpointCallback(save_freq=500_000, save_path="./checkpoints/", name_prefix="sac_walker2d")

# %%
# Train
TOTAL_TIMESTEPS = int(5e6) 
model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=[eval_callback, checkpoint_callback])
model.save("./models/sac_walker2d_final")
# save VecNormalize
train_env.save("./models/vecnormalize_train.pkl")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.8     |
# |    ep_rew_mean     | 9.4      |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 251      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 152      |
# | train/             |          |
# |    actor_loss      | -4.8     |
# |    critic_loss     | 10.5     |
# |    ent_coef        | 0.997    |
# |    ent_coef_loss   | -0.0333  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.9     |
# |    ep_rew_mean     | 4.83     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 173      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 240      |
# | train/             |          |
# |    actor_loss      | -6.72    |
# |    critic_loss     | 2.87     |
# |    ent_coef        | 0.99     |
# |    ent_coef_loss   | -0.0999  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 34       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.2     |
# |    ep_rew_mean     | 3.15     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 152      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 312      |
# | train/             |          |
# |    actor_loss      | -8       |
# |    critic_loss     | 1.49     |
# |    ent_coef        | 0.985    |
# |    ent_coef_loss   | -0.155   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 52       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.7     |
# |    ep_rew_mean     | 1.77     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 140      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 404      |
# | train/             |          |
# |    actor_loss      | -8.1     |
# |    critic_loss     | 1.15     |
# |    ent_coef        | 0.978    |
# |    ent_coef_loss   | -0.225   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 75       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.2     |
# |    ep_rew_mean     | 1.53     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 132      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 512      |
# | train/             |          |
# |    actor_loss      | -8.41    |
# |    critic_loss     | 1.47     |
# |    ent_coef        | 0.97     |
# |    ent_coef_loss   | -0.306   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.4     |
# |    ep_rew_mean     | 1.77     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 129      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 596      |
# | train/             |          |
# |    actor_loss      | -8.56    |
# |    critic_loss     | 1.45     |
# |    ent_coef        | 0.964    |
# |    ent_coef_loss   | -0.369   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 123      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.3     |
# |    ep_rew_mean     | 1.84     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 126      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 708      |
# | train/             |          |
# |    actor_loss      | -8.91    |
# |    critic_loss     | 1.25     |
# |    ent_coef        | 0.956    |
# |    ent_coef_loss   | -0.455   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 151      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.5     |
# |    ep_rew_mean     | 1.57     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 124      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 796      |
# | train/             |          |
# |    actor_loss      | -9.16    |
# |    critic_loss     | 1.62     |
# |    ent_coef        | 0.95     |
# |    ent_coef_loss   | -0.521   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 173      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.3     |
# |    ep_rew_mean     | 1.02     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 122      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 916      |
# | train/             |          |
# |    actor_loss      | -9.39    |
# |    critic_loss     | 1.2      |
# |    ent_coef        | 0.941    |
# |    ent_coef_loss   | -0.611   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 203      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.5     |
# |    ep_rew_mean     | 1.26     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 122      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 972      |
# | train/             |          |
# |    actor_loss      | -9.44    |
# |    critic_loss     | 1.38     |
# |    ent_coef        | 0.937    |
# |    ent_coef_loss   | -0.652   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 217      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23       |
# |    ep_rew_mean     | 0.667    |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 121      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1036     |
# | train/             |          |
# |    actor_loss      | -9.7     |
# |    critic_loss     | 1.34     |
# |    ent_coef        | 0.933    |
# |    ent_coef_loss   | -0.702   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 233      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.2     |
# |    ep_rew_mean     | 1.06     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 121      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1152     |
# | train/             |          |
# |    actor_loss      | -9.98    |
# |    critic_loss     | 1.34     |
# |    ent_coef        | 0.925    |
# |    ent_coef_loss   | -0.786   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 262      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23       |
# |    ep_rew_mean     | 0.603    |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 120      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1216     |
# | train/             |          |
# |    actor_loss      | -10.3    |
# |    critic_loss     | 1.19     |
# |    ent_coef        | 0.92     |
# |    ent_coef_loss   | -0.839   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 278      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.7     |
# |    ep_rew_mean     | 0.698    |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 119      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 1328     |
# | train/             |          |
# |    actor_loss      | -10.5    |
# |    critic_loss     | 1.56     |
# |    ent_coef        | 0.913    |
# |    ent_coef_loss   | -0.913   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 306      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.7     |
# |    ep_rew_mean     | 0.609    |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 119      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 1428     |
# | train/             |          |
# |    actor_loss      | -10.7    |
# |    critic_loss     | 1.32     |
# |    ent_coef        | 0.906    |
# |    ent_coef_loss   | -0.997   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 331      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.9     |
# |    ep_rew_mean     | 0.681    |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 119      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 1492     |
# | train/             |          |
# |    actor_loss      | -10.8    |
# |    critic_loss     | 1.86     |
# |    ent_coef        | 0.901    |
# |    ent_coef_loss   | -1.04    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 347      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.7     |
# |    ep_rew_mean     | 0.65     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 119      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 1564     |
# | train/             |          |
# |    actor_loss      | -10.9    |
# |    critic_loss     | 1.64     |
# |    ent_coef        | 0.897    |
# |    ent_coef_loss   | -1.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 365      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.7     |
# |    ep_rew_mean     | 0.611    |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 119      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 1656     |
# | train/             |          |
# |    actor_loss      | -11.2    |
# |    critic_loss     | 1.25     |
# |    ent_coef        | 0.89     |
# |    ent_coef_loss   | -1.16    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 388      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.3     |
# |    ep_rew_mean     | 0.452    |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 118      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 1704     |
# | train/             |          |
# |    actor_loss      | -11.3    |
# |    critic_loss     | 1.5      |
# |    ent_coef        | 0.887    |
# |    ent_coef_loss   | -1.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 400      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | 0.313    |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 118      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1844     |
# | train/             |          |
# |    actor_loss      | -11.6    |
# |    critic_loss     | 1.43     |
# |    ent_coef        | 0.878    |
# |    ent_coef_loss   | -1.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 435      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.6     |
# |    ep_rew_mean     | 0.201    |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 117      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 1996     |
# | train/             |          |
# |    actor_loss      | -12      |
# |    critic_loss     | 1.4      |
# |    ent_coef        | 0.868    |
# |    ent_coef_loss   | -1.41    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 473      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.2     |
# |    ep_rew_mean     | 0.524    |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 117      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 2076     |
# | train/             |          |
# |    actor_loss      | -12.1    |
# |    critic_loss     | 0.961    |
# |    ent_coef        | 0.863    |
# |    ent_coef_loss   | -1.47    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 493      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.1     |
# |    ep_rew_mean     | 0.48     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 117      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 2184     |
# | train/             |          |
# |    actor_loss      | -12.5    |
# |    critic_loss     | 1.01     |
# |    ent_coef        | 0.856    |
# |    ent_coef_loss   | -1.56    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 520      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.4     |
# |    ep_rew_mean     | 0.444    |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 116      |
# |    time_elapsed    | 19       |
# |    total_timesteps | 2308     |
# | train/             |          |
# |    actor_loss      | -12.7    |
# |    critic_loss     | 1.21     |
# |    ent_coef        | 0.848    |
# |    ent_coef_loss   | -1.63    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 551      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.4     |
# |    ep_rew_mean     | 0.35     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 116      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 2380     |
# | train/             |          |
# |    actor_loss      | -13      |
# |    critic_loss     | 1.04     |
# |    ent_coef        | 0.844    |
# |    ent_coef_loss   | -1.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 569      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.4     |
# |    ep_rew_mean     | -0.086   |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 116      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 2488     |
# | train/             |          |
# |    actor_loss      | -13.3    |
# |    critic_loss     | 0.981    |
# |    ent_coef        | 0.837    |
# |    ent_coef_loss   | -1.78    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 596      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.7     |
# |    ep_rew_mean     | -0.223   |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 116      |
# |    time_elapsed    | 22       |
# |    total_timesteps | 2620     |
# | train/             |          |
# |    actor_loss      | -13.7    |
# |    critic_loss     | 0.944    |
# |    ent_coef        | 0.829    |
# |    ent_coef_loss   | -1.85    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 629      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.9     |
# |    ep_rew_mean     | -0.315   |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 116      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 2792     |
# | train/             |          |
# |    actor_loss      | -14.2    |
# |    critic_loss     | 1.26     |
# |    ent_coef        | 0.818    |
# |    ent_coef_loss   | -1.99    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 672      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -0.187   |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 115      |
# |    time_elapsed    | 25       |
# |    total_timesteps | 2936     |
# | train/             |          |
# |    actor_loss      | -14      |
# |    critic_loss     | 1.26     |
# |    ent_coef        | 0.81     |
# |    ent_coef_loss   | -2.08    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 708      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.9     |
# |    ep_rew_mean     | 0.1      |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 115      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 3092     |
# | train/             |          |
# |    actor_loss      | -14.8    |
# |    critic_loss     | 0.921    |
# |    ent_coef        | 0.8      |
# |    ent_coef_loss   | -2.17    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 747      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.2     |
# |    ep_rew_mean     | -0.113   |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 115      |
# |    time_elapsed    | 28       |
# |    total_timesteps | 3248     |
# | train/             |          |
# |    actor_loss      | -15.1    |
# |    critic_loss     | 0.724    |
# |    ent_coef        | 0.791    |
# |    ent_coef_loss   | -2.28    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 786      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.5     |
# |    ep_rew_mean     | -0.244   |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 115      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 3360     |
# | train/             |          |
# |    actor_loss      | -14.9    |
# |    critic_loss     | 0.762    |
# |    ent_coef        | 0.785    |
# |    ent_coef_loss   | -2.37    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 814      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.8     |
# |    ep_rew_mean     | -0.12    |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 114      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 3464     |
# | train/             |          |
# |    actor_loss      | -15.3    |
# |    critic_loss     | 1.21     |
# |    ent_coef        | 0.779    |
# |    ent_coef_loss   | -2.44    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 840      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.7     |
# |    ep_rew_mean     | 0.263    |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 114      |
# |    time_elapsed    | 31       |
# |    total_timesteps | 3672     |
# | train/             |          |
# |    actor_loss      | -16.1    |
# |    critic_loss     | 1.04     |
# |    ent_coef        | 0.767    |
# |    ent_coef_loss   | -2.57    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 892      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28       |
# |    ep_rew_mean     | 0.227    |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 114      |
# |    time_elapsed    | 33       |
# |    total_timesteps | 3848     |
# | train/             |          |
# |    actor_loss      | -16.5    |
# |    critic_loss     | 0.933    |
# |    ent_coef        | 0.757    |
# |    ent_coef_loss   | -2.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 936      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29       |
# |    ep_rew_mean     | 0.552    |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 114      |
# |    time_elapsed    | 34       |
# |    total_timesteps | 3968     |
# | train/             |          |
# |    actor_loss      | -16.2    |
# |    critic_loss     | 1.22     |
# |    ent_coef        | 0.75     |
# |    ent_coef_loss   | -2.76    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 966      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.1     |
# |    ep_rew_mean     | 0.332    |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 114      |
# |    time_elapsed    | 36       |
# |    total_timesteps | 4204     |
# | train/             |          |
# |    actor_loss      | -17.2    |
# |    critic_loss     | 0.829    |
# |    ent_coef        | 0.737    |
# |    ent_coef_loss   | -2.94    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1025     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.7     |
# |    ep_rew_mean     | 0.956    |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 114      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 4416     |
# | train/             |          |
# |    actor_loss      | -17.8    |
# |    critic_loss     | 1.01     |
# |    ent_coef        | 0.726    |
# |    ent_coef_loss   | -3.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1078     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.2     |
# |    ep_rew_mean     | 1.46     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 114      |
# |    time_elapsed    | 40       |
# |    total_timesteps | 4628     |
# | train/             |          |
# |    actor_loss      | -17.7    |
# |    critic_loss     | 1.16     |
# |    ent_coef        | 0.715    |
# |    ent_coef_loss   | -3.22    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1131     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.5     |
# |    ep_rew_mean     | 1.95     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 114      |
# |    time_elapsed    | 42       |
# |    total_timesteps | 4912     |
# | train/             |          |
# |    actor_loss      | -18.4    |
# |    critic_loss     | 0.828    |
# |    ent_coef        | 0.7      |
# |    ent_coef_loss   | -3.44    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1202     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.8     |
# |    ep_rew_mean     | 2.24     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 114      |
# |    time_elapsed    | 45       |
# |    total_timesteps | 5156     |
# | train/             |          |
# |    actor_loss      | -19      |
# |    critic_loss     | 0.843    |
# |    ent_coef        | 0.688    |
# |    ent_coef_loss   | -3.61    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1263     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.9     |
# |    ep_rew_mean     | 2.62     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 114      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 5304     |
# | train/             |          |
# |    actor_loss      | -19.4    |
# |    critic_loss     | 0.826    |
# |    ent_coef        | 0.68     |
# |    ent_coef_loss   | -3.66    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1300     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 38.6     |
# |    ep_rew_mean     | 2.78     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 114      |
# |    time_elapsed    | 49       |
# |    total_timesteps | 5628     |
# | train/             |          |
# |    actor_loss      | -20      |
# |    critic_loss     | 1.03     |
# |    ent_coef        | 0.664    |
# |    ent_coef_loss   | -3.91    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1381     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.2     |
# |    ep_rew_mean     | 4.9      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 114      |
# |    time_elapsed    | 52       |
# |    total_timesteps | 5956     |
# | train/             |          |
# |    actor_loss      | -20.4    |
# |    critic_loss     | 1.01     |
# |    ent_coef        | 0.648    |
# |    ent_coef_loss   | -4.09    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1463     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.5     |
# |    ep_rew_mean     | 5.7      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 114      |
# |    time_elapsed    | 55       |
# |    total_timesteps | 6392     |
# | train/             |          |
# |    actor_loss      | -21.2    |
# |    critic_loss     | 0.988    |
# |    ent_coef        | 0.628    |
# |    ent_coef_loss   | -4.46    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1572     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.9     |
# |    ep_rew_mean     | 7.02     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 114      |
# |    time_elapsed    | 58       |
# |    total_timesteps | 6656     |
# | train/             |          |
# |    actor_loss      | -21.8    |
# |    critic_loss     | 1.23     |
# |    ent_coef        | 0.616    |
# |    ent_coef_loss   | -4.66    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1638     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.4     |
# |    ep_rew_mean     | 7.6      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 114      |
# |    time_elapsed    | 61       |
# |    total_timesteps | 6980     |
# | train/             |          |
# |    actor_loss      | -22.8    |
# |    critic_loss     | 1.43     |
# |    ent_coef        | 0.601    |
# |    ent_coef_loss   | -4.88    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1719     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51.1     |
# |    ep_rew_mean     | 8.07     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 114      |
# |    time_elapsed    | 64       |
# |    total_timesteps | 7416     |
# | train/             |          |
# |    actor_loss      | -23.5    |
# |    critic_loss     | 0.913    |
# |    ent_coef        | 0.582    |
# |    ent_coef_loss   | -5.15    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1828     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 54.5     |
# |    ep_rew_mean     | 7.73     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 114      |
# |    time_elapsed    | 67       |
# |    total_timesteps | 7736     |
# | train/             |          |
# |    actor_loss      | -23.6    |
# |    critic_loss     | 0.955    |
# |    ent_coef        | 0.569    |
# |    ent_coef_loss   | -5.41    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1908     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 57.9     |
# |    ep_rew_mean     | 7.65     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 114      |
# |    time_elapsed    | 72       |
# |    total_timesteps | 8296     |
# | train/             |          |
# |    actor_loss      | -24.5    |
# |    critic_loss     | 1.07     |
# |    ent_coef        | 0.546    |
# |    ent_coef_loss   | -5.74    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2048     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 61.5     |
# |    ep_rew_mean     | 7.9      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 114      |
# |    time_elapsed    | 76       |
# |    total_timesteps | 8796     |
# | train/             |          |
# |    actor_loss      | -24.6    |
# |    critic_loss     | 1.45     |
# |    ent_coef        | 0.526    |
# |    ent_coef_loss   | -5.93    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2173     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 66.3     |
# |    ep_rew_mean     | 7.38     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 114      |
# |    time_elapsed    | 81       |
# |    total_timesteps | 9364     |
# | train/             |          |
# |    actor_loss      | -25.6    |
# |    critic_loss     | 0.958    |
# |    ent_coef        | 0.505    |
# |    ent_coef_loss   | -6.36    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2315     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 70       |
# |    ep_rew_mean     | 8.39     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 114      |
# |    time_elapsed    | 85       |
# |    total_timesteps | 9840     |
# | train/             |          |
# |    actor_loss      | -25.9    |
# |    critic_loss     | 0.841    |
# |    ent_coef        | 0.488    |
# |    ent_coef_loss   | -6.62    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2434     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 72.1     |
# |    ep_rew_mean     | 7.49     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 114      |
# |    time_elapsed    | 89       |
# |    total_timesteps | 10280    |
# | train/             |          |
# |    actor_loss      | -26.5    |
# |    critic_loss     | 0.759    |
# |    ent_coef        | 0.473    |
# |    ent_coef_loss   | -6.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2544     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 76.4     |
# |    ep_rew_mean     | 6.53     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 115      |
# |    time_elapsed    | 97       |
# |    total_timesteps | 11176    |
# | train/             |          |
# |    actor_loss      | -27.3    |
# |    critic_loss     | 1.74     |
# |    ent_coef        | 0.443    |
# |    ent_coef_loss   | -7.36    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2768     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.5     |
# |    ep_rew_mean     | 6.61     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 115      |
# |    time_elapsed    | 100      |
# |    total_timesteps | 11532    |
# | train/             |          |
# |    actor_loss      | -27.7    |
# |    critic_loss     | 0.76     |
# |    ent_coef        | 0.432    |
# |    ent_coef_loss   | -7.42    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2857     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.5     |
# |    ep_rew_mean     | 5.55     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 115      |
# |    time_elapsed    | 103      |
# |    total_timesteps | 11924    |
# | train/             |          |
# |    actor_loss      | -29.1    |
# |    critic_loss     | 0.967    |
# |    ent_coef        | 0.42     |
# |    ent_coef_loss   | -7.64    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2955     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.4     |
# |    ep_rew_mean     | 4.26     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 115      |
# |    time_elapsed    | 108      |
# |    total_timesteps | 12520    |
# | train/             |          |
# |    actor_loss      | -28.8    |
# |    critic_loss     | 1.09     |
# |    ent_coef        | 0.402    |
# |    ent_coef_loss   | -8.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3104     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.6     |
# |    ep_rew_mean     | 5.94     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 115      |
# |    time_elapsed    | 111      |
# |    total_timesteps | 12884    |
# | train/             |          |
# |    actor_loss      | -30      |
# |    critic_loss     | 0.882    |
# |    ent_coef        | 0.391    |
# |    ent_coef_loss   | -8.33    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3195     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.7     |
# |    ep_rew_mean     | 4.87     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 115      |
# |    time_elapsed    | 116      |
# |    total_timesteps | 13348    |
# | train/             |          |
# |    actor_loss      | -30.6    |
# |    critic_loss     | 1.08     |
# |    ent_coef        | 0.379    |
# |    ent_coef_loss   | -8.58    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3311     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 97.5     |
# |    ep_rew_mean     | 3.61     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 115      |
# |    time_elapsed    | 120      |
# |    total_timesteps | 13872    |
# | train/             |          |
# |    actor_loss      | -30.2    |
# |    critic_loss     | 1.07     |
# |    ent_coef        | 0.364    |
# |    ent_coef_loss   | -8.74    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3442     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | 2.84     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 115      |
# |    time_elapsed    | 124      |
# |    total_timesteps | 14344    |
# | train/             |          |
# |    actor_loss      | -29.5    |
# |    critic_loss     | 0.75     |
# |    ent_coef        | 0.352    |
# |    ent_coef_loss   | -8.92    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3560     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | 1.04     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 115      |
# |    time_elapsed    | 128      |
# |    total_timesteps | 14800    |
# | train/             |          |
# |    actor_loss      | -31.3    |
# |    critic_loss     | 0.93     |
# |    ent_coef        | 0.341    |
# |    ent_coef_loss   | -9.45    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3674     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | 0.181    |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 115      |
# |    time_elapsed    | 132      |
# |    total_timesteps | 15260    |
# | train/             |          |
# |    actor_loss      | -31      |
# |    critic_loss     | 1.1      |
# |    ent_coef        | 0.33     |
# |    ent_coef_loss   | -9.68    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3789     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 109      |
# |    ep_rew_mean     | 1.7      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 115      |
# |    time_elapsed    | 137      |
# |    total_timesteps | 15784    |
# | train/             |          |
# |    actor_loss      | -31      |
# |    critic_loss     | 0.972    |
# |    ent_coef        | 0.317    |
# |    ent_coef_loss   | -9.97    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3920     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 110      |
# |    ep_rew_mean     | 0.0664   |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 115      |
# |    time_elapsed    | 140      |
# |    total_timesteps | 16224    |
# | train/             |          |
# |    actor_loss      | -31.2    |
# |    critic_loss     | 0.777    |
# |    ent_coef        | 0.307    |
# |    ent_coef_loss   | -10.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4030     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 114      |
# |    ep_rew_mean     | -1.05    |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 115      |
# |    time_elapsed    | 146      |
# |    total_timesteps | 16884    |
# | train/             |          |
# |    actor_loss      | -31.3    |
# |    critic_loss     | 1.04     |
# |    ent_coef        | 0.293    |
# |    ent_coef_loss   | -10.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4195     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 117      |
# |    ep_rew_mean     | -1.65    |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 115      |
# |    time_elapsed    | 150      |
# |    total_timesteps | 17388    |
# | train/             |          |
# |    actor_loss      | -31.2    |
# |    critic_loss     | 1.68     |
# |    ent_coef        | 0.282    |
# |    ent_coef_loss   | -11.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4321     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 118      |
# |    ep_rew_mean     | -4.89    |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 115      |
# |    time_elapsed    | 154      |
# |    total_timesteps | 17760    |
# | train/             |          |
# |    actor_loss      | -30.7    |
# |    critic_loss     | 1.14     |
# |    ent_coef        | 0.274    |
# |    ent_coef_loss   | -11.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4414     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | -6.07    |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 115      |
# |    time_elapsed    | 158      |
# |    total_timesteps | 18256    |
# | train/             |          |
# |    actor_loss      | -32.5    |
# |    critic_loss     | 1.01     |
# |    ent_coef        | 0.265    |
# |    ent_coef_loss   | -11      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4538     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | -8.17    |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 115      |
# |    time_elapsed    | 162      |
# |    total_timesteps | 18744    |
# | train/             |          |
# |    actor_loss      | -31.9    |
# |    critic_loss     | 0.894    |
# |    ent_coef        | 0.255    |
# |    ent_coef_loss   | -11.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4660     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | -10.3    |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 115      |
# |    time_elapsed    | 167      |
# |    total_timesteps | 19340    |
# | train/             |          |
# |    actor_loss      | -33.4    |
# |    critic_loss     | 1.15     |
# |    ent_coef        | 0.244    |
# |    ent_coef_loss   | -12.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4809     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | -11.3    |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 115      |
# |    time_elapsed    | 171      |
# |    total_timesteps | 19720    |
# | train/             |          |
# |    actor_loss      | -32.4    |
# |    critic_loss     | 0.81     |
# |    ent_coef        | 0.237    |
# |    ent_coef_loss   | -12.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4904     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | -12.3    |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 115      |
# |    time_elapsed    | 174      |
# |    total_timesteps | 20088    |
# | train/             |          |
# |    actor_loss      | -33      |
# |    critic_loss     | 0.874    |
# |    ent_coef        | 0.231    |
# |    ent_coef_loss   | -12.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4996     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | -12.6    |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 115      |
# |    time_elapsed    | 178      |
# |    total_timesteps | 20544    |
# | train/             |          |
# |    actor_loss      | -34.1    |
# |    critic_loss     | 0.671    |
# |    ent_coef        | 0.223    |
# |    ent_coef_loss   | -13.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5110     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 125      |
# |    ep_rew_mean     | -11.4    |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 115      |
# |    time_elapsed    | 185      |
# |    total_timesteps | 21348    |
# | train/             |          |
# |    actor_loss      | -33.2    |
# |    critic_loss     | 0.917    |
# |    ent_coef        | 0.21     |
# |    ent_coef_loss   | -13.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5311     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | -11.2    |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 115      |
# |    time_elapsed    | 188      |
# |    total_timesteps | 21696    |
# | train/             |          |
# |    actor_loss      | -32.9    |
# |    critic_loss     | 1.48     |
# |    ent_coef        | 0.205    |
# |    ent_coef_loss   | -13.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5398     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | -13.1    |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 115      |
# |    time_elapsed    | 195      |
# |    total_timesteps | 22504    |
# | train/             |          |
# |    actor_loss      | -31.7    |
# |    critic_loss     | 0.914    |
# |    ent_coef        | 0.193    |
# |    ent_coef_loss   | -14      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5600     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 126      |
# |    ep_rew_mean     | -11.8    |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 115      |
# |    time_elapsed    | 199      |
# |    total_timesteps | 22972    |
# | train/             |          |
# |    actor_loss      | -32.1    |
# |    critic_loss     | 0.87     |
# |    ent_coef        | 0.186    |
# |    ent_coef_loss   | -15.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5717     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 126      |
# |    ep_rew_mean     | -13      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 115      |
# |    time_elapsed    | 203      |
# |    total_timesteps | 23416    |
# | train/             |          |
# |    actor_loss      | -31.5    |
# |    critic_loss     | 0.994    |
# |    ent_coef        | 0.18     |
# |    ent_coef_loss   | -15.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5828     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | -13.2    |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 115      |
# |    time_elapsed    | 207      |
# |    total_timesteps | 23856    |
# | train/             |          |
# |    actor_loss      | -33      |
# |    critic_loss     | 1.03     |
# |    ent_coef        | 0.174    |
# |    ent_coef_loss   | -14.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5938     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | -9.53    |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 115      |
# |    time_elapsed    | 210      |
# |    total_timesteps | 24244    |
# | train/             |          |
# |    actor_loss      | -33      |
# |    critic_loss     | 0.957    |
# |    ent_coef        | 0.169    |
# |    ent_coef_loss   | -15.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6035     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | -7.55    |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 115      |
# |    time_elapsed    | 215      |
# |    total_timesteps | 24868    |
# | train/             |          |
# |    actor_loss      | -32.4    |
# |    critic_loss     | 0.894    |
# |    ent_coef        | 0.162    |
# |    ent_coef_loss   | -16      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6191     |
# ---------------------------------
# ...
# |    fps             | 134      |
# |    time_elapsed    | 36531    |
# |    total_timesteps | 4914248  |
# | train/             |          |
# |    actor_loss      | -2.84    |
# |    critic_loss     | 0.000446 |
# |    ent_coef        | 0.000204 |
# |    ent_coef_loss   | 1.54     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1228536  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 828      |
# |    ep_rew_mean     | 5.21e+03 |
# | time/              |          |
# |    episodes        | 6052     |
# |    fps             | 134      |
# |    time_elapsed    | 36535    |
# |    total_timesteps | 4915512  |
# | train/             |          |
# |    actor_loss      | -2.88    |
# |    critic_loss     | 0.000203 |
# |    ent_coef        | 0.0002   |
# |    ent_coef_loss   | -3.95    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1228852  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 803      |
# |    ep_rew_mean     | 5e+03    |
# | time/              |          |
# |    episodes        | 6056     |
# |    fps             | 134      |
# |    time_elapsed    | 36547    |
# |    total_timesteps | 4918696  |
# | train/             |          |
# |    actor_loss      | -2.86    |
# |    critic_loss     | 0.000344 |
# |    ent_coef        | 0.000204 |
# |    ent_coef_loss   | -5.82    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1229648  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 794      |
# |    ep_rew_mean     | 4.9e+03  |
# | time/              |          |
# |    episodes        | 6060     |
# |    fps             | 134      |
# |    time_elapsed    | 36552    |
# |    total_timesteps | 4920104  |
# | train/             |          |
# |    actor_loss      | -2.84    |
# |    critic_loss     | 0.000326 |
# |    ent_coef        | 0.000205 |
# |    ent_coef_loss   | -0.164   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1230000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 779      |
# |    ep_rew_mean     | 4.73e+03 |
# | time/              |          |
# |    episodes        | 6064     |
# |    fps             | 134      |
# |    time_elapsed    | 36561    |
# |    total_timesteps | 4923060  |
# | train/             |          |
# |    actor_loss      | -2.88    |
# |    critic_loss     | 0.000158 |
# |    ent_coef        | 0.000202 |
# |    ent_coef_loss   | -2.24    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1230739  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 756      |
# |    ep_rew_mean     | 4.52e+03 |
# | time/              |          |
# |    episodes        | 6068     |
# |    fps             | 134      |
# |    time_elapsed    | 36567    |
# |    total_timesteps | 4925040  |
# | train/             |          |
# |    actor_loss      | -2.83    |
# |    critic_loss     | 0.000202 |
# |    ent_coef        | 0.000205 |
# |    ent_coef_loss   | -2.84    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1231234  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 732      |
# |    ep_rew_mean     | 4.3e+03  |
# | time/              |          |
# |    episodes        | 6072     |
# |    fps             | 134      |
# |    time_elapsed    | 36571    |
# |    total_timesteps | 4926360  |
# | train/             |          |
# |    actor_loss      | -2.85    |
# |    critic_loss     | 0.00122  |
# |    ent_coef        | 0.000207 |
# |    ent_coef_loss   | 1.24     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1231564  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 724      |
# |    ep_rew_mean     | 4.19e+03 |
# | time/              |          |
# |    episodes        | 6076     |
# |    fps             | 134      |
# |    time_elapsed    | 36580    |
# |    total_timesteps | 4929280  |
# | train/             |          |
# |    actor_loss      | -2.77    |
# |    critic_loss     | 0.00141  |
# |    ent_coef        | 0.000195 |
# |    ent_coef_loss   | 6.45     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1232294  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 709      |
# |    ep_rew_mean     | 4.03e+03 |
# | time/              |          |
# |    episodes        | 6080     |
# |    fps             | 134      |
# |    time_elapsed    | 36583    |
# |    total_timesteps | 4930424  |
# | train/             |          |
# |    actor_loss      | -2.81    |
# |    critic_loss     | 0.000289 |
# |    ent_coef        | 0.000206 |
# |    ent_coef_loss   | 2.64     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1232580  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 694      |
# |    ep_rew_mean     | 3.87e+03 |
# | time/              |          |
# |    episodes        | 6084     |
# |    fps             | 134      |
# |    time_elapsed    | 36596    |
# |    total_timesteps | 4934360  |
# | train/             |          |
# |    actor_loss      | -2.85    |
# |    critic_loss     | 0.00927  |
# |    ent_coef        | 0.00022  |
# |    ent_coef_loss   | -2.55    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1233564  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 694      |
# |    ep_rew_mean     | 3.83e+03 |
# | time/              |          |
# |    episodes        | 6088     |
# |    fps             | 134      |
# |    time_elapsed    | 36608    |
# |    total_timesteps | 4938360  |
# | train/             |          |
# |    actor_loss      | -2.81    |
# |    critic_loss     | 0.000595 |
# |    ent_coef        | 0.000225 |
# |    ent_coef_loss   | 2.53     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1234564  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 694      |
# |    ep_rew_mean     | 3.82e+03 |
# | time/              |          |
# |    episodes        | 6092     |
# |    fps             | 134      |
# |    time_elapsed    | 36620    |
# |    total_timesteps | 4942360  |
# | train/             |          |
# |    actor_loss      | -2.83    |
# |    critic_loss     | 0.00025  |
# |    ent_coef        | 0.000234 |
# |    ent_coef_loss   | 2.06     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1235564  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 694      |
# |    ep_rew_mean     | 3.82e+03 |
# | time/              |          |
# |    episodes        | 6096     |
# |    fps             | 135      |
# |    time_elapsed    | 36633    |
# |    total_timesteps | 4946360  |
# | train/             |          |
# |    actor_loss      | -2.85    |
# |    critic_loss     | 0.000515 |
# |    ent_coef        | 0.000228 |
# |    ent_coef_loss   | -3.43    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1236564  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 702      |
# |    ep_rew_mean     | 3.89e+03 |
# | time/              |          |
# |    episodes        | 6100     |
# |    fps             | 135      |
# |    time_elapsed    | 36645    |
# |    total_timesteps | 4950360  |
# | train/             |          |
# |    actor_loss      | -2.84    |
# |    critic_loss     | 0.000291 |
# |    ent_coef        | 0.000225 |
# |    ent_coef_loss   | -1.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1237564  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 702      |
# |    ep_rew_mean     | 3.9e+03  |
# | time/              |          |
# |    episodes        | 6104     |
# |    fps             | 135      |
# |    time_elapsed    | 36658    |
# |    total_timesteps | 4954360  |
# | train/             |          |
# |    actor_loss      | -2.89    |
# |    critic_loss     | 0.00189  |
# |    ent_coef        | 0.000214 |
# |    ent_coef_loss   | -4.52    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1238564  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 710      |
# |    ep_rew_mean     | 3.97e+03 |
# | time/              |          |
# |    episodes        | 6108     |
# |    fps             | 135      |
# |    time_elapsed    | 36670    |
# |    total_timesteps | 4958360  |
# | train/             |          |
# |    actor_loss      | -2.83    |
# |    critic_loss     | 0.000466 |
# |    ent_coef        | 0.00022  |
# |    ent_coef_loss   | -0.0772  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1239564  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 719      |
# |    ep_rew_mean     | 4.04e+03 |
# | time/              |          |
# |    episodes        | 6112     |
# |    fps             | 135      |
# |    time_elapsed    | 36683    |
# |    total_timesteps | 4962360  |
# | train/             |          |
# |    actor_loss      | -2.84    |
# |    critic_loss     | 0.000316 |
# |    ent_coef        | 0.000218 |
# |    ent_coef_loss   | 5.83     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1240564  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 727      |
# |    ep_rew_mean     | 4.1e+03  |
# | time/              |          |
# |    episodes        | 6116     |
# |    fps             | 135      |
# |    time_elapsed    | 36695    |
# |    total_timesteps | 4966360  |
# | train/             |          |
# |    actor_loss      | -2.72    |
# |    critic_loss     | 0.000357 |
# |    ent_coef        | 0.00021  |
# |    ent_coef_loss   | 0.891    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1241564  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 743      |
# |    ep_rew_mean     | 4.22e+03 |
# | time/              |          |
# |    episodes        | 6120     |
# |    fps             | 135      |
# |    time_elapsed    | 36708    |
# |    total_timesteps | 4970360  |
# | train/             |          |
# |    actor_loss      | -2.83    |
# |    critic_loss     | 0.000216 |
# |    ent_coef        | 0.000203 |
# |    ent_coef_loss   | -0.581   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1242564  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 743      |
# |    ep_rew_mean     | 4.23e+03 |
# | time/              |          |
# |    episodes        | 6124     |
# |    fps             | 135      |
# |    time_elapsed    | 36720    |
# |    total_timesteps | 4974360  |
# | train/             |          |
# |    actor_loss      | -2.82    |
# |    critic_loss     | 0.000398 |
# |    ent_coef        | 0.0002   |
# |    ent_coef_loss   | -1.82    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1243564  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 760      |
# |    ep_rew_mean     | 4.35e+03 |
# | time/              |          |
# |    episodes        | 6128     |
# |    fps             | 135      |
# |    time_elapsed    | 36733    |
# |    total_timesteps | 4978360  |
# | train/             |          |
# |    actor_loss      | -2.72    |
# |    critic_loss     | 0.000377 |
# |    ent_coef        | 0.000192 |
# |    ent_coef_loss   | 9.45     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1244564  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 770      |
# |    ep_rew_mean     | 4.44e+03 |
# | time/              |          |
# |    episodes        | 6132     |
# |    fps             | 135      |
# |    time_elapsed    | 36743    |
# |    total_timesteps | 4981536  |
# | train/             |          |
# |    actor_loss      | -2.79    |
# |    critic_loss     | 0.000388 |
# |    ent_coef        | 0.000209 |
# |    ent_coef_loss   | -0.84    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1245358  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 760      |
# |    ep_rew_mean     | 4.39e+03 |
# | time/              |          |
# |    episodes        | 6136     |
# |    fps             | 135      |
# |    time_elapsed    | 36748    |
# |    total_timesteps | 4983008  |
# | train/             |          |
# |    actor_loss      | -2.83    |
# |    critic_loss     | 0.000302 |
# |    ent_coef        | 0.000205 |
# |    ent_coef_loss   | -2.08    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1245726  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 750      |
# |    ep_rew_mean     | 4.36e+03 |
# | time/              |          |
# |    episodes        | 6140     |
# |    fps             | 135      |
# |    time_elapsed    | 36758    |
# |    total_timesteps | 4986360  |
# | train/             |          |
# |    actor_loss      | -2.72    |
# |    critic_loss     | 0.000377 |
# |    ent_coef        | 0.000192 |
# |    ent_coef_loss   | -0.471   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1246564  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 758      |
# |    ep_rew_mean     | 4.46e+03 |
# | time/              |          |
# |    episodes        | 6144     |
# |    fps             | 135      |
# |    time_elapsed    | 36770    |
# |    total_timesteps | 4990360  |
# | train/             |          |
# |    actor_loss      | -2.8     |
# |    critic_loss     | 0.00033  |
# |    ent_coef        | 0.000188 |
# |    ent_coef_loss   | -1.41    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1247564  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 774      |
# |    ep_rew_mean     | 4.59e+03 |
# | time/              |          |
# |    episodes        | 6148     |
# |    fps             | 135      |
# |    time_elapsed    | 36773    |
# |    total_timesteps | 4991256  |
# | train/             |          |
# |    actor_loss      | -2.83    |
# |    critic_loss     | 0.000477 |
# |    ent_coef        | 0.00019  |
# |    ent_coef_loss   | 0.755    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1247788  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 778      |
# |    ep_rew_mean     | 4.66e+03 |
# | time/              |          |
# |    episodes        | 6152     |
# |    fps             | 135      |
# |    time_elapsed    | 36783    |
# |    total_timesteps | 4994360  |
# | train/             |          |
# |    actor_loss      | -2.8     |
# |    critic_loss     | 0.00068  |
# |    ent_coef        | 0.000204 |
# |    ent_coef_loss   | 2.54     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1248564  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 803      |
# |    ep_rew_mean     | 4.87e+03 |
# | time/              |          |
# |    episodes        | 6156     |
# |    fps             | 135      |
# |    time_elapsed    | 36795    |
# |    total_timesteps | 4998360  |
# | train/             |          |
# |    actor_loss      | -2.76    |
# |    critic_loss     | 0.000654 |
# |    ent_coef        | 0.000208 |
# |    ent_coef_loss   | 3.88     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1249564  |
# ---------------------------------

# %%
# Load model and evaluate
model = SAC.load("./models/sac_walker2d_final", device=device)

venv = make_vec_env(ENV_ID, n_envs=1, seed=42)
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

mean_reward, std_reward = evaluate_policy(model, venv, n_eval_episodes=10, deterministic=True)
print(f"Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Mean reward: 6831.57 +/- 55.58

# %%
# Visualize the agent
import os
os.environ["MUJOCO_GL"] = "glfw"

import gymnasium as gym
import imageio
import numpy as np
from IPython.display import Video, display
import tempfile

from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

ENV_ID = "Walker2d-v5"
N_EVAL_EPISODES = 10
MAX_STEPS = 1500
FPS = 30

# create env
env = gym.make(ENV_ID, render_mode="rgb_array")
venv = DummyVecEnv([lambda: env])
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

# load model
# model = SAC.load("./models/sac_humanoid_final", device="cpu")
model = SAC.load("./best_model/best_model", device="cpu")

best_frames = []
best_length = 0

for ep in range(N_EVAL_EPISODES):
    obs = venv.reset()
    frames = []

    for step in range(MAX_STEPS):
        action, _ = model.predict(obs, deterministic=True)
        obs, rewards, dones, infos = venv.step(action)

        frame = env.render()
        if frame is not None:
            frames.append(frame)

        if dones[0]:
            break

    ep_length = len(frames)
    print(f"Episode {ep+1}: {ep_length} frames")

    if ep_length > best_length:
        best_length = ep_length
        best_frames = frames

print(f"\nLongest episode length: {best_length} frames")

# save and display only the longest episode
tmp = tempfile.NamedTemporaryFile(suffix=".mp4", delete=False).name
writer = imageio.get_writer(tmp, fps=FPS, codec="libx264")
for f in best_frames:
    writer.append_data(f)
writer.close()

display(Video(tmp, embed=True))
# Out:
# Episode 1: 1000 frames
# Episode 2: 1000 frames
# Episode 3: 1000 frames
# Episode 4: 1000 frames
# Episode 5: 1000 frames
# Episode 6: 1000 frames
# Episode 7: 1000 frames
# Episode 8: 1000 frames
# Episode 9: 1000 frames
# Episode 10: 1000 frames
#
# Longest episode length: 1000 frames
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
