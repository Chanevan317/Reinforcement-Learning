# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.5.1
# CUDA available: True
# CUDA device count: 1
# GPU name: NVIDIA GeForce RTX 4080 SUPER

# %%
# Cell 1: quick checks
import sys, platform
import torch
print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())
print("PyTorch:", torch.__version__, "| CUDA available:", torch.cuda.is_available())
import mujoco
print("MuJoCo package version:", mujoco.__version__)
# Out:
# Python: 3.10.19
# Platform: Windows-10-10.0.26200-SP0
# PyTorch: 2.5.1 | CUDA available: True
# MuJoCo package version: 3.4.0

# %%
# Cell 2: imports
import os
import gymnasium as gym
import numpy as np
import torch
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecNormalize, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback
from stable_baselines3.common.evaluation import evaluate_policy

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Cell 3: env setup
ENV_ID = "HalfCheetah-v5"   # requires mujoco >= 2.3
n_envs = 4               # on Windows + single CPU, 4 is reasonable; reduce if CPU bound
seed = 0

# Make vectorized training envs
train_env = make_vec_env(
    ENV_ID,
    n_envs=n_envs,
    seed=seed,
    monitor_dir="./logs/train_monitor"
)

# VecNormalize (important for continuous control)
train_env = VecNormalize(train_env, norm_obs=True, norm_reward=True, clip_obs=10.0)

# eval env
eval_env = make_vec_env(
    ENV_ID,
    n_envs=1,
    seed=seed + 100,
    monitor_dir="./logs/eval_monitor"
)
eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

print("Obs space:", train_env.observation_space)
print("Act space:", train_env.action_space)
# Out:
# Obs space: Box(-inf, inf, (17,), float64)
# Act space: Box(-1.0, 1.0, (6,), float32)

# %%
# Cell 4: create PPO
policy_kwargs = dict(net_arch=[dict(pi=[512,512], vf=[512,512])])

model = PPO(
    "MlpPolicy",
    train_env,
    verbose=1,
    device=device,
    n_steps=2048,
    batch_size=64,
    n_epochs=10,
    learning_rate=3e-4,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=1e-3,
    policy_kwargs=policy_kwargs,
)
# Out:
# Using cuda device

# %%
# Cell 5: callbacks and save dirs
os.makedirs("./models", exist_ok=True)
os.makedirs("./checkpoints", exist_ok=True)
os.makedirs("./best_model", exist_ok=True)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./best_model/",
    log_path="./logs/eval",
    eval_freq=100_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False
)

checkpoint_callback = CheckpointCallback(save_freq=500_000, save_path="./checkpoints/", name_prefix="ppo_half_cheetah")

# %%
# Cell 6: train
TOTAL_TIMESTEPS = int(5e6)  # start with 5M; increase if you have time/resources
model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=[eval_callback, checkpoint_callback])
model.save("./models/ppo_half_cheetah_final")
# save VecNormalize
train_env.save("./models/vecnormalize_train.pkl")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -357     |
# | time/              |          |
# |    fps             | 2126     |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -352        |
# | time/                   |             |
# |    fps                  | 1263        |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009458352 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.49       |
# |    explained_variance   | -0.0176     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0405      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.000727   |
# |    std                  | 0.998       |
# |    value_loss           | 0.0646      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -349        |
# | time/                   |             |
# |    fps                  | 1114        |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009426869 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.48       |
# |    explained_variance   | 0.279       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00797    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00494    |
# |    std                  | 0.993       |
# |    value_loss           | 0.0934      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -346        |
# | time/                   |             |
# |    fps                  | 1076        |
# |    iterations           | 4           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011376506 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.42       |
# |    explained_variance   | 0.384       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0331      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0094     |
# |    std                  | 0.983       |
# |    value_loss           | 0.122       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -339        |
# | time/                   |             |
# |    fps                  | 1057        |
# |    iterations           | 5           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010131047 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.39       |
# |    explained_variance   | 0.457       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0201      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00907    |
# |    std                  | 0.978       |
# |    value_loss           | 0.122       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -332         |
# | time/                   |              |
# |    fps                  | 1029         |
# |    iterations           | 6            |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0112253595 |
# |    clip_fraction        | 0.147        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.35        |
# |    explained_variance   | 0.443        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0411       |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0131      |
# |    std                  | 0.972        |
# |    value_loss           | 0.106        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -320       |
# | time/                   |            |
# |    fps                  | 1016       |
# |    iterations           | 7          |
# |    time_elapsed         | 56         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.01198752 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.33      |
# |    explained_variance   | 0.418      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0121    |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0129    |
# |    std                  | 0.969      |
# |    value_loss           | 0.0693     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -313        |
# | time/                   |             |
# |    fps                  | 1006        |
# |    iterations           | 8           |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.013928469 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | 0.45        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00134    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 0.961       |
# |    value_loss           | 0.049       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -305        |
# | time/                   |             |
# |    fps                  | 1004        |
# |    iterations           | 9           |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.014864422 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.013      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 0.956       |
# |    value_loss           | 0.08        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -297        |
# | time/                   |             |
# |    fps                  | 1007        |
# |    iterations           | 10          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.017575094 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.2        |
# |    explained_variance   | 0.46        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.013      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0199     |
# |    std                  | 0.949       |
# |    value_loss           | 0.0663      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -290        |
# | time/                   |             |
# |    fps                  | 999         |
# |    iterations           | 11          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.018436782 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.15       |
# |    explained_variance   | 0.523       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0376      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0185     |
# |    std                  | 0.939       |
# |    value_loss           | 0.0779      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -283        |
# | time/                   |             |
# |    fps                  | 990         |
# |    iterations           | 12          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.019243991 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.11       |
# |    explained_variance   | 0.627       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0229     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0218     |
# |    std                  | 0.933       |
# |    value_loss           | 0.059       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -274        |
# | time/                   |             |
# |    fps                  | 981         |
# |    iterations           | 13          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.020498894 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.07       |
# |    explained_variance   | 0.54        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0271      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0216     |
# |    std                  | 0.927       |
# |    value_loss           | 0.0855      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -260        |
# | time/                   |             |
# |    fps                  | 975         |
# |    iterations           | 14          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.022952508 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.03       |
# |    explained_variance   | 0.446       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0438     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0232     |
# |    std                  | 0.921       |
# |    value_loss           | 0.0595      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -245        |
# | time/                   |             |
# |    fps                  | 971         |
# |    iterations           | 15          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.023872832 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.98       |
# |    explained_variance   | 0.569       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0176     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0226     |
# |    std                  | 0.913       |
# |    value_loss           | 0.0751      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -227        |
# | time/                   |             |
# |    fps                  | 969         |
# |    iterations           | 16          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.024953725 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.91       |
# |    explained_variance   | 0.556       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0282     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0245     |
# |    std                  | 0.902       |
# |    value_loss           | 0.0593      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -207        |
# | time/                   |             |
# |    fps                  | 966         |
# |    iterations           | 17          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.025327224 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.86       |
# |    explained_variance   | 0.628       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0239     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0233     |
# |    std                  | 0.895       |
# |    value_loss           | 0.0636      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -192        |
# | time/                   |             |
# |    fps                  | 963         |
# |    iterations           | 18          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.025325455 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.82       |
# |    explained_variance   | 0.573       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.015      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0234     |
# |    std                  | 0.89        |
# |    value_loss           | 0.0581      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -173        |
# | time/                   |             |
# |    fps                  | 959         |
# |    iterations           | 19          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.024926506 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.78       |
# |    explained_variance   | 0.546       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.028       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0233     |
# |    std                  | 0.885       |
# |    value_loss           | 0.089       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -149        |
# | time/                   |             |
# |    fps                  | 955         |
# |    iterations           | 20          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.027035415 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.77       |
# |    explained_variance   | 0.513       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0301     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0231     |
# |    std                  | 0.883       |
# |    value_loss           | 0.0784      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 944         |
# |    iterations           | 21          |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.028384775 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.74       |
# |    explained_variance   | 0.659       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0342     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0227     |
# |    std                  | 0.878       |
# |    value_loss           | 0.0609      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -97.3       |
# | time/                   |             |
# |    fps                  | 931         |
# |    iterations           | 22          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.029665066 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.7        |
# |    explained_variance   | 0.685       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0115     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0241     |
# |    std                  | 0.874       |
# |    value_loss           | 0.0643      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -72.7       |
# | time/                   |             |
# |    fps                  | 920         |
# |    iterations           | 23          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.028743766 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.69       |
# |    explained_variance   | 0.618       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0164     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0221     |
# |    std                  | 0.872       |
# |    value_loss           | 0.0684      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -43.6       |
# | time/                   |             |
# |    fps                  | 909         |
# |    iterations           | 24          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.032653194 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.67       |
# |    explained_variance   | 0.738       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0222     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0236     |
# |    std                  | 0.869       |
# |    value_loss           | 0.059       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -15.1       |
# | time/                   |             |
# |    fps                  | 899         |
# |    iterations           | 25          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.029265447 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.65       |
# |    explained_variance   | 0.692       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0118     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.021      |
# |    std                  | 0.866       |
# |    value_loss           | 0.0638      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 11.9        |
# | time/                   |             |
# |    fps                  | 890         |
# |    iterations           | 26          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.031262863 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.64       |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00435    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0234     |
# |    std                  | 0.866       |
# |    value_loss           | 0.0574      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 42         |
# | time/                   |            |
# |    fps                  | 882        |
# |    iterations           | 27         |
# |    time_elapsed         | 250        |
# |    total_timesteps      | 221184     |
# | train/                  |            |
# |    approx_kl            | 0.03229804 |
# |    clip_fraction        | 0.305      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.6       |
# |    explained_variance   | 0.793      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0129    |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0239    |
# |    std                  | 0.858      |
# |    value_loss           | 0.0718     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 70.7        |
# | time/                   |             |
# |    fps                  | 877         |
# |    iterations           | 28          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.033221822 |
# |    clip_fraction        | 0.322       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.55       |
# |    explained_variance   | 0.802       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00827     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0236     |
# |    std                  | 0.849       |
# |    value_loss           | 0.0624      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 92.4       |
# | time/                   |            |
# |    fps                  | 871        |
# |    iterations           | 29         |
# |    time_elapsed         | 272        |
# |    total_timesteps      | 237568     |
# | train/                  |            |
# |    approx_kl            | 0.03277485 |
# |    clip_fraction        | 0.304      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.52      |
# |    explained_variance   | 0.798      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00402    |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0218    |
# |    std                  | 0.847      |
# |    value_loss           | 0.068      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 129        |
# | time/                   |            |
# |    fps                  | 865        |
# |    iterations           | 30         |
# |    time_elapsed         | 283        |
# |    total_timesteps      | 245760     |
# | train/                  |            |
# |    approx_kl            | 0.03439473 |
# |    clip_fraction        | 0.317      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.48      |
# |    explained_variance   | 0.893      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.018     |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0232    |
# |    std                  | 0.841      |
# |    value_loss           | 0.0605     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 154         |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 31          |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.036295425 |
# |    clip_fraction        | 0.32        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.43       |
# |    explained_variance   | 0.848       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00523    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0234     |
# |    std                  | 0.834       |
# |    value_loss           | 0.0643      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 185         |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 32          |
# |    time_elapsed         | 306         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.035589285 |
# |    clip_fraction        | 0.335       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.4        |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0517      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0248     |
# |    std                  | 0.829       |
# |    value_loss           | 0.0474      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 211         |
# | time/                   |             |
# |    fps                  | 839         |
# |    iterations           | 33          |
# |    time_elapsed         | 321         |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.036834814 |
# |    clip_fraction        | 0.336       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.34       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0284     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0223     |
# |    std                  | 0.822       |
# |    value_loss           | 0.045       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 249        |
# | time/                   |            |
# |    fps                  | 826        |
# |    iterations           | 34         |
# |    time_elapsed         | 336        |
# |    total_timesteps      | 278528     |
# | train/                  |            |
# |    approx_kl            | 0.03884133 |
# |    clip_fraction        | 0.345      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.31      |
# |    explained_variance   | 0.912      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00378   |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0228    |
# |    std                  | 0.819      |
# |    value_loss           | 0.0473     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 294         |
# | time/                   |             |
# |    fps                  | 816         |
# |    iterations           | 35          |
# |    time_elapsed         | 351         |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.036146276 |
# |    clip_fraction        | 0.344       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.27       |
# |    explained_variance   | 0.827       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0621     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0222     |
# |    std                  | 0.813       |
# |    value_loss           | 0.0468      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 340         |
# | time/                   |             |
# |    fps                  | 807         |
# |    iterations           | 36          |
# |    time_elapsed         | 365         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.038620368 |
# |    clip_fraction        | 0.345       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.23       |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0156      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0224     |
# |    std                  | 0.806       |
# |    value_loss           | 0.0427      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 371         |
# | time/                   |             |
# |    fps                  | 798         |
# |    iterations           | 37          |
# |    time_elapsed         | 379         |
# |    total_timesteps      | 303104      |
# | train/                  |             |
# |    approx_kl            | 0.039541543 |
# |    clip_fraction        | 0.344       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.18       |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0199     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0205     |
# |    std                  | 0.8         |
# |    value_loss           | 0.0485      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 404        |
# | time/                   |            |
# |    fps                  | 789        |
# |    iterations           | 38         |
# |    time_elapsed         | 394        |
# |    total_timesteps      | 311296     |
# | train/                  |            |
# |    approx_kl            | 0.03680346 |
# |    clip_fraction        | 0.34       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.14      |
# |    explained_variance   | 0.932      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0191    |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.018     |
# |    std                  | 0.795      |
# |    value_loss           | 0.0393     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 457         |
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 39          |
# |    time_elapsed         | 408         |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.040101156 |
# |    clip_fraction        | 0.357       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.08       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0111     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 0.787       |
# |    value_loss           | 0.0383      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 492         |
# | time/                   |             |
# |    fps                  | 774         |
# |    iterations           | 40          |
# |    time_elapsed         | 423         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.042277254 |
# |    clip_fraction        | 0.362       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.02       |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0222     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0205     |
# |    std                  | 0.78        |
# |    value_loss           | 0.0411      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 522        |
# | time/                   |            |
# |    fps                  | 766        |
# |    iterations           | 41         |
# |    time_elapsed         | 437        |
# |    total_timesteps      | 335872     |
# | train/                  |            |
# |    approx_kl            | 0.04327074 |
# |    clip_fraction        | 0.368      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.97      |
# |    explained_variance   | 0.964      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0431    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0199    |
# |    std                  | 0.772      |
# |    value_loss           | 0.0408     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 582         |
# | time/                   |             |
# |    fps                  | 760         |
# |    iterations           | 42          |
# |    time_elapsed         | 452         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.044199254 |
# |    clip_fraction        | 0.378       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.9        |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0472     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0225     |
# |    std                  | 0.763       |
# |    value_loss           | 0.0302      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 629         |
# | time/                   |             |
# |    fps                  | 753         |
# |    iterations           | 43          |
# |    time_elapsed         | 467         |
# |    total_timesteps      | 352256      |
# | train/                  |             |
# |    approx_kl            | 0.043264676 |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.84       |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0307     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0172     |
# |    std                  | 0.758       |
# |    value_loss           | 0.0525      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 666         |
# | time/                   |             |
# |    fps                  | 747         |
# |    iterations           | 44          |
# |    time_elapsed         | 481         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.049797144 |
# |    clip_fraction        | 0.389       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.78       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0394      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0204     |
# |    std                  | 0.75        |
# |    value_loss           | 0.041       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 725         |
# | time/                   |             |
# |    fps                  | 742         |
# |    iterations           | 45          |
# |    time_elapsed         | 496         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.045054138 |
# |    clip_fraction        | 0.382       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.74       |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00394    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0214     |
# |    std                  | 0.747       |
# |    value_loss           | 0.0314      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 759         |
# | time/                   |             |
# |    fps                  | 737         |
# |    iterations           | 46          |
# |    time_elapsed         | 510         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.045484178 |
# |    clip_fraction        | 0.392       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.7        |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00969    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0205     |
# |    std                  | 0.74        |
# |    value_loss           | 0.0326      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 781         |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 47          |
# |    time_elapsed         | 525         |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.046616368 |
# |    clip_fraction        | 0.385       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.65       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0286     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.733       |
# |    value_loss           | 0.0343      |
# -----------------------------------------
# Eval num_timesteps=391808, episode_reward=1980.58 +/- 32.76
# Episode length: 1000.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1e+03      |
# |    mean_reward          | 1.98e+03   |
# | time/                   |            |
# |    total_timesteps      | 391808     |
# | train/                  |            |
# |    approx_kl            | 0.04664457 |
# |    clip_fraction        | 0.388      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.63      |
# |    explained_variance   | 0.97       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0111     |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0166    |
# |    std                  | 0.734      |
# |    value_loss           | 0.0373     |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 787      |
# | time/              |          |
# |    fps             | 719      |
# |    iterations      | 48       |
# |    time_elapsed    | 546      |
# |    total_timesteps | 393216   |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 828       |
# | time/                   |           |
# |    fps                  | 716       |
# |    iterations           | 49        |
# |    time_elapsed         | 560       |
# |    total_timesteps      | 401408    |
# | train/                  |           |
# |    approx_kl            | 0.0497382 |
# |    clip_fraction        | 0.399     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.6      |
# |    explained_variance   | 0.979     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0238   |
# |    n_updates            | 480       |
# |    policy_gradient_loss | -0.0176   |
# |    std                  | 0.727     |
# |    value_loss           | 0.0289    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 853         |
# | time/                   |             |
# |    fps                  | 712         |
# |    iterations           | 50          |
# |    time_elapsed         | 574         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.048867133 |
# |    clip_fraction        | 0.396       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.55       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0356     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0166     |
# |    std                  | 0.723       |
# |    value_loss           | 0.0308      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 866         |
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 51          |
# |    time_elapsed         | 589         |
# |    total_timesteps      | 417792      |
# | train/                  |             |
# |    approx_kl            | 0.052932225 |
# |    clip_fraction        | 0.411       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.52       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00998     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0184     |
# |    std                  | 0.718       |
# |    value_loss           | 0.0283      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 895         |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 52          |
# |    time_elapsed         | 604         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.051544096 |
# |    clip_fraction        | 0.401       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.48       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0124     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0172     |
# |    std                  | 0.714       |
# |    value_loss           | 0.0304      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 929         |
# | time/                   |             |
# |    fps                  | 701         |
# |    iterations           | 53          |
# |    time_elapsed         | 619         |
# |    total_timesteps      | 434176      |
# ...
# |    fps                  | 576        |
# |    iterations           | 594        |
# |    time_elapsed         | 8441       |
# |    total_timesteps      | 4866048    |
# | train/                  |            |
# |    approx_kl            | 0.24694717 |
# |    clip_fraction        | 0.678      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.47      |
# |    explained_variance   | 0.987      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00222   |
# |    n_updates            | 5930       |
# |    policy_gradient_loss | 0.00324    |
# |    std                  | 0.374      |
# |    value_loss           | 0.00925    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 4.23e+03   |
# | time/                   |            |
# |    fps                  | 576        |
# |    iterations           | 595        |
# |    time_elapsed         | 8455       |
# |    total_timesteps      | 4874240    |
# | train/                  |            |
# |    approx_kl            | 0.19874734 |
# |    clip_fraction        | 0.662      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.44      |
# |    explained_variance   | 0.882      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00404   |
# |    n_updates            | 5940       |
# |    policy_gradient_loss | 0.00198    |
# |    std                  | 0.372      |
# |    value_loss           | 0.00818    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 4.24e+03   |
# | time/                   |            |
# |    fps                  | 576        |
# |    iterations           | 596        |
# |    time_elapsed         | 8469       |
# |    total_timesteps      | 4882432    |
# | train/                  |            |
# |    approx_kl            | 0.22051978 |
# |    clip_fraction        | 0.686      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.46      |
# |    explained_variance   | 0.98       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0185     |
# |    n_updates            | 5950       |
# |    policy_gradient_loss | 0.00381    |
# |    std                  | 0.375      |
# |    value_loss           | 0.00851    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 4.24e+03   |
# | time/                   |            |
# |    fps                  | 576        |
# |    iterations           | 597        |
# |    time_elapsed         | 8483       |
# |    total_timesteps      | 4890624    |
# | train/                  |            |
# |    approx_kl            | 0.20468912 |
# |    clip_fraction        | 0.668      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.43      |
# |    explained_variance   | 0.764      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.017      |
# |    n_updates            | 5960       |
# |    policy_gradient_loss | 0.00634    |
# |    std                  | 0.374      |
# |    value_loss           | 0.0033     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 4.25e+03   |
# | time/                   |            |
# |    fps                  | 576        |
# |    iterations           | 598        |
# |    time_elapsed         | 8496       |
# |    total_timesteps      | 4898816    |
# | train/                  |            |
# |    approx_kl            | 0.20562193 |
# |    clip_fraction        | 0.668      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.45      |
# |    explained_variance   | 0.974      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0081     |
# |    n_updates            | 5970       |
# |    policy_gradient_loss | 0.00397    |
# |    std                  | 0.374      |
# |    value_loss           | 0.00697    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 4.23e+03   |
# | time/                   |            |
# |    fps                  | 576        |
# |    iterations           | 599        |
# |    time_elapsed         | 8510       |
# |    total_timesteps      | 4907008    |
# | train/                  |            |
# |    approx_kl            | 0.21655905 |
# |    clip_fraction        | 0.67       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.47      |
# |    explained_variance   | 0.972      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0222    |
# |    n_updates            | 5980       |
# |    policy_gradient_loss | 0.00331    |
# |    std                  | 0.376      |
# |    value_loss           | 0.0114     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 4.25e+03   |
# | time/                   |            |
# |    fps                  | 576        |
# |    iterations           | 600        |
# |    time_elapsed         | 8524       |
# |    total_timesteps      | 4915200    |
# | train/                  |            |
# |    approx_kl            | 0.23509817 |
# |    clip_fraction        | 0.676      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.46      |
# |    explained_variance   | 0.98       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0506    |
# |    n_updates            | 5990       |
# |    policy_gradient_loss | 0.000198   |
# |    std                  | 0.376      |
# |    value_loss           | 0.00352    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 4.24e+03   |
# | time/                   |            |
# |    fps                  | 576        |
# |    iterations           | 601        |
# |    time_elapsed         | 8539       |
# |    total_timesteps      | 4923392    |
# | train/                  |            |
# |    approx_kl            | 0.21035223 |
# |    clip_fraction        | 0.662      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.46      |
# |    explained_variance   | 0.812      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0108     |
# |    n_updates            | 6000       |
# |    policy_gradient_loss | 0.0016     |
# |    std                  | 0.376      |
# |    value_loss           | 0.00342    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 4.28e+03   |
# | time/                   |            |
# |    fps                  | 576        |
# |    iterations           | 602        |
# |    time_elapsed         | 8553       |
# |    total_timesteps      | 4931584    |
# | train/                  |            |
# |    approx_kl            | 0.22206232 |
# |    clip_fraction        | 0.68       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.48      |
# |    explained_variance   | 0.983      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.017      |
# |    n_updates            | 6010       |
# |    policy_gradient_loss | 0.004      |
# |    std                  | 0.377      |
# |    value_loss           | 0.0087     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 4.28e+03  |
# | time/                   |           |
# |    fps                  | 576       |
# |    iterations           | 603       |
# |    time_elapsed         | 8567      |
# |    total_timesteps      | 4939776   |
# | train/                  |           |
# |    approx_kl            | 0.1991023 |
# |    clip_fraction        | 0.674     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.5      |
# |    explained_variance   | 0.977     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0178   |
# |    n_updates            | 6020      |
# |    policy_gradient_loss | 0.00116   |
# |    std                  | 0.379     |
# |    value_loss           | 0.00905   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 4.21e+03   |
# | time/                   |            |
# |    fps                  | 576        |
# |    iterations           | 604        |
# |    time_elapsed         | 8580       |
# |    total_timesteps      | 4947968    |
# | train/                  |            |
# |    approx_kl            | 0.19929394 |
# |    clip_fraction        | 0.665      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.5       |
# |    explained_variance   | 0.986      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0263    |
# |    n_updates            | 6030       |
# |    policy_gradient_loss | 0.00109    |
# |    std                  | 0.378      |
# |    value_loss           | 0.00913    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 4.27e+03  |
# | time/                   |           |
# |    fps                  | 576       |
# |    iterations           | 605       |
# |    time_elapsed         | 8594      |
# |    total_timesteps      | 4956160   |
# | train/                  |           |
# |    approx_kl            | 0.2189857 |
# |    clip_fraction        | 0.668     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.49     |
# |    explained_variance   | 0.98      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0209   |
# |    n_updates            | 6040      |
# |    policy_gradient_loss | -0.000162 |
# |    std                  | 0.376     |
# |    value_loss           | 0.012     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 4.27e+03  |
# | time/                   |           |
# |    fps                  | 576       |
# |    iterations           | 606       |
# |    time_elapsed         | 8608      |
# |    total_timesteps      | 4964352   |
# | train/                  |           |
# |    approx_kl            | 0.2298068 |
# |    clip_fraction        | 0.671     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.47     |
# |    explained_variance   | 0.888     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0317   |
# |    n_updates            | 6050      |
# |    policy_gradient_loss | -0.0019   |
# |    std                  | 0.377     |
# |    value_loss           | 0.00893   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 4.27e+03   |
# | time/                   |            |
# |    fps                  | 576        |
# |    iterations           | 607        |
# |    time_elapsed         | 8623       |
# |    total_timesteps      | 4972544    |
# | train/                  |            |
# |    approx_kl            | 0.22094394 |
# |    clip_fraction        | 0.665      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.45      |
# |    explained_variance   | 0.681      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0257    |
# |    n_updates            | 6060       |
# |    policy_gradient_loss | -0.000979  |
# |    std                  | 0.375      |
# |    value_loss           | 0.00384    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 4.27e+03   |
# | time/                   |            |
# |    fps                  | 576        |
# |    iterations           | 608        |
# |    time_elapsed         | 8637       |
# |    total_timesteps      | 4980736    |
# | train/                  |            |
# |    approx_kl            | 0.22964758 |
# |    clip_fraction        | 0.675      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.43      |
# |    explained_variance   | 0.984      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0442    |
# |    n_updates            | 6070       |
# |    policy_gradient_loss | 0.00326    |
# |    std                  | 0.375      |
# |    value_loss           | 0.00867    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 4.27e+03   |
# | time/                   |            |
# |    fps                  | 576        |
# |    iterations           | 609        |
# |    time_elapsed         | 8651       |
# |    total_timesteps      | 4988928    |
# | train/                  |            |
# |    approx_kl            | 0.20999417 |
# |    clip_fraction        | 0.672      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.44      |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00143    |
# |    n_updates            | 6080       |
# |    policy_gradient_loss | -0.00104   |
# |    std                  | 0.377      |
# |    value_loss           | 0.00767    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 4.27e+03   |
# | time/                   |            |
# |    fps                  | 576        |
# |    iterations           | 610        |
# |    time_elapsed         | 8665       |
# |    total_timesteps      | 4997120    |
# | train/                  |            |
# |    approx_kl            | 0.25341737 |
# |    clip_fraction        | 0.677      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.46      |
# |    explained_variance   | 0.963      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0232    |
# |    n_updates            | 6090       |
# |    policy_gradient_loss | 0.00167    |
# |    std                  | 0.377      |
# |    value_loss           | 0.00674    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 4.3e+03    |
# | time/                   |            |
# |    fps                  | 576        |
# |    iterations           | 611        |
# |    time_elapsed         | 8679       |
# |    total_timesteps      | 5005312    |
# | train/                  |            |
# |    approx_kl            | 0.20949593 |
# |    clip_fraction        | 0.666      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.48      |
# |    explained_variance   | 0.752      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0507    |
# |    n_updates            | 6100       |
# |    policy_gradient_loss | 0.00313    |
# |    std                  | 0.378      |
# |    value_loss           | 0.00269    |
# ----------------------------------------

# %%
# Cell 7: load model and evaluate
model = PPO.load("./models/ppo_half_cheetah_final", device=device)

venv = make_vec_env(ENV_ID, n_envs=1, seed=42)
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

mean_reward, std_reward = evaluate_policy(model, venv, n_eval_episodes=10, deterministic=True)
print(f"Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# c:\Users\User\miniconda3\envs\env_rl\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# Mean reward: 4923.41 +/- 69.53

# %%
import os
os.environ["MUJOCO_GL"] = "glfw"

import gymnasium as gym
import imageio
import numpy as np
from IPython.display import Video, display
import tempfile

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

ENV_ID = "HalfCheetah-v5"
MAX_STEPS = 1500
FPS = 30

# create env
env = gym.make(ENV_ID, render_mode="rgb_array")
venv = DummyVecEnv([lambda: env])
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

# load model
# model = PPO.load("./models/ppo_humanoid_final", device="cpu")
model = PPO.load("./best_model/best_model", device="cpu")

obs = venv.reset()
frames = []

for step in range(MAX_STEPS):
    action, _ = model.predict(obs, deterministic=True)
    obs, rewards, dones, infos = venv.step(action)

    frame = env.render()
    if frame is not None:
        frames.append(frame)

    if dones[0]:
        break

ep_length = len(frames)
print(f"Episode: {ep_length} frames")

# save and display only the longest episode
tmp = tempfile.NamedTemporaryFile(suffix=".mp4", delete=False).name
writer = imageio.get_writer(tmp, fps=FPS, codec="libx264")
for f in frames:
    writer.append_data(f)
writer.close()

display(Video(tmp, embed=True))
# Out:
# Episode: 1000 frames
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
