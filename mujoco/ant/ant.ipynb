# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.5.1
# CUDA available: True
# CUDA device count: 1
# GPU name: NVIDIA GeForce RTX 4080 SUPER

# %%
# Cell 1: quick checks
import sys, platform
import torch
print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())
print("PyTorch:", torch.__version__, "| CUDA available:", torch.cuda.is_available())
import mujoco
print("MuJoCo package version:", mujoco.__version__)
# Out:
# Python: 3.10.19
# Platform: Windows-10-10.0.26200-SP0
# PyTorch: 2.5.1 | CUDA available: True
# MuJoCo package version: 3.4.0

# %%
# Cell 2: imports
import os
import gymnasium as gym
import numpy as np
import torch
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecNormalize, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback
from stable_baselines3.common.evaluation import evaluate_policy

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Cell 3: env setup
ENV_ID = "Ant-v5"   # requires mujoco >= 2.3
n_envs = 4               # on Windows + single CPU, 4 is reasonable; reduce if CPU bound
seed = 0

# Make vectorized training envs
train_env = make_vec_env(
    ENV_ID,
    n_envs=n_envs,
    seed=seed,
    monitor_dir="./logs/train_monitor"
)

# VecNormalize (important for continuous control)
train_env = VecNormalize(train_env, norm_obs=True, norm_reward=True, clip_obs=10.0)

# eval env
eval_env = make_vec_env(
    ENV_ID,
    n_envs=1,
    seed=seed + 100,
    monitor_dir="./logs/eval_monitor"
)
eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.0)

print("Obs space:", train_env.observation_space)
print("Act space:", train_env.action_space)
# Out:
# Obs space: Box(-inf, inf, (105,), float64)
# Act space: Box(-1.0, 1.0, (8,), float32)

# %%
# Cell 4: create PPO
policy_kwargs = dict(net_arch=[dict(pi=[512,512], vf=[512,512])])

model = PPO(
    "MlpPolicy",
    train_env,
    verbose=1,
    device=device,
    n_steps=2048,
    batch_size=64,
    n_epochs=10,
    learning_rate=3e-4,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=1e-3,
    policy_kwargs=policy_kwargs,
)
# Out:
# Using cuda device

# %%
# Cell 5: callbacks and save dirs
os.makedirs("./models", exist_ok=True)
os.makedirs("./checkpoints", exist_ok=True)
os.makedirs("./best_model", exist_ok=True)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="./best_model/",
    log_path="./logs/eval",
    eval_freq=100_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False
)

checkpoint_callback = CheckpointCallback(save_freq=500_000, save_path="./checkpoints/", name_prefix="ppo_ant")

# %%
# Cell 6: train
TOTAL_TIMESTEPS = int(5e6)  # start with 5M; increase if you have time/resources
model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=[eval_callback, checkpoint_callback])
model.save("./models/ppo_ant_final")
# save VecNormalize
train_env.save("./models/vecnormalize_train.pkl")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.6     |
# |    ep_rew_mean     | -100     |
# | time/              |          |
# |    fps             | 1426     |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 1036        |
# |    iterations           | 2           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.035077993 |
# |    clip_fraction        | 0.331       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | -0.736      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0456     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0144     |
# |    std                  | 0.991       |
# |    value_loss           | 0.169       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 968         |
# |    iterations           | 3           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.031235464 |
# |    clip_fraction        | 0.347       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | 0.113       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.05       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.982       |
# |    value_loss           | 0.0416      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.7        |
# |    ep_rew_mean          | -94.4       |
# | time/                   |             |
# |    fps                  | 930         |
# |    iterations           | 4           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.033819586 |
# |    clip_fraction        | 0.347       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | 0.358       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0147      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0166     |
# |    std                  | 0.976       |
# |    value_loss           | 0.0531      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.7        |
# |    ep_rew_mean          | -93.1       |
# | time/                   |             |
# |    fps                  | 915         |
# |    iterations           | 5           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.034282424 |
# |    clip_fraction        | 0.339       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0.435       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0373     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0227     |
# |    std                  | 0.966       |
# |    value_loss           | 0.0602      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 74.5       |
# |    ep_rew_mean          | -73.3      |
# | time/                   |            |
# |    fps                  | 902        |
# |    iterations           | 6          |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.03574329 |
# |    clip_fraction        | 0.344      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -11        |
# |    explained_variance   | 0.574      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0509    |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0291    |
# |    std                  | 0.958      |
# |    value_loss           | 0.0563     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 115         |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 896         |
# |    iterations           | 7           |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.043927096 |
# |    clip_fraction        | 0.366       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 0.669       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0385     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0362     |
# |    std                  | 0.949       |
# |    value_loss           | 0.0649      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.4        |
# |    ep_rew_mean          | -76.4       |
# | time/                   |             |
# |    fps                  | 890         |
# |    iterations           | 8           |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.050653383 |
# |    clip_fraction        | 0.4         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 0.753       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.032      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0432     |
# |    std                  | 0.94        |
# |    value_loss           | 0.0477      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 115         |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 889         |
# |    iterations           | 9           |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.052016765 |
# |    clip_fraction        | 0.403       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0555     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0475     |
# |    std                  | 0.935       |
# |    value_loss           | 0.0617      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 132        |
# |    ep_rew_mean          | -132       |
# | time/                   |            |
# |    fps                  | 887        |
# |    iterations           | 10         |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.05821652 |
# |    clip_fraction        | 0.419      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.8      |
# |    explained_variance   | 0.766      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0613    |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0505    |
# |    std                  | 0.927      |
# |    value_loss           | 0.0565     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 124       |
# |    ep_rew_mean          | -119      |
# | time/                   |           |
# |    fps                  | 889       |
# |    iterations           | 11        |
# |    time_elapsed         | 101       |
# |    total_timesteps      | 90112     |
# | train/                  |           |
# |    approx_kl            | 0.0712736 |
# |    clip_fraction        | 0.45      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -10.7     |
# |    explained_variance   | 0.808     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.1      |
# |    n_updates            | 100       |
# |    policy_gradient_loss | -0.0535   |
# |    std                  | 0.917     |
# |    value_loss           | 0.0368    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 101         |
# |    ep_rew_mean          | -95.7       |
# | time/                   |             |
# |    fps                  | 889         |
# |    iterations           | 12          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.079588234 |
# |    clip_fraction        | 0.458       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | 0.841       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0641     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0562     |
# |    std                  | 0.912       |
# |    value_loss           | 0.0349      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 83.5       |
# |    ep_rew_mean          | -79.9      |
# | time/                   |            |
# |    fps                  | 887        |
# |    iterations           | 13         |
# |    time_elapsed         | 120        |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.08706447 |
# |    clip_fraction        | 0.478      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.6      |
# |    explained_variance   | 0.835      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0764    |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.059     |
# |    std                  | 0.904      |
# |    value_loss           | 0.0464     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 75.7       |
# |    ep_rew_mean          | -73.3      |
# | time/                   |            |
# |    fps                  | 880        |
# |    iterations           | 14         |
# |    time_elapsed         | 130        |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.08766415 |
# |    clip_fraction        | 0.48       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.5      |
# |    explained_variance   | 0.803      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0855    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0606    |
# |    std                  | 0.898      |
# |    value_loss           | 0.062      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 97.7       |
# |    ep_rew_mean          | -93.2      |
# | time/                   |            |
# |    fps                  | 876        |
# |    iterations           | 15         |
# |    time_elapsed         | 140        |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.09022017 |
# |    clip_fraction        | 0.497      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.5      |
# |    explained_variance   | 0.808      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0589    |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0643    |
# |    std                  | 0.895      |
# |    value_loss           | 0.0601     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77.2        |
# |    ep_rew_mean          | -71.2       |
# | time/                   |             |
# |    fps                  | 874         |
# |    iterations           | 16          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.113016896 |
# |    clip_fraction        | 0.523       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0706     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0644     |
# |    std                  | 0.884       |
# |    value_loss           | 0.0427      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 110        |
# |    ep_rew_mean          | -98.9      |
# | time/                   |            |
# |    fps                  | 873        |
# |    iterations           | 17         |
# |    time_elapsed         | 159        |
# |    total_timesteps      | 139264     |
# | train/                  |            |
# |    approx_kl            | 0.12864256 |
# |    clip_fraction        | 0.533      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.3      |
# |    explained_variance   | 0.859      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0878    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0644    |
# |    std                  | 0.871      |
# |    value_loss           | 0.0444     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 79.2       |
# |    ep_rew_mean          | -71.5      |
# | time/                   |            |
# |    fps                  | 873        |
# |    iterations           | 18         |
# |    time_elapsed         | 168        |
# |    total_timesteps      | 147456     |
# | train/                  |            |
# |    approx_kl            | 0.12834647 |
# |    clip_fraction        | 0.539      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.2      |
# |    explained_variance   | 0.863      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.108     |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0659    |
# |    std                  | 0.864      |
# |    value_loss           | 0.0398     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 105        |
# |    ep_rew_mean          | -93.9      |
# | time/                   |            |
# |    fps                  | 869        |
# |    iterations           | 19         |
# |    time_elapsed         | 178        |
# |    total_timesteps      | 155648     |
# | train/                  |            |
# |    approx_kl            | 0.13628018 |
# |    clip_fraction        | 0.546      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.2      |
# |    explained_variance   | 0.87       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0621    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0649    |
# |    std                  | 0.859      |
# |    value_loss           | 0.0453     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 95.4       |
# |    ep_rew_mean          | -85        |
# | time/                   |            |
# |    fps                  | 869        |
# |    iterations           | 20         |
# |    time_elapsed         | 188        |
# |    total_timesteps      | 163840     |
# | train/                  |            |
# |    approx_kl            | 0.13435188 |
# |    clip_fraction        | 0.55       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.1      |
# |    explained_variance   | 0.874      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0569    |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0656    |
# |    std                  | 0.852      |
# |    value_loss           | 0.0452     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 74.2       |
# |    ep_rew_mean          | -68.1      |
# | time/                   |            |
# |    fps                  | 870        |
# |    iterations           | 21         |
# |    time_elapsed         | 197        |
# |    total_timesteps      | 172032     |
# | train/                  |            |
# |    approx_kl            | 0.14688149 |
# |    clip_fraction        | 0.558      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10        |
# |    explained_variance   | 0.859      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.109     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0643    |
# |    std                  | 0.843      |
# |    value_loss           | 0.0459     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 73.2       |
# |    ep_rew_mean          | -71.2      |
# | time/                   |            |
# |    fps                  | 872        |
# |    iterations           | 22         |
# |    time_elapsed         | 206        |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.14633209 |
# |    clip_fraction        | 0.562      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.95      |
# |    explained_variance   | 0.822      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0921    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0665    |
# |    std                  | 0.836      |
# |    value_loss           | 0.0622     |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 96       |
# |    ep_rew_mean          | -84.6    |
# | time/                   |          |
# |    fps                  | 873      |
# |    iterations           | 23       |
# |    time_elapsed         | 215      |
# |    total_timesteps      | 188416   |
# | train/                  |          |
# |    approx_kl            | 0.171664 |
# |    clip_fraction        | 0.586    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -9.89    |
# |    explained_variance   | 0.849    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.112   |
# |    n_updates            | 220      |
# |    policy_gradient_loss | -0.068   |
# |    std                  | 0.83     |
# |    value_loss           | 0.0489   |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 96.9       |
# |    ep_rew_mean          | -84.8      |
# | time/                   |            |
# |    fps                  | 872        |
# |    iterations           | 24         |
# |    time_elapsed         | 225        |
# |    total_timesteps      | 196608     |
# | train/                  |            |
# |    approx_kl            | 0.17709231 |
# |    clip_fraction        | 0.599      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.8       |
# |    explained_variance   | 0.891      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0765    |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0696    |
# |    std                  | 0.821      |
# |    value_loss           | 0.0359     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 58.4       |
# |    ep_rew_mean          | -47.3      |
# | time/                   |            |
# |    fps                  | 872        |
# |    iterations           | 25         |
# |    time_elapsed         | 234        |
# |    total_timesteps      | 204800     |
# | train/                  |            |
# |    approx_kl            | 0.17757142 |
# |    clip_fraction        | 0.594      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.68      |
# |    explained_variance   | 0.88       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0702    |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0668    |
# |    std                  | 0.808      |
# |    value_loss           | 0.0418     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 80.3      |
# |    ep_rew_mean          | -63.5     |
# | time/                   |           |
# |    fps                  | 871       |
# |    iterations           | 26        |
# |    time_elapsed         | 244       |
# |    total_timesteps      | 212992    |
# | train/                  |           |
# |    approx_kl            | 0.1690742 |
# |    clip_fraction        | 0.59      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -9.59     |
# |    explained_variance   | 0.819     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.103    |
# |    n_updates            | 250       |
# |    policy_gradient_loss | -0.0704   |
# |    std                  | 0.801     |
# |    value_loss           | 0.059     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 111        |
# |    ep_rew_mean          | -91.6      |
# | time/                   |            |
# |    fps                  | 869        |
# |    iterations           | 27         |
# |    time_elapsed         | 254        |
# |    total_timesteps      | 221184     |
# | train/                  |            |
# |    approx_kl            | 0.18767211 |
# |    clip_fraction        | 0.609      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.51      |
# |    explained_variance   | 0.888      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0892    |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0665    |
# |    std                  | 0.79       |
# |    value_loss           | 0.0378     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 57.5       |
# |    ep_rew_mean          | -45.6      |
# | time/                   |            |
# |    fps                  | 870        |
# |    iterations           | 28         |
# |    time_elapsed         | 263        |
# |    total_timesteps      | 229376     |
# | train/                  |            |
# |    approx_kl            | 0.21644995 |
# |    clip_fraction        | 0.611      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.4       |
# |    explained_variance   | 0.901      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.102     |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0655    |
# |    std                  | 0.779      |
# |    value_loss           | 0.0319     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 74.7       |
# |    ep_rew_mean          | -56        |
# | time/                   |            |
# |    fps                  | 871        |
# |    iterations           | 29         |
# |    time_elapsed         | 272        |
# |    total_timesteps      | 237568     |
# | train/                  |            |
# |    approx_kl            | 0.19084205 |
# |    clip_fraction        | 0.611      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.3       |
# |    explained_variance   | 0.857      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0722    |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0678    |
# |    std                  | 0.771      |
# |    value_loss           | 0.049      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 83.5      |
# |    ep_rew_mean          | -65.3     |
# | time/                   |           |
# |    fps                  | 871       |
# |    iterations           | 30        |
# |    time_elapsed         | 282       |
# |    total_timesteps      | 245760    |
# | train/                  |           |
# |    approx_kl            | 0.2400969 |
# |    clip_fraction        | 0.623     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -9.24     |
# |    explained_variance   | 0.893     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.114    |
# |    n_updates            | 290       |
# |    policy_gradient_loss | -0.0685   |
# |    std                  | 0.764     |
# |    value_loss           | 0.0402    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 62.7       |
# |    ep_rew_mean          | -45.3      |
# | time/                   |            |
# |    fps                  | 871        |
# |    iterations           | 31         |
# |    time_elapsed         | 291        |
# |    total_timesteps      | 253952     |
# | train/                  |            |
# |    approx_kl            | 0.26726764 |
# |    clip_fraction        | 0.636      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.13      |
# |    explained_variance   | 0.905      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0759    |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0655    |
# |    std                  | 0.753      |
# |    value_loss           | 0.0357     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 73.1       |
# |    ep_rew_mean          | -55        |
# | time/                   |            |
# |    fps                  | 871        |
# |    iterations           | 32         |
# |    time_elapsed         | 300        |
# |    total_timesteps      | 262144     |
# | train/                  |            |
# |    approx_kl            | 0.22936189 |
# |    clip_fraction        | 0.633      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.04      |
# |    explained_variance   | 0.872      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0906    |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0658    |
# |    std                  | 0.746      |
# |    value_loss           | 0.0447     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 122        |
# |    ep_rew_mean          | -93.4      |
# | time/                   |            |
# |    fps                  | 873        |
# |    iterations           | 33         |
# |    time_elapsed         | 309        |
# |    total_timesteps      | 270336     |
# | train/                  |            |
# |    approx_kl            | 0.27270982 |
# |    clip_fraction        | 0.64       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.96      |
# |    explained_variance   | 0.886      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0726    |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0669    |
# |    std                  | 0.739      |
# |    value_loss           | 0.0424     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 33.7       |
# |    ep_rew_mean          | -23.7      |
# | time/                   |            |
# |    fps                  | 873        |
# |    iterations           | 34         |
# |    time_elapsed         | 318        |
# |    total_timesteps      | 278528     |
# | train/                  |            |
# |    approx_kl            | 0.27344298 |
# |    clip_fraction        | 0.649      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.87      |
# |    explained_variance   | 0.889      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.095     |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0618    |
# |    std                  | 0.73       |
# |    value_loss           | 0.0274     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 59.8       |
# |    ep_rew_mean          | -41.7      |
# | time/                   |            |
# |    fps                  | 873        |
# |    iterations           | 35         |
# |    time_elapsed         | 328        |
# |    total_timesteps      | 286720     |
# | train/                  |            |
# |    approx_kl            | 0.24060096 |
# |    clip_fraction        | 0.638      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.8       |
# |    explained_variance   | 0.878      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0944    |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0641    |
# |    std                  | 0.726      |
# |    value_loss           | 0.042      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 107        |
# |    ep_rew_mean          | -80.5      |
# | time/                   |            |
# |    fps                  | 870        |
# |    iterations           | 36         |
# |    time_elapsed         | 338        |
# |    total_timesteps      | 294912     |
# | train/                  |            |
# |    approx_kl            | 0.26984343 |
# |    clip_fraction        | 0.651      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.75      |
# |    explained_variance   | 0.883      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.1       |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0642    |
# |    std                  | 0.718      |
# |    value_loss           | 0.0414     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 63.7      |
# |    ep_rew_mean          | -40.9     |
# | time/                   |           |
# |    fps                  | 871       |
# |    iterations           | 37        |
# |    time_elapsed         | 347       |
# |    total_timesteps      | 303104    |
# | train/                  |           |
# |    approx_kl            | 0.3571306 |
# |    clip_fraction        | 0.66      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -8.63     |
# |    explained_variance   | 0.91      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.105    |
# |    n_updates            | 360       |
# |    policy_gradient_loss | -0.0631   |
# |    std                  | 0.708     |
# |    value_loss           | 0.0241    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 70        |
# |    ep_rew_mean          | -49.7     |
# | time/                   |           |
# |    fps                  | 869       |
# |    iterations           | 38        |
# |    time_elapsed         | 358       |
# |    total_timesteps      | 311296    |
# | train/                  |           |
# |    approx_kl            | 0.2718752 |
# |    clip_fraction        | 0.661     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -8.54     |
# |    explained_variance   | 0.854     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.103    |
# |    n_updates            | 370       |
# |    policy_gradient_loss | -0.0675   |
# |    std                  | 0.7       |
# |    value_loss           | 0.0439    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 65.7       |
# |    ep_rew_mean          | -43.4      |
# | time/                   |            |
# |    fps                  | 871        |
# |    iterations           | 39         |
# |    time_elapsed         | 366        |
# |    total_timesteps      | 319488     |
# | train/                  |            |
# |    approx_kl            | 0.32179907 |
# |    clip_fraction        | 0.664      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.46      |
# |    explained_variance   | 0.844      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0934    |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0632    |
# |    std                  | 0.694      |
# |    value_loss           | 0.0483     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 64.2       |
# |    ep_rew_mean          | -42.6      |
# | time/                   |            |
# |    fps                  | 873        |
# |    iterations           | 40         |
# |    time_elapsed         | 375        |
# |    total_timesteps      | 327680     |
# | train/                  |            |
# |    approx_kl            | 0.33347604 |
# |    clip_fraction        | 0.683      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.34      |
# |    explained_variance   | 0.898      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.089     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0668    |
# |    std                  | 0.682      |
# |    value_loss           | 0.0376     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 75.3      |
# |    ep_rew_mean          | -48.8     |
# | time/                   |           |
# |    fps                  | 874       |
# |    iterations           | 41        |
# |    time_elapsed         | 384       |
# |    total_timesteps      | 335872    |
# | train/                  |           |
# |    approx_kl            | 0.3271488 |
# |    clip_fraction        | 0.68      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -8.23     |
# |    explained_variance   | 0.898     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.115    |
# |    n_updates            | 400       |
# |    policy_gradient_loss | -0.0624   |
# |    std                  | 0.673     |
# |    value_loss           | 0.0352    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 72.8       |
# |    ep_rew_mean          | -46.4      |
# | time/                   |            |
# |    fps                  | 872        |
# |    iterations           | 42         |
# |    time_elapsed         | 394        |
# |    total_timesteps      | 344064     |
# | train/                  |            |
# |    approx_kl            | 0.35178167 |
# |    clip_fraction        | 0.68       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.13      |
# |    explained_variance   | 0.902      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0584    |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0623    |
# |    std                  | 0.665      |
# |    value_loss           | 0.032      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.6       |
# |    ep_rew_mean          | -33        |
# | time/                   |            |
# |    fps                  | 871        |
# |    iterations           | 43         |
# |    time_elapsed         | 404        |
# |    total_timesteps      | 352256     |
# | train/                  |            |
# |    approx_kl            | 0.34681576 |
# |    clip_fraction        | 0.682      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.01      |
# |    explained_variance   | 0.898      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.087     |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0624    |
# |    std                  | 0.656      |
# |    value_loss           | 0.0356     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 40.5       |
# |    ep_rew_mean          | -22.6      |
# | time/                   |            |
# |    fps                  | 869        |
# |    iterations           | 44         |
# |    time_elapsed         | 414        |
# |    total_timesteps      | 360448     |
# | train/                  |            |
# |    approx_kl            | 0.30513752 |
# |    clip_fraction        | 0.685      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.91      |
# |    explained_variance   | 0.823      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0832    |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0652    |
# |    std                  | 0.648      |
# |    value_loss           | 0.0451     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 82.2      |
# |    ep_rew_mean          | -55.1     |
# | time/                   |           |
# |    fps                  | 868       |
# |    iterations           | 45        |
# |    time_elapsed         | 424       |
# |    total_timesteps      | 368640    |
# | train/                  |           |
# |    approx_kl            | 0.3569573 |
# |    clip_fraction        | 0.685     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.83     |
# |    explained_variance   | 0.84      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.107    |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.0639   |
# |    std                  | 0.641     |
# |    value_loss           | 0.0456    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 118       |
# |    ep_rew_mean          | -75.7     |
# | time/                   |           |
# |    fps                  | 870       |
# |    iterations           | 46        |
# |    time_elapsed         | 432       |
# |    total_timesteps      | 376832    |
# | train/                  |           |
# |    approx_kl            | 0.4304688 |
# |    clip_fraction        | 0.7       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.73     |
# |    explained_variance   | 0.904     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.103    |
# |    n_updates            | 450       |
# |    policy_gradient_loss | -0.0577   |
# |    std                  | 0.632     |
# |    value_loss           | 0.0243    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 55.5      |
# |    ep_rew_mean          | -28.6     |
# | time/                   |           |
# |    fps                  | 871       |
# |    iterations           | 47        |
# |    time_elapsed         | 441       |
# |    total_timesteps      | 385024    |
# | train/                  |           |
# |    approx_kl            | 0.4261694 |
# |    clip_fraction        | 0.696     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.61     |
# |    explained_variance   | 0.884     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0987   |
# |    n_updates            | 460       |
# |    policy_gradient_loss | -0.0606   |
# |    std                  | 0.624     |
# |    value_loss           | 0.0354    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 55.7       |
# |    ep_rew_mean          | -30.2      |
# | time/                   |            |
# |    fps                  | 872        |
# |    iterations           | 48         |
# |    time_elapsed         | 450        |
# |    total_timesteps      | 393216     |
# | train/                  |            |
# |    approx_kl            | 0.39223087 |
# |    clip_fraction        | 0.698      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.54      |
# |    explained_variance   | 0.856      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.105     |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0638    |
# |    std                  | 0.618      |
# |    value_loss           | 0.0441     |
# ----------------------------------------
# Eval num_timesteps=400000, episode_reward=-9.40 +/- 28.89
# Episode length: 61.60 +/- 70.68
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 61.6       |
# |    mean_reward          | -9.4       |
# | time/                   |            |
# |    total_timesteps      | 400000     |
# | train/                  |            |
# |    approx_kl            | 0.43484598 |
# |    clip_fraction        | 0.704      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.46      |
# |    explained_variance   | 0.89       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0806    |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0626    |
# |    std                  | 0.615      |
# |    value_loss           | 0.0349     |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 70.3     |
# |    ep_rew_mean     | -39.6    |
# | time/              |          |
# |    fps             | 873      |
# |    iterations      | 49       |
# |    time_elapsed    | 459      |
# |    total_timesteps | 401408   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 74         |
# |    ep_rew_mean          | -45.7      |
# | time/                   |            |
# |    fps                  | 873        |
# |    iterations           | 50         |
# |    time_elapsed         | 468        |
# |    total_timesteps      | 409600     |
# | train/                  |            |
# |    approx_kl            | 0.40229407 |
# |    clip_fraction        | 0.696      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.39      |
# |    explained_variance   | 0.852      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0707    |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.0596    |
# |    std                  | 0.607      |
# |    value_loss           | 0.0435     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 62        |
# |    ep_rew_mean          | -36.8     |
# | time/                   |           |
# |    fps                  | 874       |
# |    iterations           | 51        |
# |    time_elapsed         | 477       |
# |    total_timesteps      | 417792    |
# | train/                  |           |
# |    approx_kl            | 0.4947326 |
# |    clip_fraction        | 0.713     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.31     |
# |    explained_variance   | 0.887     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0685   |
# |    n_updates            | 500       |
# |    policy_gradient_loss | -0.0583   |
# |    std                  | 0.602     |
# |    value_loss           | 0.0374    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 85        |
# |    ep_rew_mean          | -51       |
# | time/                   |           |
# |    fps                  | 875       |
# |    iterations           | 52        |
# |    time_elapsed         | 486       |
# |    total_timesteps      | 425984    |
# | train/                  |           |
# |    approx_kl            | 0.4781228 |
# |    clip_fraction        | 0.707     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.25     |
# |    explained_variance   | 0.842     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0987   |
# |    n_updates            | 510       |
# |    policy_gradient_loss | -0.0585   |
# |    std                  | 0.597     |
# |    value_loss           | 0.0463    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 70.1      |
# |    ep_rew_mean          | -40       |
# | time/                   |           |
# |    fps                  | 875       |
# |    iterations           | 53        |
# |    time_elapsed         | 495       |
# |    total_timesteps      | 434176    |
# | train/                  |           |
# |    approx_kl            | 0.4580726 |
# |    clip_fraction        | 0.718     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.17     |
# |    explained_variance   | 0.889     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0661   |
# |    n_updates            | 520       |
# |    policy_gradient_loss | -0.0573   |
# |    std                  | 0.592     |
# |    value_loss           | 0.034     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.9      |
# |    ep_rew_mean          | -24.9     |
# | time/                   |           |
# |    fps                  | 875       |
# |    iterations           | 54        |
# |    time_elapsed         | 505       |
# |    total_timesteps      | 442368    |
# | train/                  |           |
# |    approx_kl            | 0.5949578 |
# |    clip_fraction        | 0.716     |
# |    clip_range           | 0.2       |
# ...
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.044    |
# |    n_updates            | 5920      |
# |    policy_gradient_loss | -0.0403   |
# |    std                  | 0.523     |
# |    value_loss           | 0.0654    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 13        |
# |    ep_rew_mean          | -14       |
# | time/                   |           |
# |    fps                  | 529       |
# |    iterations           | 594       |
# |    time_elapsed         | 9196      |
# |    total_timesteps      | 4866048   |
# | train/                  |           |
# |    approx_kl            | 5.0025654 |
# |    clip_fraction        | 0.865     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.21     |
# |    explained_variance   | 0.946     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.08     |
# |    n_updates            | 5930      |
# |    policy_gradient_loss | -0.0458   |
# |    std                  | 0.525     |
# |    value_loss           | 0.0614    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 20.8      |
# |    ep_rew_mean          | -28.9     |
# | time/                   |           |
# |    fps                  | 529       |
# |    iterations           | 595       |
# |    time_elapsed         | 9212      |
# |    total_timesteps      | 4874240   |
# | train/                  |           |
# |    approx_kl            | 3.7812076 |
# |    clip_fraction        | 0.883     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.17     |
# |    explained_variance   | 0.873     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0102   |
# |    n_updates            | 5940      |
# |    policy_gradient_loss | -0.0312   |
# |    std                  | 0.523     |
# |    value_loss           | 0.0752    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 12.7      |
# |    ep_rew_mean          | -12.9     |
# | time/                   |           |
# |    fps                  | 529       |
# |    iterations           | 596       |
# |    time_elapsed         | 9229      |
# |    total_timesteps      | 4882432   |
# | train/                  |           |
# |    approx_kl            | 3.7286873 |
# |    clip_fraction        | 0.872     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.21     |
# |    explained_variance   | 0.936     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.115    |
# |    n_updates            | 5950      |
# |    policy_gradient_loss | -0.0452   |
# |    std                  | 0.524     |
# |    value_loss           | 0.0663    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 21.9      |
# |    ep_rew_mean          | -29.5     |
# | time/                   |           |
# |    fps                  | 528       |
# |    iterations           | 597       |
# |    time_elapsed         | 9245      |
# |    total_timesteps      | 4890624   |
# | train/                  |           |
# |    approx_kl            | 4.2915797 |
# |    clip_fraction        | 0.873     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.23     |
# |    explained_variance   | 0.947     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0186   |
# |    n_updates            | 5960      |
# |    policy_gradient_loss | -0.042    |
# |    std                  | 0.528     |
# |    value_loss           | 0.0467    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 12.9      |
# |    ep_rew_mean          | -11.9     |
# | time/                   |           |
# |    fps                  | 528       |
# |    iterations           | 598       |
# |    time_elapsed         | 9260      |
# |    total_timesteps      | 4898816   |
# | train/                  |           |
# |    approx_kl            | 3.8530543 |
# |    clip_fraction        | 0.862     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.28     |
# |    explained_variance   | 0.931     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0942   |
# |    n_updates            | 5970      |
# |    policy_gradient_loss | -0.0391   |
# |    std                  | 0.53      |
# |    value_loss           | 0.0715    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 16        |
# |    ep_rew_mean          | -16.6     |
# | time/                   |           |
# |    fps                  | 529       |
# |    iterations           | 599       |
# |    time_elapsed         | 9273      |
# |    total_timesteps      | 4907008   |
# | train/                  |           |
# |    approx_kl            | 4.0087347 |
# |    clip_fraction        | 0.87      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.35     |
# |    explained_variance   | 0.948     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0797   |
# |    n_updates            | 5980      |
# |    policy_gradient_loss | -0.0434   |
# |    std                  | 0.536     |
# |    value_loss           | 0.0573    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 26.6      |
# |    ep_rew_mean          | -36.3     |
# | time/                   |           |
# |    fps                  | 529       |
# |    iterations           | 600       |
# |    time_elapsed         | 9285      |
# |    total_timesteps      | 4915200   |
# | train/                  |           |
# |    approx_kl            | 3.5427299 |
# |    clip_fraction        | 0.876     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.38     |
# |    explained_variance   | 0.893     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0663   |
# |    n_updates            | 5990      |
# |    policy_gradient_loss | -0.0349   |
# |    std                  | 0.537     |
# |    value_loss           | 0.06      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 15.4     |
# |    ep_rew_mean          | -14.7    |
# | time/                   |          |
# |    fps                  | 529      |
# |    iterations           | 601      |
# |    time_elapsed         | 9298     |
# |    total_timesteps      | 4923392  |
# | train/                  |          |
# |    approx_kl            | 5.309774 |
# |    clip_fraction        | 0.862    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -6.39    |
# |    explained_variance   | 0.936    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0668  |
# |    n_updates            | 6000     |
# |    policy_gradient_loss | -0.0421  |
# |    std                  | 0.535    |
# |    value_loss           | 0.0642   |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 23.3      |
# |    ep_rew_mean          | -33.4     |
# | time/                   |           |
# |    fps                  | 529       |
# |    iterations           | 602       |
# |    time_elapsed         | 9310      |
# |    total_timesteps      | 4931584   |
# | train/                  |           |
# |    approx_kl            | 3.9718215 |
# |    clip_fraction        | 0.867     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.39     |
# |    explained_variance   | 0.927     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0686   |
# |    n_updates            | 6010      |
# |    policy_gradient_loss | -0.0439   |
# |    std                  | 0.537     |
# |    value_loss           | 0.0727    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 22.9      |
# |    ep_rew_mean          | -29.7     |
# | time/                   |           |
# |    fps                  | 529       |
# |    iterations           | 603       |
# |    time_elapsed         | 9322      |
# |    total_timesteps      | 4939776   |
# | train/                  |           |
# |    approx_kl            | 3.1496673 |
# |    clip_fraction        | 0.868     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.41     |
# |    explained_variance   | 0.923     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0317   |
# |    n_updates            | 6020      |
# |    policy_gradient_loss | -0.0398   |
# |    std                  | 0.539     |
# |    value_loss           | 0.0755    |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 24.2     |
# |    ep_rew_mean          | -31.5    |
# | time/                   |          |
# |    fps                  | 529      |
# |    iterations           | 604      |
# |    time_elapsed         | 9335     |
# |    total_timesteps      | 4947968  |
# | train/                  |          |
# |    approx_kl            | 3.634122 |
# |    clip_fraction        | 0.869    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -6.46    |
# |    explained_variance   | 0.911    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0907  |
# |    n_updates            | 6030     |
# |    policy_gradient_loss | -0.0414  |
# |    std                  | 0.541    |
# |    value_loss           | 0.078    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 23.7      |
# |    ep_rew_mean          | -31.5     |
# | time/                   |           |
# |    fps                  | 530       |
# |    iterations           | 605       |
# |    time_elapsed         | 9348      |
# |    total_timesteps      | 4956160   |
# | train/                  |           |
# |    approx_kl            | 3.1506982 |
# |    clip_fraction        | 0.869     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.45     |
# |    explained_variance   | 0.941     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0715   |
# |    n_updates            | 6040      |
# |    policy_gradient_loss | -0.0451   |
# |    std                  | 0.541     |
# |    value_loss           | 0.0568    |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 30       |
# |    ep_rew_mean          | -43.3    |
# | time/                   |          |
# |    fps                  | 530      |
# |    iterations           | 606      |
# |    time_elapsed         | 9361     |
# |    total_timesteps      | 4964352  |
# | train/                  |          |
# |    approx_kl            | 4.405157 |
# |    clip_fraction        | 0.868    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -6.47    |
# |    explained_variance   | 0.927    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0702  |
# |    n_updates            | 6050     |
# |    policy_gradient_loss | -0.0442  |
# |    std                  | 0.541    |
# |    value_loss           | 0.0627   |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 12.5     |
# |    ep_rew_mean          | -12.5    |
# | time/                   |          |
# |    fps                  | 530      |
# |    iterations           | 607      |
# |    time_elapsed         | 9374     |
# |    total_timesteps      | 4972544  |
# | train/                  |          |
# |    approx_kl            | 2.981741 |
# |    clip_fraction        | 0.864    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -6.44    |
# |    explained_variance   | 0.923    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0674  |
# |    n_updates            | 6060     |
# |    policy_gradient_loss | -0.0432  |
# |    std                  | 0.538    |
# |    value_loss           | 0.0801   |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 18.8      |
# |    ep_rew_mean          | -22.1     |
# | time/                   |           |
# |    fps                  | 530       |
# |    iterations           | 608       |
# |    time_elapsed         | 9386      |
# |    total_timesteps      | 4980736   |
# | train/                  |           |
# |    approx_kl            | 3.0758832 |
# |    clip_fraction        | 0.868     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.44     |
# |    explained_variance   | 0.929     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0783   |
# |    n_updates            | 6070      |
# |    policy_gradient_loss | -0.0405   |
# |    std                  | 0.54      |
# |    value_loss           | 0.0677    |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 23.6     |
# |    ep_rew_mean          | -31.1    |
# | time/                   |          |
# |    fps                  | 530      |
# |    iterations           | 609      |
# |    time_elapsed         | 9399     |
# |    total_timesteps      | 4988928  |
# | train/                  |          |
# |    approx_kl            | 4.488467 |
# |    clip_fraction        | 0.866    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -6.43    |
# |    explained_variance   | 0.905    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0475  |
# |    n_updates            | 6080     |
# |    policy_gradient_loss | -0.0433  |
# |    std                  | 0.54     |
# |    value_loss           | 0.0953   |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 35.4      |
# |    ep_rew_mean          | -50.6     |
# | time/                   |           |
# |    fps                  | 530       |
# |    iterations           | 610       |
# |    time_elapsed         | 9411      |
# |    total_timesteps      | 4997120   |
# | train/                  |           |
# |    approx_kl            | 4.8480053 |
# |    clip_fraction        | 0.871     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.44     |
# |    explained_variance   | 0.928     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0988   |
# |    n_updates            | 6090      |
# |    policy_gradient_loss | -0.0443   |
# |    std                  | 0.54      |
# |    value_loss           | 0.0782    |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 17.2     |
# |    ep_rew_mean          | -19.7    |
# | time/                   |          |
# |    fps                  | 531      |
# |    iterations           | 611      |
# |    time_elapsed         | 9424     |
# |    total_timesteps      | 5005312  |
# | train/                  |          |
# |    approx_kl            | 4.101552 |
# |    clip_fraction        | 0.87     |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -6.45    |
# |    explained_variance   | 0.932    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0732  |
# |    n_updates            | 6100     |
# |    policy_gradient_loss | -0.0454  |
# |    std                  | 0.541    |
# |    value_loss           | 0.0697   |
# --------------------------------------

# %%
# Cell 7: load model and evaluate
model = PPO.load("./models/ppo_ant_final", device=device)

venv = make_vec_env(ENV_ID, n_envs=1, seed=42)
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

mean_reward, std_reward = evaluate_policy(model, venv, n_eval_episodes=10, deterministic=True)
print(f"Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Mean reward: -7.97 +/- 7.20

# %%
import os
os.environ["MUJOCO_GL"] = "glfw"

import gymnasium as gym
import imageio
import numpy as np
from IPython.display import Video, display
import tempfile

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

ENV_ID = "Ant-v5"
N_EVAL_EPISODES = 10
MAX_STEPS = 1500
FPS = 30

# create env
env = gym.make(ENV_ID, render_mode="rgb_array")
venv = DummyVecEnv([lambda: env])
venv = VecNormalize.load("./models/vecnormalize_train.pkl", venv)
venv.training = False
venv.norm_reward = False

# load model
# model = PPO.load("./models/ppo_humanoid_final", device="cpu")
model = PPO.load("./best_model/best_model", device="cpu")

best_frames = []
best_length = 0

for ep in range(N_EVAL_EPISODES):
    obs = venv.reset()
    frames = []

    for step in range(MAX_STEPS):
        action, _ = model.predict(obs, deterministic=True)
        obs, rewards, dones, infos = venv.step(action)

        frame = env.render()
        if frame is not None:
            frames.append(frame)

        if dones[0]:
            break

    ep_length = len(frames)
    print(f"Episode {ep+1}: {ep_length} frames")

    if ep_length > best_length:
        best_length = ep_length
        best_frames = frames

print(f"\nLongest episode length: {best_length} frames")

# save and display only the longest episode
tmp = tempfile.NamedTemporaryFile(suffix=".mp4", delete=False).name
writer = imageio.get_writer(tmp, fps=FPS, codec="libx264")
for f in best_frames:
    writer.append_data(f)
writer.close()

display(Video(tmp, embed=True))
# Out:
# Episode 1: 124 frames
# Episode 2: 20 frames
# Episode 3: 11 frames
# Episode 4: 10 frames
# Episode 5: 13 frames
# Episode 6: 65 frames
# Episode 7: 263 frames
# Episode 8: 9 frames
# Episode 9: 15 frames
# Episode 10: 93 frames
#
# Longest episode length: 263 frames
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
